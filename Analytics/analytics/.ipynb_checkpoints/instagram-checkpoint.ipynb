# %%
import pandas as pd

# %%
import numpy as np

# %%
import pymongo

# %%
import time

# %%
client = pymongo.MongoClient("mongodb+srv://KokilaReddy:KokilaReddy@cluster0.5nrpf.mongodb.net/Social_media_data?retryWrites=true&w=majority")

# %%
db=client["Social_media_data"]

# %%
instagram=db["instagram"]

# %%
instagram
# Out:
# Collection(Database(MongoClient(host=['cluster0-shard-00-02.5nrpf.mongodb.net:27017', 'cluster0-shard-00-01.5nrpf.mongodb.net:27017', 'cluster0-shard-00-00.5nrpf.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-2ieewk-shard-0', ssl=True), 'instagram'), 'instagram')

# %%
query={"tag":{"$regex":"Samsung"}}

# %%
df=pd.DataFrame(columns=["publishedTime","postId","userId","caption","url","shortcode","likes","views","is_video","accessibility_caption","comment_count","tag"])

# %%
for i in client.Social_media_data.instagram.find():
    print(i)
    df=df.append(i,ignore_index=True)
# Out:
# {'_id': ObjectId('60cf64c26ac5fb1cbe92c58e'), 'publishedTime': '2021-06-18 15:30:54', 'postId': '2598710478208641988', 'userId': '17551874868', 'caption': 'It’s Friday then it’s Saturday, Sunday… Es war mir eine riesige Freude euch diese Woche mitzunehmen. Ich hoffe, ihr hattet Spaß zu sehen, mit welchen Themen ich mich beschäftige. \nJetzt geht es aber ins Wochenende. Der Rucksack zum Wandern ist gepackt. Jetzt wird auf einer Hütte in Österreich entspannt, um wieder Kraft für die nächste Woche zu tanken. Bis bald! \n\nWenn dir meine Einblicke gefallen haben und du auch gerne ein Teil des Teams werden willst, dann schaue doch gerne auf unserer Karriereseite vorbei: \nwww.capgemini.de -> Karriere -> Jobsuche -> IT Architect \n\n#capgemini #lifeatcapgemini #capgeminideutschland #associate #itarchitect #nürnberg #homeoffice #accountmanagement #management #project #work #weekend #career #loveyourcareer #it #solution #cloud #engineering #weekend #itjob #agil #transformation #devops #newjo
# ...

# %%
df
# Out:
#             publishedTime               postId       userId  \
# 0     2021-06-18 15:30:54  2598710478208641988  17551874868
# 1     2021-06-18 14:20:54  2598675268450619966  21749937051
# 2     2021-06-18 12:30:35  2598619746613047857  36566808044
# 3     2021-06-18 12:00:13  2598604424485492046   3286700469
# 4     2021-06-18 11:57:50  2598603262151387250   2321796908
# ...                   ...                  ...          ...
# 1327  2021-06-24 10:02:25  2603058031336150125   7046551892
# 1328  2021-06-23 23:05:37  2602729343796905351  36990880080
# 1329  2021-06-14 06:43:54  2595712249468199129   1066029487
# 1330  2021-06-05 17:24:08  2589511505699794572   1066029487
# 1331  2021-06-23 17:11:35  2602545045611411922  20753514906
#
#                                                 caption  \
# 0     It’s Friday then it’s Saturday, Sunday… Es war...
# 1     We are design strategists and UX designers, pa...
# 2     À la tête de la Boucherie Massot, Didier Masso...
# ...
