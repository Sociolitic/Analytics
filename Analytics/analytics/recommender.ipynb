# %%
import numpy as np
import pandas as pd
import pymongo
import time

# %%
import collections
import random

# %%
client = pymongo.MongoClient("mongodb+srv://KokilaReddy:KokilaReddy@cluster0.5nrpf.mongodb.net/Social_media_data?retryWrites=true&w=majority")

# %%
client.list_database_names()
# Out:
# ['Social_media_data', 'admin', 'local']

# %%
db=client["Social_media_data"]

# %%
db.list_collection_names()
# Out:
# ['dummy_users',
#  'profile',
#  'users',
#  'Recommendation',
#  'aggregate',
#  'reddit',
#  'tumblr',
#  'dummy_profile',
#  'instagram',
#  'youTube',
#  'twitter']

# %%
data={"user1":["iphone","samsung","oneplus"]}

# %%
db.Recommendation.insert_one(data)

# %%
users=db['dummy_users']
profiles=db['dummy_profile']

# %% [markdown]
# # brand recommendation for given user

# %%
def output():
    skip = 0
    limit = 10_000
    while True:
        cursor = users.find()
        if skip >= cursor.count():
            return
        skip += limit
        output_=[]
        i=1
        for doc in cursor:
            print(i)
            i+=1
            brands = []
            competitors = []
            profile_ids = []
            data = profiles.find({"users":doc["_id"]})
            for ele in data:
                brands.append(ele["brand"])
                competitors.append(ele["competitors"])
                profile_ids.append(ele["_id"])
            users_data = {
                #"user_id":doc["_id"],
                "user_name":doc["name"],
                "brands":brands,
                "competitors":competitors,
                #"profile_ids":profile_ids
            }
            output_.append(users_data)
            print(users_data)
        return output_

# %%
output_=[]

# %%
output_=(output())
# Out:
# <ipython-input-12-31e59b927078>:6: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   if skip >= cursor.count():
# 1
# {'user_name': 'user1', 'brands': ['aegon', 'fluor', 'crh', 'nvidia', 'hdfc'], 'competitors': [['nike', 'canon', 'nippon', 'alibaba', 'visa'], ['airtel', 'accenture', 'qualcomm', 'sony', 'icici'], ['accenture', 'walmart', 'alphabet', 'johnson'], ['icbc', 'nokia', 'pepsi'], ['hitachi', 'nippon', 'tesco']]}
# 2
# {'user_name': 'user2', 'brands': ['super dry', 'merceds', 'at&t', 'capgemini', 'coca-cola', 'onex'], 'competitors': [None, ['pepsi'], ['abb', 'maybank'], ['oracle', 'hp', 'coca-cola', 'ebay', 'addidas'], ['wipro', 'tencent', 'citigroup', 'qualcomm', 'vadafone'], None]}
# 3
# {'user_name': 'user3', 'brands': ['danone', 'visa', 'nike', 'toyota'], 'competitors': [['visa', 'panasonic', 'merceds'], ['barclays'], ['at&t', 'bmw', 'vadafone', 'salesforce', "mcdoland's"], ['coca-cola', 'at&t', 'puma', 'vmware']]}
# 4
# {'user_name': 'user4', 'brands': ['hitachi', 'sap', 'acs', 'infosys', 'accenture'], 'competitors': [['apple'], ['comcast', 'xiaomi', 'johnson', 'apple'], ['icbc', 'vmware'], ['cisco', 'tencent', 'target', 'ibm'], ['hp', 'johnson']]}
# 5
# {'user_name': 'user5', 'brands': ['tencent', 'avnet', 'woodland', 'super dry', 'target', 'caterpillar'], 'competitors': [['loreal', 'alphabet', 'vadafone'], ['airtel', 'aegon', 'merceds'], ['siemens', 'vadafone'], ['Adobe', 'crh'], ['toyota', 'infosys', 'facebook'], ['canon', 'at&t']]}
# 6
# {'user_name': 'user6', 'brands': ['accenture', 'caterpillar', 'siemens', 'ibm'], 'competitors': [['airtel', 'xiaomi', 'capgemini'], ['rbc', 'metlife'], ['netflix'], ['johnson', 'tencent', 'paypal', 'super dry']]}
# 7
# {'user_name': 'user7', 'brands': ['qualcomn', 'salesforce', 'citigroup', 'tencent', 'tesco'], 'competitors': [['sap', 'apple'], ['ford', 'reliance', 'tcs'], ['qualcomn'], ['hp', 'vadafone', 'accenture'], ['oracle', 'sap']]}
# 8
# {'user_name': 'user8', 'brands': ['netflix', 'metlife', 'volkswagen', 'danaher', 'citigroup', 'visa'], 'competitors': [["mcdoland's", 'nippon', 'comcast'], ['Adobe', 'alibaba', 'tesco', 'onex', 'toyota'], ['cisco', 'paypal', 'addidas', 'danone'], ['rbc', 'onex', 'alphabet', 'puma', 'toyota'], ['Adobe', 'oracle'], ['woodland', 'paypal', 'canon', 'capgemini']]}
# 9
# {'user_name': 'user9', 'brands': ['nippon', 'salesforce', 'aegon', 'johnson'], 'competitors': [['toyota', 'wipro', 'oracle'], ['hp', 'alibaba', 'pubg'], ['starbucks', 'citigroup', 'icici', 'toyota', 'panasonic'], ['capgemini']]}
# 10
# {'user_name': 'user10', 'brands': ['philip', 'maruhan', 'Adobe', 'icici', 'vadafone'], 'competitors': [['fedEx', 'target', 'infosys', 'vinci'], ['rbc', 'vadafone', 'sony'], ['canon', 'wipro'], ['hp', 'puma', 'amazon', 'xiaomi', 'canon'], ['samsung', 'hitachi', 'intel', 'fedEx', 'tencent']]}
# 11
# {'user_name': 'user11', 'brands': ['paypal', 'toyota', 'fluor', 'tencent', 'renault', 'samsung'], 'competitors': [['samsung', 'puma', 'tcs', 'panasonic'], ['salesforce', 'sodexo'], ['johnson', 'volkswagen', 'cosmo'], ['visa'], ['tesla', 'target', 'alphabet', 'danaher'], ['paypal', 'loreal', 'cisco']]}
# 12
# {'user_name': 'user12', 'brands': ['abb', 'rbc', 'capgemini', 'danaher'], 'competitors': [['tesla', 'american express'], ['visa', 'alphabet'], ['tesco', 'wistron', 'canon'], ['infosys', 'at&t', 'siemens']]}
# 13
# {'user_name': 'user13', 'brands': ['microsoft', 'vadafone', 'qualcomn', 'disney', 'nokia'], 'competitors': [['ford', 'nestle', 'samsung'], ['salesforce', 'airtel'], ['staples', 'tesco', 'wistron', 'nippon', 'mastercard'], ['accenture', 'hyundai', 'siemens', 'oracle', "mcdoland's"], ['johnson', 'facebook', 'comcast', 'salesforce', 'cisco']]}
# 14
# {'user_name': 'user14', 'brands': ['disney', 'woodland', 'caterpillar', 'starbucks', 'cisco', 'rbc'], 'competitors': [['samsung', 'vmware'], ['xiaomi', 'amazon', 'merceds'], ["mcdoland's"], ['hitachi', 'nike', 'paypal', 'intel', 'visa'], ['pubg', 'hyundai', 'tencent', 'vadafone'], ['danone', 'acs', 'reliance', 'volkswagen', 'puma']]}
# 15
# {'user_name': 'user15', 'brands': ['amazon', 'cosmo', 'vmware', 'microsoft'], 'competitors': [['pubg'], ['nvidia', 'fluor', "mcdoland's", 'hdfc', 'staples'], ['fedEx', 'abb'], ['reliance', 'vmware']]}
# 16
# {'user_name': 'user16', 'brands': ['barclays', 'cisco', 'hdfc', 'ford', 'staples'], 'competitors': [['tencent', 'tesla'], ['infosys'], ['intel', 'samsung', 'maybank'], ['qualcomn', 'pubg', 'microsoft'], ['qualcomn', 'barclays']]}
# 17
# {'user_name': 'user17', 'brands': ['oracle', 'caterpillar', 'hdfc', 'fluor', 'target', 'lg'], 'competitors': [['puma', 'aegon', 'hp', 'accenture', 'cisco'], ["mcdoland's", 'accenture', 'canon'], ['mastercard'], None, ['sap'], ['icbc']]}
# 18
# {'user_name': 'user18', 'brands': ['addidas', 'tencent', "mcdoland's", 'renault'], 'competitors': [['tcs', 'rbc', 'ford', 'intel', 'xiaomi'], ['sap', 'qualcomm', 'netflix', 'mahindra'], ['paypal'], ['hitachi']]}
# 19
# {'user_name': 'user19', 'brands': ['nestle', 'citigroup', 'johnson', 'microsoft', 'disney'], 'competitors': [['intel'], ['qualcomm'], ['cosmo', 'fedEx', 'woodland'], ['toyota', 'ebay'], ['maybank']]}
# 20
# {'user_name': 'user20', 'brands': ['volkswagen', 'aegon', 'super dry', 'airtel', 'maruhan', 'merceds'], 'competitors': [['caterpillar', 'loreal', 'infosys', 'microsoft'], ['amazon', 'maruhan'], ['caterpillar'], ['metlife', 'hp'], ['airtel', 'panasonic', 'cisco', 'qualcomn', 'hdfc'], ['pepsi', 'johnson', 'mastercard', 'microsoft', 'maruhan']]}
# 21
# {'user_name': 'user21', 'brands': ['starbucks', 'sap', 'jpmorgan', 'hdfc'], 'competitors': [['accenture', 'coca-cola', 'nestle'], None, ['super dry', 'siemens'], ['citigroup', 'lg', 'woodland', 'mahindra', 'vinci']]}
# 22
# {'user_name': 'user22', 'brands': ['panasonic', 'caterpillar', 'hdfc', 'woodland', 'facebook'], 'competitors': [['target'], ['hitachi'], ['toyota', 'metlife', 'american express'], ['sony', 'pubg', 'acs'], ['hp']]}
# 23
# {'user_name': 'user23', 'brands': ['super dry', 'facebook', 'merceds', "mcdoland's", 'johnson', 'cosmo'], 'competitors': [['american express', 'sap', 'mastercard', 'toyota'], ['samsung', 'sodexo', 'volkswagen'], ['aegon'], ['amazon', 'accenture', 'metlife', 'airtel'], ['at&t', 'comcast', "mcdoland's"], ['lg', 'hitachi', 'loreal']]}
# 24
# {'user_name': 'user24', 'brands': ['fluor', 'capgemini', 'pubg', 'citigroup'], 'competitors': [['pubg', 'super dry'], ['target'], ['walmart'], ['vmware', 'capgemini']]}
# 25
# {'user_name': 'user25', 'brands': ['philip', 'hp', 'volkswagen', 'citigroup', 'danone'], 'competitors': [['tesco'], ['ebay', 'loreal'], ['ibm'], ['philip', 'apple', 'xiaomi'], ['hp']]}
# 26
# {'user_name': 'user26', 'brands': ['wipro', 'at&t', 'icici', 'nokia', 'starbucks', 'qualcomm'], 'competitors': [['salesforce', 'apple', 'hdfc', 'woodland', 'citigroup'], ['loreal', 'danaher', 'fedEx', 'maruhan'], ['sap', 'tencent'], ['intel', 'nike', 'caterpillar', 'hyundai', 'cosmo'], ['visa', 'amazon', 'renault'], ['ibm', 'xiaomi', 'starbucks', 'nike', 'johnson']]}
# 27
# {'user_name': 'user27', 'brands': ['puma', 'avnet', 'cisco', 'loreal'], 'competitors': [['infosys'], None, ['ebay'], ['nestle', 'coca-cola', 'alphabet', 'barclays', 'salesforce']]}
# 28
# {'user_name': 'user28', 'brands': ['visa', 'nokia', 'loreal', 'icici', 'alphabet'], 'competitors': [['lg', 'cosmo', 'panasonic', 'ibm'], ['hyundai', 'lg'], ['icici', 'american express', 'nippon', 'acs', "mcdoland's"], ['apple', 'siemens', "mcdoland's", 'avnet'], ['renault', 'woodland', 'hp', 'coca-cola']]}
# 29
# {'user_name': 'user29', 'brands': ['visa', 'super dry', 'infosys', 'pubg', 'facebook', 'salesforce'], 'competitors': [['icbc', 'mastercard', 'onex'], ['reliance', 'amr', 'facebook'], ['philip', 'nippon', 'amazon', 'loreal', 'addidas'], ['comcast'], ['starbucks', 'salesforce', 'woodland'], ['disney', 'loreal']]}
# 30
# {'user_name': 'user30', 'brands': ['american express', 'panasonic', 'airtel', 'hyundai'], 'competitors': [['paypal', 'sony', 'panasonic', 'rbc', 'coca-cola'], ['qualcomn', 'pubg', 'puma', 'danone', 'paypal'], ['hp', 'hdfc', 'Adobe'], ['tcs', 'infosys', 'bmw', 'vadafone']]}
# 31
# {'user_name': 'user31', 'brands': ['alphabet', 'netflix', 'sodexo', 'target', 'xiaomi'], 'competitors': [['icbc'], ['merceds', 'woodland', 'cosmo'], ['alphabet', 'danone', 'alibaba', 'abb'], ['facebook', 'aegon', 'qualcomm', "mcdoland's"], ['target']]}
# 32
# {'user_name': 'user32', 'brands': ['avnet', 'hp', 'woodland', 'danone', 'crh', 'panasonic'], 'competitors': [['pubg', 'american express', 'netflix'], ['microsoft', 'oracle', 'ibm', 'maybank'], ['barclays', 'fedEx'], ['fluor', 'pubg', 'addidas', 'icbc'], ['samsung', 'salesforce', 'visa'], ['american express', 'nokia', 'woodland', 'bmw']]}
# 33
# {'user_name': 'user33', 'brands': ['accenture', 'woodland', 'puma', 'icici'], 'competitors': [['xiaomi', 'mastercard'], ['hyundai', 'paypal', 'xiaomi', 'fedEx', 'nestle'], ['alphabet', 'icbc'], ['siemens', 'danaher']]}
# 34
# {'user_name': 'user34', 'brands': ['danaher', 'pubg', 'accenture', 'netflix', 'visa'], 'competitors': [['qualcomn'], ['target', 'maybank'], ['nokia', 'ebay'], ['qualcomn', 'johnson', 'walmart', 'oracle', 'nvidia'], ['bmw']]}
# 35
# {'user_name': 'user35', 'brands': ['pubg', 'avnet', 'sony', 'super dry', 'comcast', 'samsung'], 'competitors': [['puma', 'accenture', 'citigroup', 'icbc'], ['crh', 'aegon', 'caterpillar', 'qualcomn'], None, ['capgemini', 'microsoft', 'jpmorgan'], ['nike'], ['danone']]}
# 36
# {'user_name': 'user36', 'brands': ['airtel', 'merceds', 'icici', 'bmw'], 'competitors': [['vadafone', 'Adobe', 'american express', 'alphabet', 'onex'], ['fedEx', 'caterpillar'], ['hp'], ['at&t', 'pubg', 'mahindra', 'barclays', 'puma']]}
# 37
# {'user_name': 'user37', 'brands': ['disney', 'american express', 'puma', 'ibm', 'hyundai'], 'competitors': [['rbc', 'pepsi'], ['avnet', 'fluor'], ['at&t', 'vadafone', 'reliance', 'citigroup'], ['wipro', 'woodland', 'fedEx'], ['visa', 'microsoft', 'salesforce', 'volkswagen']]}
# 38
# {'user_name': 'user38', 'brands': ['alphabet', 'merceds', 'airtel', 'caterpillar', 'Adobe', 'infosys'], 'competitors': [['nike'], ['sap', 'samsung', 'mastercard', 'canon'], ['onex', 'pepsi', 'ibm', 'metlife', 'renault'], ["mcdoland's", 'target'], ['amazon', 'american express', 'hdfc', 'amr', 'apple'], ['crh', 'xiaomi']]}
# 39
# {'user_name': 'user39', 'brands': ['at&t', 'amr', 'vinci', 'disney'], 'competitors': [['johnson', 'alibaba', 'acs'], ['lg', 'philip', 'maruhan'], ['infosys', 'samsung'], ['barclays']]}
# 40
# {'user_name': 'user40', 'brands': ['vadafone', 'metlife', "mcdoland's", 'puma', 'paypal'], 'competitors': [['infosys', 'johnson'], ['target', 'addidas'], ['mahindra', 'visa', 'samsung'], ['aegon', 'super dry', 'toyota'], ['coca-cola', 'danone', 'reliance', 'disney', 'cisco']]}
# 41
# {'user_name': 'user41', 'brands': ['hdfc', 'danaher', 'jpmorgan', 'cosmo', 'icici', 'pubg'], 'competitors': [['walmart', 'barclays', 'pepsi', 'american express'], ['icici'], ['nokia', 'hp'], ['hdfc', 'ford', 'maruhan', 'apple', 'target'], ['caterpillar', 'qualcomm', 'infosys', 'oracle'], ['renault', 'hp']]}
# 42
# {'user_name': 'user42', 'brands': ['philip', 'tesla', 'avnet', 'super dry'], 'competitors': [['nokia', 'johnson', 'hp', 'lg'], ['hdfc', 'hitachi', 'facebook', 'johnson'], ['nokia', 'target', 'sap'], ['comcast', 'maybank', 'airtel', 'nvidia']]}
# 43
# {'user_name': 'user43', 'brands': ['crh', 'capgemini', 'ford', 'caterpillar', 'hp'], 'competitors': [['onex', 'ebay'], ['panasonic', 'amazon', 'amr', 'johnson'], ['icici', 'visa'], ['sodexo', 'sony', 'fedEx', 'sap'], ['visa']]}
# 44
# {'user_name': 'user44', 'brands': ['wipro', 'aegon', 'nike', 'acs', 'nippon', 'nestle'], 'competitors': [['danaher', 'rbc'], ['johnson', 'fluor'], ['cosmo', 'avnet', 'capgemini', 'fluor', 'loreal'], ['addidas', 'apple', 'infosys'], ['canon', 'vinci', 'qualcomm', 'metlife', 'tesla'], ['airtel', 'johnson', 'hitachi']]}
# 45
# {'user_name': 'user45', 'brands': ['sony', 'tcs', 'philip', 'intel'], 'competitors': [['hdfc', 'vinci'], ['philip'], ['microsoft', 'apple', 'samsung', 'maruhan'], ['salesforce', 'vadafone']]}
# 46
# {'user_name': 'user46', 'brands': ['wipro', 'starbucks', 'amazon', 'johnson', 'mahindra'], 'competitors': [['accenture', 'alphabet', 'johnson', 'american express'], ['wistron', 'infosys'], ['metlife', 'nokia'], ['addidas', 'aegon', "mcdoland's"], ['nike', 'microsoft', 'fluor']]}
# 47
# {'user_name': 'user47', 'brands': ['tesco', 'panasonic', 'ford', 'comcast', 'woodland', 'infosys'], 'competitors': [['at&t', 'vadafone', 'vmware', 'pubg'], ['super dry'], ['caterpillar', 'maruhan'], ['merceds'], ['renault', 'jpmorgan'], ['volkswagen', 'merceds', 'toyota', 'staples']]}
# 48
# {'user_name': 'user48', 'brands': ['comcast', 'wipro', 'woodland', 'icbc'], 'competitors': [['tcs', 'visa'], ['abb', 'target'], ['visa', 'abb', 'mahindra', 'super dry'], ['tesla', 'super dry', 'ibm', 'avnet']]}
# 49
# {'user_name': 'user49', 'brands': ['nokia', 'onex', 'mastercard', 'icbc', 'wipro'], 'competitors': [['wipro', 'nike'], ['paypal'], None, ['bmw', 'nestle', 'alibaba'], None]}
# 50
# {'user_name': 'user50', 'brands': ['toyota', 'icbc', 'wistron', 'super dry', 'loreal', 'barclays'], 'competitors': [['salesforce', 'fedEx'], ['airtel', 'vmware'], ['reliance'], ['Adobe', 'mastercard', 'alibaba', 'loreal', 'barclays'], ['johnson', 'capgemini', 'qualcomn', 'johnson', 'siemens'], ['panasonic']]}
# 51
# {'user_name': 'user51', 'brands': ['aegon', 'Adobe', 'mahindra', 'ibm'], 'competitors': [['nestle', 'cosmo'], ['microsoft', 'visa', 'citigroup', 'accenture', 'caterpillar'], ['samsung', 'vinci', 'sodexo', 'nvidia'], ['cosmo']]}
# 52
# {'user_name': 'user52', 'brands': ['acs', 'mastercard', 'puma', 'aegon', 'capgemini'], 'competitors': [['johnson'], ['icbc', 'paypal'], ['johnson', 'super dry', 'ford', 'abb'], ['metlife', 'netflix', 'cosmo'], ['wistron', 'icbc', 'nestle', 'canon', 'avnet']]}
# 53
# {'user_name': 'user53', 'brands': ['ford', 'johnson', 'alphabet', 'danaher', 'apple', 'cosmo'], 'competitors': [['johnson', 'wipro', 'avnet', 'paypal', 'crh'], ['acs'], ['sony', 'airtel'], ['cosmo', 'staples', 'wipro', 'ford'], ['caterpillar', 'disney', 'icici'], ['addidas', 'sodexo', 'nestle', 'disney', 'netflix']]}
# 54
# {'user_name': 'user54', 'brands': ['Adobe', 'nokia', 'starbucks', 'samsung'], 'competitors': [['ebay', "mcdoland's", 'nokia', 'jpmorgan'], ['cosmo'], ['maybank', 'onex', 'vinci'], ['at&t']]}
# 55
# {'user_name': 'user55', 'brands': ['capgemini', 'reliance', 'mastercard', 'coca-cola', 'maybank'], 'competitors': [['wipro'], ['oracle'], ['rbc', 'barclays'], ['netflix'], ['nike', 'nippon']]}
# 56
# {'user_name': 'user56', 'brands': ['intel', 'fedEx', 'rbc', 'accenture', 'volkswagen', 'at&t'], 'competitors': [['american express', 'addidas', 'airtel'], ['tesla', 'hdfc', 'maybank'], ['fluor', 'airtel', 'caterpillar'], ['abb'], ['avnet', 'siemens', 'alibaba'], ['volkswagen']]}
# 57
# {'user_name': 'user57', 'brands': ['Adobe', 'mastercard', 'loreal', 'vadafone'], 'competitors': [['mastercard', 'jpmorgan', 'qualcomm', 'pubg', 'qualcomn'], None, ['super dry', 'microsoft'], ['panasonic', 'coca-cola', 'maybank', 'icici', 'sony']]}
# 58
# {'user_name': 'user58', 'brands': ['coca-cola', 'at&t', 'airtel', 'barclays', 'staples'], 'competitors': [['capgemini'], ['barclays', 'facebook', 'cisco', 'cosmo'], ['hp', 'mahindra', 'facebook', 'loreal'], ['xiaomi'], ['cosmo', 'bmw', 'tesco', 'danone']]}
# 59
# {'user_name': 'user59', 'brands': ['nippon', 'staples', 'metlife', 'walmart', 'sodexo', 'philip'], 'competitors': [['target', 'sodexo', 'alibaba', 'facebook', 'starbucks'], ['target', 'vadafone', 'tesla'], ['nestle'], ['johnson', 'pubg'], ['tencent', 'pepsi', 'rbc'], ['target', 'tesco']]}
# 60
# {'user_name': 'user60', 'brands': ['pubg', 'reliance', 'volkswagen', 'mastercard'], 'competitors': [['airtel', 'danone', 'capgemini'], ['pepsi', 'alphabet'], ['disney', 'qualcomm', 'caterpillar', 'citigroup', 'amr'], ['rbc', 'capgemini']]}
# 61
# {'user_name': 'user61', 'brands': ['sony', 'cosmo', 'coca-cola', 'citigroup', 'comcast'], 'competitors': [['Adobe'], ['maruhan', 'visa', 'caterpillar'], ['netflix', 'philip'], ['avnet', 'volkswagen', 'ebay', "mcdoland's", 'addidas'], ['johnson', 'tencent', 'metlife']]}
# 62
# {'user_name': 'user62', 'brands': ['target', 'nvidia', 'intel', 'mahindra', 'tencent', 'nike'], 'competitors': [['amr', 'microsoft', 'capgemini', 'Adobe'], ['sony', 'panasonic', 'paypal', 'infosys', 'capgemini'], ['sap', 'at&t', 'netflix'], ['microsoft', 'tencent', 'nokia'], ['hp', 'visa'], ['cisco', 'tesla', 'amr']]}
# 63
# {'user_name': 'user63', 'brands': ['maybank', 'sap', 'accenture', 'johnson'], 'competitors': [['xiaomi', 'fedEx', 'maruhan', 'hdfc', 'nike'], ['tesco', 'netflix'], ['nokia', 'renault'], ['ford']]}
# 64
# {'user_name': 'user64', 'brands': ['vadafone', 'hyundai', 'apple', 'wistron', 'coca-cola'], 'competitors': [['lg', 'nestle'], ['tesla', 'vinci'], ['jpmorgan', 'at&t', 'netflix'], ['merceds', 'onex', 'bmw', 'alibaba', 'pubg'], ['comcast', 'addidas', 'Adobe', 'icici']]}
# 65
# {'user_name': 'user65', 'brands': ['fluor', 'avnet', 'starbucks', 'jpmorgan', 'fedEx', 'alibaba'], 'competitors': [['infosys', 'hitachi', 'icici', 'barclays'], ['walmart', 'pepsi'], ['cisco', 'walmart'], ['sodexo', 'tencent', 'target'], ['citigroup', 'american express', 'at&t', 'nestle', 'icici'], ['qualcomm', 'xiaomi', 'citigroup', 'sap', 'vinci']]}
# 66
# {'user_name': 'user66', 'brands': ['panasonic', 'infosys', 'at&t', 'microsoft'], 'competitors': [['alphabet', 'wipro', 'wistron', 'ebay'], ['hp', 'mahindra', 'siemens', 'danaher'], ['loreal', 'infosys', 'reliance'], None]}
# 67
# {'user_name': 'user67', 'brands': ['barclays', 'woodland', 'maruhan', 'crh', 'vmware'], 'competitors': [['mastercard'], ['toyota'], ['loreal', 'philip', 'ebay'], ['amr', 'mahindra'], ['qualcomn']]}
# 68
# {'user_name': 'user68', 'brands': ['ibm', 'johnson', 'pubg', 'cosmo', 'philip', 'nike'], 'competitors': [['renault', 'tencent'], ['qualcomn'], ["mcdoland's", 'addidas'], ['disney', 'abb', 'icbc', 'barclays', 'hdfc'], ['loreal', 'amr', 'merceds', 'metlife', 'american express'], ['tesla', 'addidas']]}
# 69
# {'user_name': 'user69', 'brands': ['rbc', 'vadafone', 'metlife', 'citigroup'], 'competitors': [['johnson', 'visa', 'oracle'], ['ebay', 'staples', 'facebook', 'panasonic', 'capgemini'], ['target', "mcdoland's", 'maybank', 'ford'], None]}
# 70
# {'user_name': 'user70', 'brands': ['fedEx', 'apple', 'maruhan', 'qualcomn', 'ibm'], 'competitors': [['hdfc', 'siemens'], ['disney', 'netflix'], ['tencent', 'airtel', 'abb', 'cosmo', 'wistron'], ['mahindra'], ['alibaba', 'canon', 'super dry', 'amazon']]}
# 71
# {'user_name': 'user71', 'brands': ['salesforce', 'facebook', 'danone', 'cosmo', 'addidas', 'staples'], 'competitors': [['pubg', 'sap', 'amazon', 'crh'], ['puma', 'vmware', 'ebay', 'visa', 'barclays'], None, ['nippon', 'johnson', 'acs', 'starbucks', 'accenture'], ['maruhan', 'volkswagen', 'samsung', 'qualcomm'], ['hp', 'hyundai', 'citigroup']]}
# 72
# {'user_name': 'user72', 'brands': ['sodexo', 'acs', 'sap', 'rbc'], 'competitors': [['comcast', 'amr', 'microsoft', 'canon'], ['abb', 'mahindra', 'airtel'], ['tesla', 'hp'], ['nippon', 'icici', 'tencent', 'accenture', 'wistron']]}
# 73
# {'user_name': 'user73', 'brands': ["mcdoland's", 'salesforce', 'xiaomi', 'merceds', 'hyundai'], 'competitors': [['fedEx', 'hdfc', 'volkswagen'], ['nippon', 'hdfc'], ['ebay', "mcdoland's", 'vmware', 'hp'], None, ['samsung', 'mastercard']]}
# 74
# {'user_name': 'user74', 'brands': ['vinci', 'woodland', 'icici', 'tesco', 'qualcomn', 'alibaba'], 'competitors': [None, ['Adobe', 'intel', 'american express'], ['philip', 'samsung', 'nokia'], ['volkswagen', 'avnet'], ['american express'], ['paypal', 'oracle', 'maruhan']]}
# 75
# {'user_name': 'user75', 'brands': ['mastercard', 'volkswagen', 'pepsi', 'tcs'], 'competitors': [['bmw', 'sodexo', 'wistron'], ['samsung', 'amr', 'Adobe'], ['microsoft', 'xiaomi', 'hp', 'wipro', 'merceds'], ['philip', 'danaher', 'xiaomi', 'nokia']]}
# 76
# {'user_name': 'user76', 'brands': ['hp', 'nvidia', 'nestle', 'capgemini', 'cisco'], 'competitors': [['hitachi', 'abb', 'mahindra', 'puma'], ['addidas', 'mastercard', 'super dry'], ['facebook', 'intel'], ['oracle', 'metlife'], ['mahindra', 'sony', 'ebay']]}
# 77
# {'user_name': 'user77', 'brands': ['samsung', 'coca-cola', 'mahindra', 'capgemini', 'citigroup', 'pubg'], 'competitors': [['acs', 'johnson', 'disney', 'hp', 'johnson'], ['paypal'], ['super dry', 'barclays', 'volkswagen', 'icici'], ['vadafone', 'nippon', 'acs', 'renault', 'amr'], ['maybank', 'johnson'], ['starbucks', 'staples', 'toyota', 'icici', 'danaher']]}
# 78
# {'user_name': 'user78', 'brands': ['wipro', 'coca-cola', 'fedEx', 'accenture'], 'competitors': [['apple'], ['wistron', 'qualcomn', 'nippon', 'aegon'], ['qualcomn'], ['loreal', 'puma', 'apple', 'toyota']]}
# 79
# {'user_name': 'user79', 'brands': ['wistron', 'crh', 'amr', 'amazon', 'walmart'], 'competitors': [['volkswagen', 'crh', 'danone'], ['hitachi'], ['alibaba', 'qualcomn', 'microsoft'], ['rbc', 'tencent', 'addidas', 'danone'], ['disney', 'ebay', 'danaher']]}
# 80
# {'user_name': 'user80', 'brands': ['volkswagen', 'pubg', 'fluor', 'amr', 'nokia', 'nvidia'], 'competitors': [['maybank', 'abb', 'tesco', 'ford', 'nippon'], ['facebook', 'accenture', 'canon', 'Adobe'], ['netflix'], ['xiaomi', 'metlife', 'infosys'], ['airtel', 'pubg', 'citigroup', 'wistron', 'vadafone'], ['bmw', 'danaher', 'crh', 'jpmorgan', 'walmart']]}
# 81
# {'user_name': 'user81', 'brands': ['alphabet', 'disney', 'sony', 'oracle'], 'competitors': [['abb', 'coca-cola'], ['siemens', 'hitachi', 'hp', 'reliance', 'visa'], ['ebay', 'ford', 'Adobe', 'cosmo', 'johnson'], ['vmware', 'tencent', 'sony']]}
# 82
# {'user_name': 'user82', 'brands': ['merceds', 'danone', 'intel', 'starbucks', 'nippon'], 'competitors': [['hp', 'fluor', 'staples'], ['jpmorgan', 'addidas'], ['woodland'], ['fluor', 'nippon', 'wistron', 'caterpillar', 'nvidia'], ['puma', 'disney']]}
# 83
# {'user_name': 'user83', 'brands': ['nippon', 'woodland', 'target', 'volkswagen', 'metlife', 'airtel'], 'competitors': [['disney', 'american express'], ['ford', 'super dry', 'volkswagen', 'staples'], ['hyundai', 'icici', 'ibm'], ['renault', 'bmw'], ['rbc', 'hdfc'], ['apple']]}
# 84
# {'user_name': 'user84', 'brands': ['vadafone', 'amr', 'fedEx', 'visa'], 'competitors': [['cosmo', 'cisco'], ['starbucks'], ['hitachi', 'target', 'tencent'], ['vadafone', 'super dry', 'xiaomi', 'sony']]}
# 85
# {'user_name': 'user85', 'brands': ['danaher', 'vadafone', 'caterpillar', 'mahindra', 'comcast'], 'competitors': [['maybank'], ['xiaomi', 'bmw', 'nippon', 'citigroup', 'hyundai'], ['addidas', 'sony', 'mastercard'], ['Adobe'], ['airtel', 'microsoft', 'jpmorgan', 'icbc']]}
# 86
# {'user_name': 'user86', 'brands': ['super dry', 'nippon', 'tesco', 'pepsi', 'paypal', 'visa'], 'competitors': [['oracle', 'danaher', 'bmw', 'accenture'], ['capgemini', 'microsoft'], ['wistron', 'icbc'], None, ['nestle', 'ebay'], ['apple', 'hp']]}
# 87
# {'user_name': 'user87', 'brands': ['siemens', 'puma', 'amazon', 'woodland'], 'competitors': [['nestle', 'facebook', 'super dry', 'danaher'], ['toyota', 'hdfc', 'reliance', 'crh'], ['abb', 'reliance', 'citigroup', 'canon'], ['siemens', 'disney', 'puma']]}
# 88
# {'user_name': 'user88', 'brands': ['mahindra', 'hitachi', 'target', 'walmart', 'renault'], 'competitors': [['qualcomm', 'merceds'], ['jpmorgan', 'siemens'], ['nestle', 'wistron', 'merceds', 'xiaomi'], ['tcs', 'abb', 'disney'], ['airtel', 'ibm']]}
# 89
# {'user_name': 'user89', 'brands': ['danone', 'bmw', 'paypal', 'renault', 'fluor', 'qualcomm'], 'competitors': [['crh', 'comcast'], ['intel', 'lg'], ['accenture', 'mastercard', 'pubg', 'nvidia'], ['nippon', 'abb'], ['volkswagen', 'capgemini', 'hitachi', 'abb', 'puma'], ['icbc', 'nike', 'sony', 'rbc']]}
# 90
# {'user_name': 'user90', 'brands': ['wistron', 'loreal', 'mastercard', 'pubg'], 'competitors': [['staples', 'Adobe', 'accenture', 'fedEx', 'cisco'], ['acs', 'merceds'], ['paypal'], ['wipro', 'nvidia', 'intel', 'walmart', 'paypal']]}
# 91
# {'user_name': 'user91', 'brands': ['fedEx', 'abb', 'nestle', 'alibaba', 'vadafone'], 'competitors': [['nvidia', 'onex', 'crh', 'johnson', 'Adobe'], ['tcs'], ['johnson', 'Adobe', 'sony'], ['metlife', 'maybank', 'alphabet'], ['puma']]}
# 92
# {'user_name': 'user92', 'brands': ['volkswagen', 'tesla', 'xiaomi', 'loreal', 'wipro', 'bmw'], 'competitors': [['reliance', 'target', 'panasonic'], ['disney', 'pubg'], ['nvidia', 'sodexo'], ['woodland', 'wistron', 'johnson'], ['merceds', 'cosmo'], ['mahindra', 'danone']]}
# 93
# {'user_name': 'user93', 'brands': ['at&t', 'danaher', 'loreal', 'avnet'], 'competitors': [['icici', 'onex'], ['mahindra'], ['fedEx', 'danaher', 'merceds', 'bmw', 'tencent'], ['nippon', 'metlife', 'sony', 'amazon', 'super dry']]}
# 94
# {'user_name': 'user94', 'brands': ['target', 'amr', 'nokia', 'accenture', "mcdoland's"], 'competitors': [['barclays', 'walmart', 'ebay', 'cosmo'], ['ford', 'avnet', 'mastercard', 'nestle', 'qualcomn'], ['ebay'], ['siemens', 'Adobe', 'bmw', 'lg', 'wipro'], ['toyota', 'comcast']]}
# 95
# {'user_name': 'user95', 'brands': ['maybank', 'tesla', 'icbc', 'cisco', 'johnson', 'onex'], 'competitors': [['crh', 'hitachi', 'staples', 'tcs'], ['philip', 'Adobe', 'rbc', 'vadafone', 'panasonic'], ['tencent', 'nvidia'], ['tesla', 'canon'], ['qualcomm', 'nokia'], ['infosys', 'cisco', 'staples', 'disney', 'tcs']]}
# 96
# {'user_name': 'user96', 'brands': ['danaher', 'comcast', 'vinci', 'sodexo'], 'competitors': [['accenture', 'barclays', 'tesco', 'toyota', 'icici'], ['canon'], ['qualcomn', 'nestle', 'addidas', 'woodland', 'samsung'], ['nike', 'apple', 'aegon', 'johnson']]}
# 97
# {'user_name': 'user97', 'brands': ['addidas', 'siemens', 'tesco', 'hyundai', 'cosmo'], 'competitors': [['icbc', 'fedEx', 'danaher'], ['visa', 'hitachi', 'aegon'], ["mcdoland's", 'maybank', 'fluor', 'citigroup'], ['lg', "mcdoland's", 'ford', 'caterpillar'], ['hp', 'vadafone']]}
# 98
# {'user_name': 'user98', 'brands': ['aegon', 'toyota', 'oracle', 'hdfc', 'canon', 'apple'], 'competitors': [['bmw', 'danaher'], ['Adobe', 'salesforce', 'samsung', 'comcast', 'starbucks'], ['qualcomn', 'woodland'], ['reliance'], ['staples'], ['volkswagen', 'ford', 'salesforce', 'hitachi']]}
# 99
# {'user_name': 'user99', 'brands': ['vmware', 'crh', 'infosys', 'salesforce'], 'competitors': [['ibm', 'netflix', 'sony'], ['nokia', 'microsoft', 'merceds', 'tcs'], ['aegon', 'visa', 'amr'], ['alibaba']]}
# 100
# {'user_name': 'user100', 'brands': ['xiaomi', 'nippon', 'jpmorgan', 'comcast', 'sodexo'], 'competitors': [['abb', 'volkswagen'], ['walmart', 'siemens', 'hdfc', 'tcs'], ['starbucks', 'visa', 'intel', 'tcs', 'nike'], ['mastercard', 'pubg', 'infosys'], ['alibaba', 'maruhan', 'accenture', 'facebook', 'airtel']]}
# 101
# {'user_name': 'user101', 'brands': ['toyota', 'hyundai', 'qualcomn', 'disney', 'rbc', 'reliance'], 'competitors': [['pepsi', 'icbc', 'addidas', 'visa'], ['caterpillar', 'comcast', 'mastercard'], ['Adobe', 'hitachi', 'nike', 'cisco', 'vmware'], ['wipro', 'fluor', 'nike'], ['intel', "mcdoland's", 'cisco', 'maruhan', 'american express'], ['hyundai', 'infosys', 'sony', 'starbucks', 'pepsi']]}
# 102
# {'user_name': 'user102', 'brands': ['woodland', 'cisco', 'visa', 'hitachi'], 'competitors': [['merceds', 'intel', 'hp'], ['xiaomi', 'jpmorgan'], ['maruhan', 'danone', 'canon', 'toyota'], ['acs', 'paypal', 'Adobe']]}
# 103
# {'user_name': 'user103', 'brands': ['Adobe', 'toyota', 'caterpillar', 'fedEx', 'qualcomm'], 'competitors': [['american express', 'puma', 'icbc'], ['barclays', 'apple', 'microsoft', 'samsung', 'super dry'], ['ford', 'alphabet', 'rbc', 'facebook', 'johnson'], ['vmware', 'microsoft', 'american express', 'aegon', 'tencent'], ['hdfc']]}
# 104
# {'user_name': 'user104', 'brands': ['Adobe', 'intel', 'comcast', 'hyundai', 'at&t', 'rbc'], 'competitors': [['icbc', 'merceds', 'staples', 'microsoft', 'american express'], ['abb', 'netflix', 'fedEx', 'walmart', 'hp'], ['staples', 'wistron', 'danaher', 'mastercard', 'qualcomm'], ['at&t', 'lg', 'qualcomn'], ['renault', 'johnson', 'pubg', 'icici'], ['merceds', 'reliance', 'metlife', 'philip']]}
# 105
# {'user_name': 'user105', 'brands': ['intel', 'canon', 'hdfc', 'abb'], 'competitors': [['rbc', 'toyota', 'woodland', 'visa', 'renault'], ['facebook'], ['nippon'], ['amr']]}
# 106
# {'user_name': 'user106', 'brands': ['alphabet', 'sodexo', 'vmware', 'metlife', 'accenture'], 'competitors': [None, ['mastercard'], ['caterpillar', 'metlife', 'woodland', 'nokia', 'comcast'], ['barclays', 'alibaba', 'toyota', 'netflix', 'amr'], ['at&t', 'american express', 'capgemini']]}
# 107
# {'user_name': 'user107', 'brands': ['volkswagen', 'hitachi', 'at&t', 'acs', 'tcs', 'canon'], 'competitors': [['nike', 'puma', 'crh', 'pubg'], ['mahindra', 'samsung', 'sony', 'crh'], ['apple', 'pubg', 'netflix', 'reliance', 'loreal'], ['crh', 'caterpillar', 'addidas', 'fedEx', 'amr'], ['target', 'siemens', 'mahindra', 'comcast'], ['hdfc', 'target']]}
# 108
# {'user_name': 'user108', 'brands': ['hdfc', 'tencent', 'icici', 'renault'], 'competitors': [['tesco', 'jpmorgan', 'maruhan', 'american express'], ['acs', 'hyundai', 'icbc', 'amazon', 'vmware'], ['target', 'nvidia', 'sodexo', 'walmart'], ['ibm', 'walmart']]}
# 109
# {'user_name': 'user109', 'brands': ['coca-cola', 'disney', 'comcast', 'apple', 'sodexo'], 'competitors': [["mcdoland's", 'vinci'], ['toyota', 'icici', 'tcs'], ['facebook'], ['ibm'], ['fedEx', 'johnson']]}
# 110
# {'user_name': 'user110', 'brands': ['merceds', 'tesco', 'johnson', 'staples', 'intel', 'infosys'], 'competitors': [['maybank', 'super dry'], ['salesforce', 'danone', 'addidas'], ['tesco', 'canon', 'sap'], ['hitachi', 'netflix', 'vmware', 'icbc'], ['wistron', 'hyundai', 'philip', 'alphabet'], ['johnson', 'merceds', 'avnet', 'super dry']]}
# 111
# {'user_name': 'user111', 'brands': ['aegon', 'acs', 'samsung', 'Adobe'], 'competitors': [['rbc', 'cisco', 'merceds'], ['facebook'], ['capgemini', 'xiaomi', 'cosmo', 'ebay'], ['comcast', 'at&t', 'puma']]}
# 112
# {'user_name': 'user112', 'brands': ['puma', 'infosys', 'alphabet', 'salesforce', 'nestle'], 'competitors': [['tesla', 'vadafone', 'loreal', 'pubg', 'visa'], ['starbucks', 'volkswagen'], ['woodland', 'sap'], ['jpmorgan'], ['addidas']]}
# 113
# {'user_name': 'user113', 'brands': ['hdfc', 'onex', 'sodexo', 'fedEx', 'vmware', 'citigroup'], 'competitors': [['ibm', "mcdoland's", 'loreal', 'tencent', 'nvidia'], ['capgemini'], ['hitachi', 'sony'], ['renault', 'qualcomn', 'wistron'], ['canon'], ['ibm', 'nokia', 'acs']]}
# 114
# {'user_name': 'user114', 'brands': ['aegon', 'onex', 'panasonic', 'pubg'], 'competitors': [['vadafone', 'visa'], ['vadafone', 'avnet', 'tesco'], ['hdfc', 'nike'], ['wistron', 'nike', 'tesco', 'acs', 'aegon']]}
# 115
# {'user_name': 'user115', 'brands': ['capgemini', 'visa', 'panasonic', 'apple', "mcdoland's"], 'competitors': [['ibm'], ['walmart'], ['reliance', 'microsoft', 'merceds', 'Adobe'], ['netflix', 'disney'], ['vinci', 'tcs']]}
# 116
# {'user_name': 'user116', 'brands': ['nike', 'acs', 'mahindra', 'puma', 'alphabet', 'wipro'], 'competitors': [['loreal'], ['disney', 'hyundai', 'sap'], ['loreal'], None, ['volkswagen', 'sony', 'mahindra', 'rbc'], ['american express']]}
# 117
# {'user_name': 'user117', 'brands': ['fluor', 'johnson', 'aegon', 'woodland'], 'competitors': [['tencent'], ['capgemini'], ['hyundai', 'reliance'], ['loreal', 'vinci', 'caterpillar', 'jpmorgan', 'vmware']]}
# 118
# {'user_name': 'user118', 'brands': ['rbc', 'mahindra', 'nike', 'bmw', 'reliance'], 'competitors': [['capgemini', 'at&t', 'bmw'], ['danaher'], ['sap', 'oracle', 'vadafone', 'mastercard'], ['infosys'], ['alphabet', 'johnson', 'comcast', 'acs']]}
# 119
# {'user_name': 'user119', 'brands': ['crh', 'sodexo', 'lg', 'comcast', 'qualcomn', 'target'], 'competitors': [['amr', 'tcs', 'bmw', 'ford'], ['target', 'avnet', 'visa', 'loreal'], ['samsung', 'merceds', 'fluor', 'starbucks', 'apple'], ['tcs'], ['capgemini', 'hdfc', 'coca-cola'], ['maruhan', 'philip', 'ibm']]}
# 120
# {'user_name': 'user120', 'brands': ['paypal', 'ibm', 'abb', 'vadafone'], 'competitors': [['hp', 'fluor'], ['maybank', 'microsoft'], ['ibm', 'super dry', 'Adobe', 'tcs', 'target'], ['avnet']]}
# 121
# {'user_name': 'user121', 'brands': ['facebook', 'hitachi', 'target', 'super dry', 'woodland'], 'competitors': [['lg', 'puma'], ['siemens', 'metlife', 'hdfc', 'nike'], ['capgemini', 'vinci', 'facebook', 'xiaomi'], ['sony', 'samsung', 'ford'], ['wistron', 'crh']]}
# 122
# {'user_name': 'user122', 'brands': ['target', 'avnet', 'qualcomm', 'hp', 'sap', 'amazon'], 'competitors': [['maybank', 'fluor', 'canon', 'hyundai', 'danaher'], ['abb'], ['fluor', 'wipro'], ['alphabet'], ['nike', 'visa'], ['icici', 'maybank', 'barclays', 'volkswagen', 'comcast']]}
# 123
# {'user_name': 'user123', 'brands': ['accenture', 'Adobe', 'mahindra', 'ebay'], 'competitors': [['at&t', 'sap'], None, ['nvidia', 'danaher', 'sony'], ['coca-cola', 'nokia', 'disney']]}
# 124
# {'user_name': 'user124', 'brands': ['american express', 'oracle', 'johnson', 'visa', 'tencent'], 'competitors': [['crh', 'hitachi', 'at&t', 'siemens', 'loreal'], ['canon'], ['lg'], ['ford'], ['merceds']]}
# 125
# {'user_name': 'user125', 'brands': ['rbc', 'coca-cola', 'tencent', 'sap', 'tesco', 'ebay'], 'competitors': [['addidas', 'lg', 'philip'], ['cisco', 'toyota', 'merceds', 'infosys'], ['starbucks', 'nestle'], ['fluor', 'caterpillar', 'panasonic', 'maybank'], ['staples', 'nippon'], None]}
# 126
# {'user_name': 'user126', 'brands': ['infosys', 'mastercard', 'nestle', 'wipro'], 'competitors': [['vinci', 'xiaomi', 'hitachi', 'pepsi', 'ford'], ['qualcomm', 'fluor'], ['tcs'], ['vinci', 'alphabet', 'pepsi', 'nippon']]}
# 127
# {'user_name': 'user127', 'brands': ['vmware', 'citigroup', 'icbc', 'ebay', 'puma'], 'competitors': [['reliance', 'american express'], ['microsoft', 'staples', 'hyundai', 'intel'], ['apple', 'mastercard'], ['nestle', 'renault'], ['panasonic', 'sodexo', 'tcs', 'abb', 'qualcomn']]}
# 128
# {'user_name': 'user128', 'brands': ['salesforce', 'sodexo', 'nvidia', 'nestle', 'accenture', 'nippon'], 'competitors': [['maruhan'], ['renault', 'paypal', 'ibm'], ['hp', 'renault', 'canon'], ['samsung', 'coca-cola', 'toyota'], ['johnson', 'microsoft', 'bmw', 'ibm', 'pepsi'], ['wipro']]}
# 129
# {'user_name': 'user129', 'brands': ['woodland', 'nokia', 'danone', 'infosys'], 'competitors': [['salesforce', 'citigroup', 'nvidia', 'maruhan'], ['accenture'], ['reliance', 'sap', 'wipro', 'hitachi', 'qualcomm'], ['johnson', 'citigroup', 'ford']]}
# 130
# {'user_name': 'user130', 'brands': ['netflix', 'maruhan', 'amazon', 'johnson', 'amr'], 'competitors': [['qualcomn'], ['nestle', 'crh'], None, ['facebook', 'accenture'], None]}
# 131
# {'user_name': 'user131', 'brands': ['cosmo', 'capgemini', 'tencent', 'merceds', 'panasonic', 'infosys'], 'competitors': [None, ['vadafone', 'addidas', 'tencent'], ['facebook', 'caterpillar'], ['ebay', 'Adobe', 'american express'], ['hp', 'mastercard', 'walmart', 'caterpillar'], ['mahindra']]}
# 132
# {'user_name': 'user132', 'brands': ['icici', 'tencent', 'netflix', 'barclays'], 'competitors': [None, ["mcdoland's", 'onex', 'crh', 'mastercard'], None, ['reliance', 'qualcomn', 'philip', 'tcs']]}
# 133
# {'user_name': 'user133', 'brands': ['nestle', 'nippon', 'metlife', 'addidas', 'staples'], 'competitors': [['nvidia', 'tcs', 'maybank', 'salesforce'], ['comcast', 'johnson'], ['cosmo', 'panasonic', 'tcs'], ['ibm'], ['accenture', 'abb', 'hitachi', 'vmware']]}
# 134
# {'user_name': 'user134', 'brands': ['staples', 'super dry', 'johnson', 'jpmorgan', 'starbucks', 'mastercard'], 'competitors': [['vadafone', 'danone'], ['philip', 'woodland', 'target'], ['icici', 'wipro', 'lg', 'xiaomi'], ['caterpillar', 'acs'], ['puma', 'cosmo', 'icbc'], ['comcast', 'wipro', 'icbc']]}
# 135
# {'user_name': 'user135', 'brands': ['hdfc', 'alibaba', 'hp', 'vadafone'], 'competitors': [['vadafone', 'renault', 'target'], ['amazon'], ['amr', 'rbc'], ['rbc', 'intel']]}
# 136
# {'user_name': 'user136', 'brands': ['nvidia', 'qualcomn', 'acs', 'target', 'citigroup'], 'competitors': [['maybank', 'danone'], ['netflix', 'apple'], ['salesforce', 'puma', 'johnson', 'tencent', 'wistron'], ['alphabet', 'nippon', 'barclays', 'hyundai'], ['hdfc', 'fedEx']]}
# 137
# {'user_name': 'user137', 'brands': ['cisco', 'starbucks', 'accenture', 'american express', 'loreal', 'oracle'], 'competitors': [['nokia', 'mahindra', 'nvidia', 'siemens'], ['target', 'aegon'], ['amr', 'samsung'], None, ['maruhan', 'merceds'], ['fedEx', 'Adobe', 'ford', 'vmware', 'wistron']]}
# 138
# {'user_name': 'user138', 'brands': ['starbucks', 'aegon', 'volkswagen', 'nokia'], 'competitors': [None, ['staples'], ['nike', 'oracle', 'sony', 'visa'], ['vinci', 'icbc', 'sony', 'qualcomm', 'acs']]}
# 139
# {'user_name': 'user139', 'brands': ['amazon', 'rbc', 'sap', 'aegon', 'icbc'], 'competitors': [['tencent', 'pubg', 'nippon', 'visa'], ['visa'], ['comcast'], ['addidas', 'icici', 'Adobe'], ['apple', 'tesco', 'nvidia', 'alibaba', 'airtel']]}
# 140
# {'user_name': 'user140', 'brands': ['barclays', 'american express', 'volkswagen', 'puma', 'maybank', 'paypal'], 'competitors': [['acs', 'hp', 'ibm'], ['woodland', 'facebook', 'ebay'], ['canon', 'hyundai', 'aegon', 'nike', 'pepsi'], ['danaher', 'staples'], ['woodland'], ['airtel', 'ebay', 'salesforce', 'hp', 'alphabet']]}
# 141
# {'user_name': 'user141', 'brands': ['tesco', 'hdfc', 'philip', 'jpmorgan'], 'competitors': [['amazon', 'renault', 'qualcomm', 'sap', 'tcs'], ['intel'], ['nike'], ['nvidia']]}
# 142
# {'user_name': 'user142', 'brands': ['volkswagen', 'coca-cola', 'hitachi', 'samsung', 'oracle'], 'competitors': [['target', 'samsung'], ['alibaba', 'amazon', 'wistron', 'pubg'], ['alibaba', 'apple'], ['sap'], None]}
# 143
# {'user_name': 'user143', 'brands': ['tencent', 'sap', 'vinci', 'intel', 'puma', 'tesco'], 'competitors': [['qualcomn'], ['avnet', 'infosys', 'rbc', 'comcast'], ['capgemini', 'icici'], ['caterpillar'], ['wipro'], ['siemens', 'philip']]}
# 144
# {'user_name': 'user144', 'brands': ['crh', 'disney', 'sap', 'vinci'], 'competitors': [['woodland', 'puma', 'wipro'], ['acs', 'bmw', 'airtel'], ['nestle'], ['icbc']]}
# 145
# {'user_name': 'user145', 'brands': ['qualcomn', 'puma', 'canon', 'tesco', 'citigroup'], 'competitors': [['nestle', 'sap', 'Adobe', 'samsung', 'caterpillar'], ['loreal'], ['qualcomn'], ['coca-cola', 'alphabet', 'aegon'], ['tesco', 'ford']]}
# 146
# {'user_name': 'user146', 'brands': ['ibm', 'vinci', 'johnson', 'fluor', 'tencent', 'tcs'], 'competitors': [['lg', 'sodexo'], ['hp', 'sap', 'vadafone', 'fedEx'], ['infosys', 'nippon', 'sap'], ['danone', 'canon', 'siemens', 'american express', 'qualcomn'], None, ['alphabet', 'wipro']]}
# 147
# {'user_name': 'user147', 'brands': ['vinci', 'ford', 'nvidia', 'intel'], 'competitors': [['cisco', 'cosmo'], ['volkswagen'], ['disney', 'qualcomm', 'aegon'], ['avnet', 'danaher', 'hp', 'vinci']]}
# 148
# {'user_name': 'user148', 'brands': ['starbucks', 'hitachi', 'netflix', 'cisco', 'woodland'], 'competitors': [['maybank'], ['pepsi', 'lg', 'xiaomi'], ['merceds', 'vinci'], ['qualcomm', 'lg', 'pubg', 'walmart'], ['ebay', 'merceds', 'tcs']]}
# 149
# {'user_name': 'user149', 'brands': ['fluor', 'acs', 'citigroup', 'caterpillar', 'qualcomn', 'microsoft'], 'competitors': [['hp', 'renault', 'nokia'], ['infosys', 'mastercard', 'volkswagen', 'paypal'], ['volkswagen', 'nippon', 'pepsi', 'american express', 'amazon'], ['wistron'], ['fluor', 'comcast', 'mastercard', 'pubg'], ['sodexo', 'maybank']]}
# 150
# {'user_name': 'user150', 'brands': ['intel', 'philip', 'comcast', 'oracle'], 'competitors': [['merceds', 'tesla', 'icici', 'johnson', 'nike'], ['toyota', 'ibm', 'coca-cola'], ['danaher'], ['icici']]}
# 151
# {'user_name': 'user151', 'brands': ['citigroup', 'panasonic', 'puma', 'ebay', 'nestle'], 'competitors': [['comcast', 'microsoft', 'panasonic', 'pepsi', 'salesforce'], ['alibaba', 'crh', 'accenture', 'wistron', 'jpmorgan'], ['comcast'], ['tcs', 'paypal', 'tesla', 'disney'], ['salesforce', 'merceds', 'lg', 'visa']]}
# 152
# {'user_name': 'user152', 'brands': ['vadafone', 'apple', 'paypal', 'sap', 'comcast', 'xiaomi'], 'competitors': [['alphabet', 'nike', 'sap'], ['facebook', 'sony', 'tencent', 'wistron', 'panasonic'], ['ford', 'woodland', 'american express', 'loreal', 'tesco'], ['tesco', 'xiaomi', 'nokia', 'capgemini'], ['target', 'hp', 'oracle'], ['walmart']]}
# 153
# {'user_name': 'user153', 'brands': ['sap', 'capgemini', 'cisco', 'microsoft'], 'competitors': [['sony'], ['apple', 'lg'], ['siemens', 'onex', 'paypal'], ['cosmo', 'danaher', 'at&t', 'abb']]}
# 154
# {'user_name': 'user154', 'brands': ['tcs', 'staples', 'maruhan', 'amazon', 'rbc'], 'competitors': [['facebook', 'toyota', 'johnson', 'philip', 'amr'], ['vmware'], ['philip', 'american express', 'super dry'], ['philip', 'microsoft', 'sap', 'aegon', 'lg'], ['tencent', 'nippon', 'merceds', 'super dry', 'ibm']]}
# 155
# {'user_name': 'user155', 'brands': ['mastercard', 'sap', 'philip', 'alibaba', 'woodland', 'Adobe'], 'competitors': [['pubg', 'puma', 'ford', 'canon', 'mahindra'], ['reliance'], ['toyota', 'wipro', 'vinci'], ['salesforce'], ['pubg', 'loreal'], ['reliance', 'hdfc']]}
# 156
# {'user_name': 'user156', 'brands': ['qualcomn', 'pepsi', 'acs', 'intel'], 'competitors': [['merceds', 'pepsi', 'hyundai'], ['avnet', 'sony'], ['Adobe', 'vinci', 'paypal'], ['fedEx']]}
# 157
# {'user_name': 'user157', 'brands': ['canon', 'hp', 'intel', 'vinci', 'capgemini'], 'competitors': [['ford', 'caterpillar', 'american express'], ['vmware'], ['mahindra', 'maruhan'], ['pepsi', 'nvidia', 'tesla', 'canon', 'volkswagen'], ['loreal', 'avnet', 'Adobe', 'cisco', 'amazon']]}
# 158
# {'user_name': 'user158', 'brands': ['hp', 'airtel', 'caterpillar', 'merceds', 'mastercard', 'siemens'], 'competitors': [['panasonic', 'mahindra', 'nestle', 'pepsi'], ['tcs', 'siemens', 'visa', 'apple', 'staples'], ['acs'], ['apple'], ['jpmorgan', 'at&t', 'rbc', 'hp'], ['tcs', 'apple', 'avnet', 'disney']]}
# 159
# {'user_name': 'user159', 'brands': ['avnet', 'woodland', 'lg', 'vmware'], 'competitors': [['qualcomn', 'nokia', 'panasonic', 'alphabet'], ['nippon', 'panasonic', 'alibaba', 'walmart'], ['samsung'], ['paypal']]}
# 160
# {'user_name': 'user160', 'brands': ['nvidia', 'ford', 'abb', 'nike', 'fluor'], 'competitors': [['crh', 'caterpillar', 'panasonic', 'philip'], ['philip', 'acs', 'amazon', 'ebay', 'apple'], ['acs', 'walmart', 'hyundai', 'cisco'], ['alibaba', 'disney', 'maruhan', 'johnson'], ['wistron', 'merceds', 'reliance', 'danaher', 'staples']]}
# 161
# {'user_name': 'user161', 'brands': ['icbc', 'qualcomn', 'cosmo', 'alibaba', 'Adobe', 'avnet'], 'competitors': [['caterpillar'], ['facebook', 'citigroup'], ['loreal', 'danaher'], ['addidas', 'reliance', 'icbc'], ['sony', 'abb', 'mastercard', 'walmart'], ['oracle', 'tcs', 'vadafone', 'reliance']]}
# 162
# {'user_name': 'user162', 'brands': ['icbc', 'apple', 'intel', 'merceds'], 'competitors': [['aegon', 'toyota', 'oracle', 'ford', 'hdfc'], ['capgemini', 'reliance', 'pepsi', 'siemens', 'Adobe'], ['target', 'pepsi', 'alphabet', 'salesforce'], ['apple', 'wistron', 'nike', 'target']]}
# 163
# {'user_name': 'user163', 'brands': ['citigroup', 'apple', 'infosys', 'merceds', 'ebay'], 'competitors': [['hp', 'tesla', 'onex', 'samsung', 'puma'], ['pepsi'], ['merceds', 'fluor', 'wistron', 'wipro', 'visa'], ['bmw', 'onex', 'nokia', 'coca-cola', 'acs'], ['icici']]}
# 164
# {'user_name': 'user164', 'brands': ['salesforce', 'vmware', 'disney', 'infosys', 'barclays', 'nike'], 'competitors': [['nvidia'], ['staples', 'volkswagen', 'icici', 'walmart'], None, ['reliance', "mcdoland's"], ['caterpillar', 'wipro', 'hyundai', 'fedEx', 'tencent'], ['avnet', 'Adobe', 'wipro', 'visa', 'lg']]}
# 165
# {'user_name': 'user165', 'brands': ['intel', 'comcast', 'siemens', 'nike'], 'competitors': [['philip', 'mahindra'], ['vinci', 'maybank', 'mahindra', 'lg'], ['qualcomn', 'vinci', 'johnson', 'nvidia', 'paypal'], ['cosmo', 'facebook', 'amr', 'wistron']]}
# 166
# {'user_name': 'user166', 'brands': ['vmware', 'pepsi', 'coca-cola', 'ford', 'maybank'], 'competitors': [['acs', 'pepsi', 'ibm', 'starbucks', 'bmw'], ['starbucks'], ['philip', 'siemens'], ['coca-cola', "mcdoland's"], ['comcast']]}
# 167
# {'user_name': 'user167', 'brands': ['bmw', 'toyota', 'amazon', 'ebay', 'puma', 'lg'], 'competitors': [['coca-cola', 'pepsi', 'tesco'], ['mastercard'], ['oracle', 'sap', 'volkswagen', 'nike', 'tesco'], ['icbc', 'nestle'], ['at&t', 'infosys', 'philip', 'qualcomm'], ['pubg', 'hyundai', 'american express', 'sap', 'siemens']]}
# 168
# {'user_name': 'user168', 'brands': ['capgemini', 'rbc', 'ibm', 'tcs'], 'competitors': [['panasonic', 'samsung', 'acs'], ['apple', 'vadafone', 'amazon', 'vinci'], ['alibaba', 'merceds', 'oracle', 'cisco', 'Adobe'], ['hitachi', 'volkswagen', 'sony', 'oracle']]}
# 169
# {'user_name': 'user169', 'brands': ['sodexo', 'ford', 'samsung', 'facebook', 'nike'], 'competitors': [['qualcomn', 'nvidia', 'sony'], ['aegon', 'american express'], ['crh'], ['cisco', 'Adobe'], ['fluor', 'accenture']]}
# 170
# {'user_name': 'user170', 'brands': ['target', 'amazon', 'samsung', 'airtel', 'super dry', 'nokia'], 'competitors': [['lg', 'amazon', 'panasonic'], ['starbucks', 'apple', 'pepsi', 'aegon', 'microsoft'], None, ['canon', 'barclays', 'alibaba', 'loreal'], ['hyundai', 'bmw', 'pubg', 'mastercard'], ['vmware']]}
# 171
# {'user_name': 'user171', 'brands': ['abb', 'avnet', 'caterpillar', 'puma'], 'competitors': [['reliance', 'panasonic', 'bmw'], ['fluor', 'qualcomn', 'loreal'], ['cisco', 'avnet', 'maruhan', 'tesla'], ["mcdoland's", 'citigroup', 'bmw']]}
# 172
# {'user_name': 'user172', 'brands': ['apple', 'hdfc', 'samsung', 'disney', 'abb'], 'competitors': [['staples', 'microsoft'], ['paypal', 'cosmo'], ['wistron', 'netflix'], ['infosys', 'oracle', 'icici', 'nestle', 'pepsi'], ['onex', 'loreal', 'wipro', "mcdoland's"]]}
# 173
# {'user_name': 'user173', 'brands': ['loreal', 'Adobe', 'bmw', 'nestle', 'facebook', 'reliance'], 'competitors': [['avnet', 'samsung', 'sodexo'], ['abb', 'sap', 'siemens', 'pubg'], ['tesco'], ['addidas', 'rbc'], ['cisco', 'maybank', 'samsung', 'super dry'], ['xiaomi', 'mastercard', 'comcast', 'nvidia']]}
# 174
# {'user_name': 'user174', 'brands': ['target', 'fluor', 'citigroup', 'woodland'], 'competitors': [['reliance', 'renault'], ['vinci', 'cisco'], ['super dry', 'apple'], ['merceds', 'staples', 'vmware']]}
# 175
# {'user_name': 'user175', 'brands': ['barclays', 'apple', 'crh', 'Adobe', 'danaher'], 'competitors': [['at&t'], ['philip', 'cosmo'], ['nippon'], ['target', 'super dry', 'vinci', 'tcs', "mcdoland's"], ['staples', 'philip', 'netflix']]}
# 176
# {'user_name': 'user176', 'brands': ['nike', 'coca-cola', 'renault', 'barclays', 'qualcomn', 'onex'], 'competitors': [['siemens', 'onex', 'staples'], ['tcs', 'sony', 'pubg'], ['qualcomn', 'canon', 'loreal', 'puma', 'oracle'], ['reliance', 'starbucks', 'qualcomm', 'ebay', 'toyota'], ['philip', 'johnson', 'icbc'], ['capgemini', 'nippon']]}
# 177
# {'user_name': 'user177', 'brands': ['ford', 'cisco', 'airtel', 'philip'], 'competitors': [['sap', 'mastercard', "mcdoland's", 'qualcomm'], ['target', 'sodexo', 'hdfc', 'american express'], ['samsung', 'reliance'], ['staples']]}
# 178
# {'user_name': 'user178', 'brands': ['acs', 'coca-cola', 'reliance', 'cosmo', 'woodland'], 'competitors': [['oracle', 'tesco', 'nippon', 'johnson', 'loreal'], ['vadafone', 'johnson', 'pubg'], ['ford', 'amazon', 'wistron', 'barclays'], ['ford'], ['apple']]}
# 179
# {'user_name': 'user179', 'brands': ['paypal', 'renault', 'infosys', 'alibaba', 'staples', 'qualcomm'], 'competitors': [['acs', 'maybank', 'mastercard', 'reliance', 'accenture'], ['alibaba'], ['canon', 'intel', 'abb', 'coca-cola', 'lg'], ['xiaomi', 'nvidia', 'airtel'], None, ['alibaba', 'aegon', 'puma']]}
# 180
# {'user_name': 'user180', 'brands': ['starbucks', 'hdfc', 'hyundai', 'vadafone'], 'competitors': [['philip', 'barclays'], ['cisco', 'facebook', 'hitachi', 'starbucks'], ['xiaomi', 'renault', 'ford'], ['avnet', 'volkswagen']]}
# 181
# {'user_name': 'user181', 'brands': ['vinci', 'bmw', 'sony', 'danone', 'hp'], 'competitors': [['tencent'], ['hdfc', 'maybank'], ['paypal'], ['qualcomn', 'sap', 'nike', 'canon', 'maruhan'], ['puma', 'super dry']]}
# 182
# ...
# 941
# {'user_name': 'user941', 'brands': ['ford', 'siemens', 'qualcomn', 'mastercard', 'merceds', 'at&t'], 'competitors': [['caterpillar', 'jpmorgan', 'amazon', 'samsung', 'philip'], ['american express'], None, ['icici', 'pepsi', 'amazon'], ['jpmorgan', 'alphabet', 'acs', 'citigroup', 'vinci'], ['xiaomi', 'hyundai', 'hdfc', 'jpmorgan']]}
# 942
# {'user_name': 'user942', 'brands': ['reliance', 'fedEx', 'accenture', 'wipro'], 'competitors': [['acs', 'tesco', 'salesforce', 'sodexo'], ['nvidia'], ['crh', 'disney', 'merceds'], ['alphabet', "mcdoland's", 'tcs']]}
# 943
# {'user_name': 'user943', 'brands': ['mastercard', 'vadafone', 'renault', 'metlife', 'netflix'], 'competitors': [['icici'], ['sony', 'comcast', 'onex'], ['amr', 'danone', 'mastercard'], ['maruhan'], ['johnson', 'crh', 'oracle']]}
# 944
# {'user_name': 'user944', 'brands': ['coca-cola', 'onex', 'hyundai', 'netflix', 'ford', 'vmware'], 'competitors': [['tencent', 'paypal'], ['Adobe'], ['vadafone', 'lg', 'tencent'], ['philip', 'ibm', 'nestle', 'qualcomn', 'nippon'], ['avnet'], ['loreal']]}
# 945
# {'user_name': 'user945', 'brands': ['paypal', 'siemens', 'pepsi', 'super dry'], 'competitors': [['netflix', 'super dry', 'rbc'], ['american express'], ['microsoft', 'american express', 'merceds', 'aegon'], ['toyota', 'rbc', 'microsoft', 'staples']]}
# 946
# {'user_name': 'user946', 'brands': ['toyota', 'nvidia', 'hdfc', 'airtel', 'panasonic'], 'competitors': [['onex', 'citigroup', 'hitachi'], ['capgemini', 'coca-cola'], ['sony', 'hp', 'pepsi', 'tesla'], ['tesco'], ['tesco']]}
# 947
# {'user_name': 'user947', 'brands': ['mastercard', 'ibm', 'renault', 'panasonic', 'danone', 'vmware'], 'competitors': [['nestle', 'volkswagen'], ['tcs', 'at&t', 'johnson', 'siemens'], ['alibaba', 'capgemini'], ['maybank', 'acs', 'merceds'], ['rbc', 'maybank'], ['apple']]}
# 948
# {'user_name': 'user948', 'brands': ['salesforce', 'volkswagen', 'airtel', 'facebook'], 'competitors': [['nestle'], ['accenture'], ['philip', 'sodexo', 'pepsi', 'danone'], ['sap', "mcdoland's", 'caterpillar', 'rbc']]}
# 949
# {'user_name': 'user949', 'brands': ['maruhan', 'citigroup', 'acs', 'crh', 'addidas'], 'competitors': [['at&t', 'disney', 'mastercard'], ['wistron', "mcdoland's"], ['hp', 'crh', 'avnet'], ['tcs', 'bmw', 'pubg'], ['xiaomi', 'microsoft', 'vadafone']]}
# 950
# {'user_name': 'user950', 'brands': ['nippon', 'jpmorgan', 'siemens', 'hp', 'maybank', 'vinci'], 'competitors': [['vinci'], ['american express', 'fedEx', 'bmw', 'nokia', 'abb'], ['hp', 'microsoft', 'reliance'], ['netflix', 'amr', 'hyundai', 'accenture'], ['qualcomn', 'acs', 'fedEx', 'tcs', 'starbucks'], ['hdfc', 'woodland']]}
# 951
# {'user_name': 'user951', 'brands': ['capgemini', 'onex', 'vadafone', 'hitachi'], 'competitors': [['vinci', 'mahindra', 'pepsi', 'Adobe', 'hitachi'], ['avnet', 'pubg', 'sony', 'target', 'alphabet'], None, ['fluor']]}
# 952
# {'user_name': 'user952', 'brands': ['tcs', 'oracle', 'reliance', 'avnet', 'tesla'], 'competitors': [['cosmo', 'sony', 'nestle'], ['airtel', 'starbucks', 'abb'], ['target'], ['ebay', 'acs', 'at&t', 'danone', 'metlife'], None]}
# 953
# {'user_name': 'user953', 'brands': ['amr', 'nvidia', 'cosmo', 'paypal', 'danaher', 'aegon'], 'competitors': [['sap', 'philip'], ['volkswagen', 'icbc', 'panasonic', 'ford'], ['nippon'], ['pepsi'], ['comcast', 'barclays', "mcdoland's", 'vmware', 'super dry'], ['salesforce', 'johnson']]}
# 954
# {'user_name': 'user954', 'brands': ['walmart', 'icbc', 'abb', 'cosmo'], 'competitors': [['visa', 'hyundai', 'philip', 'metlife'], ['lg', 'icici', 'abb', 'nvidia'], ['super dry', 'pubg', 'volkswagen', 'intel'], ['facebook', 'maybank', 'tcs']]}
# 955
# {'user_name': 'user955', 'brands': ['fedEx', 'nvidia', 'hitachi', 'woodland', 'salesforce'], 'competitors': [['barclays'], ['crh', 'hyundai', 'accenture', 'philip'], ['icici', 'cosmo'], ['johnson', 'nestle', 'Adobe', 'loreal'], ['renault', 'ford']]}
# 956
# {'user_name': 'user956', 'brands': ['target', 'metlife', 'visa', 'citigroup', 'jpmorgan', 'tesco'], 'competitors': [['danaher', 'microsoft'], ['jpmorgan', 'maybank', 'philip'], ['wistron', 'bmw'], ['cisco', 'starbucks', 'mastercard', 'metlife', 'qualcomn'], ['tesla', 'capgemini', 'amr', 'pubg'], ['volkswagen']]}
# 957
# {'user_name': 'user957', 'brands': ['microsoft', 'paypal', 'sodexo', 'Adobe'], 'competitors': [['tencent', 'amr', 'disney', 'danone', 'icici'], ['maruhan', 'oracle', 'qualcomm'], ['onex', 'nestle', 'ebay', 'comcast'], ['xiaomi', 'renault', 'ebay']]}
# 958
# {'user_name': 'user958', 'brands': ['visa', 'tencent', 'vadafone', 'apple', 'nokia'], 'competitors': [['amazon'], ['tesla', 'puma', 'danaher'], ['fedEx', 'comcast', 'cisco', 'avnet', 'netflix'], ['citigroup', 'barclays', 'facebook', 'accenture'], None]}
# 959
# {'user_name': 'user959', 'brands': ['mahindra', 'toyota', 'avnet', 'danone', 'loreal', 'tesco'], 'competitors': [['renault'], ['addidas', 'siemens', 'coca-cola', 'disney', 'abb'], ['rbc', 'capgemini'], ['fedEx', 'salesforce'], ['tesla', 'mastercard'], ['jpmorgan', 'microsoft', 'icbc', 'vmware', 'netflix']]}
# 960
# {'user_name': 'user960', 'brands': ['mahindra', 'fluor', 'citigroup', 'hp'], 'competitors': [["mcdoland's", 'walmart'], ['nvidia', 'pubg', 'netflix', 'pepsi', 'abb'], ['johnson', 'vinci', 'nippon', 'xiaomi'], ['coca-cola', "mcdoland's", 'airtel', 'sony']]}
# 961
# {'user_name': 'user961', 'brands': ['avnet', 'paypal', 'nestle', 'facebook', 'netflix'], 'competitors': [['puma'], ['amr', 'fluor', 'facebook', 'ibm'], ['jpmorgan'], ['danaher', 'cosmo', 'walmart'], ['cisco', 'philip', 'disney']]}
# 962
# {'user_name': 'user962', 'brands': ['ford', 'tencent', 'sodexo', 'staples', 'johnson', 'american express'], 'competitors': [['avnet', 'tesla'], ['acs'], ['amr', 'oracle', 'at&t'], ['ford', 'samsung', 'vmware', 'vadafone'], ['amazon'], ['comcast', 'lg', 'vadafone', 'at&t']]}
# 963
# {'user_name': 'user963', 'brands': ['woodland', 'avnet', 'rbc', 'paypal'], 'competitors': [['ibm', 'aegon', 'samsung', 'citigroup', 'capgemini'], ['philip', 'tesla', 'bmw'], ['intel'], ['loreal']]}
# 964
# {'user_name': 'user964', 'brands': ['fedEx', 'wistron', 'vadafone', 'loreal', 'tencent'], 'competitors': [['philip', 'crh', 'sony'], ['nike', 'xiaomi', 'tesco', 'tencent'], ['johnson'], ['american express', 'cisco'], ['loreal', 'vinci', 'alphabet']]}
# 965
# {'user_name': 'user965', 'brands': ['pubg', 'pepsi', 'mahindra', 'target', 'microsoft', 'facebook'], 'competitors': [['ibm'], ['amazon', 'mastercard'], ['johnson', 'nvidia'], ['sony'], ['visa', 'canon', 'hitachi', 'vinci', 'accenture'], ['sony', 'capgemini']]}
# 966
# {'user_name': 'user966', 'brands': ['panasonic', 'philip', 'qualcomm', 'paypal'], 'competitors': [['maruhan', 'sodexo', 'amazon', 'intel', 'cisco'], ['bmw', 'toyota', 'salesforce', 'starbucks'], ['infosys', 'lg'], ['comcast', 'american express', 'apple', 'nestle']]}
# 967
# {'user_name': 'user967', 'brands': ['ebay', 'hyundai', 'ford', 'merceds', 'nvidia'], 'competitors': [['wistron', 'fluor'], ['netflix', 'ibm', 'renault', 'maybank'], ['walmart'], ['nestle', 'cisco'], ['icici', 'sony', 'sodexo']]}
# 968
# {'user_name': 'user968', 'brands': ['bmw', 'wistron', 'oracle', 'woodland', 'barclays', 'vinci'], 'competitors': [['puma', 'hdfc'], ['fluor', 'alibaba', 'pubg'], ['infosys'], ['nike'], ['sodexo', 'american express'], ['johnson', 'staples', 'acs']]}
# 969
# {'user_name': 'user969', 'brands': ['xiaomi', 'volkswagen', 'reliance', 'vmware'], 'competitors': [['nokia', 'pubg', 'bmw', 'tencent'], ['pubg'], ['hitachi', 'avnet', 'maruhan', 'qualcomm'], None]}
# 970
# {'user_name': 'user970', 'brands': ['visa', 'mahindra', 'wistron', 'hyundai', 'woodland'], 'competitors': [['johnson', 'hdfc', 'reliance', 'samsung', 'lg'], ['microsoft', 'icici', 'cisco'], ['qualcomm', 'nike', 'canon', 'renault'], ['facebook', 'paypal', 'salesforce'], ['facebook']]}
# 971
# {'user_name': 'user971', 'brands': ['toyota', 'pepsi', 'accenture', 'at&t', 'siemens', 'maruhan'], 'competitors': [['capgemini'], ['apple'], ['maybank', 'avnet'], ['nike', 'woodland', 'xiaomi'], ['lg'], ['icbc', 'nippon', 'apple', 'philip', 'visa']]}
# 972
# {'user_name': 'user972', 'brands': ['accenture', 'siemens', 'intel', 'acs'], 'competitors': [['tesla', 'apple', 'oracle'], ['tesco'], ['xiaomi', 'merceds', 'visa', 'rbc'], ['addidas', 'icici', "mcdoland's", 'comcast', 'pepsi']]}
# 973
# {'user_name': 'user973', 'brands': ['disney', "mcdoland's", 'onex', 'rbc', 'citigroup'], 'competitors': [['icbc', 'sodexo', 'oracle'], ['hyundai', 'woodland', 'starbucks', 'sap'], ['abb', 'woodland', 'sap'], ['airtel'], ['tesla', 'nestle', 'coca-cola', 'vadafone']]}
# 974
# {'user_name': 'user974', 'brands': ['airtel', 'salesforce', 'comcast', 'amazon', 'nokia', 'panasonic'], 'competitors': [['qualcomn', 'nike', 'american express', 'hyundai', 'vadafone'], ['danaher', 'maruhan', 'renault', 'icici', 'avnet'], ['qualcomn', 'nvidia', 'loreal', 'walmart', 'alibaba'], ['alibaba', 'ebay', 'american express', 'salesforce'], ['onex', 'netflix', 'aegon', 'siemens'], ['avnet']]}
# 975
# {'user_name': 'user975', 'brands': ['ford', 'crh', 'target', 'nvidia'], 'competitors': [['ibm', 'at&t', 'philip', 'salesforce'], ['staples', 'alibaba', 'xiaomi', 'vinci', 'accenture'], ['super dry', 'barclays', 'comcast', 'nike', 'samsung'], ['johnson']]}
# 976
# {'user_name': 'user976', 'brands': ['tcs', 'walmart', 'cisco', 'disney', 'ebay'], 'competitors': [['mahindra', 'sap', 'woodland', 'visa'], ['nippon', 'infosys'], ['tesla', "mcdoland's", 'volkswagen', 'woodland', 'tencent'], ['apple', 'vmware', 'samsung', 'walmart', 'fedEx'], ['ibm']]}
# 977
# {'user_name': 'user977', 'brands': ['super dry', 'alibaba', 'airtel', 'wipro', 'amr', 'cisco'], 'competitors': [['aegon', 'walmart'], ['siemens'], ['infosys', 'sony', 'vadafone', 'sap'], ['comcast', 'starbucks', 'siemens'], ['danone', 'mahindra', 'cosmo', 'maybank'], ['at&t', 'infosys', 'vadafone']]}
# 978
# {'user_name': 'user978', 'brands': ['cosmo', 'hitachi', 'tencent', 'microsoft'], 'competitors': [['accenture', 'woodland', 'at&t', 'addidas', 'lg'], ['lg', 'abb'], ['tcs', 'toyota'], ['johnson', 'hdfc']]}
# 979
# {'user_name': 'user979', 'brands': ['abb', 'metlife', 'tesla', 'apple', 'reliance'], 'competitors': [['reliance', 'sony', 'johnson', 'salesforce', 'cosmo'], ['acs', 'netflix', 'paypal'], ['johnson', 'merceds', 'qualcomn', 'abb', 'nestle'], ['johnson', 'tesco', 'barclays'], ['bmw', 'qualcomm', 'comcast', 'addidas']]}
# 980
# {'user_name': 'user980', 'brands': ['vinci', 'sodexo', 'philip', 'panasonic', 'acs', 'american express'], 'competitors': [['mahindra', 'nike'], ['sony'], ['maybank', 'panasonic'], ['icici', 'metlife', 'pepsi', 'xiaomi', 'toyota'], ['icici'], ['fedEx', 'nokia', 'nippon', 'panasonic']]}
# 981
# {'user_name': 'user981', 'brands': ["mcdoland's", 'johnson', 'metlife', 'addidas'], 'competitors': [['coca-cola', 'alphabet', 'nippon', 'vadafone', 'vinci'], ['ibm'], ['acs', 'rbc'], ['puma']]}
# 982
# {'user_name': 'user982', 'brands': ['philip', 'disney', 'netflix', 'volkswagen', 'reliance'], 'competitors': [["mcdoland's", 'danaher', 'xiaomi'], ['accenture'], ['salesforce', 'tencent', 'barclays', 'johnson'], ['caterpillar', 'sap'], ['infosys', 'crh']]}
# 983
# {'user_name': 'user983', 'brands': ['tcs', 'tencent', 'maruhan', 'at&t', 'hitachi', 'fluor'], 'competitors': [['walmart', 'toyota', 'vmware', 'barclays', 'alibaba'], ['pepsi', "mcdoland's", 'infosys'], ['nestle', 'johnson', 'wistron', 'nippon'], ['nvidia', 'amazon', 'renault', 'tesla'], ['comcast', 'nippon', 'hyundai'], ['hdfc']]}
# 984
# {'user_name': 'user984', 'brands': ['american express', "mcdoland's", 'maybank', 'wipro'], 'competitors': [['vinci', 'amr', 'mastercard', 'walmart'], ['woodland', 'amazon', 'nestle'], ['ibm', 'tcs', 'vinci'], ['hdfc', 'woodland', 'danone', 'panasonic']]}
# 985
# {'user_name': 'user985', 'brands': ['visa', 'rbc', 'caterpillar', 'ebay', 'merceds'], 'competitors': [['maybank', 'icici', 'onex'], ['vadafone', 'samsung'], ['nokia', 'salesforce', 'nestle', 'qualcomn'], ['icici', 'crh', 'sony', 'xiaomi'], ['hyundai', 'johnson', 'samsung']]}
# 986
# {'user_name': 'user986', 'brands': ['microsoft', 'lg', 'sap', 'amazon', 'wipro', 'tencent'], 'competitors': [['amazon', 'ibm'], ['sodexo'], ['salesforce'], ['paypal', 'ebay', 'pubg'], ['barclays', 'caterpillar', 'sony'], ['siemens', 'icbc', 'hp', 'visa', 'citigroup']]}
# 987
# {'user_name': 'user987', 'brands': ['apple', 'citigroup', 'target', 'canon'], 'competitors': [['mastercard', 'philip'], ['netflix', 'nestle', 'jpmorgan'], ['acs', 'reliance'], ['vinci']]}
# 988
# {'user_name': 'user988', 'brands': ['mahindra', 'Adobe', 'super dry', 'siemens', 'sony'], 'competitors': [['sony', 'avnet', 'american express'], ['icici'], ['apple', 'canon', 'nike', 'intel', 'vmware'], ['aegon'], ['icbc', 'nike']]}
# 989
# {'user_name': 'user989', 'brands': ['wipro', "mcdoland's", 'renault', 'coca-cola', 'target', 'salesforce'], 'competitors': [['danone', 'mastercard', 'reliance'], ['qualcomn', 'cisco', 'barclays', 'cosmo', 'Adobe'], ['citigroup'], ['infosys'], ['rbc', 'aegon', 'pepsi', 'comcast', 'lg'], ['visa', 'tencent', 'puma', 'danaher', 'nestle']]}
# 990
# {'user_name': 'user990', 'brands': ['qualcomn', 'at&t', 'fedEx', 'avnet'], 'competitors': [['netflix', 'icbc'], ['tcs', 'comcast', 'infosys', 'barclays', 'loreal'], ['canon', 'vmware', 'caterpillar'], ['hdfc', 'onex', 'rbc', 'salesforce', 'ebay']]}
# 991
# {'user_name': 'user991', 'brands': ['metlife', 'panasonic', 'hitachi', 'netflix', 'toyota'], 'competitors': [['intel', 'volkswagen', 'airtel'], ['paypal', 'coca-cola', 'onex', 'abb', 'fedEx'], ['xiaomi', 'starbucks'], ['danaher', 'onex', 'comcast'], ['tesco', 'metlife', 'vmware', 'starbucks', 'comcast']]}
# 992
# {'user_name': 'user992', 'brands': ['target', 'tesla', 'nvidia', 'merceds', 'airtel', 'at&t'], 'competitors': [['philip', 'vinci', 'cisco'], ['toyota', 'facebook', 'starbucks', 'walmart', 'caterpillar'], None, ['amazon', 'hdfc'], ['rbc', 'visa'], ['american express']]}
# 993
# {'user_name': 'user993', 'brands': ['nvidia', 'sony', 'nike', 'rbc'], 'competitors': [['volkswagen', 'accenture', 'jpmorgan'], ['xiaomi', 'metlife', "mcdoland's"], ['accenture', 'american express'], ['staples', 'siemens', 'barclays', 'american express', 'citigroup']]}
# 994
# {'user_name': 'user994', 'brands': ['hitachi', 'danaher', 'accenture', 'puma', 'ebay'], 'competitors': [['vinci', 'bmw'], ['super dry', 'onex'], ['johnson'], ['super dry', 'nokia', 'aegon'], ['avnet']]}
# 995
# {'user_name': 'user995', 'brands': ['ford', 'super dry', 'nippon', 'tesla', 'target', 'lg'], 'competitors': [['nippon', 'volkswagen'], ['caterpillar', 'icici', 'pubg', 'facebook'], ['pubg'], ['alibaba'], ['pubg'], ['netflix']]}
# 996
# {'user_name': 'user996', 'brands': ['woodland', 'salesforce', 'pepsi', 'target'], 'competitors': [['xiaomi', 'siemens', 'hdfc', 'paypal'], ['merceds', 'icici', 'capgemini', 'intel', 'bmw'], ['nippon', 'vinci', 'coca-cola', 'target', 'netflix'], ['tcs', 'comcast', 'wipro', 'hyundai', 'citigroup']]}
# 997
# {'user_name': 'user997', 'brands': ['capgemini', 'maybank', 'amazon', 'icici', 'addidas'], 'competitors': [['xiaomi', 'alphabet', 'pepsi', 'caterpillar'], ['johnson', 'loreal'], ['danaher', 'salesforce'], ['airtel', 'cosmo', 'citigroup'], ['icbc', 'hdfc', 'alibaba']]}
# 998
# {'user_name': 'user998', 'brands': ['oracle', 'microsoft', 'maybank', 'cosmo', 'Adobe', 'philip'], 'competitors': [['caterpillar', 'apple'], ['vinci', 'starbucks'], ['facebook', 'hdfc', 'alphabet', 'vadafone'], ['hdfc', 'alibaba', 'panasonic', 'amr', 'merceds'], ['amazon', 'alphabet', 'visa', 'tesla'], ['target']]}
# 999
# {'user_name': 'user999', 'brands': ['sap', 'comcast', 'Adobe', 'visa'], 'competitors': [['addidas', 'vadafone', 'toyota', 'acs'], ['cisco'], ['target', 'american express', 'nokia'], ['mastercard']]}
# 1000
# {'user_name': 'user1000', 'brands': ['toyota', 'puma', 'salesforce', 'target', 'siemens'], 'competitors': [['maruhan', 'visa', 'danone'], ['alibaba', 'woodland', 'amr', 'nvidia'], ['tcs', 'mastercard', 'samsung', 'infosys'], ['rbc', 'apple'], ['johnson', 'aegon', 'reliance', 'intel', 'vadafone']]}

# %%
for i in output_:
    print(i['brands'])
# Out:
# ['aegon', 'fluor', 'crh', 'nvidia', 'hdfc']
# ['super dry', 'merceds', 'at&t', 'capgemini', 'coca-cola', 'onex']
# ['danone', 'visa', 'nike', 'toyota']
# ['hitachi', 'sap', 'acs', 'infosys', 'accenture']
# ['tencent', 'avnet', 'woodland', 'super dry', 'target', 'caterpillar']
# ['accenture', 'caterpillar', 'siemens', 'ibm']
# ['qualcomn', 'salesforce', 'citigroup', 'tencent', 'tesco']
# ['netflix', 'metlife', 'volkswagen', 'danaher', 'citigroup', 'visa']
# ['nippon', 'salesforce', 'aegon', 'johnson']
# ['philip', 'maruhan', 'Adobe', 'icici', 'vadafone']
# ['paypal', 'toyota', 'fluor', 'tencent', 'renault', 'samsung']
# ['abb', 'rbc', 'capgemini', 'danaher']
# ['microsoft', 'vadafone', 'qualcomn', 'disney', 'nokia']
# ['disney', 'woodland', 'caterpillar', 'starbucks', 'cisco', 'rbc']
# ['amazon', 'cosmo', 'vmware', 'microsoft']
# ['barclays', 'cisco', 'hdfc', 'ford', 'staples']
# ['oracle', 'caterpillar', 'hdfc', 'fluor', 'target', 'lg']
# ['addidas', 'tencent', "mcdoland's", 'renault']
# ['nestle', 'citigroup', 'johnson', 'microsoft', 'disney']
# ['volkswagen', 'aegon', 'super dry', 'airtel', 'maruhan', 'merceds']
# ['starbucks', 'sap', 'jpmorgan', 'hdfc']
# ['panasonic', 'caterpillar', 'hdfc', 'woodland', 'facebook']
# ['super dry', 'facebook', 'merceds', "mcdoland's", 'johnson', 'cosmo']
# ['fluor', 'capgemini', 'pubg', 'citigroup']
# ['philip', 'hp', 'volkswagen', 'citigroup', 'danone']
# ['wipro', 'at&t', 'icici', 'nokia', 'starbucks', 'qualcomm']
# ['puma', 'avnet', 'cisco', 'loreal']
# ['visa', 'nokia', 'loreal', 'icici', 'alphabet']
# ['visa', 'super dry', 'infosys', 'pubg', 'facebook', 'salesforce']
# ['american express', 'panasonic', 'airtel', 'hyundai']
# ['alphabet', 'netflix', 'sodexo', 'target', 'xiaomi']
# ['avnet', 'hp', 'woodland', 'danone', 'crh', 'panasonic']
# ['accenture', 'woodland', 'puma', 'icici']
# ['danaher', 'pubg', 'accenture', 'netflix', 'visa']
# ['pubg', 'avnet', 'sony', 'super dry', 'comcast', 'samsung']
# ['airtel', 'merceds', 'icici', 'bmw']
# ['disney', 'american express', 'puma', 'ibm', 'hyundai']
# ['alphabet', 'merceds', 'airtel', 'caterpillar', 'Adobe', 'infosys']
# ['at&t', 'amr', 'vinci', 'disney']
# ['vadafone', 'metlife', "mcdoland's", 'puma', 'paypal']
# ['hdfc', 'danaher', 'jpmorgan', 'cosmo', 'icici', 'pubg']
# ['philip', 'tesla', 'avnet', 'super dry']
# ['crh', 'capgemini', 'ford', 'caterpillar', 'hp']
# ['wipro', 'aegon', 'nike', 'acs', 'nippon', 'nestle']
# ['sony', 'tcs', 'philip', 'intel']
# ['wipro', 'starbucks', 'amazon', 'johnson', 'mahindra']
# ['tesco', 'panasonic', 'ford', 'comcast', 'woodland', 'infosys']
# ['comcast', 'wipro', 'woodland', 'icbc']
# ['nokia', 'onex', 'mastercard', 'icbc', 'wipro']
# ['toyota', 'icbc', 'wistron', 'super dry', 'loreal', 'barclays']
# ['aegon', 'Adobe', 'mahindra', 'ibm']
# ['acs', 'mastercard', 'puma', 'aegon', 'capgemini']
# ['ford', 'johnson', 'alphabet', 'danaher', 'apple', 'cosmo']
# ['Adobe', 'nokia', 'starbucks', 'samsung']
# ['capgemini', 'reliance', 'mastercard', 'coca-cola', 'maybank']
# ['intel', 'fedEx', 'rbc', 'accenture', 'volkswagen', 'at&t']
# ['Adobe', 'mastercard', 'loreal', 'vadafone']
# ['coca-cola', 'at&t', 'airtel', 'barclays', 'staples']
# ['nippon', 'staples', 'metlife', 'walmart', 'sodexo', 'philip']
# ['pubg', 'reliance', 'volkswagen', 'mastercard']
# ['sony', 'cosmo', 'coca-cola', 'citigroup', 'comcast']
# ['target', 'nvidia', 'intel', 'mahindra', 'tencent', 'nike']
# ['maybank', 'sap', 'accenture', 'johnson']
# ['vadafone', 'hyundai', 'apple', 'wistron', 'coca-cola']
# ['fluor', 'avnet', 'starbucks', 'jpmorgan', 'fedEx', 'alibaba']
# ['panasonic', 'infosys', 'at&t', 'microsoft']
# ['barclays', 'woodland', 'maruhan', 'crh', 'vmware']
# ['ibm', 'johnson', 'pubg', 'cosmo', 'philip', 'nike']
# ['rbc', 'vadafone', 'metlife', 'citigroup']
# ['fedEx', 'apple', 'maruhan', 'qualcomn', 'ibm']
# ['salesforce', 'facebook', 'danone', 'cosmo', 'addidas', 'staples']
# ['sodexo', 'acs', 'sap', 'rbc']
# ["mcdoland's", 'salesforce', 'xiaomi', 'merceds', 'hyundai']
# ['vinci', 'woodland', 'icici', 'tesco', 'qualcomn', 'alibaba']
# ['mastercard', 'volkswagen', 'pepsi', 'tcs']
# ['hp', 'nvidia', 'nestle', 'capgemini', 'cisco']
# ['samsung', 'coca-cola', 'mahindra', 'capgemini', 'citigroup', 'pubg']
# ['wipro', 'coca-cola', 'fedEx', 'accenture']
# ['wistron', 'crh', 'amr', 'amazon', 'walmart']
# ['volkswagen', 'pubg', 'fluor', 'amr', 'nokia', 'nvidia']
# ['alphabet', 'disney', 'sony', 'oracle']
# ['merceds', 'danone', 'intel', 'starbucks', 'nippon']
# ['nippon', 'woodland', 'target', 'volkswagen', 'metlife', 'airtel']
# ['vadafone', 'amr', 'fedEx', 'visa']
# ['danaher', 'vadafone', 'caterpillar', 'mahindra', 'comcast']
# ['super dry', 'nippon', 'tesco', 'pepsi', 'paypal', 'visa']
# ['siemens', 'puma', 'amazon', 'woodland']
# ['mahindra', 'hitachi', 'target', 'walmart', 'renault']
# ['danone', 'bmw', 'paypal', 'renault', 'fluor', 'qualcomm']
# ['wistron', 'loreal', 'mastercard', 'pubg']
# ['fedEx', 'abb', 'nestle', 'alibaba', 'vadafone']
# ['volkswagen', 'tesla', 'xiaomi', 'loreal', 'wipro', 'bmw']
# ['at&t', 'danaher', 'loreal', 'avnet']
# ['target', 'amr', 'nokia', 'accenture', "mcdoland's"]
# ['maybank', 'tesla', 'icbc', 'cisco', 'johnson', 'onex']
# ['danaher', 'comcast', 'vinci', 'sodexo']
# ['addidas', 'siemens', 'tesco', 'hyundai', 'cosmo']
# ['aegon', 'toyota', 'oracle', 'hdfc', 'canon', 'apple']
# ['vmware', 'crh', 'infosys', 'salesforce']
# ['xiaomi', 'nippon', 'jpmorgan', 'comcast', 'sodexo']
# ['toyota', 'hyundai', 'qualcomn', 'disney', 'rbc', 'reliance']
# ['woodland', 'cisco', 'visa', 'hitachi']
# ['Adobe', 'toyota', 'caterpillar', 'fedEx', 'qualcomm']
# ['Adobe', 'intel', 'comcast', 'hyundai', 'at&t', 'rbc']
# ['intel', 'canon', 'hdfc', 'abb']
# ['alphabet', 'sodexo', 'vmware', 'metlife', 'accenture']
# ['volkswagen', 'hitachi', 'at&t', 'acs', 'tcs', 'canon']
# ['hdfc', 'tencent', 'icici', 'renault']
# ['coca-cola', 'disney', 'comcast', 'apple', 'sodexo']
# ['merceds', 'tesco', 'johnson', 'staples', 'intel', 'infosys']
# ['aegon', 'acs', 'samsung', 'Adobe']
# ['puma', 'infosys', 'alphabet', 'salesforce', 'nestle']
# ['hdfc', 'onex', 'sodexo', 'fedEx', 'vmware', 'citigroup']
# ['aegon', 'onex', 'panasonic', 'pubg']
# ['capgemini', 'visa', 'panasonic', 'apple', "mcdoland's"]
# ['nike', 'acs', 'mahindra', 'puma', 'alphabet', 'wipro']
# ['fluor', 'johnson', 'aegon', 'woodland']
# ['rbc', 'mahindra', 'nike', 'bmw', 'reliance']
# ['crh', 'sodexo', 'lg', 'comcast', 'qualcomn', 'target']
# ['paypal', 'ibm', 'abb', 'vadafone']
# ['facebook', 'hitachi', 'target', 'super dry', 'woodland']
# ['target', 'avnet', 'qualcomm', 'hp', 'sap', 'amazon']
# ['accenture', 'Adobe', 'mahindra', 'ebay']
# ['american express', 'oracle', 'johnson', 'visa', 'tencent']
# ['rbc', 'coca-cola', 'tencent', 'sap', 'tesco', 'ebay']
# ['infosys', 'mastercard', 'nestle', 'wipro']
# ['vmware', 'citigroup', 'icbc', 'ebay', 'puma']
# ['salesforce', 'sodexo', 'nvidia', 'nestle', 'accenture', 'nippon']
# ['woodland', 'nokia', 'danone', 'infosys']
# ['netflix', 'maruhan', 'amazon', 'johnson', 'amr']
# ['cosmo', 'capgemini', 'tencent', 'merceds', 'panasonic', 'infosys']
# ['icici', 'tencent', 'netflix', 'barclays']
# ['nestle', 'nippon', 'metlife', 'addidas', 'staples']
# ['staples', 'super dry', 'johnson', 'jpmorgan', 'starbucks', 'mastercard']
# ['hdfc', 'alibaba', 'hp', 'vadafone']
# ['nvidia', 'qualcomn', 'acs', 'target', 'citigroup']
# ['cisco', 'starbucks', 'accenture', 'american express', 'loreal', 'oracle']
# ['starbucks', 'aegon', 'volkswagen', 'nokia']
# ['amazon', 'rbc', 'sap', 'aegon', 'icbc']
# ['barclays', 'american express', 'volkswagen', 'puma', 'maybank', 'paypal']
# ['tesco', 'hdfc', 'philip', 'jpmorgan']
# ['volkswagen', 'coca-cola', 'hitachi', 'samsung', 'oracle']
# ['tencent', 'sap', 'vinci', 'intel', 'puma', 'tesco']
# ['crh', 'disney', 'sap', 'vinci']
# ['qualcomn', 'puma', 'canon', 'tesco', 'citigroup']
# ['ibm', 'vinci', 'johnson', 'fluor', 'tencent', 'tcs']
# ['vinci', 'ford', 'nvidia', 'intel']
# ['starbucks', 'hitachi', 'netflix', 'cisco', 'woodland']
# ['fluor', 'acs', 'citigroup', 'caterpillar', 'qualcomn', 'microsoft']
# ['intel', 'philip', 'comcast', 'oracle']
# ['citigroup', 'panasonic', 'puma', 'ebay', 'nestle']
# ['vadafone', 'apple', 'paypal', 'sap', 'comcast', 'xiaomi']
# ['sap', 'capgemini', 'cisco', 'microsoft']
# ['tcs', 'staples', 'maruhan', 'amazon', 'rbc']
# ['mastercard', 'sap', 'philip', 'alibaba', 'woodland', 'Adobe']
# ['qualcomn', 'pepsi', 'acs', 'intel']
# ['canon', 'hp', 'intel', 'vinci', 'capgemini']
# ['hp', 'airtel', 'caterpillar', 'merceds', 'mastercard', 'siemens']
# ['avnet', 'woodland', 'lg', 'vmware']
# ['nvidia', 'ford', 'abb', 'nike', 'fluor']
# ['icbc', 'qualcomn', 'cosmo', 'alibaba', 'Adobe', 'avnet']
# ['icbc', 'apple', 'intel', 'merceds']
# ['citigroup', 'apple', 'infosys', 'merceds', 'ebay']
# ['salesforce', 'vmware', 'disney', 'infosys', 'barclays', 'nike']
# ['intel', 'comcast', 'siemens', 'nike']
# ['vmware', 'pepsi', 'coca-cola', 'ford', 'maybank']
# ['bmw', 'toyota', 'amazon', 'ebay', 'puma', 'lg']
# ['capgemini', 'rbc', 'ibm', 'tcs']
# ['sodexo', 'ford', 'samsung', 'facebook', 'nike']
# ['target', 'amazon', 'samsung', 'airtel', 'super dry', 'nokia']
# ['abb', 'avnet', 'caterpillar', 'puma']
# ['apple', 'hdfc', 'samsung', 'disney', 'abb']
# ['loreal', 'Adobe', 'bmw', 'nestle', 'facebook', 'reliance']
# ['target', 'fluor', 'citigroup', 'woodland']
# ['barclays', 'apple', 'crh', 'Adobe', 'danaher']
# ['nike', 'coca-cola', 'renault', 'barclays', 'qualcomn', 'onex']
# ['ford', 'cisco', 'airtel', 'philip']
# ['acs', 'coca-cola', 'reliance', 'cosmo', 'woodland']
# ['paypal', 'renault', 'infosys', 'alibaba', 'staples', 'qualcomm']
# ['starbucks', 'hdfc', 'hyundai', 'vadafone']
# ['vinci', 'bmw', 'sony', 'danone', 'hp']
# ['icici', 'infosys', 'airtel', 'visa', 'walmart', 'nippon']
# ['abb', 'ebay', 'addidas', 'siemens']
# ['mastercard', 'panasonic', 'nippon', 'siemens', 'qualcomm']
# ['sap', 'maruhan', 'lg', 'fedEx', 'super dry', 'Adobe']
# ['nestle', 'facebook', 'onex', 'merceds']
# ['puma', 'hdfc', 'qualcomn', 'aegon', 'philip']
# ['super dry', 'vmware', 'tesco', 'microsoft', 'philip', 'jpmorgan']
# ['nippon', 'danaher', 'ibm', 'pubg']
# ['wipro', 'staples', 'fedEx', 'airtel', 'onex']
# ['capgemini', 'cosmo', 'hdfc', 'airtel', 'merceds', 'ford']
# ['pepsi', 'at&t', 'reliance', 'siemens']
# ['sap', 'american express', 'philip', 'cosmo', 'nike']
# ['philip', 'hitachi', 'starbucks', 'caterpillar', 'cisco', 'tesla']
# ['rbc', 'Adobe', 'at&t', 'merceds']
# ['nippon', 'siemens', 'tcs', "mcdoland's", 'caterpillar']
# ['cosmo', 'ebay', 'sony', 'rbc', 'xiaomi', 'hitachi']
# ['vadafone', 'hitachi', 'infosys', 'mahindra']
# ['facebook', 'tesco', 'disney', 'jpmorgan', 'super dry']
# ['hitachi', 'mahindra', 'staples', 'infosys', 'metlife', 'ebay']
# ['starbucks', 'pepsi', 'pubg', 'super dry']
# ['qualcomn', 'salesforce', 'cisco', 'nippon', 'capgemini']
# ['addidas', 'nokia', 'bmw', 'nike', 'super dry', 'ford']
# ['danaher', 'tencent', 'wipro', 'reliance']
# ['rbc', 'ibm', 'hyundai', 'paypal', 'tesla']
# ['oracle', 'Adobe', 'american express', 'starbucks', 'tcs', 'woodland']
# ['rbc', 'icbc', 'sodexo', 'danone']
# ['intel', 'sap', 'icici', 'nvidia', 'onex']
# ['tesla', 'lg', 'qualcomm', "mcdoland's", 'crh', 'qualcomn']
# ['ibm', 'apple', 'wipro', 'caterpillar']
# ['hdfc', 'metlife', 'coca-cola', 'xiaomi', 'staples']
# ['sony', 'nokia', 'cisco', 'ibm', 'canon', 'ebay']
# ['samsung', 'super dry', 'ibm', 'vmware']
# ['tesco', 'barclays', 'onex', 'philip', 'jpmorgan']
# ['starbucks', 'maybank', 'ebay', 'rbc', 'cosmo', 'hyundai']
# ['canon', 'crh', 'icbc', 'airtel']
# ['nvidia', 'target', 'pepsi', 'mastercard', 'infosys']
# ['icbc', 'ibm', 'jpmorgan', 'loreal', 'oracle', 'maruhan']
# ['addidas', 'tencent', 'puma', 'airtel']
# ['vmware', 'apple', 'pubg', 'icici', 'pepsi']
# ['apple', 'icbc', 'philip', 'ibm', 'mastercard', 'alibaba']
# ['mahindra', 'puma', 'paypal', 'tcs']
# ['ibm', 'citigroup', 'amazon', 'wipro', 'reliance']
# ['amr', 'starbucks', 'tesla', 'sodexo', 'toyota', 'canon']
# ['american express', 'Adobe', 'panasonic', 'walmart']
# ['super dry', 'sony', 'danone', 'walmart', 'alibaba']
# ['tencent', 'walmart', 'microsoft', 'crh', 'citigroup', 'mastercard']
# ['hp', 'citigroup', 'danaher', 'toyota']
# ['airtel', 'vmware', 'qualcomn', 'walmart', 'intel']
# ['loreal', 'nokia', 'volkswagen', 'philip', 'microsoft', 'abb']
# ['siemens', 'pubg', 'nokia', 'wipro']
# ['tesla', 'panasonic', 'oracle', 'siemens', 'renault']
# ['cosmo', 'staples', 'danone', 'merceds', 'addidas', 'Adobe']
# ['vadafone', 'sap', 'vmware', 'panasonic']
# ['visa', 'wistron', 'Adobe', 'intel', 'rbc']
# ['caterpillar', 'ford', 'amazon', 'johnson', 'pubg', 'netflix']
# ["mcdoland's", 'mahindra', 'reliance', 'lg']
# ['citigroup', 'nippon', 'mastercard', 'alibaba', 'acs']
# ['xiaomi', 'alphabet', 'hdfc', 'starbucks', 'maruhan', 'lg']
# ['addidas', 'amazon', 'toyota', 'siemens']
# ['maruhan', 'avnet', 'jpmorgan', 'philip', 'reliance']
# ['nokia', 'microsoft', 'pepsi', 'caterpillar', 'cisco', 'canon']
# ['woodland', 'facebook', 'nike', 'ebay']
# ['samsung', 'mahindra', 'puma', 'tcs', 'volkswagen']
# ['super dry', 'philip', 'intel', 'pubg', 'coca-cola', 'aegon']
# ['ford', 'loreal', 'facebook', 'addidas']
# ['reliance', 'metlife', 'tcs', 'intel', 'hitachi']
# ['tcs', 'nippon', 'mahindra', 'reliance', 'addidas', 'nestle']
# ['nike', 'sodexo', 'pubg', 'barclays']
# ['nestle', 'hp', 'nippon', 'ibm', 'renault']
# ['qualcomn', 'crh', 'johnson', 'merceds', 'nestle', 'mahindra']
# ['puma', 'reliance', 'target', 'johnson']
# ['wipro', 'panasonic', 'hp', 'cisco', 'amr']
# ['woodland', 'maruhan', 'crh', 'abb', 'oracle', 'amazon']
# ['maybank', 'tesco', 'qualcomm', 'vmware']
# ['loreal', 'nike', 'coca-cola', 'qualcomn', 'hitachi']
# ['puma', 'qualcomm', 'pubg', 'maruhan', 'tesla', 'addidas']
# ['addidas', 'ford', 'apple', 'acs']
# ['tesla', 'philip', 'renault', 'netflix', 'target']
# ['loreal', 'tencent', 'johnson', 'crh', 'onex', 'jpmorgan']
# ['wistron', 'microsoft', 'nvidia', 'maybank']
# ['fluor', 'facebook', 'mahindra', 'nokia', 'staples']
# ['xiaomi', 'philip', 'mahindra', 'nvidia', 'abb', 'disney']
# ['apple', 'sony', 'starbucks', 'pubg']
# ['maybank', 'citigroup', 'ford', 'vinci', 'rbc']
# ['woodland', 'wipro', 'merceds', 'icbc', 'accenture', 'samsung']
# ['avnet', 'salesforce', 'capgemini', 'nike']
# ['hp', 'renault', 'avnet', 'citigroup', 'tesla']
# ['johnson', 'visa', 'abb', 'tcs', 'mastercard', 'hyundai']
# ['ebay', 'cisco', 'intel', 'oracle']
# ['super dry', 'pepsi', 'hitachi', 'target', 'alibaba']
# ["mcdoland's", 'hyundai', 'nike', 'staples', 'ibm', 'siemens']
# ['loreal', 'paypal', 'reliance', 'infosys']
# ['airtel', 'toyota', 'cisco', 'panasonic', 'loreal']
# ['danone', 'panasonic', 'reliance', 'fedEx', 'rbc', 'tcs']
# ['cosmo', 'acs', 'caterpillar', 'lg']
# ['metlife', 'abb', 'loreal', 'starbucks', 'hyundai']
# ['cisco', 'icbc', 'maybank', 'toyota', 'nestle', 'facebook']
# ['qualcomm', 'oracle', 'airtel', 'addidas']
# ['Adobe', 'acs', 'hp', 'cosmo', 'walmart']
# ['volkswagen', 'paypal', 'ford', 'onex', 'metlife', 'caterpillar']
# ['bmw', 'avnet', 'mahindra', 'johnson']
# ['capgemini', 'panasonic', 'crh', 'metlife', 'paypal']
# ['merceds', 'hdfc', 'qualcomn', 'starbucks', 'visa', 'lg']
# ['hp', 'alphabet', 'vadafone', 'hyundai']
# ['acs', 'maruhan', 'nestle', 'nippon', "mcdoland's"]
# ['nestle', 'onex', 'Adobe', 'addidas', 'johnson', 'facebook']
# ['amazon', 'citigroup', 'hdfc', "mcdoland's"]
# ['amr', 'onex', 'toyota', 'Adobe', 'pepsi']
# ['hp', "mcdoland's", 'cisco', 'fluor', 'crh', 'icbc']
# ['loreal', 'puma', 'salesforce', 'nvidia']
# ['puma', 'nike', 'hitachi', 'citigroup', 'caterpillar']
# ['philip', 'super dry', 'barclays', 'aegon', 'johnson', 'Adobe']
# ['salesforce', 'onex', 'danaher', 'hyundai']
# ['apple', 'danone', 'nokia', 'merceds', 'ford']
# ['tesla', 'aegon', 'sodexo', 'airtel', 'starbucks', 'siemens']
# ['renault', 'samsung', 'canon', 'barclays']
# ['hitachi', 'addidas', 'tcs', 'wipro', 'woodland']
# ['qualcomn', 'apple', 'oracle', 'intel', 'rbc', 'vadafone']
# ['hitachi', 'intel', 'avnet', 'toyota']
# ['merceds', 'tesco', 'at&t', 'aegon', 'accenture']
# ['rbc', 'hitachi', 'danone', 'cisco', 'cosmo', 'target']
# ['qualcomn', 'paypal', 'addidas', 'at&t']
# ['cosmo', 'avnet', 'american express', 'hdfc', 'staples']
# ['nike', 'walmart', 'barclays', 'qualcomn', 'sap', 'pubg']
# ['fedEx', 'staples', 'citigroup', 'alphabet']
# ['philip', 'samsung', 'target', 'qualcomm', 'accenture']
# ['danaher', 'at&t', 'maybank', 'walmart', 'nvidia', 'staples']
# ['aegon', 'hdfc', 'renault', 'icbc']
# ['amazon', 'comcast', 'hitachi', 'tesla', 'super dry']
# ['airtel', 'toyota', 'volkswagen', 'alibaba', 'ibm', 'addidas']
# ['pepsi', 'hdfc', 'avnet', 'nokia']
# ['wipro', 'comcast', 'airtel', 'danaher', 'maybank']
# ['intel', 'fluor', 'metlife', 'icici', 'rbc', 'oracle']
# ['danaher', 'maybank', 'salesforce', 'bmw']
# ['icici', 'vinci', 'nippon', 'Adobe', 'starbucks']
# ['wistron', 'danaher', 'metlife', 'visa', 'tesla', 'hitachi']
# ['rbc', 'tcs', 'super dry', 'caterpillar']
# ['aegon', 'avnet', 'microsoft', 'johnson', 'ford']
# ['maybank', 'ibm', 'renault', 'wipro', 'walmart', 'citigroup']
# ['nvidia', 'mastercard', 'icici', 'cosmo']
# ['lg', 'amazon', 'nike', 'ford', 'merceds']
# ['lg', 'toyota', 'tcs', 'vinci', 'super dry', 'ford']
# ['ford', 'xiaomi', 'Adobe', 'paypal']
# ['capgemini', 'danone', 'mahindra', 'fedEx', 'pubg']
# ['lg', 'metlife', 'barclays', 'oracle', 'tencent', 'walmart']
# ['american express', 'nokia', 'tesco', 'qualcomm']
# ['wipro', 'nippon', 'disney', 'tencent', 'ibm']
# ['lg', 'sodexo', 'capgemini', 'acs', 'vadafone', 'nike']
# ['addidas', 'hyundai', 'reliance', 'nokia']
# ['samsung', 'onex', 'acs', 'caterpillar', 'siemens']
# ['qualcomn', 'ibm', 'renault', 'bmw', 'nestle', 'wistron']
# ['wistron', 'pubg', 'amazon', 'abb']
# ['siemens', 'metlife', 'icici', 'mahindra', 'coca-cola']
# ['siemens', 'tesco', 'caterpillar', 'pubg', 'alphabet', 'paypal']
# ['danaher', 'aegon', 'caterpillar', 'qualcomm']
# ['tesco', 'comcast', 'netflix', 'barclays', 'danaher']
# ['tesco', 'sap', 'airtel', 'paypal', 'tcs', 'loreal']
# ['samsung', 'philip', 'acs', 'danaher']
# ['philip', 'apple', 'at&t', 'maruhan', 'hdfc']
# ['target', 'puma', 'capgemini', 'hp', 'pepsi', 'johnson']
# ['oracle', 'amazon', 'hyundai', 'netflix']
# ['pubg', 'xiaomi', 'avnet', 'hitachi', 'netflix']
# ['visa', 'sodexo', 'acs', 'siemens', 'amr', 'sap']
# ['qualcomn', 'amazon', 'woodland', 'wipro']
# ['nvidia', 'puma', 'aegon', 'qualcomn', 'lg']
# ['microsoft', 'siemens', 'amr', 'addidas', 'johnson', 'staples']
# ['xiaomi', 'puma', 'coca-cola', 'pubg']
# ['danaher', 'staples', 'xiaomi', 'microsoft', 'fluor']
# ['puma', 'onex', 'vmware', 'hitachi', 'qualcomm', 'acs']
# ['danaher', 'Adobe', 'metlife', 'intel']
# ['bmw', 'vmware', 'avnet', 'ford', 'qualcomn']
# ['merceds', 'super dry', 'microsoft', 'amr', 'airtel', 'metlife']
# ['fedEx', 'wistron', 'avnet', 'facebook']
# ['amr', 'capgemini', 'starbucks', 'disney', 'abb']
# ['siemens', 'capgemini', 'acs', 'nike', 'wistron', 'toyota']
# ['sony', 'sap', 'starbucks', 'mahindra']
# ['johnson', 'capgemini', 'sony', 'nike', 'coca-cola']
# ['nvidia', 'starbucks', 'cosmo', 'hitachi', 'addidas', 'danone']
# ['accenture', 'intel', 'facebook', 'tencent']
# ['hitachi', 'icici', 'metlife', 'starbucks', 'johnson']
# ['toyota', 'fedEx', 'nippon', 'bmw', 'samsung', 'sodexo']
# ['ebay', 'nestle', 'maybank', 'wistron']
# ['capgemini', 'oracle', 'ebay', 'toyota', 'loreal']
# ['amazon', 'citigroup', 'disney', 'aegon', 'metlife', 'fedEx']
# ['capgemini', 'caterpillar', 'oracle', 'hdfc']
# ['woodland', 'airtel', 'vadafone', 'amr', 'mahindra']
# ['tesco', 'siemens', 'lg', 'target', 'qualcomn', 'cosmo']
# ['alibaba', 'samsung', 'nvidia', 'vinci']
# ['starbucks', 'sodexo', 'loreal', 'renault', 'cosmo']
# ['ibm', 'oracle', 'maybank', 'mastercard', 'disney', 'maruhan']
# ['onex', 'american express', 'canon', 'ebay']
# ['mahindra', 'american express', 'mastercard', 'infosys', 'nestle']
# ['icici', 'puma', 'johnson', 'tencent', 'tesco', 'icbc']
# ['rbc', 'volkswagen', 'vadafone', 'woodland']
# ['hp', 'vadafone', 'philip', 'hitachi', 'nvidia']
# ['renault', 'vinci', 'sony', 'philip', 'airtel', 'merceds']
# ['renault', 'nippon', 'fedEx', 'johnson']
# ['samsung', 'cisco', 'crh', 'hdfc', 'Adobe']
# ['caterpillar', 'cisco', 'jpmorgan', 'citigroup', 'airtel', 'comcast']
# ['salesforce', 'cosmo', 'ford', "mcdoland's"]
# ['xiaomi', 'facebook', 'qualcomm', 'vmware', 'icici']
# ['hdfc', 'volkswagen', 'tencent', 'accenture', 'infosys', 'salesforce']
# ['netflix', 'intel', 'icbc', 'hp']
# ['mahindra', 'woodland', 'infosys', 'johnson', 'rbc']
# ['danaher', 'vadafone', 'onex', 'tesco', 'hyundai', 'facebook']
# ['walmart', 'intel', 'tcs', 'accenture']
# ['alibaba', 'reliance', 'hyundai', 'ibm', 'cosmo']
# ['netflix', 'tencent', 'ebay', 'onex', 'pubg', 'siemens']
# ['nippon', 'vadafone', 'ford', 'alphabet']
# ['danone', 'alibaba', 'panasonic', 'metlife', 'airtel']
# ['hitachi', 'hyundai', 'sap', 'cosmo', 'fluor', 'johnson']
# ['Adobe', 'disney', 'maruhan', 'sap']
# ['nvidia', 'avnet', 'sony', 'tencent', 'salesforce']
# ['toyota', 'sap', 'nike', 'cisco', 'nvidia', 'accenture']
# ['ibm', 'intel', 'accenture', 'icici']
# ['wistron', 'hp', 'crh', 'samsung', 'icbc']
# ['wipro', 'amr', 'bmw', 'mahindra', 'siemens', 'danaher']
# ['johnson', 'cisco', 'airtel', 'renault']
# ['at&t', 'barclays', 'tesco', 'icbc', 'accenture']
# ['coca-cola', 'amr', 'siemens', "mcdoland's", 'vmware', 'hyundai']
# ['super dry', 'mastercard', "mcdoland's", 'at&t']
# ['super dry', 'abb', 'johnson', 'nike', 'walmart']
# ['tesla', 'mastercard', 'paypal', 'accenture', 'loreal', 'hyundai']
# ['paypal', 'capgemini', 'addidas', 'facebook']
# ['nestle', 'loreal', 'hitachi', 'hyundai', 'renault']
# ['avnet', 'citigroup', 'airtel', 'salesforce', 'paypal', 'microsoft']
# ['tencent', 'staples', 'cisco', 'nestle']
# ['siemens', 'ibm', 'mahindra', 'staples', 'loreal']
# ['at&t', 'comcast', 'apple', 'avnet', "mcdoland's", 'canon']
# ['onex', 'nippon', 'nestle', 'lg']
# ['salesforce', 'tcs', 'at&t', 'hdfc', 'coca-cola']
# ['paypal', 'disney', 'apple', 'capgemini', 'amazon', 'nestle']
# ['amazon', 'cosmo', 'vinci', 'johnson']
# ['toyota', 'accenture', 'vinci', 'at&t', 'target']
# ['danone', 'hp', 'renault', 'nippon', 'citigroup', "mcdoland's"]
# ['pepsi', 'johnson', 'rbc', 'tcs']
# ['nvidia', "mcdoland's", 'amr', 'sap', 'woodland']
# ['netflix', 'mastercard', 'abb', 'hitachi', 'danaher', 'nippon']
# ['microsoft', 'philip', 'infosys', 'wistron']
# ['alphabet', 'avnet', 'staples', 'canon', 'airtel']
# ['tesla', 'mahindra', 'samsung', 'hyundai', 'nippon', 'woodland']
# ['coca-cola', 'Adobe', 'cisco', 'tesco']
# ['avnet', 'mahindra', 'coca-cola', 'rbc', 'wistron']
# ['jpmorgan', 'facebook', 'microsoft', 'onex', 'icbc', 'canon']
# ['danaher', 'icbc', 'cisco', 'sodexo']
# ['hdfc', 'nvidia', 'infosys', 'alibaba', 'sony']
# ['philip', 'airtel', 'merceds', 'starbucks', 'johnson', 'samsung']
# ['airtel', 'coca-cola', 'maybank', 'maruhan']
# ['super dry', 'addidas', 'target', 'nokia', 'pubg']
# ['onex', 'pepsi', 'airtel', 'abb', 'sony', 'sodexo']
# ['hp', 'alphabet', 'oracle', 'bmw']
# ['icbc', 'jpmorgan', 'disney', 'woodland', 'nestle']
# ['johnson', 'tcs', 'american express', 'nvidia', 'icici', 'xiaomi']
# ['netflix', 'accenture', 'mahindra', 'crh']
# ['woodland', 'pubg', 'ford', 'tcs', 'hyundai']
# ['citigroup', 'bmw', 'pubg', 'hyundai', 'danone', 'philip']
# ['sodexo', 'walmart', 'pepsi', 'hp']
# ['merceds', 'oracle', 'citigroup', 'comcast', 'danaher']
# ['renault', 'icici', 'netflix', 'panasonic', 'johnson', 'icbc']
# ['reliance', 'ford', 'oracle', 'airtel']
# ['onex', 'amazon', 'oracle', 'nike', 'hyundai']
# ['vmware', 'icbc', 'johnson', 'toyota', 'maruhan', 'hitachi']
# ['nestle', 'acs', 'ebay', 'sony']
# ['target', 'cisco', 'danone', 'onex', 'cosmo']
# ['ebay', 'reliance', 'cosmo', 'nokia', 'rbc', 'woodland']
# ['apple', 'philip', 'wistron', 'hyundai']
# ['xiaomi', 'sodexo', 'visa', 'caterpillar', 'infosys']
# ['ebay', 'wistron', 'philip', 'siemens', 'paypal', 'sony']
# ['facebook', 'metlife', 'netflix', 'merceds']
# ['abb', 'bmw', 'qualcomm', 'danaher', 'avnet']
# ['coca-cola', 'jpmorgan', 'salesforce', 'xiaomi', 'amr', 'fedEx']
# ['ford', 'renault', 'philip', 'infosys']
# ['puma', 'target', 'pubg', 'at&t', 'hyundai']
# ['puma', 'tencent', 'vmware', 'panasonic', 'philip', 'lg']
# ['wistron', 'tencent', 'capgemini', 'reliance']
# ['onex', 'vadafone', 'staples', 'microsoft', 'intel']
# ['vmware', 'danaher', 'oracle', 'capgemini', 'target', 'rbc']
# ['tencent', 'paypal', 'ebay', 'netflix']
# ['citigroup', 'super dry', 'abb', 'lg', 'woodland']
# ['icici', 'sodexo', 'lg', 'wipro', 'comcast', 'hitachi']
# ['johnson', 'hdfc', 'maruhan', 'avnet']
# ['volkswagen', 'american express', 'sodexo', 'icbc', 'nippon']
# ['starbucks', 'vmware', 'visa', 'abb', 'renault', 'danaher']
# ['panasonic', 'reliance', 'samsung', 'super dry']
# ['philip', 'xiaomi', 'walmart', 'citigroup', 'maruhan']
# ['coca-cola', 'ford', 'puma', 'canon', 'starbucks', 'cisco']
# ['oracle', 'american express', 'acs', 'citigroup']
# ['fedEx', 'vadafone', 'avnet', 'qualcomn', 'tencent']
# ['canon', 'cisco', 'crh', 'airtel', 'qualcomm', 'johnson']
# ['hdfc', 'metlife', 'xiaomi', 'vinci']
# ['vmware', 'coca-cola', 'nippon', 'qualcomn', 'intel']
# ['starbucks', 'infosys', 'danaher', 'tesla', 'mahindra', 'vadafone']
# ['sony', 'xiaomi', 'avnet', 'apple']
# ['wistron', 'facebook', 'vmware', 'american express', 'sony']
# ['airtel', 'staples', 'nike', 'tencent', 'oracle', 'nokia']
# ['facebook', 'rbc', 'philip', 'maybank']
# ['onex', 'abb', 'wipro', 'mastercard', 'walmart']
# ['onex', 'maybank', 'hdfc', 'starbucks', 'super dry', 'amazon']
# ['facebook', 'salesforce', 'loreal', 'mahindra']
# ['philip', 'american express', 'tesco', 'staples', 'salesforce']
# ['volkswagen', 'tcs', "mcdoland's", 'fedEx', 'airtel', 'avnet']
# ['pubg', 'infosys', 'xiaomi', 'sodexo']
# ['mahindra', 'amr', 'siemens', 'maruhan', 'icici']
# ['danaher', 'hyundai', 'fluor', 'johnson', 'jpmorgan', 'samsung']
# ['vinci', 'qualcomn', 'airtel', 'tencent']
# ['tesco', 'abb', 'icici', 'oracle', 'american express']
# ['fluor', 'pubg', 'nippon', 'tcs', 'target', 'wipro']
# ['maybank', 'loreal', 'xiaomi', 'sodexo']
# ['maruhan', 'maybank', 'loreal', 'johnson', 'intel']
# ['metlife', 'nestle', 'coca-cola', 'johnson', 'hitachi', 'hp']
# ['nippon', 'intel', 'volkswagen', 'staples']
# ['qualcomm', 'vadafone', 'rbc', 'nvidia', 'reliance']
# ['vmware', 'toyota', 'nestle', 'vadafone', 'coca-cola', 'nippon']
# ['hp', 'staples', 'mastercard', 'vadafone']
# ['nokia', 'starbucks', 'oracle', 'accenture', 'tencent']
# ['reliance', 'icbc', 'caterpillar', 'ibm', 'starbucks', 'american express']
# ['icbc', 'super dry', 'crh', 'ebay']
# ['cisco', 'netflix', 'tesla', 'nvidia', 'american express']
# ['barclays', 'alphabet', 'tesco', 'philip', 'Adobe', 'jpmorgan']
# ['fedEx', 'airtel', 'cisco', 'ford']
# ['tesco', 'merceds', 'at&t', 'ebay', 'starbucks']
# ['caterpillar', 'target', 'staples', 'johnson', 'renault', 'nike']
# ["mcdoland's", 'amr', 'maybank', 'lg']
# ['hdfc', 'maruhan', 'crh', 'mahindra', 'accenture']
# ['icici', 'canon', 'abb', 'panasonic', 'ebay', 'mastercard']
# ['cosmo', 'staples', 'fluor', 'qualcomm']
# ['amazon', 'Adobe', 'rbc', 'comcast', 'ford']
# ['ebay', 'qualcomn', 'walmart', 'toyota', 'crh', 'netflix']
# ['tcs', 'at&t', 'nippon', 'nike']
# ['barclays', 'mastercard', 'hdfc', 'at&t', 'abb']
# ['infosys', 'puma', 'lg', 'bmw', 'fluor', 'tesla']
# ['tcs', 'walmart', 'starbucks', 'ebay']
# ['rbc', 'nvidia', 'aegon', 'vadafone', 'nippon']
# ['tesla', 'pubg', 'toyota', 'puma', 'xiaomi', 'hp']
# ['fedEx', 'facebook', 'amr', 'cisco']
# ['intel', 'qualcomn', 'nokia', 'vmware', 'jpmorgan']
# ['pubg', 'jpmorgan', 'hp', 'disney', 'rbc', 'cosmo']
# ['citigroup', 'sap', "mcdoland's", 'puma']
# ['johnson', 'ford', 'maybank', 'amazon', 'caterpillar']
# ['mastercard', 'lg', 'volkswagen', 'apple', 'pubg', "mcdoland's"]
# ['at&t', 'paypal', 'renault', 'tesco']
# ['renault', 'starbucks', 'hitachi', 'intel', 'toyota']
# ['avnet', 'qualcomm', 'vmware', 'netflix', 'siemens', 'fluor']
# ['qualcomn', 'barclays', 'lg', 'nippon']
# ['airtel', 'pepsi', 'loreal', 'nokia', 'icici']
# ["mcdoland's", 'johnson', 'wipro', 'disney', 'infosys', 'samsung']
# ['amr', 'renault', 'nestle', 'johnson']
# ['renault', 'sap', 'nike', 'puma', 'volkswagen']
# ['accenture', 'maybank', 'volkswagen', 'vadafone', 'johnson', 'nippon']
# ['starbucks', 'mastercard', 'fluor', 'acs']
# ['icbc', 'rbc', 'abb', 'icici', 'fluor']
# ['cosmo', 'tencent', 'siemens', 'acs', 'pepsi', 'panasonic']
# ['walmart', 'toyota', 'super dry', 'xiaomi']
# ['metlife', 'rbc', 'accenture', 'starbucks', 'caterpillar']
# ['xiaomi', "mcdoland's", 'microsoft', 'walmart', 'mahindra', 'avnet']
# ['johnson', 'danaher', 'puma', 'alibaba']
# ['intel', 'hyundai', 'philip', 'microsoft', 'icbc']
# ['cosmo', 'hdfc', 'bmw', 'alphabet', 'hyundai', 'jpmorgan']
# ['philip', 'Adobe', 'staples', 'at&t']
# ['mastercard', 'oracle', 'qualcomm', 'mahindra', 'staples']
# ['vinci', 'rbc', 'apple', 'microsoft', 'aegon', 'intel']
# ['maybank', 'fluor', 'amazon', 'tencent']
# ['toyota', 'capgemini', 'hyundai', "mcdoland's", 'sap']
# ['airtel', 'fluor', 'hdfc', 'fedEx', 'avnet', 'at&t']
# ['barclays', 'pubg', 'hyundai', 'qualcomm']
# ['comcast', 'renault', 'amazon', 'hp', 'danaher']
# ['abb', 'qualcomn', 'nokia', 'amazon', 'reliance', 'sony']
# ['toyota', 'nestle', 'paypal', 'qualcomm']
# ['danaher', 'danone', 'staples', 'lg', 'philip']
# ['abb', 'qualcomn', 'siemens', 'hyundai', 'alibaba', 'lg']
# ['tesla', 'netflix', 'apple', 'onex']
# ['maruhan', 'sap', 'woodland', 'loreal', 'danone']
# ['xiaomi', 'ibm', 'walmart', 'siemens', 'amr', 'alibaba']
# ['oracle', 'airtel', 'addidas', 'alibaba']
# ['metlife', 'apple', 'rbc', 'coca-cola', 'qualcomn']
# ['maruhan', 'paypal', 'nippon', 'alphabet', 'wipro', 'nvidia']
# ['ibm', 'american express', 'target', 'intel']
# ['lg', 'paypal', 'mastercard', 'facebook', 'nokia']
# ['bmw', 'nvidia', 'tesla', 'mahindra', 'metlife', 'merceds']
# ['comcast', 'accenture', "mcdoland's", 'merceds']
# ['danaher', 'airtel', 'cosmo', 'abb', 'cisco']
# ['xiaomi', 'amazon', 'pepsi', 'netflix', 'oracle', 'cisco']
# ['qualcomm', 'american express', 'aegon', 'alphabet']
# ['reliance', 'wipro', 'nestle', 'ibm', 'at&t']
# ['alphabet', 'sap', 'visa', 'icbc', 'renault', 'starbucks']
# ['metlife', 'lg', 'barclays', 'cisco']
# ["mcdoland's", 'ebay', 'vinci', 'american express', 'oracle']
# ['mastercard', 'nike', 'danaher', 'woodland', 'aegon', 'panasonic']
# ['target', 'renault', 'alibaba', 'coca-cola']
# ['nestle', 'wipro', 'onex', 'barclays', 'volkswagen']
# ['microsoft', 'apple', 'acs', 'qualcomm', 'comcast', 'nokia']
# ['alibaba', 'siemens', 'tesco', 'aegon']
# ['qualcomm', 'icici', 'target', 'ford', 'metlife']
# ['paypal', 'wistron', 'pubg', 'hp', 'volkswagen', 'mahindra']
# ['sodexo', 'wistron', 'merceds', 'vadafone']
# ['qualcomm', 'icbc', 'netflix', 'wistron', 'facebook']
# ['netflix', 'american express', 'Adobe', 'sap', 'amr', 'intel']
# ['ford', 'airtel', 'oracle', 'icici']
# ['mahindra', 'nippon', 'tencent', 'intel', 'starbucks']
# ['bmw', 'vadafone', 'avnet', 'alphabet', 'danaher', 'coca-cola']
# ['disney', 'puma', 'paypal', 'avnet']
# ['fluor', 'hitachi', 'qualcomm', 'qualcomn', 'hp']
# ['amazon', 'abb', 'maybank', 'bmw', 'at&t', 'infosys']
# ['hdfc', 'mahindra', 'woodland', 'sony']
# ['icici', 'fedEx', 'reliance', 'mastercard', 'loreal']
# ['hp', 'ebay', 'hdfc', 'target', 'vinci', 'pubg']
# ['tencent', 'capgemini', 'vadafone', 'samsung']
# ['siemens', 'rbc', 'sap', 'citigroup', 'avnet']
# ['metlife', 'samsung', 'american express', 'icbc', 'vmware', 'wipro']
# ['airtel', 'danone', 'toyota', 'fedEx']
# ['nippon', 'philip', 'sodexo', 'alphabet', 'target']
# ['fedEx', 'puma', 'jpmorgan', 'vinci', 'fluor', 'tesco']
# ['puma', 'avnet', 'qualcomm', 'renault']
# ['at&t', 'mastercard', 'volkswagen', 'pepsi', 'pubg']
# ['american express', 'airtel', 'walmart', 'hitachi', 'samsung', 'volkswagen']
# ['maybank', 'microsoft', 'mahindra', 'cisco']
# ['philip', 'netflix', 'tcs', 'hyundai', 'wistron']
# ['xiaomi', "mcdoland's", 'alphabet', 'woodland', 'jpmorgan', 'wipro']
# ['hp', 'rbc', 'walmart', 'ford']
# ['canon', 'lg', 'jpmorgan', 'danone', 'samsung']
# ['infosys', 'philip', 'maruhan', 'avnet', "mcdoland's", 'xiaomi']
# ['johnson', 'Adobe', 'at&t', 'loreal']
# ['volkswagen', 'siemens', 'target', 'tesco', 'qualcomn']
# ['tesla', 'icici', 'fedEx', 'alibaba', 'xiaomi', 'american express']
# ['facebook', 'alphabet', 'Adobe', 'amr']
# ['sodexo', 'starbucks', 'sap', 'hitachi', 'hdfc']
# ['jpmorgan', 'airtel', 'onex', 'tencent', 'disney', 'danaher']
# ['volkswagen', 'reliance', 'xiaomi', 'lg']
# ['samsung', 'sony', 'johnson', 'amr', 'accenture']
# ['johnson', 'fluor', 'tcs', 'toyota', 'icbc', 'barclays']
# ['tesco', 'cisco', 'super dry', 'oracle']
# ['sodexo', 'pubg', 'johnson', 'qualcomm', 'volkswagen']
# ['qualcomm', 'paypal', 'abb', 'danaher', 'tencent', 'sodexo']
# ['apple', 'panasonic', 'coca-cola', 'Adobe']
# ['wipro', 'coca-cola', 'ebay', 'caterpillar', 'pepsi']
# ['wistron', 'cisco', 'vmware', 'visa', 'johnson', 'starbucks']
# ['salesforce', 'american express', 'ibm', 'infosys']
# ['paypal', 'apple', 'onex', "mcdoland's", 'ibm']
# ['walmart', 'avnet', 'tencent', 'amazon', 'woodland', 'amr']
# ['danone', 'amazon', 'target', 'ford']
# ['tesco', 'accenture', 'salesforce', 'xiaomi', 'mastercard']
# ['tcs', 'hyundai', 'fluor', 'jpmorgan', 'philip', 'johnson']
# ['vinci', 'ebay', 'hitachi', "mcdoland's"]
# ['coca-cola', 'pepsi', 'philip', 'icbc', 'hitachi']
# ['tesla', 'netflix', 'onex', 'toyota', 'woodland', 'ibm']
# ['puma', 'mahindra', 'mastercard', 'netflix']
# ['Adobe', 'hp', 'vinci', 'comcast', 'oracle']
# ['hyundai', 'coca-cola', 'cisco', 'crh', 'amr', 'salesforce']
# ['amr', 'lg', 'merceds', 'samsung']
# ['nike', 'onex', 'sap', 'danone', 'super dry']
# ['fedEx', 'siemens', 'hitachi', 'renault', 'amr', 'super dry']
# ['alphabet', 'addidas', 'american express', 'wipro']
# ['abb', 'amazon', 'nippon', 'qualcomn', 'tcs']
# ['barclays', 'johnson', 'siemens', 'reliance', 'fluor', 'staples']
# ['vmware', 'oracle', 'fluor', 'hyundai']
# ['avnet', 'mahindra', 'vadafone', 'salesforce', 'mastercard']
# ['salesforce', 'wipro', 'johnson', 'sap', 'citigroup', 'amr']
# ['ford', 'intel', 'aegon', 'nvidia']
# ['tcs', 'paypal', 'facebook', 'onex', 'icbc']
# ['mastercard', 'Adobe', 'walmart', 'merceds', 'tesla', 'mahindra']
# ['metlife', 'philip', 'ibm', 'alphabet']
# ['vadafone', 'capgemini', 'nestle', 'maruhan', 'onex']
# ['microsoft', 'reliance', 'apple', "mcdoland's", 'sap', 'philip']
# ['amazon', 'icici', 'hdfc', 'samsung']
# ['nike', 'salesforce', 'hitachi', 'crh', 'loreal']
# ['icici', 'accenture', 'nokia', 'hyundai', 'onex', 'oracle']
# ['microsoft', 'hyundai', 'fluor', 'maybank']
# ['comcast', 'acs', 'tcs', 'avnet', 'crh']
# ['staples', 'tcs', 'samsung', 'reliance', 'icbc', 'vmware']
# ['acs', 'paypal', 'panasonic', 'accenture']
# ['acs', 'wistron', 'qualcomn', 'nvidia', 'visa']
# ['oracle', 'siemens', 'caterpillar', 'intel', 'nippon', 'airtel']
# ['fedEx', 'hitachi', 'citigroup', 'staples']
# ['ford', 'visa', 'sodexo', 'alphabet', 'comcast']
# ['amr', 'icbc', 'qualcomm', 'crh', 'aegon', 'nokia']
# ['salesforce', 'icbc', 'rbc', 'apple']
# ['abb', 'pubg', 'canon', 'vadafone', 'bmw']
# ['merceds', 'tcs', 'aegon', 'tencent', 'cosmo', 'target']
# ['onex', 'tencent', 'reliance', 'at&t']
# ['ibm', 'xiaomi', 'american express', 'wipro', 'vinci']
# ['crh', 'hitachi', 'lg', 'metlife', 'airtel', 'cisco']
# ['fedEx', 'maruhan', 'abb', 'siemens']
# ['mahindra', 'starbucks', 'facebook', 'toyota', 'mastercard']
# ['mastercard', 'abb', 'tcs', 'metlife', 'sony', 'ford']
# ['sodexo', 'oracle', 'hitachi', 'staples']
# ['panasonic', 'volkswagen', 'ford', 'addidas', 'facebook']
# ['Adobe', 'pubg', 'infosys', 'hyundai', 'avnet', 'coca-cola']
# ['maruhan', 'netflix', 'hyundai', 'salesforce']
# ['alibaba', 'nippon', 'danone', 'tencent', 'microsoft']
# ['at&t', 'hyundai', 'intel', 'ibm', 'infosys', 'maybank']
# ['hdfc', 'sony', 'airtel', 'siemens']
# ['capgemini', 'amr', 'samsung', 'hdfc', 'rbc']
# ['vmware', 'danone', 'alphabet', 'pubg', 'amazon', 'nvidia']
# ['sony', 'canon', 'ibm', 'addidas']
# ['barclays', 'vadafone', 'netflix', 'lg', 'caterpillar']
# ['alphabet', 'hitachi', 'jpmorgan', 'lg', 'visa', 'accenture']
# ['icbc', 'facebook', 'paypal', 'nike']
# ['amazon', 'sodexo', 'nvidia', 'tesco', 'aegon']
# ['fluor', 'siemens', "mcdoland's", 'sodexo', 'netflix', 'abb']
# ['apple', 'nokia', 'amazon', 'johnson']
# ['nippon', 'american express', 'nestle', 'target', 'icici']
# ['mastercard', 'cosmo', 'maybank', 'nestle', 'walmart', 'sony']
# ['maybank', 'vmware', 'super dry', 'at&t']
# ['fedEx', 'capgemini', 'hitachi', 'danaher', 'aegon']
# ['hp', 'reliance', 'acs', 'alibaba', 'tencent', 'xiaomi']
# ['alibaba', 'staples', 'merceds', 'vinci']
# ['alphabet', 'sodexo', 'merceds', 'starbucks', 'nvidia']
# ['hp', 'ibm', 'danone', 'apple', 'icbc', 'acs']
# ['renault', 'samsung', 'addidas', 'fluor']
# ['walmart', 'johnson', 'canon', 'Adobe', 'abb']
# ['ibm', 'nike', 'wistron', 'onex', 'caterpillar', 'alibaba']
# ['facebook', 'nippon', 'merceds', 'pepsi']
# ['mastercard', 'pubg', 'paypal', 'Adobe', 'starbucks']
# ['abb', 'danone', 'hdfc', 'puma', 'bmw', 'mahindra']
# ['accenture', 'cosmo', 'barclays', 'pepsi']
# ['jpmorgan', 'renault', 'nike', 'metlife', 'hdfc']
# ['nippon', 'amr', 'disney', 'apple', 'sap', 'microsoft']
# ['samsung', 'cosmo', 'amazon', 'nestle']
# ['fedEx', 'hp', 'nestle', 'accenture', 'lg']
# ['vadafone', 'woodland', 'american express', 'icbc', 'staples', 'pubg']
# ['tcs', 'Adobe', 'crh', 'sodexo']
# ['alibaba', 'puma', 'vadafone', 'maruhan', 'tcs']
# ['citigroup', 'salesforce', 'starbucks', 'philip', 'tcs', 'visa']
# ['johnson', 'jpmorgan', 'tcs', 'maybank']
# ['abb', 'jpmorgan', 'caterpillar', 'qualcomn', 'crh']
# ['disney', 'salesforce', 'mahindra', 'alibaba', 'vinci', 'hdfc']
# ['danaher', 'sony', 'reliance', 'citigroup']
# ['oracle', 'canon', 'hitachi', 'qualcomn', 'icici']
# ['alphabet', 'hdfc', 'woodland', 'tesco', 'johnson', 'vinci']
# ['ford', 'fluor', 'fedEx', 'abb']
# ['onex', 'facebook', 'icbc', 'reliance', 'capgemini']
# ['icbc', 'tencent', 'nokia', 'hyundai', 'microsoft', 'ebay']
# ['xiaomi', 'amr', 'ford', 'infosys']
# ['alphabet', 'barclays', 'oracle', 'danaher', 'facebook']
# ['nike', 'woodland', 'american express', 'cisco', 'icbc', 'salesforce']
# ['cisco', 'toyota', 'at&t', 'fluor']
# ['hitachi', 'disney', 'johnson', 'accenture', 'alibaba']
# ['tencent', 'visa', 'tesla', 'sodexo', 'nokia', 'philip']
# ['pepsi', 'amr', 'crh', 'target']
# ['netflix', 'tencent', 'airtel', 'johnson', 'starbucks']
# ['siemens', 'qualcomm', 'netflix', 'airtel', 'avnet', 'Adobe']
# ['icbc', 'american express', 'tencent', 'lg']
# ['apple', 'pepsi', 'caterpillar', 'addidas', 'alibaba']
# ['philip', 'onex', 'siemens', 'airtel', 'coca-cola', 'avnet']
# ['sap', 'volkswagen', 'bmw', 'addidas']
# ['nike', 'ibm', 'vinci', 'volkswagen', 'walmart']
# ['metlife', 'crh', 'qualcomn', 'tcs', 'apple', 'pubg']
# ['intel', 'jpmorgan', 'mahindra', 'airtel']
# ['walmart', 'apple', 'johnson', 'amazon', 'disney']
# ['pepsi', 'danaher', 'abb', 'danone', 'tencent', 'airtel']
# ['nokia', 'nike', 'vadafone', 'acs']
# ['samsung', 'pubg', 'oracle', 'amr', 'wistron']
# ['qualcomm', 'hp', 'wistron', 'xiaomi', 'target', 'danone']
# ['volkswagen', 'comcast', 'nvidia', 'paypal']
# ['microsoft', 'paypal', 'at&t', 'mastercard', 'maybank']
# ['danaher', 'samsung', 'Adobe', 'tencent', 'netflix', 'ebay']
# ['lg', 'microsoft', 'bmw', 'qualcomn']
# ['apple', 'target', 'walmart', 'puma', 'tcs']
# ['tencent', 'comcast', 'vadafone', 'renault', 'tcs', 'salesforce']
# ['siemens', 'capgemini', 'nippon', 'sap']
# ['starbucks', 'reliance', 'mahindra', 'icbc', 'capgemini']
# ['icbc', 'danone', 'at&t', 'oracle', 'hp', 'acs']
# ['icici', 'qualcomm', 'nokia', 'coca-cola']
# ['comcast', 'nestle', 'ford', 'tesco', 'capgemini']
# ['walmart', 'abb', 'woodland', 'mahindra', 'citigroup', 'danaher']
# ['microsoft', 'barclays', 'loreal', 'crh']
# ['hp', 'coca-cola', 'fedEx', 'nokia', 'capgemini']
# ['danone', 'woodland', 'vmware', 'johnson', 'netflix', 'infosys']
# ['merceds', 'barclays', 'cosmo', 'netflix']
# ['hp', 'american express', 'infosys', 'icici', 'ebay']
# ['metlife', 'paypal', 'johnson', 'danone', 'netflix', 'loreal']
# ['nokia', 'vadafone', 'lg', 'panasonic']
# ['lg', "mcdoland's", 'vadafone', 'tcs', 'tesco']
# ['acs', 'Adobe', 'netflix', 'hyundai', 'target', 'paypal']
# ['toyota', 'johnson', 'american express', 'ford']
# ['Adobe', 'addidas', 'johnson', 'visa', 'loreal']
# ['starbucks', 'pepsi', 'mastercard', 'maruhan', 'bmw', 'super dry']
# ['hyundai', 'volkswagen', 'sony', 'sap']
# ['tesla', 'accenture', 'fedEx', 'crh', 'loreal']
# ['siemens', 'vmware', 'nike', 'starbucks', 'comcast', 'johnson']
# ['nestle', 'ford', 'jpmorgan', 'volkswagen']
# ['caterpillar', 'alibaba', 'walmart', 'bmw', 'volkswagen']
# ['vadafone', 'woodland', 'nvidia', 'panasonic', 'tencent', 'aegon']
# ['sodexo', 'abb', 'fluor', 'siemens']
# ['coca-cola', 'panasonic', 'ibm', 'qualcomm', 'disney']
# ['siemens', 'oracle', 'at&t', 'johnson', 'tesco', 'mahindra']
# ['ebay', 'apple', 'qualcomn', 'panasonic']
# ['walmart', 'icici', 'jpmorgan', 'ibm', 'metlife']
# ['pubg', 'coca-cola', 'tesco', 'ford', 'reliance', 'tesla']
# ['merceds', 'aegon', 'jpmorgan', 'tesco']
# ['qualcomm', 'pubg', 'nike', 'walmart', 'disney']
# ['vadafone', 'salesforce', 'amr', 'paypal', 'hp', 'tcs']
# ['metlife', 'volkswagen', 'paypal', 'onex']
# ['hyundai', 'alibaba', 'oracle', 'intel', 'danone']
# ['at&t', 'woodland', 'cosmo', 'tesco', 'oracle', 'puma']
# ['tesla', 'xiaomi', 'loreal', 'ford']
# ['apple', 'coca-cola', 'tencent', 'danone', 'icbc']
# ['tcs', 'crh', 'airtel', 'infosys', 'amr', 'tencent']
# ['wistron', 'at&t', 'intel', 'qualcomn']
# ['amazon', 'cisco', 'canon', 'netflix', 'visa']
# ['citigroup', 'apple', 'accenture', 'comcast', 'fedEx', 'tencent']
# ['toyota', 'netflix', 'puma', 'facebook']
# ['canon', 'samsung', 'maybank', 'renault', 'volkswagen']
# ['abb', 'starbucks', 'mastercard', 'salesforce', 'walmart', 'Adobe']
# ['pubg', 'at&t', 'crh', 'hdfc']
# ['super dry', 'tesco', 'mahindra', 'panasonic', 'starbucks']
# ['ebay', 'nippon', 'nokia', 'danaher', 'american express', 'maruhan']
# ['apple', 'maybank', 'johnson', 'danone']
# ['ford', 'bmw', 'hdfc', 'paypal', 'nestle']
# ['hitachi', 'cisco', 'intel', 'nokia', 'danaher', 'salesforce']
# ['sony', 'aegon', 'barclays', 'apple']
# ['jpmorgan', 'icici', 'qualcomn', 'comcast', 'renault']
# ['loreal', 'renault', 'jpmorgan', 'accenture', 'at&t', 'disney']
# ['canon', 'qualcomm', 'addidas', 'johnson']
# ['comcast', 'metlife', 'reliance', 'nestle', 'cosmo']
# ['citigroup', 'merceds', 'vmware', 'alphabet', 'sodexo', 'siemens']
# ['oracle', 'avnet', 'qualcomm', 'wistron']
# ['salesforce', 'acs', 'nippon', 'danone', 'rbc']
# ['woodland', 'nokia', 'onex', 'loreal', 'Adobe', 'mahindra']
# ['cosmo', 'super dry', 'apple', 'microsoft']
# ['tesco', 'intel', 'icici', 'vinci', 'apple']
# ['siemens', 'hyundai', 'samsung', 'merceds', 'microsoft', 'at&t']
# ['alphabet', 'mastercard', 'lg', 'ford']
# ['canon', 'cosmo', 'infosys', 'walmart', 'vadafone']
# ['coca-cola', 'citigroup', 'pepsi', 'canon', 'nestle', 'merceds']
# ['vinci', 'fedEx', 'puma', 'johnson']
# ['staples', 'fedEx', 'pubg', 'tesco', 'vadafone']
# ['capgemini', 'hdfc', 'barclays', 'crh', 'lg', 'infosys']
# ['staples', 'super dry', 'apple', 'johnson']
# ['cosmo', 'american express', 'citigroup', 'visa', 'woodland']
# ['intel', 'johnson', 'visa', 'accenture', 'paypal', 'hyundai']
# ['salesforce', 'volkswagen', 'icici', 'ford']
# ['samsung', 'facebook', 'wipro', 'fluor', 'toyota']
# ['addidas', 'icici', "mcdoland's", 'fluor', 'rbc', 'toyota']
# ['super dry', 'danaher', 'coca-cola', 'disney']
# ['volkswagen', 'fluor', 'johnson', 'target', 'acs']
# ["mcdoland's", 'netflix', 'paypal', 'onex', 'apple', 'tcs']
# ['hitachi', 'visa', 'crh', 'intel']
# ['cosmo', 'loreal', 'alphabet', 'nokia', 'sony']
# ['merceds', 'panasonic', 'johnson', 'nike', 'puma', 'tencent']
# ['maybank', 'mahindra', 'facebook', 'starbucks']
# ['fedEx', 'rbc', 'coca-cola', 'hdfc', 'disney']
# ['johnson', 'facebook', 'wipro', 'bmw', 'amr', 'intel']
# ['woodland', 'capgemini', 'Adobe', 'nokia']
# ['citigroup', 'alphabet', 'jpmorgan', 'super dry', 'nvidia']
# ['metlife', 'woodland', 'starbucks', 'pubg', 'ford', 'super dry']
# ['wipro', 'crh', 'danaher', 'fedEx']
# ['accenture', 'qualcomm', 'hdfc', 'icici', 'vadafone']
# ['danaher', 'philip', 'canon', 'addidas', 'qualcomn', 'puma']
# ['panasonic', 'ibm', 'sap', 'merceds']
# ['merceds', 'puma', 'panasonic', 'Adobe', 'apple']
# ['wipro', 'canon', 'intel', 'avnet', 'icbc', 'maybank']
# ['facebook', 'hitachi', 'tencent', 'vinci']
# ['hdfc', 'infosys', 'staples', 'aegon', 'barclays']
# ['qualcomm', 'aegon', 'sap', 'paypal', 'fluor', 'alphabet']
# ['sony', 'super dry', 'qualcomn', 'volkswagen']
# ['hitachi', 'amr', 'tencent', 'visa', 'qualcomm']
# ['pubg', 'philip', 'super dry', 'fluor', 'alphabet', "mcdoland's"]
# ['qualcomn', 'maybank', 'sony', 'merceds']
# ['ebay', 'hyundai', 'qualcomm', 'loreal', 'walmart']
# ['reliance', 'wistron', 'accenture', 'hitachi', 'nokia', 'bmw']
# ['onex', 'microsoft', 'vadafone', 'nestle']
# ['airtel', 'fluor', 'sap', 'qualcomn', 'danaher']
# ['abb', 'amazon', 'hdfc', 'airtel', 'onex', 'pepsi']
# ['pepsi', 'netflix', 'fedEx', 'bmw']
# ['xiaomi', 'alphabet', 'cosmo', 'citigroup', 'bmw']
# ['staples', 'disney', 'metlife', 'tesla', 'volkswagen', 'american express']
# ['nvidia', 'ford', 'coca-cola', 'avnet']
# ['walmart', 'coca-cola', 'sodexo', 'nestle', 'loreal']
# ['walmart', 'paypal', 'tesla', 'ford', 'staples', 'super dry']
# ['wistron', 'toyota', 'onex', 'tencent']
# ['xiaomi', 'jpmorgan', 'alibaba', 'disney', 'walmart']
# ['fluor', 'target', 'maybank', 'amr', 'qualcomn', 'pubg']
# ['salesforce', 'xiaomi', 'hdfc', 'cosmo']
# ['crh', 'sony', 'infosys', 'mastercard', 'tcs']
# ['sony', 'alibaba', 'barclays', 'capgemini', 'nvidia', 'canon']
# ['icbc', 'alibaba', 'wistron', 'fluor']
# ['danone', 'xiaomi', 'citigroup', 'tencent', 'addidas']
# ['oracle', 'cosmo', 'Adobe', 'qualcomn', 'alphabet', 'loreal']
# ['loreal', 'caterpillar', 'alphabet', 'nestle']
# ['mahindra', 'danaher', 'tcs', 'avnet', 'pubg']
# ['xiaomi', 'walmart', 'pubg', 'disney', 'volkswagen', 'microsoft']
# ['super dry', 'philip', 'canon', 'merceds']
# ['panasonic', 'paypal', 'philip', 'netflix', 'fedEx']
# ['ebay', 'fedEx', 'vadafone', 'tcs', 'johnson', 'cosmo']
# ['ebay', 'samsung', 'oracle', 'icici']
# ['alphabet', 'mahindra', 'acs', 'volkswagen', 'sap']
# ['ibm', 'accenture', 'hdfc', 'barclays', 'danone', 'hitachi']
# ['coca-cola', 'jpmorgan', 'acs', 'icici']
# ['xiaomi', 'jpmorgan', 'ebay', 'nestle', 'danone']
# ['nvidia', 'cosmo', 'ibm', 'renault', 'hitachi', 'hdfc']
# ['nike', 'vadafone', 'icbc', 'icici']
# ['american express', 'icici', 'acs', 'loreal', 'hitachi']
# ['pubg', 'crh', 'walmart', 'starbucks', 'tesla', 'oracle']
# ['american express', 'hp', 'citigroup', 'tcs']
# ['hp', 'danaher', 'salesforce', 'sodexo', 'starbucks']
# ['caterpillar', 'rbc', 'ford', 'icbc', 'acs', 'target']
# ['cosmo', 'ford', 'volkswagen', 'fluor']
# ['amazon', 'metlife', 'american express', 'coca-cola', 'samsung']
# ['qualcomm', 'disney', 'american express', 'infosys', 'tesla', 'salesforce']
# ['coca-cola', 'microsoft', 'wistron', 'infosys']
# ['walmart', 'nippon', 'oracle', 'citigroup', 'cosmo']
# ['wistron', 'fedEx', 'Adobe', 'addidas', 'icbc', 'sodexo']
# ['woodland', 'nippon', 'qualcomn', 'rbc']
# ['abb', 'visa', 'lg', 'xiaomi', 'reliance']
# ["mcdoland's", 'citigroup', 'infosys', 'netflix', 'reliance', 'hitachi']
# ['microsoft', 'sodexo', 'intel', 'acs']
# ['hitachi', 'loreal', 'metlife', 'salesforce', 'visa']
# ['citigroup', 'Adobe', 'mastercard', 'disney', 'nvidia', 'jpmorgan']
# ['ford', 'philip', 'vmware', 'danaher']
# ['capgemini', 'nokia', 'mastercard', 'disney', 'fluor']
# ['coca-cola', 'nike', 'vinci', 'cosmo', 'icici', 'rbc']
# ['fedEx', 'bmw', 'vadafone', 'ford']
# ['pubg', 'infosys', 'accenture', 'hp', 'philip']
# ['jpmorgan', 'metlife', 'johnson', 'accenture', 'nokia', 'cisco']
# ['puma', 'wistron', 'coca-cola', 'hitachi']
# ['hitachi', 'Adobe', 'bmw', 'nike', 'lg']
# ['target', 'rbc', 'qualcomm', 'nvidia', 'accenture', 'fedEx']
# ['onex', "mcdoland's", 'danaher', 'nvidia']
# ['vmware', 'fedEx', 'visa', 'walmart', 'oracle']
# ['mastercard', 'caterpillar', 'volkswagen', 'vadafone', 'icici', 'reliance']
# ['alphabet', 'metlife', 'loreal', 'sap']
# ['xiaomi', 'danaher', 'sap', 'johnson', 'volkswagen']
# ['facebook', 'aegon', 'bmw', 'jpmorgan', 'nippon', 'fedEx']
# ['oracle', 'hyundai', 'paypal', 'walmart']
# ['avnet', 'coca-cola', 'icici', 'maybank', 'cisco']
# ['renault', 'intel', 'starbucks', "mcdoland's", 'puma', 'cosmo']
# ['ebay', 'microsoft', 'panasonic', 'airtel']
# ['panasonic', 'hp', 'xiaomi', 'fluor', 'tcs']
# ['nokia', 'apple', 'Adobe', 'reliance', 'xiaomi', 'capgemini']
# ['danone', 'addidas', 'comcast', 'siemens']
# ['maybank', 'super dry', 'toyota', 'comcast', 'pubg']
# ['capgemini', 'amr', 'cosmo', 'cisco', 'at&t', 'accenture']
# ['icici', 'addidas', 'woodland', 'super dry']
# ['panasonic', 'caterpillar', 'nike', 'comcast', 'icbc']
# ['ebay', 'onex', 'samsung', 'walmart', 'staples', 'philip']
# ['johnson', 'amr', 'danone', 'capgemini']
# ['american express', 'onex', 'acs', 'hitachi', 'samsung']
# ['oracle', 'mastercard', 'jpmorgan', 'nestle', 'fluor', 'lg']
# ['mahindra', 'ibm', 'nestle', 'reliance']
# ['nike', 'barclays', 'alibaba', 'icbc', 'mahindra']
# ['intel', 'pubg', 'disney', 'sap', 'cisco', 'caterpillar']
# ['salesforce', 'nokia', 'lg', 'addidas']
# ['maybank', 'american express', 'johnson', 'fedEx', 'danone']
# ['reliance', 'xiaomi', 'tesla', 'Adobe', 'acs', 'target']
# ['Adobe', 'addidas', 'tesco', 'siemens']
# ['nvidia', 'metlife', 'mastercard', 'danaher', 'sony']
# ['super dry', 'netflix', 'volkswagen', 'ibm', 'tesla', 'metlife']
# ['comcast', 'ibm', 'capgemini', 'starbucks']
# ['canon', 'facebook', 'reliance', 'xiaomi', 'wipro']
# ['crh', 'loreal', 'mahindra', 'alibaba', 'johnson', 'airtel']
# ['avnet', 'qualcomn', 'salesforce', 'coca-cola']
# ['qualcomm', 'loreal', 'bmw', 'target', 'apple']
# ['intel', 'oracle', 'icici', 'walmart', 'at&t', 'disney']
# ['cosmo', 'johnson', 'hitachi', 'sodexo']
# ['bmw', 'infosys', 'starbucks', 'crh', 'abb']
# ['danone', 'siemens', 'amr', 'vmware', 'wipro', 'mahindra']
# ['ford', 'cisco', 'fedEx', 'nippon']
# ['infosys', 'airtel', 'danone', 'nestle', 'avnet']
# ['ford', 'siemens', 'qualcomn', 'mastercard', 'merceds', 'at&t']
# ['reliance', 'fedEx', 'accenture', 'wipro']
# ['mastercard', 'vadafone', 'renault', 'metlife', 'netflix']
# ['coca-cola', 'onex', 'hyundai', 'netflix', 'ford', 'vmware']
# ['paypal', 'siemens', 'pepsi', 'super dry']
# ['toyota', 'nvidia', 'hdfc', 'airtel', 'panasonic']
# ['mastercard', 'ibm', 'renault', 'panasonic', 'danone', 'vmware']
# ['salesforce', 'volkswagen', 'airtel', 'facebook']
# ['maruhan', 'citigroup', 'acs', 'crh', 'addidas']
# ['nippon', 'jpmorgan', 'siemens', 'hp', 'maybank', 'vinci']
# ['capgemini', 'onex', 'vadafone', 'hitachi']
# ['tcs', 'oracle', 'reliance', 'avnet', 'tesla']
# ['amr', 'nvidia', 'cosmo', 'paypal', 'danaher', 'aegon']
# ['walmart', 'icbc', 'abb', 'cosmo']
# ['fedEx', 'nvidia', 'hitachi', 'woodland', 'salesforce']
# ['target', 'metlife', 'visa', 'citigroup', 'jpmorgan', 'tesco']
# ['microsoft', 'paypal', 'sodexo', 'Adobe']
# ['visa', 'tencent', 'vadafone', 'apple', 'nokia']
# ['mahindra', 'toyota', 'avnet', 'danone', 'loreal', 'tesco']
# ['mahindra', 'fluor', 'citigroup', 'hp']
# ['avnet', 'paypal', 'nestle', 'facebook', 'netflix']
# ['ford', 'tencent', 'sodexo', 'staples', 'johnson', 'american express']
# ['woodland', 'avnet', 'rbc', 'paypal']
# ['fedEx', 'wistron', 'vadafone', 'loreal', 'tencent']
# ['pubg', 'pepsi', 'mahindra', 'target', 'microsoft', 'facebook']
# ['panasonic', 'philip', 'qualcomm', 'paypal']
# ['ebay', 'hyundai', 'ford', 'merceds', 'nvidia']
# ['bmw', 'wistron', 'oracle', 'woodland', 'barclays', 'vinci']
# ['xiaomi', 'volkswagen', 'reliance', 'vmware']
# ['visa', 'mahindra', 'wistron', 'hyundai', 'woodland']
# ['toyota', 'pepsi', 'accenture', 'at&t', 'siemens', 'maruhan']
# ['accenture', 'siemens', 'intel', 'acs']
# ['disney', "mcdoland's", 'onex', 'rbc', 'citigroup']
# ['airtel', 'salesforce', 'comcast', 'amazon', 'nokia', 'panasonic']
# ['ford', 'crh', 'target', 'nvidia']
# ['tcs', 'walmart', 'cisco', 'disney', 'ebay']
# ['super dry', 'alibaba', 'airtel', 'wipro', 'amr', 'cisco']
# ['cosmo', 'hitachi', 'tencent', 'microsoft']
# ['abb', 'metlife', 'tesla', 'apple', 'reliance']
# ['vinci', 'sodexo', 'philip', 'panasonic', 'acs', 'american express']
# ["mcdoland's", 'johnson', 'metlife', 'addidas']
# ['philip', 'disney', 'netflix', 'volkswagen', 'reliance']
# ['tcs', 'tencent', 'maruhan', 'at&t', 'hitachi', 'fluor']
# ['american express', "mcdoland's", 'maybank', 'wipro']
# ['visa', 'rbc', 'caterpillar', 'ebay', 'merceds']
# ['microsoft', 'lg', 'sap', 'amazon', 'wipro', 'tencent']
# ['apple', 'citigroup', 'target', 'canon']
# ['mahindra', 'Adobe', 'super dry', 'siemens', 'sony']
# ['wipro', "mcdoland's", 'renault', 'coca-cola', 'target', 'salesforce']
# ['qualcomn', 'at&t', 'fedEx', 'avnet']
# ['metlife', 'panasonic', 'hitachi', 'netflix', 'toyota']
# ['target', 'tesla', 'nvidia', 'merceds', 'airtel', 'at&t']
# ['nvidia', 'sony', 'nike', 'rbc']
# ['hitachi', 'danaher', 'accenture', 'puma', 'ebay']
# ['ford', 'super dry', 'nippon', 'tesla', 'target', 'lg']
# ['woodland', 'salesforce', 'pepsi', 'target']
# ['capgemini', 'maybank', 'amazon', 'icici', 'addidas']
# ['oracle', 'microsoft', 'maybank', 'cosmo', 'Adobe', 'philip']
# ['sap', 'comcast', 'Adobe', 'visa']
# ['toyota', 'puma', 'salesforce', 'target', 'siemens']

# %%
user_brand={}

# %%
for i in output_:
    user_brand[i['user_name']]=i['brands']

# %%
user_brand
# Out:
# {'user1': ['aegon', 'fluor', 'crh', 'nvidia', 'hdfc'],
#  'user2': ['super dry', 'merceds', 'at&t', 'capgemini', 'coca-cola', 'onex'],
#  'user3': ['danone', 'visa', 'nike', 'toyota'],
#  'user4': ['hitachi', 'sap', 'acs', 'infosys', 'accenture'],
#  'user5': ['tencent',
#   'avnet',
#   'woodland',
#   'super dry',
#   'target',
#   'caterpillar'],
#  'user6': ['accenture', 'caterpillar', 'siemens', 'ibm'],
#  'user7': ['qualcomn', 'salesforce', 'citigroup', 'tencent', 'tesco'],
#  'user8': ['netflix', 'metlife', 'volkswagen', 'danaher', 'citigroup', 'visa'],
#  'user9': ['nippon', 'salesforce', 'aegon', 'johnson'],
#  'user10': ['philip', 'maruhan', 'Adobe', 'icici', 'vadafone'],
#  'user11': ['paypal', 'toyota', 'fluor', 'tencent', 'renault', 'samsung'],
#  'user12': ['abb', 'rbc', 'capgemini', 'danaher'],
#  'user13': ['microsoft', 'vadafone', 'qualcomn', 'disney', 'nokia'],
#  'user14': ['disney', 'woodland', 'caterpillar', 'starbucks', 'cisco', 'rbc'],
#  'user15': ['amazon', 'cosmo', 'vmware', 'microsoft'],
#  'user16': ['barclays', 'cisco', 'hdfc', 'ford', 'staples'],
#  'user17': ['oracle', 'caterpillar', 'hdfc', 'fluor', 'target', 'lg'],
#  'user18': ['addidas', 'tencent', "mcdoland's", 'renault'],
#  'user19': ['nestle', 'citigroup', 'johnson', 'microsoft', 'disney'],
#  'user20': ['volkswagen',
#   'aegon',
#   'super dry',
#   'airtel',
#   'maruhan',
#   'merceds'],
#  'user21': ['starbucks', 'sap', 'jpmorgan', 'hdfc'],
#  'user22': ['panasonic', 'caterpillar', 'hdfc', 'woodland', 'facebook'],
#  'user23': ['super dry',
#   'facebook',
#   'merceds',
#   "mcdoland's",
#   'johnson',
#   'cosmo'],
#  'user24': ['fluor', 'capgemini', 'pubg', 'citigroup'],
#  'user25': ['philip', 'hp', 'volkswagen', 'citigroup', 'danone'],
#  'user26': ['wipro', 'at&t', 'icici', 'nokia', 'starbucks', 'qualcomm'],
#  'user27': ['puma', 'avnet', 'cisco', 'loreal'],
#  'user28': ['visa', 'nokia', 'loreal', 'icici', 'alphabet'],
#  'user29': ['visa', 'super dry', 'infosys', 'pubg', 'facebook', 'salesforce'],
#  'user30': ['american express', 'panasonic', 'airtel', 'hyundai'],
#  'user31': ['alphabet', 'netflix', 'sodexo', 'target', 'xiaomi'],
#  'user32': ['avnet', 'hp', 'woodland', 'danone', 'crh', 'panasonic'],
#  'user33': ['accenture', 'woodland', 'puma', 'icici'],
#  'user34': ['danaher', 'pubg', 'accenture', 'netflix', 'visa'],
#  'user35': ['pubg', 'avnet', 'sony', 'super dry', 'comcast', 'samsung'],
#  'user36': ['airtel', 'merceds', 'icici', 'bmw'],
#  'user37': ['disney', 'american express', 'puma', 'ibm', 'hyundai'],
#  'user38': ['alphabet',
#   'merceds',
#   'airtel',
#   'caterpillar',
#   'Adobe',
#   'infosys'],
#  'user39': ['at&t', 'amr', 'vinci', 'disney'],
#  'user40': ['vadafone', 'metlife', "mcdoland's", 'puma', 'paypal'],
#  'user41': ['hdfc', 'danaher', 'jpmorgan', 'cosmo', 'icici', 'pubg'],
#  'user42': ['philip', 'tesla', 'avnet', 'super dry'],
#  'user43': ['crh', 'capgemini', 'ford', 'caterpillar', 'hp'],
#  'user44': ['wipro', 'aegon', 'nike', 'acs', 'nippon', 'nestle'],
#  'user45': ['sony', 'tcs', 'philip', 'intel'],
#  'user46': ['wipro', 'starbucks', 'amazon', 'johnson', 'mahindra'],
#  'user47': ['tesco', 'panasonic', 'ford', 'comcast', 'woodland', 'infosys'],
#  'user48': ['comcast', 'wipro', 'woodland', 'icbc'],
#  'user49': ['nokia', 'onex', 'mastercard', 'icbc', 'wipro'],
#  'user50': ['toyota', 'icbc', 'wistron', 'super dry', 'loreal', 'barclays'],
#  'user51': ['aegon', 'Adobe', 'mahindra', 'ibm'],
#  'user52': ['acs', 'mastercard', 'puma', 'aegon', 'capgemini'],
#  'user53': ['ford', 'johnson', 'alphabet', 'danaher', 'apple', 'cosmo'],
#  'user54': ['Adobe', 'nokia', 'starbucks', 'samsung'],
#  'user55': ['capgemini', 'reliance', 'mastercard', 'coca-cola', 'maybank'],
#  'user56': ['intel', 'fedEx', 'rbc', 'accenture', 'volkswagen', 'at&t'],
#  'user57': ['Adobe', 'mastercard', 'loreal', 'vadafone'],
#  'user58': ['coca-cola', 'at&t', 'airtel', 'barclays', 'staples'],
#  'user59': ['nippon', 'staples', 'metlife', 'walmart', 'sodexo', 'philip'],
#  'user60': ['pubg', 'reliance', 'volkswagen', 'mastercard'],
#  'user61': ['sony', 'cosmo', 'coca-cola', 'citigroup', 'comcast'],
#  'user62': ['target', 'nvidia', 'intel', 'mahindra', 'tencent', 'nike'],
#  'user63': ['maybank', 'sap', 'accenture', 'johnson'],
#  'user64': ['vadafone', 'hyundai', 'apple', 'wistron', 'coca-cola'],
#  'user65': ['fluor', 'avnet', 'starbucks', 'jpmorgan', 'fedEx', 'alibaba'],
#  'user66': ['panasonic', 'infosys', 'at&t', 'microsoft'],
#  'user67': ['barclays', 'woodland', 'maruhan', 'crh', 'vmware'],
#  'user68': ['ibm', 'johnson', 'pubg', 'cosmo', 'philip', 'nike'],
#  'user69': ['rbc', 'vadafone', 'metlife', 'citigroup'],
#  'user70': ['fedEx', 'apple', 'maruhan', 'qualcomn', 'ibm'],
#  'user71': ['salesforce', 'facebook', 'danone', 'cosmo', 'addidas', 'staples'],
#  'user72': ['sodexo', 'acs', 'sap', 'rbc'],
#  'user73': ["mcdoland's", 'salesforce', 'xiaomi', 'merceds', 'hyundai'],
#  'user74': ['vinci', 'woodland', 'icici', 'tesco', 'qualcomn', 'alibaba'],
#  'user75': ['mastercard', 'volkswagen', 'pepsi', 'tcs'],
#  'user76': ['hp', 'nvidia', 'nestle', 'capgemini', 'cisco'],
#  'user77': ['samsung',
#   'coca-cola',
#   'mahindra',
#   'capgemini',
#   'citigroup',
#   'pubg'],
#  'user78': ['wipro', 'coca-cola', 'fedEx', 'accenture'],
#  'user79': ['wistron', 'crh', 'amr', 'amazon', 'walmart'],
#  'user80': ['volkswagen', 'pubg', 'fluor', 'amr', 'nokia', 'nvidia'],
#  'user81': ['alphabet', 'disney', 'sony', 'oracle'],
#  'user82': ['merceds', 'danone', 'intel', 'starbucks', 'nippon'],
#  'user83': ['nippon', 'woodland', 'target', 'volkswagen', 'metlife', 'airtel'],
#  'user84': ['vadafone', 'amr', 'fedEx', 'visa'],
#  'user85': ['danaher', 'vadafone', 'caterpillar', 'mahindra', 'comcast'],
#  'user86': ['super dry', 'nippon', 'tesco', 'pepsi', 'paypal', 'visa'],
#  'user87': ['siemens', 'puma', 'amazon', 'woodland'],
#  'user88': ['mahindra', 'hitachi', 'target', 'walmart', 'renault'],
#  'user89': ['danone', 'bmw', 'paypal', 'renault', 'fluor', 'qualcomm'],
#  'user90': ['wistron', 'loreal', 'mastercard', 'pubg'],
#  'user91': ['fedEx', 'abb', 'nestle', 'alibaba', 'vadafone'],
#  'user92': ['volkswagen', 'tesla', 'xiaomi', 'loreal', 'wipro', 'bmw'],
#  'user93': ['at&t', 'danaher', 'loreal', 'avnet'],
#  'user94': ['target', 'amr', 'nokia', 'accenture', "mcdoland's"],
#  'user95': ['maybank', 'tesla', 'icbc', 'cisco', 'johnson', 'onex'],
#  'user96': ['danaher', 'comcast', 'vinci', 'sodexo'],
#  'user97': ['addidas', 'siemens', 'tesco', 'hyundai', 'cosmo'],
#  'user98': ['aegon', 'toyota', 'oracle', 'hdfc', 'canon', 'apple'],
#  'user99': ['vmware', 'crh', 'infosys', 'salesforce'],
#  'user100': ['xiaomi', 'nippon', 'jpmorgan', 'comcast', 'sodexo'],
#  'user101': ['toyota', 'hyundai', 'qualcomn', 'disney', 'rbc', 'reliance'],
#  'user102': ['woodland', 'cisco', 'visa', 'hitachi'],
#  'user103': ['Adobe', 'toyota', 'caterpillar', 'fedEx', 'qualcomm'],
#  'user104': ['Adobe', 'intel', 'comcast', 'hyundai', 'at&t', 'rbc'],
#  'user105': ['intel', 'canon', 'hdfc', 'abb'],
#  'user106': ['alphabet', 'sodexo', 'vmware', 'metlife', 'accenture'],
#  'user107': ['volkswagen', 'hitachi', 'at&t', 'acs', 'tcs', 'canon'],
#  'user108': ['hdfc', 'tencent', 'icici', 'renault'],
#  'user109': ['coca-cola', 'disney', 'comcast', 'apple', 'sodexo'],
#  'user110': ['merceds', 'tesco', 'johnson', 'staples', 'intel', 'infosys'],
#  'user111': ['aegon', 'acs', 'samsung', 'Adobe'],
#  'user112': ['puma', 'infosys', 'alphabet', 'salesforce', 'nestle'],
#  'user113': ['hdfc', 'onex', 'sodexo', 'fedEx', 'vmware', 'citigroup'],
#  'user114': ['aegon', 'onex', 'panasonic', 'pubg'],
#  'user115': ['capgemini', 'visa', 'panasonic', 'apple', "mcdoland's"],
#  'user116': ['nike', 'acs', 'mahindra', 'puma', 'alphabet', 'wipro'],
#  'user117': ['fluor', 'johnson', 'aegon', 'woodland'],
#  'user118': ['rbc', 'mahindra', 'nike', 'bmw', 'reliance'],
#  'user119': ['crh', 'sodexo', 'lg', 'comcast', 'qualcomn', 'target'],
#  'user120': ['paypal', 'ibm', 'abb', 'vadafone'],
#  'user121': ['facebook', 'hitachi', 'target', 'super dry', 'woodland'],
#  'user122': ['target', 'avnet', 'qualcomm', 'hp', 'sap', 'amazon'],
#  'user123': ['accenture', 'Adobe', 'mahindra', 'ebay'],
#  'user124': ['american express', 'oracle', 'johnson', 'visa', 'tencent'],
#  'user125': ['rbc', 'coca-cola', 'tencent', 'sap', 'tesco', 'ebay'],
#  'user126': ['infosys', 'mastercard', 'nestle', 'wipro'],
#  'user127': ['vmware', 'citigroup', 'icbc', 'ebay', 'puma'],
#  'user128': ['salesforce',
#   'sodexo',
#   'nvidia',
#   'nestle',
#   'accenture',
#   'nippon'],
#  'user129': ['woodland', 'nokia', 'danone', 'infosys'],
#  'user130': ['netflix', 'maruhan', 'amazon', 'johnson', 'amr'],
#  'user131': ['cosmo',
#   'capgemini',
#   'tencent',
#   'merceds',
#   'panasonic',
#   'infosys'],
#  'user132': ['icici', 'tencent', 'netflix', 'barclays'],
#  'user133': ['nestle', 'nippon', 'metlife', 'addidas', 'staples'],
#  'user134': ['staples',
#   'super dry',
#   'johnson',
#   'jpmorgan',
#   'starbucks',
#   'mastercard'],
#  'user135': ['hdfc', 'alibaba', 'hp', 'vadafone'],
#  'user136': ['nvidia', 'qualcomn', 'acs', 'target', 'citigroup'],
#  'user137': ['cisco',
#   'starbucks',
#   'accenture',
#   'american express',
#   'loreal',
#   'oracle'],
#  'user138': ['starbucks', 'aegon', 'volkswagen', 'nokia'],
#  'user139': ['amazon', 'rbc', 'sap', 'aegon', 'icbc'],
#  'user140': ['barclays',
#   'american express',
#   'volkswagen',
#   'puma',
#   'maybank',
#   'paypal'],
#  'user141': ['tesco', 'hdfc', 'philip', 'jpmorgan'],
#  'user142': ['volkswagen', 'coca-cola', 'hitachi', 'samsung', 'oracle'],
#  'user143': ['tencent', 'sap', 'vinci', 'intel', 'puma', 'tesco'],
#  'user144': ['crh', 'disney', 'sap', 'vinci'],
#  'user145': ['qualcomn', 'puma', 'canon', 'tesco', 'citigroup'],
#  'user146': ['ibm', 'vinci', 'johnson', 'fluor', 'tencent', 'tcs'],
#  'user147': ['vinci', 'ford', 'nvidia', 'intel'],
#  'user148': ['starbucks', 'hitachi', 'netflix', 'cisco', 'woodland'],
#  'user149': ['fluor',
#   'acs',
#   'citigroup',
#   'caterpillar',
#   'qualcomn',
#   'microsoft'],
#  'user150': ['intel', 'philip', 'comcast', 'oracle'],
#  'user151': ['citigroup', 'panasonic', 'puma', 'ebay', 'nestle'],
#  'user152': ['vadafone', 'apple', 'paypal', 'sap', 'comcast', 'xiaomi'],
#  'user153': ['sap', 'capgemini', 'cisco', 'microsoft'],
#  'user154': ['tcs', 'staples', 'maruhan', 'amazon', 'rbc'],
#  'user155': ['mastercard', 'sap', 'philip', 'alibaba', 'woodland', 'Adobe'],
#  'user156': ['qualcomn', 'pepsi', 'acs', 'intel'],
#  'user157': ['canon', 'hp', 'intel', 'vinci', 'capgemini'],
#  'user158': ['hp',
#   'airtel',
#   'caterpillar',
#   'merceds',
#   'mastercard',
#   'siemens'],
#  'user159': ['avnet', 'woodland', 'lg', 'vmware'],
#  'user160': ['nvidia', 'ford', 'abb', 'nike', 'fluor'],
#  'user161': ['icbc', 'qualcomn', 'cosmo', 'alibaba', 'Adobe', 'avnet'],
#  'user162': ['icbc', 'apple', 'intel', 'merceds'],
#  'user163': ['citigroup', 'apple', 'infosys', 'merceds', 'ebay'],
#  'user164': ['salesforce', 'vmware', 'disney', 'infosys', 'barclays', 'nike'],
#  'user165': ['intel', 'comcast', 'siemens', 'nike'],
#  'user166': ['vmware', 'pepsi', 'coca-cola', 'ford', 'maybank'],
#  'user167': ['bmw', 'toyota', 'amazon', 'ebay', 'puma', 'lg'],
#  'user168': ['capgemini', 'rbc', 'ibm', 'tcs'],
#  'user169': ['sodexo', 'ford', 'samsung', 'facebook', 'nike'],
#  'user170': ['target', 'amazon', 'samsung', 'airtel', 'super dry', 'nokia'],
#  'user171': ['abb', 'avnet', 'caterpillar', 'puma'],
#  'user172': ['apple', 'hdfc', 'samsung', 'disney', 'abb'],
#  'user173': ['loreal', 'Adobe', 'bmw', 'nestle', 'facebook', 'reliance'],
#  'user174': ['target', 'fluor', 'citigroup', 'woodland'],
#  'user175': ['barclays', 'apple', 'crh', 'Adobe', 'danaher'],
#  'user176': ['nike', 'coca-cola', 'renault', 'barclays', 'qualcomn', 'onex'],
#  'user177': ['ford', 'cisco', 'airtel', 'philip'],
#  'user178': ['acs', 'coca-cola', 'reliance', 'cosmo', 'woodland'],
#  'user179': ['paypal', 'renault', 'infosys', 'alibaba', 'staples', 'qualcomm'],
#  'user180': ['starbucks', 'hdfc', 'hyundai', 'vadafone'],
#  'user181': ['vinci', 'bmw', 'sony', 'danone', 'hp'],
#  'user182': ['icici', 'infosys', 'airtel', 'visa', 'walmart', 'nippon'],
#  'user183': ['abb', 'ebay', 'addidas', 'siemens'],
#  'user184': ['mastercard', 'panasonic', 'nippon', 'siemens', 'qualcomm'],
#  'user185': ['sap', 'maruhan', 'lg', 'fedEx', 'super dry', 'Adobe'],
#  'user186': ['nestle', 'facebook', 'onex', 'merceds'],
#  'user187': ['puma', 'hdfc', 'qualcomn', 'aegon', 'philip'],
#  'user188': ['super dry',
#   'vmware',
#   'tesco',
#   'microsoft',
#   'philip',
#   'jpmorgan'],
#  'user189': ['nippon', 'danaher', 'ibm', 'pubg'],
#  'user190': ['wipro', 'staples', 'fedEx', 'airtel', 'onex'],
#  'user191': ['capgemini', 'cosmo', 'hdfc', 'airtel', 'merceds', 'ford'],
#  'user192': ['pepsi', 'at&t', 'reliance', 'siemens'],
#  'user193': ['sap', 'american express', 'philip', 'cosmo', 'nike'],
#  'user194': ['philip',
#   'hitachi',
#   'starbucks',
#   'caterpillar',
#   'cisco',
#   'tesla'],
#  'user195': ['rbc', 'Adobe', 'at&t', 'merceds'],
#  'user196': ['nippon', 'siemens', 'tcs', "mcdoland's", 'caterpillar'],
#  'user197': ['cosmo', 'ebay', 'sony', 'rbc', 'xiaomi', 'hitachi'],
#  'user198': ['vadafone', 'hitachi', 'infosys', 'mahindra'],
#  'user199': ['facebook', 'tesco', 'disney', 'jpmorgan', 'super dry'],
#  'user200': ['hitachi', 'mahindra', 'staples', 'infosys', 'metlife', 'ebay'],
#  'user201': ['starbucks', 'pepsi', 'pubg', 'super dry'],
#  'user202': ['qualcomn', 'salesforce', 'cisco', 'nippon', 'capgemini'],
#  'user203': ['addidas', 'nokia', 'bmw', 'nike', 'super dry', 'ford'],
#  'user204': ['danaher', 'tencent', 'wipro', 'reliance'],
#  'user205': ['rbc', 'ibm', 'hyundai', 'paypal', 'tesla'],
#  'user206': ['oracle',
#   'Adobe',
#   'american express',
#   'starbucks',
#   'tcs',
#   'woodland'],
#  'user207': ['rbc', 'icbc', 'sodexo', 'danone'],
#  'user208': ['intel', 'sap', 'icici', 'nvidia', 'onex'],
#  'user209': ['tesla', 'lg', 'qualcomm', "mcdoland's", 'crh', 'qualcomn'],
#  'user210': ['ibm', 'apple', 'wipro', 'caterpillar'],
#  'user211': ['hdfc', 'metlife', 'coca-cola', 'xiaomi', 'staples'],
#  'user212': ['sony', 'nokia', 'cisco', 'ibm', 'canon', 'ebay'],
#  'user213': ['samsung', 'super dry', 'ibm', 'vmware'],
#  'user214': ['tesco', 'barclays', 'onex', 'philip', 'jpmorgan'],
#  'user215': ['starbucks', 'maybank', 'ebay', 'rbc', 'cosmo', 'hyundai'],
#  'user216': ['canon', 'crh', 'icbc', 'airtel'],
#  'user217': ['nvidia', 'target', 'pepsi', 'mastercard', 'infosys'],
#  'user218': ['icbc', 'ibm', 'jpmorgan', 'loreal', 'oracle', 'maruhan'],
#  'user219': ['addidas', 'tencent', 'puma', 'airtel'],
#  'user220': ['vmware', 'apple', 'pubg', 'icici', 'pepsi'],
#  'user221': ['apple', 'icbc', 'philip', 'ibm', 'mastercard', 'alibaba'],
#  'user222': ['mahindra', 'puma', 'paypal', 'tcs'],
#  'user223': ['ibm', 'citigroup', 'amazon', 'wipro', 'reliance'],
#  'user224': ['amr', 'starbucks', 'tesla', 'sodexo', 'toyota', 'canon'],
#  'user225': ['american express', 'Adobe', 'panasonic', 'walmart'],
#  'user226': ['super dry', 'sony', 'danone', 'walmart', 'alibaba'],
#  'user227': ['tencent',
#   'walmart',
#   'microsoft',
#   'crh',
#   'citigroup',
#   'mastercard'],
#  'user228': ['hp', 'citigroup', 'danaher', 'toyota'],
#  'user229': ['airtel', 'vmware', 'qualcomn', 'walmart', 'intel'],
#  'user230': ['loreal', 'nokia', 'volkswagen', 'philip', 'microsoft', 'abb'],
#  'user231': ['siemens', 'pubg', 'nokia', 'wipro'],
#  'user232': ['tesla', 'panasonic', 'oracle', 'siemens', 'renault'],
#  'user233': ['cosmo', 'staples', 'danone', 'merceds', 'addidas', 'Adobe'],
#  'user234': ['vadafone', 'sap', 'vmware', 'panasonic'],
#  'user235': ['visa', 'wistron', 'Adobe', 'intel', 'rbc'],
#  'user236': ['caterpillar', 'ford', 'amazon', 'johnson', 'pubg', 'netflix'],
#  'user237': ["mcdoland's", 'mahindra', 'reliance', 'lg'],
#  'user238': ['citigroup', 'nippon', 'mastercard', 'alibaba', 'acs'],
#  'user239': ['xiaomi', 'alphabet', 'hdfc', 'starbucks', 'maruhan', 'lg'],
#  'user240': ['addidas', 'amazon', 'toyota', 'siemens'],
#  'user241': ['maruhan', 'avnet', 'jpmorgan', 'philip', 'reliance'],
#  'user242': ['nokia', 'microsoft', 'pepsi', 'caterpillar', 'cisco', 'canon'],
#  'user243': ['woodland', 'facebook', 'nike', 'ebay'],
#  'user244': ['samsung', 'mahindra', 'puma', 'tcs', 'volkswagen'],
#  'user245': ['super dry', 'philip', 'intel', 'pubg', 'coca-cola', 'aegon'],
#  'user246': ['ford', 'loreal', 'facebook', 'addidas'],
#  'user247': ['reliance', 'metlife', 'tcs', 'intel', 'hitachi'],
#  'user248': ['tcs', 'nippon', 'mahindra', 'reliance', 'addidas', 'nestle'],
#  'user249': ['nike', 'sodexo', 'pubg', 'barclays'],
#  'user250': ['nestle', 'hp', 'nippon', 'ibm', 'renault'],
#  'user251': ['qualcomn', 'crh', 'johnson', 'merceds', 'nestle', 'mahindra'],
#  'user252': ['puma', 'reliance', 'target', 'johnson'],
#  'user253': ['wipro', 'panasonic', 'hp', 'cisco', 'amr'],
#  'user254': ['woodland', 'maruhan', 'crh', 'abb', 'oracle', 'amazon'],
#  'user255': ['maybank', 'tesco', 'qualcomm', 'vmware'],
#  'user256': ['loreal', 'nike', 'coca-cola', 'qualcomn', 'hitachi'],
#  'user257': ['puma', 'qualcomm', 'pubg', 'maruhan', 'tesla', 'addidas'],
#  'user258': ['addidas', 'ford', 'apple', 'acs'],
#  'user259': ['tesla', 'philip', 'renault', 'netflix', 'target'],
#  'user260': ['loreal', 'tencent', 'johnson', 'crh', 'onex', 'jpmorgan'],
#  'user261': ['wistron', 'microsoft', 'nvidia', 'maybank'],
#  'user262': ['fluor', 'facebook', 'mahindra', 'nokia', 'staples'],
#  'user263': ['xiaomi', 'philip', 'mahindra', 'nvidia', 'abb', 'disney'],
#  'user264': ['apple', 'sony', 'starbucks', 'pubg'],
#  'user265': ['maybank', 'citigroup', 'ford', 'vinci', 'rbc'],
#  'user266': ['woodland', 'wipro', 'merceds', 'icbc', 'accenture', 'samsung'],
#  'user267': ['avnet', 'salesforce', 'capgemini', 'nike'],
#  'user268': ['hp', 'renault', 'avnet', 'citigroup', 'tesla'],
#  'user269': ['johnson', 'visa', 'abb', 'tcs', 'mastercard', 'hyundai'],
#  'user270': ['ebay', 'cisco', 'intel', 'oracle'],
#  'user271': ['super dry', 'pepsi', 'hitachi', 'target', 'alibaba'],
#  'user272': ["mcdoland's", 'hyundai', 'nike', 'staples', 'ibm', 'siemens'],
#  'user273': ['loreal', 'paypal', 'reliance', 'infosys'],
#  'user274': ['airtel', 'toyota', 'cisco', 'panasonic', 'loreal'],
#  'user275': ['danone', 'panasonic', 'reliance', 'fedEx', 'rbc', 'tcs'],
#  'user276': ['cosmo', 'acs', 'caterpillar', 'lg'],
#  'user277': ['metlife', 'abb', 'loreal', 'starbucks', 'hyundai'],
#  'user278': ['cisco', 'icbc', 'maybank', 'toyota', 'nestle', 'facebook'],
#  'user279': ['qualcomm', 'oracle', 'airtel', 'addidas'],
#  'user280': ['Adobe', 'acs', 'hp', 'cosmo', 'walmart'],
#  'user281': ['volkswagen', 'paypal', 'ford', 'onex', 'metlife', 'caterpillar'],
#  'user282': ['bmw', 'avnet', 'mahindra', 'johnson'],
#  'user283': ['capgemini', 'panasonic', 'crh', 'metlife', 'paypal'],
#  'user284': ['merceds', 'hdfc', 'qualcomn', 'starbucks', 'visa', 'lg'],
#  'user285': ['hp', 'alphabet', 'vadafone', 'hyundai'],
#  'user286': ['acs', 'maruhan', 'nestle', 'nippon', "mcdoland's"],
#  'user287': ['nestle', 'onex', 'Adobe', 'addidas', 'johnson', 'facebook'],
#  'user288': ['amazon', 'citigroup', 'hdfc', "mcdoland's"],
#  'user289': ['amr', 'onex', 'toyota', 'Adobe', 'pepsi'],
#  'user290': ['hp', "mcdoland's", 'cisco', 'fluor', 'crh', 'icbc'],
#  'user291': ['loreal', 'puma', 'salesforce', 'nvidia'],
#  'user292': ['puma', 'nike', 'hitachi', 'citigroup', 'caterpillar'],
#  'user293': ['philip', 'super dry', 'barclays', 'aegon', 'johnson', 'Adobe'],
#  'user294': ['salesforce', 'onex', 'danaher', 'hyundai'],
#  'user295': ['apple', 'danone', 'nokia', 'merceds', 'ford'],
#  'user296': ['tesla', 'aegon', 'sodexo', 'airtel', 'starbucks', 'siemens'],
#  'user297': ['renault', 'samsung', 'canon', 'barclays'],
#  'user298': ['hitachi', 'addidas', 'tcs', 'wipro', 'woodland'],
#  'user299': ['qualcomn', 'apple', 'oracle', 'intel', 'rbc', 'vadafone'],
#  'user300': ['hitachi', 'intel', 'avnet', 'toyota'],
#  'user301': ['merceds', 'tesco', 'at&t', 'aegon', 'accenture'],
#  'user302': ['rbc', 'hitachi', 'danone', 'cisco', 'cosmo', 'target'],
#  'user303': ['qualcomn', 'paypal', 'addidas', 'at&t'],
#  'user304': ['cosmo', 'avnet', 'american express', 'hdfc', 'staples'],
#  'user305': ['nike', 'walmart', 'barclays', 'qualcomn', 'sap', 'pubg'],
#  'user306': ['fedEx', 'staples', 'citigroup', 'alphabet'],
#  'user307': ['philip', 'samsung', 'target', 'qualcomm', 'accenture'],
#  'user308': ['danaher', 'at&t', 'maybank', 'walmart', 'nvidia', 'staples'],
#  'user309': ['aegon', 'hdfc', 'renault', 'icbc'],
#  'user310': ['amazon', 'comcast', 'hitachi', 'tesla', 'super dry'],
#  'user311': ['airtel', 'toyota', 'volkswagen', 'alibaba', 'ibm', 'addidas'],
#  'user312': ['pepsi', 'hdfc', 'avnet', 'nokia'],
#  'user313': ['wipro', 'comcast', 'airtel', 'danaher', 'maybank'],
#  'user314': ['intel', 'fluor', 'metlife', 'icici', 'rbc', 'oracle'],
#  'user315': ['danaher', 'maybank', 'salesforce', 'bmw'],
#  'user316': ['icici', 'vinci', 'nippon', 'Adobe', 'starbucks'],
#  'user317': ['wistron', 'danaher', 'metlife', 'visa', 'tesla', 'hitachi'],
#  'user318': ['rbc', 'tcs', 'super dry', 'caterpillar'],
#  'user319': ['aegon', 'avnet', 'microsoft', 'johnson', 'ford'],
#  'user320': ['maybank', 'ibm', 'renault', 'wipro', 'walmart', 'citigroup'],
#  'user321': ['nvidia', 'mastercard', 'icici', 'cosmo'],
#  'user322': ['lg', 'amazon', 'nike', 'ford', 'merceds'],
#  'user323': ['lg', 'toyota', 'tcs', 'vinci', 'super dry', 'ford'],
#  'user324': ['ford', 'xiaomi', 'Adobe', 'paypal'],
#  'user325': ['capgemini', 'danone', 'mahindra', 'fedEx', 'pubg'],
#  'user326': ['lg', 'metlife', 'barclays', 'oracle', 'tencent', 'walmart'],
#  'user327': ['american express', 'nokia', 'tesco', 'qualcomm'],
#  'user328': ['wipro', 'nippon', 'disney', 'tencent', 'ibm'],
#  'user329': ['lg', 'sodexo', 'capgemini', 'acs', 'vadafone', 'nike'],
#  'user330': ['addidas', 'hyundai', 'reliance', 'nokia'],
#  'user331': ['samsung', 'onex', 'acs', 'caterpillar', 'siemens'],
#  'user332': ['qualcomn', 'ibm', 'renault', 'bmw', 'nestle', 'wistron'],
#  'user333': ['wistron', 'pubg', 'amazon', 'abb'],
#  'user334': ['siemens', 'metlife', 'icici', 'mahindra', 'coca-cola'],
#  'user335': ['siemens', 'tesco', 'caterpillar', 'pubg', 'alphabet', 'paypal'],
#  'user336': ['danaher', 'aegon', 'caterpillar', 'qualcomm'],
#  'user337': ['tesco', 'comcast', 'netflix', 'barclays', 'danaher'],
#  'user338': ['tesco', 'sap', 'airtel', 'paypal', 'tcs', 'loreal'],
#  'user339': ['samsung', 'philip', 'acs', 'danaher'],
#  'user340': ['philip', 'apple', 'at&t', 'maruhan', 'hdfc'],
#  'user341': ['target', 'puma', 'capgemini', 'hp', 'pepsi', 'johnson'],
#  'user342': ['oracle', 'amazon', 'hyundai', 'netflix'],
#  'user343': ['pubg', 'xiaomi', 'avnet', 'hitachi', 'netflix'],
#  'user344': ['visa', 'sodexo', 'acs', 'siemens', 'amr', 'sap'],
#  'user345': ['qualcomn', 'amazon', 'woodland', 'wipro'],
#  'user346': ['nvidia', 'puma', 'aegon', 'qualcomn', 'lg'],
#  'user347': ['microsoft', 'siemens', 'amr', 'addidas', 'johnson', 'staples'],
#  'user348': ['xiaomi', 'puma', 'coca-cola', 'pubg'],
#  'user349': ['danaher', 'staples', 'xiaomi', 'microsoft', 'fluor'],
#  'user350': ['puma', 'onex', 'vmware', 'hitachi', 'qualcomm', 'acs'],
#  'user351': ['danaher', 'Adobe', 'metlife', 'intel'],
#  'user352': ['bmw', 'vmware', 'avnet', 'ford', 'qualcomn'],
#  'user353': ['merceds', 'super dry', 'microsoft', 'amr', 'airtel', 'metlife'],
#  'user354': ['fedEx', 'wistron', 'avnet', 'facebook'],
#  'user355': ['amr', 'capgemini', 'starbucks', 'disney', 'abb'],
#  'user356': ['siemens', 'capgemini', 'acs', 'nike', 'wistron', 'toyota'],
#  'user357': ['sony', 'sap', 'starbucks', 'mahindra'],
#  'user358': ['johnson', 'capgemini', 'sony', 'nike', 'coca-cola'],
#  'user359': ['nvidia', 'starbucks', 'cosmo', 'hitachi', 'addidas', 'danone'],
#  'user360': ['accenture', 'intel', 'facebook', 'tencent'],
#  'user361': ['hitachi', 'icici', 'metlife', 'starbucks', 'johnson'],
#  'user362': ['toyota', 'fedEx', 'nippon', 'bmw', 'samsung', 'sodexo'],
#  'user363': ['ebay', 'nestle', 'maybank', 'wistron'],
#  'user364': ['capgemini', 'oracle', 'ebay', 'toyota', 'loreal'],
#  'user365': ['amazon', 'citigroup', 'disney', 'aegon', 'metlife', 'fedEx'],
#  'user366': ['capgemini', 'caterpillar', 'oracle', 'hdfc'],
#  'user367': ['woodland', 'airtel', 'vadafone', 'amr', 'mahindra'],
#  'user368': ['tesco', 'siemens', 'lg', 'target', 'qualcomn', 'cosmo'],
#  'user369': ['alibaba', 'samsung', 'nvidia', 'vinci'],
#  'user370': ['starbucks', 'sodexo', 'loreal', 'renault', 'cosmo'],
#  'user371': ['ibm', 'oracle', 'maybank', 'mastercard', 'disney', 'maruhan'],
#  'user372': ['onex', 'american express', 'canon', 'ebay'],
#  'user373': ['mahindra',
#   'american express',
#   'mastercard',
#   'infosys',
#   'nestle'],
#  'user374': ['icici', 'puma', 'johnson', 'tencent', 'tesco', 'icbc'],
#  'user375': ['rbc', 'volkswagen', 'vadafone', 'woodland'],
#  'user376': ['hp', 'vadafone', 'philip', 'hitachi', 'nvidia'],
#  'user377': ['renault', 'vinci', 'sony', 'philip', 'airtel', 'merceds'],
#  'user378': ['renault', 'nippon', 'fedEx', 'johnson'],
#  'user379': ['samsung', 'cisco', 'crh', 'hdfc', 'Adobe'],
#  'user380': ['caterpillar',
#   'cisco',
#   'jpmorgan',
#   'citigroup',
#   'airtel',
#   'comcast'],
#  'user381': ['salesforce', 'cosmo', 'ford', "mcdoland's"],
#  'user382': ['xiaomi', 'facebook', 'qualcomm', 'vmware', 'icici'],
#  'user383': ['hdfc',
#   'volkswagen',
#   'tencent',
#   'accenture',
#   'infosys',
#   'salesforce'],
#  'user384': ['netflix', 'intel', 'icbc', 'hp'],
#  'user385': ['mahindra', 'woodland', 'infosys', 'johnson', 'rbc'],
#  'user386': ['danaher', 'vadafone', 'onex', 'tesco', 'hyundai', 'facebook'],
#  'user387': ['walmart', 'intel', 'tcs', 'accenture'],
#  'user388': ['alibaba', 'reliance', 'hyundai', 'ibm', 'cosmo'],
#  'user389': ['netflix', 'tencent', 'ebay', 'onex', 'pubg', 'siemens'],
#  'user390': ['nippon', 'vadafone', 'ford', 'alphabet'],
#  'user391': ['danone', 'alibaba', 'panasonic', 'metlife', 'airtel'],
#  'user392': ['hitachi', 'hyundai', 'sap', 'cosmo', 'fluor', 'johnson'],
#  'user393': ['Adobe', 'disney', 'maruhan', 'sap'],
#  'user394': ['nvidia', 'avnet', 'sony', 'tencent', 'salesforce'],
#  'user395': ['toyota', 'sap', 'nike', 'cisco', 'nvidia', 'accenture'],
#  'user396': ['ibm', 'intel', 'accenture', 'icici'],
#  'user397': ['wistron', 'hp', 'crh', 'samsung', 'icbc'],
#  'user398': ['wipro', 'amr', 'bmw', 'mahindra', 'siemens', 'danaher'],
#  'user399': ['johnson', 'cisco', 'airtel', 'renault'],
#  'user400': ['at&t', 'barclays', 'tesco', 'icbc', 'accenture'],
#  'user401': ['coca-cola', 'amr', 'siemens', "mcdoland's", 'vmware', 'hyundai'],
#  'user402': ['super dry', 'mastercard', "mcdoland's", 'at&t'],
#  'user403': ['super dry', 'abb', 'johnson', 'nike', 'walmart'],
#  'user404': ['tesla',
#   'mastercard',
#   'paypal',
#   'accenture',
#   'loreal',
#   'hyundai'],
#  'user405': ['paypal', 'capgemini', 'addidas', 'facebook'],
#  'user406': ['nestle', 'loreal', 'hitachi', 'hyundai', 'renault'],
#  'user407': ['avnet',
#   'citigroup',
#   'airtel',
#   'salesforce',
#   'paypal',
#   'microsoft'],
#  'user408': ['tencent', 'staples', 'cisco', 'nestle'],
#  'user409': ['siemens', 'ibm', 'mahindra', 'staples', 'loreal'],
#  'user410': ['at&t', 'comcast', 'apple', 'avnet', "mcdoland's", 'canon'],
#  'user411': ['onex', 'nippon', 'nestle', 'lg'],
#  'user412': ['salesforce', 'tcs', 'at&t', 'hdfc', 'coca-cola'],
#  'user413': ['paypal', 'disney', 'apple', 'capgemini', 'amazon', 'nestle'],
#  'user414': ['amazon', 'cosmo', 'vinci', 'johnson'],
#  'user415': ['toyota', 'accenture', 'vinci', 'at&t', 'target'],
#  'user416': ['danone', 'hp', 'renault', 'nippon', 'citigroup', "mcdoland's"],
#  'user417': ['pepsi', 'johnson', 'rbc', 'tcs'],
#  'user418': ['nvidia', "mcdoland's", 'amr', 'sap', 'woodland'],
#  'user419': ['netflix', 'mastercard', 'abb', 'hitachi', 'danaher', 'nippon'],
#  'user420': ['microsoft', 'philip', 'infosys', 'wistron'],
#  'user421': ['alphabet', 'avnet', 'staples', 'canon', 'airtel'],
#  'user422': ['tesla', 'mahindra', 'samsung', 'hyundai', 'nippon', 'woodland'],
#  'user423': ['coca-cola', 'Adobe', 'cisco', 'tesco'],
#  'user424': ['avnet', 'mahindra', 'coca-cola', 'rbc', 'wistron'],
#  'user425': ['jpmorgan', 'facebook', 'microsoft', 'onex', 'icbc', 'canon'],
#  'user426': ['danaher', 'icbc', 'cisco', 'sodexo'],
#  'user427': ['hdfc', 'nvidia', 'infosys', 'alibaba', 'sony'],
#  'user428': ['philip', 'airtel', 'merceds', 'starbucks', 'johnson', 'samsung'],
#  'user429': ['airtel', 'coca-cola', 'maybank', 'maruhan'],
#  'user430': ['super dry', 'addidas', 'target', 'nokia', 'pubg'],
#  'user431': ['onex', 'pepsi', 'airtel', 'abb', 'sony', 'sodexo'],
#  'user432': ['hp', 'alphabet', 'oracle', 'bmw'],
#  'user433': ['icbc', 'jpmorgan', 'disney', 'woodland', 'nestle'],
#  'user434': ['johnson',
#   'tcs',
#   'american express',
#   'nvidia',
#   'icici',
#   'xiaomi'],
#  'user435': ['netflix', 'accenture', 'mahindra', 'crh'],
#  'user436': ['woodland', 'pubg', 'ford', 'tcs', 'hyundai'],
#  'user437': ['citigroup', 'bmw', 'pubg', 'hyundai', 'danone', 'philip'],
#  'user438': ['sodexo', 'walmart', 'pepsi', 'hp'],
#  'user439': ['merceds', 'oracle', 'citigroup', 'comcast', 'danaher'],
#  'user440': ['renault', 'icici', 'netflix', 'panasonic', 'johnson', 'icbc'],
#  'user441': ['reliance', 'ford', 'oracle', 'airtel'],
#  'user442': ['onex', 'amazon', 'oracle', 'nike', 'hyundai'],
#  'user443': ['vmware', 'icbc', 'johnson', 'toyota', 'maruhan', 'hitachi'],
#  'user444': ['nestle', 'acs', 'ebay', 'sony'],
#  'user445': ['target', 'cisco', 'danone', 'onex', 'cosmo'],
#  'user446': ['ebay', 'reliance', 'cosmo', 'nokia', 'rbc', 'woodland'],
#  'user447': ['apple', 'philip', 'wistron', 'hyundai'],
#  'user448': ['xiaomi', 'sodexo', 'visa', 'caterpillar', 'infosys'],
#  'user449': ['ebay', 'wistron', 'philip', 'siemens', 'paypal', 'sony'],
#  'user450': ['facebook', 'metlife', 'netflix', 'merceds'],
#  'user451': ['abb', 'bmw', 'qualcomm', 'danaher', 'avnet'],
#  'user452': ['coca-cola', 'jpmorgan', 'salesforce', 'xiaomi', 'amr', 'fedEx'],
#  'user453': ['ford', 'renault', 'philip', 'infosys'],
#  'user454': ['puma', 'target', 'pubg', 'at&t', 'hyundai'],
#  'user455': ['puma', 'tencent', 'vmware', 'panasonic', 'philip', 'lg'],
#  'user456': ['wistron', 'tencent', 'capgemini', 'reliance'],
#  'user457': ['onex', 'vadafone', 'staples', 'microsoft', 'intel'],
#  'user458': ['vmware', 'danaher', 'oracle', 'capgemini', 'target', 'rbc'],
#  'user459': ['tencent', 'paypal', 'ebay', 'netflix'],
#  'user460': ['citigroup', 'super dry', 'abb', 'lg', 'woodland'],
#  'user461': ['icici', 'sodexo', 'lg', 'wipro', 'comcast', 'hitachi'],
#  'user462': ['johnson', 'hdfc', 'maruhan', 'avnet'],
#  'user463': ['volkswagen', 'american express', 'sodexo', 'icbc', 'nippon'],
#  'user464': ['starbucks', 'vmware', 'visa', 'abb', 'renault', 'danaher'],
#  'user465': ['panasonic', 'reliance', 'samsung', 'super dry'],
#  'user466': ['philip', 'xiaomi', 'walmart', 'citigroup', 'maruhan'],
#  'user467': ['coca-cola', 'ford', 'puma', 'canon', 'starbucks', 'cisco'],
#  'user468': ['oracle', 'american express', 'acs', 'citigroup'],
#  'user469': ['fedEx', 'vadafone', 'avnet', 'qualcomn', 'tencent'],
#  'user470': ['canon', 'cisco', 'crh', 'airtel', 'qualcomm', 'johnson'],
#  'user471': ['hdfc', 'metlife', 'xiaomi', 'vinci'],
#  'user472': ['vmware', 'coca-cola', 'nippon', 'qualcomn', 'intel'],
#  'user473': ['starbucks',
#   'infosys',
#   'danaher',
#   'tesla',
#   'mahindra',
#   'vadafone'],
#  'user474': ['sony', 'xiaomi', 'avnet', 'apple'],
#  'user475': ['wistron', 'facebook', 'vmware', 'american express', 'sony'],
#  'user476': ['airtel', 'staples', 'nike', 'tencent', 'oracle', 'nokia'],
#  'user477': ['facebook', 'rbc', 'philip', 'maybank'],
#  'user478': ['onex', 'abb', 'wipro', 'mastercard', 'walmart'],
#  'user479': ['onex', 'maybank', 'hdfc', 'starbucks', 'super dry', 'amazon'],
#  'user480': ['facebook', 'salesforce', 'loreal', 'mahindra'],
#  'user481': ['philip', 'american express', 'tesco', 'staples', 'salesforce'],
#  'user482': ['volkswagen', 'tcs', "mcdoland's", 'fedEx', 'airtel', 'avnet'],
#  'user483': ['pubg', 'infosys', 'xiaomi', 'sodexo'],
#  'user484': ['mahindra', 'amr', 'siemens', 'maruhan', 'icici'],
#  'user485': ['danaher', 'hyundai', 'fluor', 'johnson', 'jpmorgan', 'samsung'],
#  'user486': ['vinci', 'qualcomn', 'airtel', 'tencent'],
#  'user487': ['tesco', 'abb', 'icici', 'oracle', 'american express'],
#  'user488': ['fluor', 'pubg', 'nippon', 'tcs', 'target', 'wipro'],
#  'user489': ['maybank', 'loreal', 'xiaomi', 'sodexo'],
#  'user490': ['maruhan', 'maybank', 'loreal', 'johnson', 'intel'],
#  'user491': ['metlife', 'nestle', 'coca-cola', 'johnson', 'hitachi', 'hp'],
#  'user492': ['nippon', 'intel', 'volkswagen', 'staples'],
#  'user493': ['qualcomm', 'vadafone', 'rbc', 'nvidia', 'reliance'],
#  'user494': ['vmware', 'toyota', 'nestle', 'vadafone', 'coca-cola', 'nippon'],
#  'user495': ['hp', 'staples', 'mastercard', 'vadafone'],
#  'user496': ['nokia', 'starbucks', 'oracle', 'accenture', 'tencent'],
#  'user497': ['reliance',
#   'icbc',
#   'caterpillar',
#   'ibm',
#   'starbucks',
#   'american express'],
#  'user498': ['icbc', 'super dry', 'crh', 'ebay'],
#  'user499': ['cisco', 'netflix', 'tesla', 'nvidia', 'american express'],
#  'user500': ['barclays', 'alphabet', 'tesco', 'philip', 'Adobe', 'jpmorgan'],
#  'user501': ['fedEx', 'airtel', 'cisco', 'ford'],
#  'user502': ['tesco', 'merceds', 'at&t', 'ebay', 'starbucks'],
#  'user503': ['caterpillar', 'target', 'staples', 'johnson', 'renault', 'nike'],
#  'user504': ["mcdoland's", 'amr', 'maybank', 'lg'],
#  'user505': ['hdfc', 'maruhan', 'crh', 'mahindra', 'accenture'],
#  'user506': ['icici', 'canon', 'abb', 'panasonic', 'ebay', 'mastercard'],
#  'user507': ['cosmo', 'staples', 'fluor', 'qualcomm'],
#  'user508': ['amazon', 'Adobe', 'rbc', 'comcast', 'ford'],
#  'user509': ['ebay', 'qualcomn', 'walmart', 'toyota', 'crh', 'netflix'],
#  'user510': ['tcs', 'at&t', 'nippon', 'nike'],
#  'user511': ['barclays', 'mastercard', 'hdfc', 'at&t', 'abb'],
#  'user512': ['infosys', 'puma', 'lg', 'bmw', 'fluor', 'tesla'],
#  'user513': ['tcs', 'walmart', 'starbucks', 'ebay'],
#  'user514': ['rbc', 'nvidia', 'aegon', 'vadafone', 'nippon'],
#  'user515': ['tesla', 'pubg', 'toyota', 'puma', 'xiaomi', 'hp'],
#  'user516': ['fedEx', 'facebook', 'amr', 'cisco'],
#  'user517': ['intel', 'qualcomn', 'nokia', 'vmware', 'jpmorgan'],
#  'user518': ['pubg', 'jpmorgan', 'hp', 'disney', 'rbc', 'cosmo'],
#  'user519': ['citigroup', 'sap', "mcdoland's", 'puma'],
#  'user520': ['johnson', 'ford', 'maybank', 'amazon', 'caterpillar'],
#  'user521': ['mastercard', 'lg', 'volkswagen', 'apple', 'pubg', "mcdoland's"],
#  'user522': ['at&t', 'paypal', 'renault', 'tesco'],
#  'user523': ['renault', 'starbucks', 'hitachi', 'intel', 'toyota'],
#  'user524': ['avnet', 'qualcomm', 'vmware', 'netflix', 'siemens', 'fluor'],
#  'user525': ['qualcomn', 'barclays', 'lg', 'nippon'],
#  'user526': ['airtel', 'pepsi', 'loreal', 'nokia', 'icici'],
#  'user527': ["mcdoland's", 'johnson', 'wipro', 'disney', 'infosys', 'samsung'],
#  'user528': ['amr', 'renault', 'nestle', 'johnson'],
#  'user529': ['renault', 'sap', 'nike', 'puma', 'volkswagen'],
#  'user530': ['accenture',
#   'maybank',
#   'volkswagen',
#   'vadafone',
#   'johnson',
#   'nippon'],
#  'user531': ['starbucks', 'mastercard', 'fluor', 'acs'],
#  'user532': ['icbc', 'rbc', 'abb', 'icici', 'fluor'],
#  'user533': ['cosmo', 'tencent', 'siemens', 'acs', 'pepsi', 'panasonic'],
#  'user534': ['walmart', 'toyota', 'super dry', 'xiaomi'],
#  'user535': ['metlife', 'rbc', 'accenture', 'starbucks', 'caterpillar'],
#  'user536': ['xiaomi',
#   "mcdoland's",
#   'microsoft',
#   'walmart',
#   'mahindra',
#   'avnet'],
#  'user537': ['johnson', 'danaher', 'puma', 'alibaba'],
#  'user538': ['intel', 'hyundai', 'philip', 'microsoft', 'icbc'],
#  'user539': ['cosmo', 'hdfc', 'bmw', 'alphabet', 'hyundai', 'jpmorgan'],
#  'user540': ['philip', 'Adobe', 'staples', 'at&t'],
#  'user541': ['mastercard', 'oracle', 'qualcomm', 'mahindra', 'staples'],
#  'user542': ['vinci', 'rbc', 'apple', 'microsoft', 'aegon', 'intel'],
#  'user543': ['maybank', 'fluor', 'amazon', 'tencent'],
#  'user544': ['toyota', 'capgemini', 'hyundai', "mcdoland's", 'sap'],
#  'user545': ['airtel', 'fluor', 'hdfc', 'fedEx', 'avnet', 'at&t'],
#  'user546': ['barclays', 'pubg', 'hyundai', 'qualcomm'],
#  'user547': ['comcast', 'renault', 'amazon', 'hp', 'danaher'],
#  'user548': ['abb', 'qualcomn', 'nokia', 'amazon', 'reliance', 'sony'],
#  'user549': ['toyota', 'nestle', 'paypal', 'qualcomm'],
#  'user550': ['danaher', 'danone', 'staples', 'lg', 'philip'],
#  'user551': ['abb', 'qualcomn', 'siemens', 'hyundai', 'alibaba', 'lg'],
#  'user552': ['tesla', 'netflix', 'apple', 'onex'],
#  'user553': ['maruhan', 'sap', 'woodland', 'loreal', 'danone'],
#  'user554': ['xiaomi', 'ibm', 'walmart', 'siemens', 'amr', 'alibaba'],
#  'user555': ['oracle', 'airtel', 'addidas', 'alibaba'],
#  'user556': ['metlife', 'apple', 'rbc', 'coca-cola', 'qualcomn'],
#  'user557': ['maruhan', 'paypal', 'nippon', 'alphabet', 'wipro', 'nvidia'],
#  'user558': ['ibm', 'american express', 'target', 'intel'],
#  'user559': ['lg', 'paypal', 'mastercard', 'facebook', 'nokia'],
#  'user560': ['bmw', 'nvidia', 'tesla', 'mahindra', 'metlife', 'merceds'],
#  'user561': ['comcast', 'accenture', "mcdoland's", 'merceds'],
#  'user562': ['danaher', 'airtel', 'cosmo', 'abb', 'cisco'],
#  'user563': ['xiaomi', 'amazon', 'pepsi', 'netflix', 'oracle', 'cisco'],
#  'user564': ['qualcomm', 'american express', 'aegon', 'alphabet'],
#  'user565': ['reliance', 'wipro', 'nestle', 'ibm', 'at&t'],
#  'user566': ['alphabet', 'sap', 'visa', 'icbc', 'renault', 'starbucks'],
#  'user567': ['metlife', 'lg', 'barclays', 'cisco'],
#  'user568': ["mcdoland's", 'ebay', 'vinci', 'american express', 'oracle'],
#  'user569': ['mastercard',
#   'nike',
#   'danaher',
#   'woodland',
#   'aegon',
#   'panasonic'],
#  'user570': ['target', 'renault', 'alibaba', 'coca-cola'],
#  'user571': ['nestle', 'wipro', 'onex', 'barclays', 'volkswagen'],
#  'user572': ['microsoft', 'apple', 'acs', 'qualcomm', 'comcast', 'nokia'],
#  'user573': ['alibaba', 'siemens', 'tesco', 'aegon'],
#  'user574': ['qualcomm', 'icici', 'target', 'ford', 'metlife'],
#  'user575': ['paypal', 'wistron', 'pubg', 'hp', 'volkswagen', 'mahindra'],
#  'user576': ['sodexo', 'wistron', 'merceds', 'vadafone'],
#  'user577': ['qualcomm', 'icbc', 'netflix', 'wistron', 'facebook'],
#  'user578': ['netflix', 'american express', 'Adobe', 'sap', 'amr', 'intel'],
#  'user579': ['ford', 'airtel', 'oracle', 'icici'],
#  'user580': ['mahindra', 'nippon', 'tencent', 'intel', 'starbucks'],
#  'user581': ['bmw', 'vadafone', 'avnet', 'alphabet', 'danaher', 'coca-cola'],
#  'user582': ['disney', 'puma', 'paypal', 'avnet'],
#  'user583': ['fluor', 'hitachi', 'qualcomm', 'qualcomn', 'hp'],
#  'user584': ['amazon', 'abb', 'maybank', 'bmw', 'at&t', 'infosys'],
#  'user585': ['hdfc', 'mahindra', 'woodland', 'sony'],
#  'user586': ['icici', 'fedEx', 'reliance', 'mastercard', 'loreal'],
#  'user587': ['hp', 'ebay', 'hdfc', 'target', 'vinci', 'pubg'],
#  'user588': ['tencent', 'capgemini', 'vadafone', 'samsung'],
#  'user589': ['siemens', 'rbc', 'sap', 'citigroup', 'avnet'],
#  'user590': ['metlife',
#   'samsung',
#   'american express',
#   'icbc',
#   'vmware',
#   'wipro'],
#  'user591': ['airtel', 'danone', 'toyota', 'fedEx'],
#  'user592': ['nippon', 'philip', 'sodexo', 'alphabet', 'target'],
#  'user593': ['fedEx', 'puma', 'jpmorgan', 'vinci', 'fluor', 'tesco'],
#  'user594': ['puma', 'avnet', 'qualcomm', 'renault'],
#  'user595': ['at&t', 'mastercard', 'volkswagen', 'pepsi', 'pubg'],
#  'user596': ['american express',
#   'airtel',
#   'walmart',
#   'hitachi',
#   'samsung',
#   'volkswagen'],
#  'user597': ['maybank', 'microsoft', 'mahindra', 'cisco'],
#  'user598': ['philip', 'netflix', 'tcs', 'hyundai', 'wistron'],
#  'user599': ['xiaomi',
#   "mcdoland's",
#   'alphabet',
#   'woodland',
#   'jpmorgan',
#   'wipro'],
#  'user600': ['hp', 'rbc', 'walmart', 'ford'],
#  'user601': ['canon', 'lg', 'jpmorgan', 'danone', 'samsung'],
#  'user602': ['infosys', 'philip', 'maruhan', 'avnet', "mcdoland's", 'xiaomi'],
#  'user603': ['johnson', 'Adobe', 'at&t', 'loreal'],
#  'user604': ['volkswagen', 'siemens', 'target', 'tesco', 'qualcomn'],
#  'user605': ['tesla',
#   'icici',
#   'fedEx',
#   'alibaba',
#   'xiaomi',
#   'american express'],
#  'user606': ['facebook', 'alphabet', 'Adobe', 'amr'],
#  'user607': ['sodexo', 'starbucks', 'sap', 'hitachi', 'hdfc'],
#  'user608': ['jpmorgan', 'airtel', 'onex', 'tencent', 'disney', 'danaher'],
#  'user609': ['volkswagen', 'reliance', 'xiaomi', 'lg'],
#  'user610': ['samsung', 'sony', 'johnson', 'amr', 'accenture'],
#  'user611': ['johnson', 'fluor', 'tcs', 'toyota', 'icbc', 'barclays'],
#  'user612': ['tesco', 'cisco', 'super dry', 'oracle'],
#  'user613': ['sodexo', 'pubg', 'johnson', 'qualcomm', 'volkswagen'],
#  'user614': ['qualcomm', 'paypal', 'abb', 'danaher', 'tencent', 'sodexo'],
#  'user615': ['apple', 'panasonic', 'coca-cola', 'Adobe'],
#  'user616': ['wipro', 'coca-cola', 'ebay', 'caterpillar', 'pepsi'],
#  'user617': ['wistron', 'cisco', 'vmware', 'visa', 'johnson', 'starbucks'],
#  'user618': ['salesforce', 'american express', 'ibm', 'infosys'],
#  'user619': ['paypal', 'apple', 'onex', "mcdoland's", 'ibm'],
#  'user620': ['walmart', 'avnet', 'tencent', 'amazon', 'woodland', 'amr'],
#  'user621': ['danone', 'amazon', 'target', 'ford'],
#  'user622': ['tesco', 'accenture', 'salesforce', 'xiaomi', 'mastercard'],
#  'user623': ['tcs', 'hyundai', 'fluor', 'jpmorgan', 'philip', 'johnson'],
#  'user624': ['vinci', 'ebay', 'hitachi', "mcdoland's"],
#  'user625': ['coca-cola', 'pepsi', 'philip', 'icbc', 'hitachi'],
#  'user626': ['tesla', 'netflix', 'onex', 'toyota', 'woodland', 'ibm'],
#  'user627': ['puma', 'mahindra', 'mastercard', 'netflix'],
#  'user628': ['Adobe', 'hp', 'vinci', 'comcast', 'oracle'],
#  'user629': ['hyundai', 'coca-cola', 'cisco', 'crh', 'amr', 'salesforce'],
#  'user630': ['amr', 'lg', 'merceds', 'samsung'],
#  'user631': ['nike', 'onex', 'sap', 'danone', 'super dry'],
#  'user632': ['fedEx', 'siemens', 'hitachi', 'renault', 'amr', 'super dry'],
#  'user633': ['alphabet', 'addidas', 'american express', 'wipro'],
#  'user634': ['abb', 'amazon', 'nippon', 'qualcomn', 'tcs'],
#  'user635': ['barclays', 'johnson', 'siemens', 'reliance', 'fluor', 'staples'],
#  'user636': ['vmware', 'oracle', 'fluor', 'hyundai'],
#  'user637': ['avnet', 'mahindra', 'vadafone', 'salesforce', 'mastercard'],
#  'user638': ['salesforce', 'wipro', 'johnson', 'sap', 'citigroup', 'amr'],
#  'user639': ['ford', 'intel', 'aegon', 'nvidia'],
#  'user640': ['tcs', 'paypal', 'facebook', 'onex', 'icbc'],
#  'user641': ['mastercard', 'Adobe', 'walmart', 'merceds', 'tesla', 'mahindra'],
#  'user642': ['metlife', 'philip', 'ibm', 'alphabet'],
#  'user643': ['vadafone', 'capgemini', 'nestle', 'maruhan', 'onex'],
#  'user644': ['microsoft', 'reliance', 'apple', "mcdoland's", 'sap', 'philip'],
#  'user645': ['amazon', 'icici', 'hdfc', 'samsung'],
#  'user646': ['nike', 'salesforce', 'hitachi', 'crh', 'loreal'],
#  'user647': ['icici', 'accenture', 'nokia', 'hyundai', 'onex', 'oracle'],
#  'user648': ['microsoft', 'hyundai', 'fluor', 'maybank'],
#  'user649': ['comcast', 'acs', 'tcs', 'avnet', 'crh'],
#  'user650': ['staples', 'tcs', 'samsung', 'reliance', 'icbc', 'vmware'],
#  'user651': ['acs', 'paypal', 'panasonic', 'accenture'],
#  'user652': ['acs', 'wistron', 'qualcomn', 'nvidia', 'visa'],
#  'user653': ['oracle', 'siemens', 'caterpillar', 'intel', 'nippon', 'airtel'],
#  'user654': ['fedEx', 'hitachi', 'citigroup', 'staples'],
#  'user655': ['ford', 'visa', 'sodexo', 'alphabet', 'comcast'],
#  'user656': ['amr', 'icbc', 'qualcomm', 'crh', 'aegon', 'nokia'],
#  'user657': ['salesforce', 'icbc', 'rbc', 'apple'],
#  'user658': ['abb', 'pubg', 'canon', 'vadafone', 'bmw'],
#  'user659': ['merceds', 'tcs', 'aegon', 'tencent', 'cosmo', 'target'],
#  'user660': ['onex', 'tencent', 'reliance', 'at&t'],
#  'user661': ['ibm', 'xiaomi', 'american express', 'wipro', 'vinci'],
#  'user662': ['crh', 'hitachi', 'lg', 'metlife', 'airtel', 'cisco'],
#  'user663': ['fedEx', 'maruhan', 'abb', 'siemens'],
#  'user664': ['mahindra', 'starbucks', 'facebook', 'toyota', 'mastercard'],
#  'user665': ['mastercard', 'abb', 'tcs', 'metlife', 'sony', 'ford'],
#  'user666': ['sodexo', 'oracle', 'hitachi', 'staples'],
#  'user667': ['panasonic', 'volkswagen', 'ford', 'addidas', 'facebook'],
#  'user668': ['Adobe', 'pubg', 'infosys', 'hyundai', 'avnet', 'coca-cola'],
#  'user669': ['maruhan', 'netflix', 'hyundai', 'salesforce'],
#  'user670': ['alibaba', 'nippon', 'danone', 'tencent', 'microsoft'],
#  'user671': ['at&t', 'hyundai', 'intel', 'ibm', 'infosys', 'maybank'],
#  'user672': ['hdfc', 'sony', 'airtel', 'siemens'],
#  'user673': ['capgemini', 'amr', 'samsung', 'hdfc', 'rbc'],
#  'user674': ['vmware', 'danone', 'alphabet', 'pubg', 'amazon', 'nvidia'],
#  'user675': ['sony', 'canon', 'ibm', 'addidas'],
#  'user676': ['barclays', 'vadafone', 'netflix', 'lg', 'caterpillar'],
#  'user677': ['alphabet', 'hitachi', 'jpmorgan', 'lg', 'visa', 'accenture'],
#  'user678': ['icbc', 'facebook', 'paypal', 'nike'],
#  'user679': ['amazon', 'sodexo', 'nvidia', 'tesco', 'aegon'],
#  'user680': ['fluor', 'siemens', "mcdoland's", 'sodexo', 'netflix', 'abb'],
#  'user681': ['apple', 'nokia', 'amazon', 'johnson'],
#  'user682': ['nippon', 'american express', 'nestle', 'target', 'icici'],
#  'user683': ['mastercard', 'cosmo', 'maybank', 'nestle', 'walmart', 'sony'],
#  'user684': ['maybank', 'vmware', 'super dry', 'at&t'],
#  'user685': ['fedEx', 'capgemini', 'hitachi', 'danaher', 'aegon'],
#  'user686': ['hp', 'reliance', 'acs', 'alibaba', 'tencent', 'xiaomi'],
#  'user687': ['alibaba', 'staples', 'merceds', 'vinci'],
#  'user688': ['alphabet', 'sodexo', 'merceds', 'starbucks', 'nvidia'],
#  'user689': ['hp', 'ibm', 'danone', 'apple', 'icbc', 'acs'],
#  'user690': ['renault', 'samsung', 'addidas', 'fluor'],
#  'user691': ['walmart', 'johnson', 'canon', 'Adobe', 'abb'],
#  'user692': ['ibm', 'nike', 'wistron', 'onex', 'caterpillar', 'alibaba'],
#  'user693': ['facebook', 'nippon', 'merceds', 'pepsi'],
#  'user694': ['mastercard', 'pubg', 'paypal', 'Adobe', 'starbucks'],
#  'user695': ['abb', 'danone', 'hdfc', 'puma', 'bmw', 'mahindra'],
#  'user696': ['accenture', 'cosmo', 'barclays', 'pepsi'],
#  'user697': ['jpmorgan', 'renault', 'nike', 'metlife', 'hdfc'],
#  'user698': ['nippon', 'amr', 'disney', 'apple', 'sap', 'microsoft'],
#  'user699': ['samsung', 'cosmo', 'amazon', 'nestle'],
#  'user700': ['fedEx', 'hp', 'nestle', 'accenture', 'lg'],
#  'user701': ['vadafone',
#   'woodland',
#   'american express',
#   'icbc',
#   'staples',
#   'pubg'],
#  'user702': ['tcs', 'Adobe', 'crh', 'sodexo'],
#  'user703': ['alibaba', 'puma', 'vadafone', 'maruhan', 'tcs'],
#  'user704': ['citigroup', 'salesforce', 'starbucks', 'philip', 'tcs', 'visa'],
#  'user705': ['johnson', 'jpmorgan', 'tcs', 'maybank'],
#  'user706': ['abb', 'jpmorgan', 'caterpillar', 'qualcomn', 'crh'],
#  'user707': ['disney', 'salesforce', 'mahindra', 'alibaba', 'vinci', 'hdfc'],
#  'user708': ['danaher', 'sony', 'reliance', 'citigroup'],
#  'user709': ['oracle', 'canon', 'hitachi', 'qualcomn', 'icici'],
#  'user710': ['alphabet', 'hdfc', 'woodland', 'tesco', 'johnson', 'vinci'],
#  'user711': ['ford', 'fluor', 'fedEx', 'abb'],
#  'user712': ['onex', 'facebook', 'icbc', 'reliance', 'capgemini'],
#  'user713': ['icbc', 'tencent', 'nokia', 'hyundai', 'microsoft', 'ebay'],
#  'user714': ['xiaomi', 'amr', 'ford', 'infosys'],
#  'user715': ['alphabet', 'barclays', 'oracle', 'danaher', 'facebook'],
#  'user716': ['nike',
#   'woodland',
#   'american express',
#   'cisco',
#   'icbc',
#   'salesforce'],
#  'user717': ['cisco', 'toyota', 'at&t', 'fluor'],
#  'user718': ['hitachi', 'disney', 'johnson', 'accenture', 'alibaba'],
#  'user719': ['tencent', 'visa', 'tesla', 'sodexo', 'nokia', 'philip'],
#  'user720': ['pepsi', 'amr', 'crh', 'target'],
#  'user721': ['netflix', 'tencent', 'airtel', 'johnson', 'starbucks'],
#  'user722': ['siemens', 'qualcomm', 'netflix', 'airtel', 'avnet', 'Adobe'],
#  'user723': ['icbc', 'american express', 'tencent', 'lg'],
#  'user724': ['apple', 'pepsi', 'caterpillar', 'addidas', 'alibaba'],
#  'user725': ['philip', 'onex', 'siemens', 'airtel', 'coca-cola', 'avnet'],
#  'user726': ['sap', 'volkswagen', 'bmw', 'addidas'],
#  'user727': ['nike', 'ibm', 'vinci', 'volkswagen', 'walmart'],
#  'user728': ['metlife', 'crh', 'qualcomn', 'tcs', 'apple', 'pubg'],
#  'user729': ['intel', 'jpmorgan', 'mahindra', 'airtel'],
#  'user730': ['walmart', 'apple', 'johnson', 'amazon', 'disney'],
#  'user731': ['pepsi', 'danaher', 'abb', 'danone', 'tencent', 'airtel'],
#  'user732': ['nokia', 'nike', 'vadafone', 'acs'],
#  'user733': ['samsung', 'pubg', 'oracle', 'amr', 'wistron'],
#  'user734': ['qualcomm', 'hp', 'wistron', 'xiaomi', 'target', 'danone'],
# ...
#  'user759': ['hyundai', 'volkswagen', 'sony', 'sap'],
#  'user760': ['tesla', 'accenture', 'fedEx', 'crh', 'loreal'],
#  'user761': ['siemens', 'vmware', 'nike', 'starbucks', 'comcast', 'johnson'],
#  'user762': ['nestle', 'ford', 'jpmorgan', 'volkswagen'],
#  'user763': ['caterpillar', 'alibaba', 'walmart', 'bmw', 'volkswagen'],
#  'user764': ['vadafone',
#   'woodland',
#   'nvidia',
#   'panasonic',
#   'tencent',
#   'aegon'],
#  'user765': ['sodexo', 'abb', 'fluor', 'siemens'],
#  'user766': ['coca-cola', 'panasonic', 'ibm', 'qualcomm', 'disney'],
#  'user767': ['siemens', 'oracle', 'at&t', 'johnson', 'tesco', 'mahindra'],
#  'user768': ['ebay', 'apple', 'qualcomn', 'panasonic'],
#  'user769': ['walmart', 'icici', 'jpmorgan', 'ibm', 'metlife'],
#  'user770': ['pubg', 'coca-cola', 'tesco', 'ford', 'reliance', 'tesla'],
#  'user771': ['merceds', 'aegon', 'jpmorgan', 'tesco'],
#  'user772': ['qualcomm', 'pubg', 'nike', 'walmart', 'disney'],
#  'user773': ['vadafone', 'salesforce', 'amr', 'paypal', 'hp', 'tcs'],
#  'user774': ['metlife', 'volkswagen', 'paypal', 'onex'],
#  'user775': ['hyundai', 'alibaba', 'oracle', 'intel', 'danone'],
#  'user776': ['at&t', 'woodland', 'cosmo', 'tesco', 'oracle', 'puma'],
#  'user777': ['tesla', 'xiaomi', 'loreal', 'ford'],
#  'user778': ['apple', 'coca-cola', 'tencent', 'danone', 'icbc'],
#  'user779': ['tcs', 'crh', 'airtel', 'infosys', 'amr', 'tencent'],
#  'user780': ['wistron', 'at&t', 'intel', 'qualcomn'],
#  'user781': ['amazon', 'cisco', 'canon', 'netflix', 'visa'],
#  'user782': ['citigroup', 'apple', 'accenture', 'comcast', 'fedEx', 'tencent'],
#  'user783': ['toyota', 'netflix', 'puma', 'facebook'],
#  'user784': ['canon', 'samsung', 'maybank', 'renault', 'volkswagen'],
#  'user785': ['abb',
#   'starbucks',
#   'mastercard',
#   'salesforce',
#   'walmart',
#   'Adobe'],
#  'user786': ['pubg', 'at&t', 'crh', 'hdfc'],
#  'user787': ['super dry', 'tesco', 'mahindra', 'panasonic', 'starbucks'],
#  'user788': ['ebay',
#   'nippon',
#   'nokia',
#   'danaher',
#   'american express',
#   'maruhan'],
#  'user789': ['apple', 'maybank', 'johnson', 'danone'],
#  'user790': ['ford', 'bmw', 'hdfc', 'paypal', 'nestle'],
#  'user791': ['hitachi', 'cisco', 'intel', 'nokia', 'danaher', 'salesforce'],
#  'user792': ['sony', 'aegon', 'barclays', 'apple'],
#  'user793': ['jpmorgan', 'icici', 'qualcomn', 'comcast', 'renault'],
#  'user794': ['loreal', 'renault', 'jpmorgan', 'accenture', 'at&t', 'disney'],
#  'user795': ['canon', 'qualcomm', 'addidas', 'johnson'],
#  'user796': ['comcast', 'metlife', 'reliance', 'nestle', 'cosmo'],
#  'user797': ['citigroup',
#   'merceds',
#   'vmware',
#   'alphabet',
#   'sodexo',
#   'siemens'],
#  'user798': ['oracle', 'avnet', 'qualcomm', 'wistron'],
#  'user799': ['salesforce', 'acs', 'nippon', 'danone', 'rbc'],
#  'user800': ['woodland', 'nokia', 'onex', 'loreal', 'Adobe', 'mahindra'],
#  'user801': ['cosmo', 'super dry', 'apple', 'microsoft'],
#  'user802': ['tesco', 'intel', 'icici', 'vinci', 'apple'],
#  'user803': ['siemens', 'hyundai', 'samsung', 'merceds', 'microsoft', 'at&t'],
#  'user804': ['alphabet', 'mastercard', 'lg', 'ford'],
#  'user805': ['canon', 'cosmo', 'infosys', 'walmart', 'vadafone'],
#  'user806': ['coca-cola', 'citigroup', 'pepsi', 'canon', 'nestle', 'merceds'],
#  'user807': ['vinci', 'fedEx', 'puma', 'johnson'],
#  'user808': ['staples', 'fedEx', 'pubg', 'tesco', 'vadafone'],
#  'user809': ['capgemini', 'hdfc', 'barclays', 'crh', 'lg', 'infosys'],
#  'user810': ['staples', 'super dry', 'apple', 'johnson'],
#  'user811': ['cosmo', 'american express', 'citigroup', 'visa', 'woodland'],
#  'user812': ['intel', 'johnson', 'visa', 'accenture', 'paypal', 'hyundai'],
#  'user813': ['salesforce', 'volkswagen', 'icici', 'ford'],
#  'user814': ['samsung', 'facebook', 'wipro', 'fluor', 'toyota'],
#  'user815': ['addidas', 'icici', "mcdoland's", 'fluor', 'rbc', 'toyota'],
#  'user816': ['super dry', 'danaher', 'coca-cola', 'disney'],
#  'user817': ['volkswagen', 'fluor', 'johnson', 'target', 'acs'],
#  'user818': ["mcdoland's", 'netflix', 'paypal', 'onex', 'apple', 'tcs'],
#  'user819': ['hitachi', 'visa', 'crh', 'intel'],
#  'user820': ['cosmo', 'loreal', 'alphabet', 'nokia', 'sony'],
#  'user821': ['merceds', 'panasonic', 'johnson', 'nike', 'puma', 'tencent'],
#  'user822': ['maybank', 'mahindra', 'facebook', 'starbucks'],
#  'user823': ['fedEx', 'rbc', 'coca-cola', 'hdfc', 'disney'],
#  'user824': ['johnson', 'facebook', 'wipro', 'bmw', 'amr', 'intel'],
#  'user825': ['woodland', 'capgemini', 'Adobe', 'nokia'],
#  'user826': ['citigroup', 'alphabet', 'jpmorgan', 'super dry', 'nvidia'],
#  'user827': ['metlife', 'woodland', 'starbucks', 'pubg', 'ford', 'super dry'],
#  'user828': ['wipro', 'crh', 'danaher', 'fedEx'],
#  'user829': ['accenture', 'qualcomm', 'hdfc', 'icici', 'vadafone'],
#  'user830': ['danaher', 'philip', 'canon', 'addidas', 'qualcomn', 'puma'],
#  'user831': ['panasonic', 'ibm', 'sap', 'merceds'],
#  'user832': ['merceds', 'puma', 'panasonic', 'Adobe', 'apple'],
#  'user833': ['wipro', 'canon', 'intel', 'avnet', 'icbc', 'maybank'],
#  'user834': ['facebook', 'hitachi', 'tencent', 'vinci'],
#  'user835': ['hdfc', 'infosys', 'staples', 'aegon', 'barclays'],
#  'user836': ['qualcomm', 'aegon', 'sap', 'paypal', 'fluor', 'alphabet'],
#  'user837': ['sony', 'super dry', 'qualcomn', 'volkswagen'],
#  'user838': ['hitachi', 'amr', 'tencent', 'visa', 'qualcomm'],
#  'user839': ['pubg', 'philip', 'super dry', 'fluor', 'alphabet', "mcdoland's"],
#  'user840': ['qualcomn', 'maybank', 'sony', 'merceds'],
#  'user841': ['ebay', 'hyundai', 'qualcomm', 'loreal', 'walmart'],
#  'user842': ['reliance', 'wistron', 'accenture', 'hitachi', 'nokia', 'bmw'],
#  'user843': ['onex', 'microsoft', 'vadafone', 'nestle'],
#  'user844': ['airtel', 'fluor', 'sap', 'qualcomn', 'danaher'],
#  'user845': ['abb', 'amazon', 'hdfc', 'airtel', 'onex', 'pepsi'],
#  'user846': ['pepsi', 'netflix', 'fedEx', 'bmw'],
#  'user847': ['xiaomi', 'alphabet', 'cosmo', 'citigroup', 'bmw'],
#  'user848': ['staples',
#   'disney',
#   'metlife',
#   'tesla',
#   'volkswagen',
#   'american express'],
#  'user849': ['nvidia', 'ford', 'coca-cola', 'avnet'],
#  'user850': ['walmart', 'coca-cola', 'sodexo', 'nestle', 'loreal'],
#  'user851': ['walmart', 'paypal', 'tesla', 'ford', 'staples', 'super dry'],
#  'user852': ['wistron', 'toyota', 'onex', 'tencent'],
#  'user853': ['xiaomi', 'jpmorgan', 'alibaba', 'disney', 'walmart'],
#  'user854': ['fluor', 'target', 'maybank', 'amr', 'qualcomn', 'pubg'],
#  'user855': ['salesforce', 'xiaomi', 'hdfc', 'cosmo'],
#  'user856': ['crh', 'sony', 'infosys', 'mastercard', 'tcs'],
#  'user857': ['sony', 'alibaba', 'barclays', 'capgemini', 'nvidia', 'canon'],
#  'user858': ['icbc', 'alibaba', 'wistron', 'fluor'],
#  'user859': ['danone', 'xiaomi', 'citigroup', 'tencent', 'addidas'],
#  'user860': ['oracle', 'cosmo', 'Adobe', 'qualcomn', 'alphabet', 'loreal'],
#  'user861': ['loreal', 'caterpillar', 'alphabet', 'nestle'],
#  'user862': ['mahindra', 'danaher', 'tcs', 'avnet', 'pubg'],
#  'user863': ['xiaomi', 'walmart', 'pubg', 'disney', 'volkswagen', 'microsoft'],
#  'user864': ['super dry', 'philip', 'canon', 'merceds'],
#  'user865': ['panasonic', 'paypal', 'philip', 'netflix', 'fedEx'],
#  'user866': ['ebay', 'fedEx', 'vadafone', 'tcs', 'johnson', 'cosmo'],
#  'user867': ['ebay', 'samsung', 'oracle', 'icici'],
#  'user868': ['alphabet', 'mahindra', 'acs', 'volkswagen', 'sap'],
#  'user869': ['ibm', 'accenture', 'hdfc', 'barclays', 'danone', 'hitachi'],
#  'user870': ['coca-cola', 'jpmorgan', 'acs', 'icici'],
#  'user871': ['xiaomi', 'jpmorgan', 'ebay', 'nestle', 'danone'],
#  'user872': ['nvidia', 'cosmo', 'ibm', 'renault', 'hitachi', 'hdfc'],
#  'user873': ['nike', 'vadafone', 'icbc', 'icici'],
#  'user874': ['american express', 'icici', 'acs', 'loreal', 'hitachi'],
#  'user875': ['pubg', 'crh', 'walmart', 'starbucks', 'tesla', 'oracle'],
#  'user876': ['american express', 'hp', 'citigroup', 'tcs'],
#  'user877': ['hp', 'danaher', 'salesforce', 'sodexo', 'starbucks'],
#  'user878': ['caterpillar', 'rbc', 'ford', 'icbc', 'acs', 'target'],
#  'user879': ['cosmo', 'ford', 'volkswagen', 'fluor'],
#  'user880': ['amazon', 'metlife', 'american express', 'coca-cola', 'samsung'],
#  'user881': ['qualcomm',
#   'disney',
#   'american express',
#   'infosys',
#   'tesla',
#   'salesforce'],
#  'user882': ['coca-cola', 'microsoft', 'wistron', 'infosys'],
#  'user883': ['walmart', 'nippon', 'oracle', 'citigroup', 'cosmo'],
#  'user884': ['wistron', 'fedEx', 'Adobe', 'addidas', 'icbc', 'sodexo'],
#  'user885': ['woodland', 'nippon', 'qualcomn', 'rbc'],
#  'user886': ['abb', 'visa', 'lg', 'xiaomi', 'reliance'],
#  'user887': ["mcdoland's",
#   'citigroup',
#   'infosys',
#   'netflix',
#   'reliance',
#   'hitachi'],
#  'user888': ['microsoft', 'sodexo', 'intel', 'acs'],
#  'user889': ['hitachi', 'loreal', 'metlife', 'salesforce', 'visa'],
#  'user890': ['citigroup',
#   'Adobe',
#   'mastercard',
#   'disney',
#   'nvidia',
#   'jpmorgan'],
#  'user891': ['ford', 'philip', 'vmware', 'danaher'],
#  'user892': ['capgemini', 'nokia', 'mastercard', 'disney', 'fluor'],
#  'user893': ['coca-cola', 'nike', 'vinci', 'cosmo', 'icici', 'rbc'],
#  'user894': ['fedEx', 'bmw', 'vadafone', 'ford'],
#  'user895': ['pubg', 'infosys', 'accenture', 'hp', 'philip'],
#  'user896': ['jpmorgan', 'metlife', 'johnson', 'accenture', 'nokia', 'cisco'],
#  'user897': ['puma', 'wistron', 'coca-cola', 'hitachi'],
#  'user898': ['hitachi', 'Adobe', 'bmw', 'nike', 'lg'],
#  'user899': ['target', 'rbc', 'qualcomm', 'nvidia', 'accenture', 'fedEx'],
#  'user900': ['onex', "mcdoland's", 'danaher', 'nvidia'],
#  'user901': ['vmware', 'fedEx', 'visa', 'walmart', 'oracle'],
#  'user902': ['mastercard',
#   'caterpillar',
#   'volkswagen',
#   'vadafone',
#   'icici',
#   'reliance'],
#  'user903': ['alphabet', 'metlife', 'loreal', 'sap'],
#  'user904': ['xiaomi', 'danaher', 'sap', 'johnson', 'volkswagen'],
#  'user905': ['facebook', 'aegon', 'bmw', 'jpmorgan', 'nippon', 'fedEx'],
#  'user906': ['oracle', 'hyundai', 'paypal', 'walmart'],
#  'user907': ['avnet', 'coca-cola', 'icici', 'maybank', 'cisco'],
#  'user908': ['renault', 'intel', 'starbucks', "mcdoland's", 'puma', 'cosmo'],
#  'user909': ['ebay', 'microsoft', 'panasonic', 'airtel'],
#  'user910': ['panasonic', 'hp', 'xiaomi', 'fluor', 'tcs'],
#  'user911': ['nokia', 'apple', 'Adobe', 'reliance', 'xiaomi', 'capgemini'],
#  'user912': ['danone', 'addidas', 'comcast', 'siemens'],
#  'user913': ['maybank', 'super dry', 'toyota', 'comcast', 'pubg'],
#  'user914': ['capgemini', 'amr', 'cosmo', 'cisco', 'at&t', 'accenture'],
#  'user915': ['icici', 'addidas', 'woodland', 'super dry'],
#  'user916': ['panasonic', 'caterpillar', 'nike', 'comcast', 'icbc'],
#  'user917': ['ebay', 'onex', 'samsung', 'walmart', 'staples', 'philip'],
#  'user918': ['johnson', 'amr', 'danone', 'capgemini'],
#  'user919': ['american express', 'onex', 'acs', 'hitachi', 'samsung'],
#  'user920': ['oracle', 'mastercard', 'jpmorgan', 'nestle', 'fluor', 'lg'],
#  'user921': ['mahindra', 'ibm', 'nestle', 'reliance'],
#  'user922': ['nike', 'barclays', 'alibaba', 'icbc', 'mahindra'],
#  'user923': ['intel', 'pubg', 'disney', 'sap', 'cisco', 'caterpillar'],
#  'user924': ['salesforce', 'nokia', 'lg', 'addidas'],
#  'user925': ['maybank', 'american express', 'johnson', 'fedEx', 'danone'],
#  'user926': ['reliance', 'xiaomi', 'tesla', 'Adobe', 'acs', 'target'],
#  'user927': ['Adobe', 'addidas', 'tesco', 'siemens'],
#  'user928': ['nvidia', 'metlife', 'mastercard', 'danaher', 'sony'],
#  'user929': ['super dry', 'netflix', 'volkswagen', 'ibm', 'tesla', 'metlife'],
#  'user930': ['comcast', 'ibm', 'capgemini', 'starbucks'],
#  'user931': ['canon', 'facebook', 'reliance', 'xiaomi', 'wipro'],
#  'user932': ['crh', 'loreal', 'mahindra', 'alibaba', 'johnson', 'airtel'],
#  'user933': ['avnet', 'qualcomn', 'salesforce', 'coca-cola'],
#  'user934': ['qualcomm', 'loreal', 'bmw', 'target', 'apple'],
#  'user935': ['intel', 'oracle', 'icici', 'walmart', 'at&t', 'disney'],
#  'user936': ['cosmo', 'johnson', 'hitachi', 'sodexo'],
#  'user937': ['bmw', 'infosys', 'starbucks', 'crh', 'abb'],
#  'user938': ['danone', 'siemens', 'amr', 'vmware', 'wipro', 'mahindra'],
#  'user939': ['ford', 'cisco', 'fedEx', 'nippon'],
#  'user940': ['infosys', 'airtel', 'danone', 'nestle', 'avnet'],
#  'user941': ['ford', 'siemens', 'qualcomn', 'mastercard', 'merceds', 'at&t'],
#  'user942': ['reliance', 'fedEx', 'accenture', 'wipro'],
#  'user943': ['mastercard', 'vadafone', 'renault', 'metlife', 'netflix'],
#  'user944': ['coca-cola', 'onex', 'hyundai', 'netflix', 'ford', 'vmware'],
#  'user945': ['paypal', 'siemens', 'pepsi', 'super dry'],
#  'user946': ['toyota', 'nvidia', 'hdfc', 'airtel', 'panasonic'],
#  'user947': ['mastercard', 'ibm', 'renault', 'panasonic', 'danone', 'vmware'],
#  'user948': ['salesforce', 'volkswagen', 'airtel', 'facebook'],
#  'user949': ['maruhan', 'citigroup', 'acs', 'crh', 'addidas'],
#  'user950': ['nippon', 'jpmorgan', 'siemens', 'hp', 'maybank', 'vinci'],
#  'user951': ['capgemini', 'onex', 'vadafone', 'hitachi'],
#  'user952': ['tcs', 'oracle', 'reliance', 'avnet', 'tesla'],
#  'user953': ['amr', 'nvidia', 'cosmo', 'paypal', 'danaher', 'aegon'],
#  'user954': ['walmart', 'icbc', 'abb', 'cosmo'],
#  'user955': ['fedEx', 'nvidia', 'hitachi', 'woodland', 'salesforce'],
#  'user956': ['target', 'metlife', 'visa', 'citigroup', 'jpmorgan', 'tesco'],
#  'user957': ['microsoft', 'paypal', 'sodexo', 'Adobe'],
#  'user958': ['visa', 'tencent', 'vadafone', 'apple', 'nokia'],
#  'user959': ['mahindra', 'toyota', 'avnet', 'danone', 'loreal', 'tesco'],
#  'user960': ['mahindra', 'fluor', 'citigroup', 'hp'],
#  'user961': ['avnet', 'paypal', 'nestle', 'facebook', 'netflix'],
#  'user962': ['ford',
#   'tencent',
#   'sodexo',
#   'staples',
#   'johnson',
#   'american express'],
#  'user963': ['woodland', 'avnet', 'rbc', 'paypal'],
#  'user964': ['fedEx', 'wistron', 'vadafone', 'loreal', 'tencent'],
#  'user965': ['pubg', 'pepsi', 'mahindra', 'target', 'microsoft', 'facebook'],
#  'user966': ['panasonic', 'philip', 'qualcomm', 'paypal'],
#  'user967': ['ebay', 'hyundai', 'ford', 'merceds', 'nvidia'],
#  'user968': ['bmw', 'wistron', 'oracle', 'woodland', 'barclays', 'vinci'],
#  'user969': ['xiaomi', 'volkswagen', 'reliance', 'vmware'],
#  'user970': ['visa', 'mahindra', 'wistron', 'hyundai', 'woodland'],
#  'user971': ['toyota', 'pepsi', 'accenture', 'at&t', 'siemens', 'maruhan'],
#  'user972': ['accenture', 'siemens', 'intel', 'acs'],
#  'user973': ['disney', "mcdoland's", 'onex', 'rbc', 'citigroup'],
#  'user974': ['airtel',
#   'salesforce',
#   'comcast',
#   'amazon',
#   'nokia',
#   'panasonic'],
#  'user975': ['ford', 'crh', 'target', 'nvidia'],
#  'user976': ['tcs', 'walmart', 'cisco', 'disney', 'ebay'],
#  'user977': ['super dry', 'alibaba', 'airtel', 'wipro', 'amr', 'cisco'],
#  'user978': ['cosmo', 'hitachi', 'tencent', 'microsoft'],
#  'user979': ['abb', 'metlife', 'tesla', 'apple', 'reliance'],
#  'user980': ['vinci',
#   'sodexo',
#   'philip',
#   'panasonic',
#   'acs',
#   'american express'],
#  'user981': ["mcdoland's", 'johnson', 'metlife', 'addidas'],
#  'user982': ['philip', 'disney', 'netflix', 'volkswagen', 'reliance'],
#  'user983': ['tcs', 'tencent', 'maruhan', 'at&t', 'hitachi', 'fluor'],
#  'user984': ['american express', "mcdoland's", 'maybank', 'wipro'],
#  'user985': ['visa', 'rbc', 'caterpillar', 'ebay', 'merceds'],
#  'user986': ['microsoft', 'lg', 'sap', 'amazon', 'wipro', 'tencent'],
#  'user987': ['apple', 'citigroup', 'target', 'canon'],
#  'user988': ['mahindra', 'Adobe', 'super dry', 'siemens', 'sony'],
#  'user989': ['wipro',
#   "mcdoland's",
#   'renault',
#   'coca-cola',
#   'target',
#   'salesforce'],
#  'user990': ['qualcomn', 'at&t', 'fedEx', 'avnet'],
#  'user991': ['metlife', 'panasonic', 'hitachi', 'netflix', 'toyota'],
#  'user992': ['target', 'tesla', 'nvidia', 'merceds', 'airtel', 'at&t'],
#  'user993': ['nvidia', 'sony', 'nike', 'rbc'],
#  'user994': ['hitachi', 'danaher', 'accenture', 'puma', 'ebay'],
#  'user995': ['ford', 'super dry', 'nippon', 'tesla', 'target', 'lg'],
#  'user996': ['woodland', 'salesforce', 'pepsi', 'target'],
#  'user997': ['capgemini', 'maybank', 'amazon', 'icici', 'addidas'],
#  'user998': ['oracle', 'microsoft', 'maybank', 'cosmo', 'Adobe', 'philip'],
#  'user999': ['sap', 'comcast', 'Adobe', 'visa'],
#  'user1000': ['toyota', 'puma', 'salesforce', 'target', 'siemens']}

# %%
complete_brands=[value  for values in user_brand.values() for value in values]

# %%
complete_brands
# Out:
# ['aegon',
#  'fluor',
#  'crh',
#  'nvidia',
#  'hdfc',
#  'super dry',
#  'merceds',
#  'at&t',
#  'capgemini',
#  'coca-cola',
#  'onex',
#  'danone',
#  'visa',
#  'nike',
#  'toyota',
#  'hitachi',
#  'sap',
#  'acs',
#  'infosys',
#  'accenture',
#  'tencent',
#  'avnet',
#  'woodland',
#  'super dry',
#  'target',
#  'caterpillar',
#  'accenture',
#  'caterpillar',
#  'siemens',
#  'ibm',
#  'qualcomn',
#  'salesforce',
#  'citigroup',
#  'tencent',
#  'tesco',
#  'netflix',
#  'metlife',
#  'volkswagen',
#  'danaher',
#  'citigroup',
#  'visa',
#  'nippon',
#  'salesforce',
#  'aegon',
#  'johnson',
#  'philip',
#  'maruhan',
#  'Adobe',
#  'icici',
#  'vadafone',
#  'paypal',
#  'toyota',
#  'fluor',
#  'tencent',
#  'renault',
#  'samsung',
#  'abb',
#  'rbc',
#  'capgemini',
#  'danaher',
#  'microsoft',
#  'vadafone',
#  'qualcomn',
#  'disney',
#  'nokia',
#  'disney',
#  'woodland',
#  'caterpillar',
#  'starbucks',
#  'cisco',
#  'rbc',
#  'amazon',
#  'cosmo',
#  'vmware',
#  'microsoft',
#  'barclays',
#  'cisco',
#  'hdfc',
#  'ford',
#  'staples',
#  'oracle',
#  'caterpillar',
#  'hdfc',
#  'fluor',
#  'target',
#  'lg',
#  'addidas',
#  'tencent',
#  "mcdoland's",
#  'renault',
#  'nestle',
#  'citigroup',
#  'johnson',
#  'microsoft',
#  'disney',
#  'volkswagen',
#  'aegon',
#  'super dry',
#  'airtel',
#  'maruhan',
#  'merceds',
#  'starbucks',
#  'sap',
#  'jpmorgan',
#  'hdfc',
#  'panasonic',
#  'caterpillar',
#  'hdfc',
#  'woodland',
#  'facebook',
#  'super dry',
#  'facebook',
#  'merceds',
#  "mcdoland's",
#  'johnson',
#  'cosmo',
#  'fluor',
#  'capgemini',
#  'pubg',
#  'citigroup',
#  'philip',
#  'hp',
#  'volkswagen',
#  'citigroup',
#  'danone',
#  'wipro',
#  'at&t',
#  'icici',
#  'nokia',
#  'starbucks',
#  'qualcomm',
#  'puma',
#  'avnet',
#  'cisco',
#  'loreal',
#  'visa',
#  'nokia',
#  'loreal',
#  'icici',
#  'alphabet',
#  'visa',
#  'super dry',
#  'infosys',
#  'pubg',
#  'facebook',
#  'salesforce',
#  'american express',
#  'panasonic',
#  'airtel',
#  'hyundai',
#  'alphabet',
#  'netflix',
#  'sodexo',
#  'target',
#  'xiaomi',
#  'avnet',
#  'hp',
#  'woodland',
#  'danone',
#  'crh',
#  'panasonic',
#  'accenture',
#  'woodland',
#  'puma',
#  'icici',
#  'danaher',
#  'pubg',
#  'accenture',
#  'netflix',
#  'visa',
#  'pubg',
#  'avnet',
#  'sony',
#  'super dry',
#  'comcast',
#  'samsung',
#  'airtel',
#  'merceds',
#  'icici',
#  'bmw',
#  'disney',
#  'american express',
#  'puma',
#  'ibm',
#  'hyundai',
#  'alphabet',
#  'merceds',
#  'airtel',
#  'caterpillar',
#  'Adobe',
#  'infosys',
#  'at&t',
#  'amr',
#  'vinci',
#  'disney',
#  'vadafone',
#  'metlife',
#  "mcdoland's",
#  'puma',
#  'paypal',
#  'hdfc',
#  'danaher',
#  'jpmorgan',
#  'cosmo',
#  'icici',
#  'pubg',
#  'philip',
#  'tesla',
#  'avnet',
#  'super dry',
#  'crh',
#  'capgemini',
#  'ford',
#  'caterpillar',
#  'hp',
#  'wipro',
#  'aegon',
#  'nike',
#  'acs',
#  'nippon',
#  'nestle',
#  'sony',
#  'tcs',
#  'philip',
#  'intel',
#  'wipro',
#  'starbucks',
#  'amazon',
#  'johnson',
#  'mahindra',
#  'tesco',
#  'panasonic',
#  'ford',
#  'comcast',
#  'woodland',
#  'infosys',
#  'comcast',
#  'wipro',
#  'woodland',
#  'icbc',
#  'nokia',
#  'onex',
#  'mastercard',
#  'icbc',
#  'wipro',
#  'toyota',
#  'icbc',
#  'wistron',
#  'super dry',
#  'loreal',
#  'barclays',
#  'aegon',
#  'Adobe',
#  'mahindra',
#  'ibm',
#  'acs',
#  'mastercard',
#  'puma',
#  'aegon',
#  'capgemini',
#  'ford',
#  'johnson',
#  'alphabet',
#  'danaher',
#  'apple',
#  'cosmo',
#  'Adobe',
#  'nokia',
#  'starbucks',
#  'samsung',
#  'capgemini',
#  'reliance',
#  'mastercard',
#  'coca-cola',
#  'maybank',
#  'intel',
#  'fedEx',
#  'rbc',
#  'accenture',
#  'volkswagen',
#  'at&t',
#  'Adobe',
#  'mastercard',
#  'loreal',
#  'vadafone',
#  'coca-cola',
#  'at&t',
#  'airtel',
#  'barclays',
#  'staples',
#  'nippon',
#  'staples',
#  'metlife',
#  'walmart',
#  'sodexo',
#  'philip',
#  'pubg',
#  'reliance',
#  'volkswagen',
#  'mastercard',
#  'sony',
#  'cosmo',
#  'coca-cola',
#  'citigroup',
#  'comcast',
#  'target',
#  'nvidia',
#  'intel',
#  'mahindra',
#  'tencent',
#  'nike',
#  'maybank',
#  'sap',
#  'accenture',
#  'johnson',
#  'vadafone',
#  'hyundai',
#  'apple',
#  'wistron',
#  'coca-cola',
#  'fluor',
#  'avnet',
#  'starbucks',
#  'jpmorgan',
#  'fedEx',
#  'alibaba',
#  'panasonic',
#  'infosys',
#  'at&t',
#  'microsoft',
#  'barclays',
#  'woodland',
#  'maruhan',
#  'crh',
#  'vmware',
#  'ibm',
#  'johnson',
#  'pubg',
#  'cosmo',
#  'philip',
#  'nike',
#  'rbc',
#  'vadafone',
#  'metlife',
#  'citigroup',
#  'fedEx',
#  'apple',
#  'maruhan',
#  'qualcomn',
#  'ibm',
#  'salesforce',
#  'facebook',
#  'danone',
#  'cosmo',
#  'addidas',
#  'staples',
#  'sodexo',
#  'acs',
#  'sap',
#  'rbc',
#  "mcdoland's",
#  'salesforce',
#  'xiaomi',
#  'merceds',
#  'hyundai',
#  'vinci',
#  'woodland',
#  'icici',
#  'tesco',
#  'qualcomn',
#  'alibaba',
#  'mastercard',
#  'volkswagen',
#  'pepsi',
#  'tcs',
#  'hp',
#  'nvidia',
#  'nestle',
#  'capgemini',
#  'cisco',
#  'samsung',
#  'coca-cola',
#  'mahindra',
#  'capgemini',
#  'citigroup',
#  'pubg',
#  'wipro',
#  'coca-cola',
#  'fedEx',
#  'accenture',
#  'wistron',
#  'crh',
#  'amr',
#  'amazon',
#  'walmart',
#  'volkswagen',
#  'pubg',
#  'fluor',
#  'amr',
#  'nokia',
#  'nvidia',
#  'alphabet',
#  'disney',
#  'sony',
#  'oracle',
#  'merceds',
#  'danone',
#  'intel',
#  'starbucks',
#  'nippon',
#  'nippon',
#  'woodland',
#  'target',
#  'volkswagen',
#  'metlife',
#  'airtel',
#  'vadafone',
#  'amr',
#  'fedEx',
#  'visa',
#  'danaher',
#  'vadafone',
#  'caterpillar',
#  'mahindra',
#  'comcast',
#  'super dry',
#  'nippon',
#  'tesco',
#  'pepsi',
#  'paypal',
#  'visa',
#  'siemens',
#  'puma',
#  'amazon',
#  'woodland',
#  'mahindra',
#  'hitachi',
#  'target',
#  'walmart',
#  'renault',
#  'danone',
#  'bmw',
#  'paypal',
#  'renault',
#  'fluor',
#  'qualcomm',
#  'wistron',
#  'loreal',
#  'mastercard',
#  'pubg',
#  'fedEx',
#  'abb',
#  'nestle',
#  'alibaba',
#  'vadafone',
#  'volkswagen',
#  'tesla',
#  'xiaomi',
#  'loreal',
#  'wipro',
#  'bmw',
#  'at&t',
#  'danaher',
#  'loreal',
#  'avnet',
#  'target',
#  'amr',
#  'nokia',
#  'accenture',
#  "mcdoland's",
#  'maybank',
#  'tesla',
#  'icbc',
#  'cisco',
#  'johnson',
#  'onex',
#  'danaher',
#  'comcast',
#  'vinci',
#  'sodexo',
#  'addidas',
#  'siemens',
#  'tesco',
#  'hyundai',
#  'cosmo',
#  'aegon',
#  'toyota',
#  'oracle',
#  'hdfc',
#  'canon',
#  'apple',
#  'vmware',
#  'crh',
#  'infosys',
#  'salesforce',
#  'xiaomi',
#  'nippon',
#  'jpmorgan',
#  'comcast',
#  'sodexo',
#  'toyota',
#  'hyundai',
#  'qualcomn',
#  'disney',
#  'rbc',
#  'reliance',
#  'woodland',
#  'cisco',
#  'visa',
#  'hitachi',
#  'Adobe',
#  'toyota',
#  'caterpillar',
#  'fedEx',
#  'qualcomm',
#  'Adobe',
#  'intel',
#  'comcast',
#  'hyundai',
#  'at&t',
#  'rbc',
#  'intel',
#  'canon',
#  'hdfc',
#  'abb',
#  'alphabet',
#  'sodexo',
#  'vmware',
#  'metlife',
#  'accenture',
#  'volkswagen',
#  'hitachi',
#  'at&t',
#  'acs',
#  'tcs',
#  'canon',
#  'hdfc',
#  'tencent',
#  'icici',
#  'renault',
#  'coca-cola',
#  'disney',
#  'comcast',
#  'apple',
#  'sodexo',
#  'merceds',
#  'tesco',
#  'johnson',
#  'staples',
#  'intel',
#  'infosys',
#  'aegon',
#  'acs',
#  'samsung',
#  'Adobe',
#  'puma',
#  'infosys',
#  'alphabet',
#  'salesforce',
#  'nestle',
#  'hdfc',
#  'onex',
#  'sodexo',
#  'fedEx',
#  'vmware',
#  'citigroup',
#  'aegon',
#  'onex',
#  'panasonic',
#  'pubg',
#  'capgemini',
#  'visa',
#  'panasonic',
#  'apple',
#  "mcdoland's",
#  'nike',
#  'acs',
#  'mahindra',
#  'puma',
#  'alphabet',
#  'wipro',
#  'fluor',
#  'johnson',
#  'aegon',
#  'woodland',
#  'rbc',
#  'mahindra',
#  'nike',
#  'bmw',
#  'reliance',
#  'crh',
#  'sodexo',
#  'lg',
#  'comcast',
#  'qualcomn',
#  'target',
#  'paypal',
#  'ibm',
#  'abb',
#  'vadafone',
#  'facebook',
#  'hitachi',
#  'target',
#  'super dry',
#  'woodland',
#  'target',
#  'avnet',
#  'qualcomm',
#  'hp',
#  'sap',
#  'amazon',
#  'accenture',
#  'Adobe',
#  'mahindra',
#  'ebay',
#  'american express',
#  'oracle',
#  'johnson',
#  'visa',
#  'tencent',
#  'rbc',
#  'coca-cola',
#  'tencent',
#  'sap',
#  'tesco',
#  'ebay',
#  'infosys',
#  'mastercard',
#  'nestle',
#  'wipro',
#  'vmware',
#  'citigroup',
#  'icbc',
#  'ebay',
#  'puma',
#  'salesforce',
#  'sodexo',
#  'nvidia',
#  'nestle',
#  'accenture',
#  'nippon',
#  'woodland',
#  'nokia',
#  'danone',
#  'infosys',
#  'netflix',
#  'maruhan',
#  'amazon',
#  'johnson',
#  'amr',
#  'cosmo',
#  'capgemini',
#  'tencent',
#  'merceds',
#  'panasonic',
#  'infosys',
#  'icici',
#  'tencent',
#  'netflix',
#  'barclays',
#  'nestle',
#  'nippon',
#  'metlife',
#  'addidas',
#  'staples',
#  'staples',
#  'super dry',
#  'johnson',
#  'jpmorgan',
#  'starbucks',
#  'mastercard',
#  'hdfc',
#  'alibaba',
#  'hp',
#  'vadafone',
#  'nvidia',
#  'qualcomn',
#  'acs',
#  'target',
#  'citigroup',
#  'cisco',
#  'starbucks',
#  'accenture',
#  'american express',
#  'loreal',
#  'oracle',
#  'starbucks',
#  'aegon',
#  'volkswagen',
#  'nokia',
#  'amazon',
#  'rbc',
#  'sap',
#  'aegon',
#  'icbc',
#  'barclays',
#  'american express',
#  'volkswagen',
#  'puma',
#  'maybank',
#  'paypal',
#  'tesco',
#  'hdfc',
#  'philip',
#  'jpmorgan',
#  'volkswagen',
#  'coca-cola',
#  'hitachi',
#  'samsung',
#  'oracle',
#  'tencent',
#  'sap',
#  'vinci',
#  'intel',
#  'puma',
#  'tesco',
#  'crh',
#  'disney',
#  'sap',
#  'vinci',
#  'qualcomn',
#  'puma',
#  'canon',
#  'tesco',
#  'citigroup',
#  'ibm',
#  'vinci',
#  'johnson',
#  'fluor',
#  'tencent',
#  'tcs',
#  'vinci',
#  'ford',
#  'nvidia',
#  'intel',
#  'starbucks',
#  'hitachi',
#  'netflix',
#  'cisco',
#  'woodland',
#  'fluor',
#  'acs',
#  'citigroup',
#  'caterpillar',
#  'qualcomn',
#  'microsoft',
#  'intel',
#  'philip',
#  'comcast',
#  'oracle',
#  'citigroup',
#  'panasonic',
#  'puma',
#  'ebay',
#  'nestle',
#  'vadafone',
#  'apple',
#  'paypal',
#  'sap',
#  'comcast',
#  'xiaomi',
#  'sap',
#  'capgemini',
#  'cisco',
#  'microsoft',
#  'tcs',
#  'staples',
#  'maruhan',
#  'amazon',
#  'rbc',
#  'mastercard',
#  'sap',
#  'philip',
#  'alibaba',
#  'woodland',
#  'Adobe',
#  'qualcomn',
#  'pepsi',
#  'acs',
#  'intel',
#  'canon',
#  'hp',
#  'intel',
#  'vinci',
#  'capgemini',
#  'hp',
#  'airtel',
#  'caterpillar',
#  'merceds',
#  'mastercard',
#  'siemens',
#  'avnet',
#  'woodland',
#  'lg',
#  'vmware',
#  'nvidia',
#  'ford',
#  'abb',
#  'nike',
#  'fluor',
#  'icbc',
#  'qualcomn',
#  'cosmo',
#  'alibaba',
#  'Adobe',
#  'avnet',
#  'icbc',
#  'apple',
#  'intel',
#  'merceds',
#  'citigroup',
#  'apple',
#  'infosys',
#  'merceds',
#  'ebay',
#  'salesforce',
#  'vmware',
#  'disney',
#  'infosys',
#  'barclays',
#  'nike',
#  'intel',
#  'comcast',
#  'siemens',
#  'nike',
#  'vmware',
#  'pepsi',
#  'coca-cola',
#  'ford',
#  'maybank',
#  'bmw',
#  'toyota',
#  'amazon',
#  'ebay',
#  'puma',
#  'lg',
#  'capgemini',
#  'rbc',
#  'ibm',
#  'tcs',
#  'sodexo',
#  'ford',
#  'samsung',
#  'facebook',
#  'nike',
#  'target',
#  'amazon',
#  'samsung',
#  'airtel',
#  'super dry',
#  'nokia',
#  'abb',
#  'avnet',
#  'caterpillar',
#  'puma',
#  'apple',
#  'hdfc',
#  'samsung',
#  'disney',
#  'abb',
#  'loreal',
#  'Adobe',
#  'bmw',
#  'nestle',
#  'facebook',
#  'reliance',
#  'target',
#  'fluor',
#  'citigroup',
#  'woodland',
#  'barclays',
#  'apple',
#  'crh',
#  'Adobe',
#  'danaher',
#  'nike',
#  'coca-cola',
#  'renault',
#  'barclays',
#  'qualcomn',
#  'onex',
#  'ford',
#  'cisco',
#  'airtel',
#  'philip',
#  'acs',
#  'coca-cola',
#  'reliance',
#  'cosmo',
#  'woodland',
#  'paypal',
#  'renault',
#  'infosys',
#  'alibaba',
#  'staples',
#  'qualcomm',
#  'starbucks',
#  'hdfc',
#  'hyundai',
#  'vadafone',
#  'vinci',
#  'bmw',
#  'sony',
#  'danone',
#  'hp',
#  'icici',
#  'infosys',
#  'airtel',
#  'visa',
#  'walmart',
#  'nippon',
#  'abb',
#  'ebay',
#  'addidas',
#  'siemens',
#  'mastercard',
#  'panasonic',
#  'nippon',
#  'siemens',
#  'qualcomm',
#  'sap',
#  'maruhan',
#  'lg',
#  'fedEx',
#  'super dry',
#  'Adobe',
#  'nestle',
#  'facebook',
#  'onex',
#  'merceds',
#  'puma',
#  'hdfc',
#  'qualcomn',
#  'aegon',
#  'philip',
#  'super dry',
#  'vmware',
#  'tesco',
#  'microsoft',
#  'philip',
#  'jpmorgan',
#  'nippon',
#  'danaher',
#  'ibm',
#  'pubg',
#  'wipro',
#  'staples',
#  'fedEx',
#  'airtel',
#  'onex',
#  'capgemini',
#  'cosmo',
#  'hdfc',
#  'airtel',
#  'merceds',
#  'ford',
#  'pepsi',
#  'at&t',
#  'reliance',
#  'siemens',
#  'sap',
#  'american express',
#  'philip',
#  'cosmo',
#  'nike',
#  'philip',
#  'hitachi',
#  'starbucks',
#  'caterpillar',
#  'cisco',
#  'tesla',
#  'rbc',
#  'Adobe',
#  'at&t',
#  'merceds',
#  'nippon',
#  'siemens',
#  'tcs',
#  "mcdoland's",
#  'caterpillar',
#  'cosmo',
#  'ebay',
#  'sony',
#  'rbc',
#  'xiaomi',
#  'hitachi',
#  'vadafone',
#  'hitachi',
#  'infosys',
#  'mahindra',
#  'facebook',
#  'tesco',
#  'disney',
#  'jpmorgan',
#  'super dry',
#  'hitachi',
#  'mahindra',
#  'staples',
#  'infosys',
#  'metlife',
#  ...]

# %%
brands_frequency=collections.Counter(complete_brands)

# %%
brands_frequency
# Out:
# Counter({'aegon': 39,
#          'fluor': 52,
#          'crh': 46,
#          'nvidia': 51,
#          'hdfc': 57,
#          'super dry': 56,
#          'merceds': 51,
#          'at&t': 50,
#          'capgemini': 49,
#          'coca-cola': 57,
#          'onex': 53,
#          'danone': 49,
#          'visa': 39,
#          'nike': 49,
#          'toyota': 45,
#          'hitachi': 66,
#          'sap': 48,
#          'acs': 47,
#          'infosys': 49,
#          'accenture': 52,
#          'tencent': 64,
#          'avnet': 58,
#          'woodland': 59,
#          'target': 56,
#          'caterpillar': 44,
#          'siemens': 58,
#          'ibm': 49,
#          'qualcomn': 57,
#          'salesforce': 51,
#          'citigroup': 58,
#          'tesco': 48,
#          'netflix': 50,
#          'metlife': 53,
#          'volkswagen': 54,
#          'danaher': 60,
#          'nippon': 54,
#          'johnson': 88,
#          'philip': 62,
#          'maruhan': 35,
#          'Adobe': 61,
#          'icici': 54,
#          'vadafone': 58,
#          'paypal': 54,
#          'renault': 45,
#          'samsung': 45,
#          'abb': 49,
#          'rbc': 54,
#          'microsoft': 44,
#          'disney': 44,
#          'nokia': 50,
#          'starbucks': 61,
#          'cisco': 52,
#          'amazon': 47,
#          'cosmo': 61,
#          'vmware': 43,
#          'barclays': 37,
#          'ford': 63,
#          'staples': 46,
#          'oracle': 59,
#          'lg': 47,
#          'addidas': 43,
#          "mcdoland's": 45,
#          'nestle': 50,
#          'airtel': 65,
#          'jpmorgan': 46,
#          'panasonic': 45,
#          'facebook': 45,
#          'pubg': 62,
#          'hp': 47,
#          'wipro': 46,
#          'qualcomm': 47,
#          'puma': 53,
#          'loreal': 51,
#          'alphabet': 43,
#          'american express': 48,
#          'hyundai': 55,
#          'sodexo': 49,
#          'xiaomi': 50,
#          'sony': 37,
#          'comcast': 40,
#          'bmw': 39,
#          'amr': 47,
#          'vinci': 36,
#          'tesla': 39,
#          'tcs': 55,
#          'intel': 56,
#          'mahindra': 65,
#          'icbc': 57,
#          'mastercard': 55,
#          'wistron': 39,
#          'apple': 54,
#          'reliance': 51,
#          'maybank': 46,
#          'fedEx': 54,
#          'walmart': 51,
#          'alibaba': 39,
#          'pepsi': 35,
#          'canon': 33,
#          'ebay': 45})

# %%
from queue import PriorityQueue

# %%
q = PriorityQueue()

# %%
q.put(4)
q.put(2)
q.put(5)
q.put(1)
q.put(3)

# %%
while not q.empty():
    next_item = q.get()
    print(next_item)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
def findsimilarity_returnrecommendations(users,brands):
    length=len(users)
    recommendations={}
    similarity=[PriorityQueue() for i in range(length)]
    for i in range(len(brands)):
        maxsimilarity=0
        maxuser=0
        for j in range(len(brands)):
            if(i!=j):
                similar=len(set(brands[i]).intersection(set(brands[j])))
                similarity[i].put([similar*-1,j])
                '''if(i!=j and (similarity[i][j])>maxsimilarity):
                    maxsimilarity=(similarity[i][j])
                    maxuser=j'''
        q=similarity[i]
        #recommend_list=recommendations_helper(q,i)
        recommend_list=[]
        first=q.get()
        recommend_list+=list(set(brands[first[1]])-set(brands[i]))
        while(not q.empty()):
            next_max=q.get()
            if(next_max[0]!=first[0]):
                break;
            recommend_list+=list(set(brands[next_max[1]])-set(brands[i]))
        if(len(recommend_list)<15):
            while(len(recommend_list)<15):
                next_max=q.get()
                recommend_list+=list(set(brands[next_max[1]])-set(brands[i]))
        recommendations[users[i]]=recommend_list
                
        
        
                
    return recommendations

# %%
def recommendations_helper(q,user):
    recommend_list=[]
    first=q.get()
    print(type(first))
    recommend_list+=list(set(brands[first[1]])-set(brands[user]))
    while(not q.empty()):
        next_max=q.get()
        if(next_max[0]!=first[0]):
            break;
        recommend_list+=list(set(brands[next_max[1]])-set(brands[user]))
    if(len(recommend_list)<15):
        while(len(recommend_list)<15):
            next_max=q.get()
            recommend_list+=list(set(brands[next_max[1]])-set(brands[user]))
            
    return recommend_list

# %%
#if their exists similarity 
#not required
'''def totalrecommendataions(similarity,users,brands):
    recommendations={}
    for i in users:
        recommendations[i]=set()
    for i in range(len(similarity)):
        maxsimilarity=0
        maxuser=0
        for j in range(len(similarity[0])):
                if(i!=j and (similarity[i][j])>maxsimilarity):
                    maxsimilarity=(similarity[i][j])
                    maxuser=j
                    
        recommendations[users[i]]=list(set(brands[maxuser])-set(brands[i]))
    return recommendations'''
# Out:
# 'def totalrecommendataions(similarity,users,brands):\n    recommendations={}\n    for i in users:\n        recommendations[i]=set()\n    for i in range(len(similarity)):\n        maxsimilarity=0\n        maxuser=0\n        for j in range(len(similarity[0])):\n                if(i!=j and (similarity[i][j])>maxsimilarity):\n                    maxsimilarity=(similarity[i][j])\n                    maxuser=j\n                    \n        recommendations[users[i]]=list(set(brands[maxuser])-set(brands[i]))\n    return recommendations'

# %%
def recommendRand5(brands):
    print(len(brands))
    randlist=set()
    while(len(randlist)<5):
        randlist.add(random.choice(brands))
    return list(randlist)

# %%
def recommend(user_brand):
    users=[]
    brands=[]
    recommendations={}
    for key,value in user_brand.items():
        users.append(key)
        brands.append(value)
    recommendations=findsimilarity_returnrecommendations(users,brands)
    #print(len(users))
    '''for i in range(len(users)):  
        q=similarity[i]
        while not q.empty():
            next_item = q.get()
            print(next_item,end=" ")
        print()'''
    #recommending random 5  brand from recommendation list
    for i in users:
        recommendations[i]=recommendRand5(recommendations[i])
        print(recommendations[i])
    return recommendations

# %%
recommedations=recommend(user_brand)
# Out:
# 84
# ['ford', 'paypal', 'panasonic', 'airtel', 'infosys']
# 110
# ['nokia', 'citigroup', 'hyundai', 'disney', 'panasonic']
# 17
# ['siemens', 'accenture', 'acs', 'onex', 'super dry']
# 75
# ['mahindra', 'icici', 'tcs', 'onex', 'bmw']
# 16
# ['amazon', 'hitachi', 'facebook', 'lg', 'panasonic']
# 54
# ['wistron', 'pepsi', 'walmart', 'tcs', 'alibaba']
# 17
# ['target', 'sap', 'nvidia', 'puma', 'ebay']
# 17
# ['tesco', 'ibm', 'tesla', 'vadafone', 'airtel']
# 40
# ['accenture', 'acs', 'jpmorgan', 'fluor', 'volkswagen']
# 63
# ['avnet', 'mastercard', 'at&t', 'icbc', 'xiaomi']
# 16
# ['addidas', 'johnson', 'tcs', 'qualcomm', 'alibaba']
# 17
# ['vmware', 'target', 'starbucks', 'hitachi', 'qualcomm']
# 66
# ['amazon', 'citigroup', 'acs', 'icbc', 'reliance']
# 17
# ['hitachi', 'facebook', 'pubg', 'hyundai', 'panasonic']
# 24
# ['danone', 'philip', 'pubg', 'nvidia', 'super dry']
# 17
# ['avnet', 'metlife', 'american express', 'aegon', 'cosmo']
# 15
# ['avnet', 'mastercard', 'aegon', 'capgemini', 'toyota']
# 35
# ['icici', 'citigroup', 'cosmo', 'tcs', 'samsung']
# 85
# ['crh', 'sap', 'qualcomn', 'capgemini', 'onex']
# 17
# ['woodland', "mcdoland's", 'johnson', 'alphabet', 'bmw']
# 18
# ['avnet', 'sodexo', 'hyundai', 'xiaomi', 'maruhan']
# 50
# ['comcast', 'danaher', 'hp', 'aegon', 'volkswagen']
# 134
# ['renault', 'woodland', 'jpmorgan', 'panasonic', 'xiaomi']
# 16
# ['danone', 'mahindra', 'target', 'philip', 'bmw']
# 15
# ['woodland', 'sony', 'crh', 'pubg', 'bmw']
# 16
# ['mahindra', 'amazon', 'mastercard', 'pubg', 'icbc']
# 28
# ['ford', 'danaher', 'nvidia', 'paypal', 'airtel']
# 16
# ['microsoft', 'pepsi', 'walmart', 'nippon', 'volkswagen']
# 95
# ['starbucks', 'accenture', 'addidas', 'tencent', 'airtel']
# 28
# ['Adobe', 'philip', 'walmart', 'nvidia', 'puma']
# 16
# ['renault', 'metlife', 'crh', 'philip', 'lg']
# 112
# ['mahindra', 'wistron', 'oracle', 'wipro', 'icbc']
# 32
# ['tesco', 'at&t', 'ibm', 'icbc', 'vadafone']
# 17
# ['icici', 'metlife', 'hitachi', 'citigroup', 'jpmorgan']
# 15
# ['mahindra', 'citigroup', 'capgemini', 'coca-cola', 'visa']
# 45
# ['target', 'hp', 'loreal', 'nvidia', 'super dry']
# 58
# ['intel', 'starbucks', 'icbc', 'reliance', 'paypal']
# 15
# ['icici', 'tesco', 'hp', 'toyota', 'salesforce']
# 28
# ['renault', 'salesforce', 'accenture', 'nippon', 'apple']
# 57
# ['amr', 'maybank', 'ford', 'ibm', 'volkswagen']
# 17
# ['accenture', 'hyundai', 'nike', 'alphabet', 'bmw']
# 69
# ['comcast', 'starbucks', 'oracle', 'citigroup', 'airtel']
# 66
# ['target', 'abb', 'pubg', 'icbc', 'jpmorgan']
# 16
# ['capgemini', 'puma', 'infosys', 'salesforce', 'samsung']
# 40
# ['metlife', 'abb', 'merceds', 'reliance', 'salesforce']
# 117
# ['maybank', 'metlife', 'rbc', 'sap', 'apple']
# 18
# ['crh', 'at&t', 'hp', 'johnson', 'alibaba']
# 17
# ['maybank', 'hitachi', 'nokia', 'qualcomn', 'onex']
# 17
# ['comcast', 'cisco', 'airtel', 'tesla', 'alibaba']
# 18
# ['Adobe', 'facebook', 'ibm', 'airtel', 'maruhan']
# 24
# ['mastercard', 'walmart', 'staples', 'loreal', 'super dry']
# 52
# ['wistron', 'wipro', 'fedEx', 'hdfc', 'nippon']
# 117
# ['vinci', 'walmart', 'citigroup', 'nippon', 'hdfc']
# 50
# ['amazon', 'loreal', 'hdfc', 'ebay', 'tencent']
# 70
# ['facebook', 'disney', 'volkswagen', 'vadafone', 'maruhan']
# 15
# ['Adobe', 'hitachi', 'wistron', 'hyundai', 'nvidia']
# 63
# ['avnet', 'woodland', 'oracle', 'philip', 'salesforce']
# 60
# ['tesco', 'icbc', 'nike', 'fluor', 'onex']
# 17
# ['vmware', 'nvidia', 'alphabet', 'onex', 'salesforce']
# 16
# ['nvidia', 'fluor', 'caterpillar', 'tcs', 'vadafone']
# 61
# ['apple', 'capgemini', 'alphabet', 'rbc', 'samsung']
# 15
# ['acs', 'alphabet', 'nippon', 'rbc', 'bmw']
# 15
# ['cisco', 'icbc', 'tesla', 'onex', 'volkswagen']
# 17
# ['tesco', 'oracle', 'hp', 'alphabet', 'paypal']
# 17
# ['vinci', 'mastercard', 'icbc', 'hdfc', 'super dry']
# 29
# ['maybank', 'woodland', 'merceds', 'ebay', 'bmw']
# 18
# ['Adobe', 'avnet', 'danaher', 'oracle', 'apple']
# 16
# ['icici', 'american express', 'jpmorgan', 'fluor', 'tencent']
# 49
# ['avnet', 'intel', 'oracle', 'puma', 'paypal']
# 56
# ['avnet', 'crh', 'tcs', 'icbc', 'panasonic']
# 16
# ['tesco', 'hyundai', 'merceds', 'nestle', 'super dry']
# 16
# ['danone', 'amazon', 'tesco', 'aegon', 'nike']
# 59
# ['amr', 'microsoft', 'avnet', 'walmart', 'onex']
# 15
# ['intel', 'puma', 'alphabet', 'hdfc', 'infosys']
# 16
# ['mahindra', 'at&t', 'acs', 'puma', 'samsung']
# 73
# ['barclays', 'sap', 'wipro', "mcdoland's", 'nippon']
# 16
# ['maybank', 'comcast', 'oracle', 'volkswagen', 'super dry']
# 15
# ['pepsi', 'jpmorgan', 'caterpillar', 'ebay', 'airtel']
# 16
# ['avnet', 'abb', 'woodland', 'oracle', 'tencent']
# 15
# ['maybank', 'target', 'ford', 'citigroup', 'nike']
# 20
# ['icici', 'mastercard', 'at&t', 'walmart', 'maruhan']
# 15
# ['mahindra', 'qualcomn', 'staples', 'tencent', 'visa']
# 132
# ['alibaba', 'walmart', 'ibm', 'fedEx', 'vadafone']
# 48
# ['woodland', 'staples', 'loreal', 'ebay', 'salesforce']
# 17
# ['starbucks', 'aegon', 'tesla', 'qualcomm', 'infosys']
# 17
# ['vmware', 'icici', 'disney', 'alibaba', 'infosys']
# 25
# ['abb', 'at&t', 'accenture', 'toyota', 'salesforce']
# 74
# ['intel', 'metlife', 'citigroup', 'salesforce', 'vadafone']
# 17
# ['sap', 'staples', 'toyota', 'alibaba', 'infosys']
# 37
# ['icici', 'fedEx', 'hp', 'paypal', 'volkswagen']
# 55
# ['qualcomn', 'accenture', 'jpmorgan', 'capgemini', 'maruhan']
# 15
# ['amr', 'maybank', 'mastercard', 'abb', 'ford']
# 36
# ['maybank', 'mahindra', 'comcast', 'canon', 'toyota']
# 68
# ['crh', 'oracle', 'qualcomm', 'super dry', 'samsung']
# 17
# ['hitachi', 'facebook', 'accenture', 'jpmorgan', 'nestle']
# 48
# ['jpmorgan', 'caterpillar', 'lg', 'panasonic', 'salesforce']
# 16
# ['Adobe', 'amazon', 'target', 'starbucks', 'abb']
# 54
# ['renault', 'amr', 'avnet', 'at&t', 'philip']
# 15
# ['barclays', 'accenture', 'ibm', 'volkswagen', 'hdfc']
# 77
# ['ford', 'facebook', 'qualcomn', 'wipro', 'fedEx']
# 81
# ['abb', 'netflix', 'philip', 'fedEx', 'apple']
# 16
# ['target', 'starbucks', 'facebook', 'cosmo', 'super dry']
# 33
# ['siemens', 'wistron', 'danaher', 'airtel', 'samsung']
# 15
# ['amazon', 'siemens', 'ibm', 'fedEx', 'volkswagen']
# 35
# ['icici', 'icbc', 'johnson', 'onex', 'vadafone']
# 15
# ['walmart', 'staples', 'nippon', 'onex', 'nestle']
# 15
# ['mahindra', 'oracle', 'fluor', 'tencent', 'maruhan']
# 45
# ['accenture', 'ibm', 'jpmorgan', 'puma', 'salesforce']
# 71
# ['Adobe', 'amazon', 'loreal', 'tencent', 'vadafone']
# 139
# ['paypal', 'loreal', 'puma', 'panasonic', 'qualcomm']
# 41
# ['cisco', 'danaher', 'netflix', 'onex', 'tencent']
# 54
# ['facebook', 'citigroup', 'loreal', 'nippon', 'super dry']
# 17
# ['amazon', "mcdoland's", 'merceds', 'puma', 'alphabet']
# 16
# ['intel', 'woodland', 'ebay', 'tencent', 'super dry']
# 47
# ['Adobe', 'microsoft', 'amazon', 'cosmo', 'xiaomi']
# 15
# ['intel', 'aegon', 'nvidia', 'volkswagen', 'infosys']
# 64
# ['vmware', 'mahindra', 'philip', 'ibm', 'tencent']
# 78
# ['vinci', 'disney', 'tencent', 'nestle', 'qualcomm']
# 17
# ['hitachi', 'danaher', "mcdoland's", 'jpmorgan', 'qualcomm']
# 27
# ['metlife', 'danaher', 'puma', 'apple', 'alibaba']
# 17
# ['metlife', 'pubg', 'johnson', 'caterpillar', 'infosys']
# 17
# ['renault', 'danone', 'nokia', 'icbc', 'airtel']
# 29
# ['hitachi', 'aegon', 'staples', 'merceds', 'samsung']
# 15
# ['starbucks', 'woodland', 'loreal', 'tcs', 'onex']
# 16
# ['intel', 'vinci', 'icbc', 'puma', 'cosmo']
# 18
# ['abb', 'walmart', 'disney', 'onex', 'salesforce']
# 15
# ['tesco', 'caterpillar', 'lg', 'bmw', 'infosys']
# 109
# ['sap', 'walmart', 'qualcomn', 'puma', 'fedEx']
# 17
# ['ford', 'tesco', 'johnson', 'reliance', 'rbc']
# 15
# ['abb', 'oracle', 'hyundai', 'staples', 'caterpillar']
# 16
# ['siemens', 'johnson', 'puma', 'hdfc', 'super dry']
# 35
# ['renault', 'icbc', 'lg', 'panasonic', 'ebay']
# 18
# ['danone', 'philip', 'walmart', 'salesforce', 'airtel']
# 15
# ['amazon', 'mahindra', 'wipro', 'apple', 'alibaba']
# 37
# ['amr', 'sony', 'hyundai', 'salesforce', 'xiaomi']
# 16
# ['intel', 'wistron', 'visa', 'fluor', 'tencent']
# 17
# ['hitachi', 'netflix', 'tesla', 'johnson', 'tcs']
# 29
# ['amr', 'philip', 'accenture', 'tesla', 'airtel']
# 62
# ['target', 'alphabet', 'ebay', 'tencent', 'apple']
# 57
# ['microsoft', 'mahindra', 'mastercard', 'nike', 'tcs']
# 15
# ['Adobe', 'qualcomn', 'pubg', 'alphabet', 'onex']
# 17
# ['american express', 'at&t', 'hp', 'tcs', 'nestle']
# 15
# ['target', 'icici', 'fluor', 'coca-cola', 'ebay']
# 20
# ['mahindra', 'intel', 'tesco', 'puma', 'alibaba']
# 15
# ['vmware', 'intel', 'vinci', 'danaher', 'tencent']
# 15
# ['philip', 'hyundai', 'jpmorgan', 'icbc', 'cosmo']
# 17
# ['sap', 'aegon', 'nike', 'fluor', 'rbc']
# 15
# ['Adobe', 'american express', 'oracle', 'tcs', 'visa']
# 17
# ['nokia', 'tesco', 'johnson', 'capgemini', 'nestle']
# 46
# ['Adobe', 'maybank', 'vinci', 'sony', 'citigroup']
# 15
# ['tesco', 'merceds', 'salesforce', 'bmw', 'infosys']
# 88
# ['avnet', 'nokia', 'ibm', 'tcs', 'tencent']
# 41
# ['amr', 'pepsi', 'disney', 'reliance', 'apple']
# 37
# ['hitachi', 'pepsi', 'ibm', 'capgemini', 'reliance']
# 17
# ['qualcomn', 'loreal', 'icbc', 'cosmo', 'apple']
# 33
# ['vmware', 'microsoft', 'siemens', 'wistron', 'vadafone']
# 52
# ['microsoft', 'tesco', 'oracle', 'aegon', 'nippon']
# 15
# ['ford', 'oracle', 'alphabet', 'volkswagen', 'bmw']
# 35
# ['danone', 'crh', 'panasonic', 'tencent', 'infosys']
# 18
# ['target', 'vinci', 'fedEx', 'volkswagen', 'sodexo']
# 15
# ['vinci', 'mastercard', 'woodland', 'philip', 'ibm']
# 53
# ['Adobe', 'danone', 'vinci', 'oracle', 'ebay']
# 65
# ['comcast', 'hp', 'alphabet', 'fedEx', 'visa']
# 16
# ['crh', 'puma', 'alphabet', 'coca-cola', 'sodexo']
# 17
# ['Adobe', 'starbucks', 'johnson', 'capgemini', 'toyota']
# 18
# ['amr', 'vinci', 'tesco', 'hyundai', "mcdoland's"]
# 18
# ['siemens', 'vinci', 'ford', 'super dry', 'infosys']
# 29
# ['amr', 'danaher', 'staples', 'johnson', 'tencent']
# 39
# ['addidas', 'icbc', 'loreal', 'fluor', 'super dry']
# 15
# ['pubg', 'addidas', 'merceds', 'panasonic', 'salesforce']
# 23
# ['nike', 'disney', 'hdfc', 'qualcomm', 'bmw']
# 63
# ['comcast', 'coca-cola', 'fedEx', 'maruhan', 'infosys']
# 18
# ['mahindra', 'addidas', 'merceds', 'wipro', 'xiaomi']
# 57
# ['metlife', 'hp', 'acs', 'cosmo', 'nippon']
# 55
# ['tesco', 'oracle', 'philip', 'puma', 'hdfc']
# 15
# ['hitachi', 'tesco', 'walmart', 'pubg', 'staples']
# 16
# ['starbucks', 'loreal', 'cosmo', 'caterpillar', 'hdfc']
# 18
# ['siemens', 'nokia', 'hp', 'hyundai', 'rbc']
# 16
# ['mahindra', 'sony', 'loreal', 'nvidia', 'fluor']
# 46
# ['mahindra', 'abb', 'danaher', 'cosmo', 'alphabet']
# 62
# ['mahindra', 'woodland', 'citigroup', 'xiaomi', 'airtel']
# 76
# ['intel', 'woodland', 'canon', 'fedEx', 'super dry']
# 37
# ['microsoft', 'netflix', 'philip', "mcdoland's", 'paypal']
# 63
# ['acs', 'tesla', 'fluor', 'caterpillar', 'alibaba']
# 15
# ['aegon', 'ibm', 'caterpillar', 'volkswagen', 'airtel']
# 15
# ['Adobe', 'crh', 'qualcomn', 'loreal', 'johnson']
# 17
# ['canon', 'tesco', 'acs', 'capgemini', 'toyota']
# 18
# ['starbucks', 'barclays', 'pepsi', 'disney', 'nippon']
# 32
# ['avnet', 'netflix', 'hp', 'disney', 'hdfc']
# 78
# ['amazon', 'danaher', 'ford', 'volkswagen', 'super dry']
# 16
# ['aegon', "mcdoland's", 'panasonic', 'tencent', 'super dry']
# 15
# ['mastercard', 'barclays', 'accenture', 'staples', 'ibm']
# 18
# ['cisco', 'qualcomn', 'hyundai', 'nvidia', 'toyota']
# 15
# ['american express', 'netflix', 'oracle', 'loreal', 'rbc']
# 15
# ['comcast', 'hyundai', 'addidas', 'cosmo', 'airtel']
# 18
# ['mahindra', 'ibm', 'addidas', 'nike', 'panasonic']
# 17
# ['maybank', 'hyundai', 'staples', 'coca-cola', 'tencent']
# 15
# ['amr', 'target', 'comcast', 'metlife', 'danaher']
# 18
# ['microsoft', 'mastercard', 'johnson', 'nippon', 'visa']
# 17
# ['walmart', 'nippon', 'nestle', 'sodexo', 'vadafone']
# 18
# ['sony', 'jpmorgan', 'paypal', 'maruhan', 'samsung']
# 51
# ['vmware', 'danone', 'woodland', 'citigroup', 'cosmo']
# 16
# ['target', 'facebook', 'pubg', 'acs', 'apple']
# 53
# ['Adobe', 'mahindra', 'ibm', 'airtel', 'bmw']
# 15
# ['Adobe', 'comcast', 'loreal', 'disney', 'capgemini']
# 15
# ['cisco', 'netflix', 'philip', 'johnson', 'visa']
# 45
# ['salesforce', 'cisco', 'danaher', 'fedEx', 'apple']
# 58
# ['microsoft', 'vinci', 'oracle', 'aegon', 'cosmo']
# 15
# ['target', 'starbucks', 'merceds', 'puma', 'sodexo']
# 46
# ['accenture', 'nike', 'nestle', 'alibaba', 'maruhan']
# 15
# ['vinci', 'philip', 'walmart', 'nippon', 'infosys']
# 18
# ['intel', 'oracle', 'philip', 'acs', 'onex']
# 32
# ['american express', 'at&t', 'philip', 'pubg', 'icbc']
# 15
# ['facebook', 'disney', 'coca-cola', 'super dry', 'maruhan']
# 17
# ['intel', 'sony', 'qualcomn', 'disney', 'reliance']
# 15
# ['avnet', 'hp', 'johnson', 'onex', 'samsung']
# 61
# ['american express', 'at&t', 'hp', 'capgemini', 'puma']
# 17
# ['avnet', 'starbucks', 'cisco', 'mastercard', 'qualcomn']
# 58
# ['canon', 'oracle', 'qualcomn', 'citigroup', 'philip']
# 42
# ['microsoft', 'amazon', 'facebook', 'qualcomn', "mcdoland's"]
# 17
# ['woodland', 'sap', 'qualcomn', 'nike', 'maruhan']
# 18
# ['sap', 'acs', 'reliance', 'nippon', 'samsung']
# 16
# ['renault', 'woodland', 'qualcomn', 'tencent', 'apple']
# 17
# ['hitachi', 'aegon', 'acs', 'capgemini', 'onex']
# 37
# ['vinci', 'mastercard', 'acs', 'tcs', 'salesforce']
# 61
# ['siemens', 'hitachi', 'sap', 'nike', 'volkswagen']
# 116
# ['danone', 'danaher', 'sony', 'qualcomn', 'onex']
# 37
# ['starbucks', "mcdoland's", 'puma', 'salesforce', 'sodexo']
# 16
# ['icici', 'oracle', 'nippon', 'visa', 'apple']
# 82
# ['disney', 'reliance', 'caterpillar', 'onex', 'tencent']
# 34
# ['amr', 'icici', 'tesco', 'fluor', 'super dry']
# 44
# ['amr', 'starbucks', 'tesco', 'cosmo', 'airtel']
# 16
# ['tesco', 'facebook', 'johnson', "mcdoland's", 'infosys']
# 24
# ['renault', 'comcast', 'mastercard', 'woodland', 'puma']
# 17
# ['metlife', 'hitachi', 'oracle', 'apple', 'vadafone']
# 18
# ['maybank', 'hp', 'cosmo', 'alphabet', 'visa']
# 42
# ['starbucks', 'abb', 'mastercard', 'citigroup', 'nippon']
# 64
# ['salesforce', 'netflix', 'jpmorgan', 'fluor', 'apple']
# 17
# ['Adobe', 'qualcomn', 'staples', 'visa', 'sodexo']
# 41
# ['danone', 'comcast', "mcdoland's", 'volkswagen', 'alibaba']
# 15
# ['microsoft', "mcdoland's", 'hdfc', 'alibaba', 'infosys']
# 17
# ['woodland', 'qualcomn', 'ibm', 'tesla', 'disney']
# 23
# ['target', 'ford', 'rbc', 'super dry', 'samsung']
# 17
# ['hitachi', 'canon', 'at&t', 'citigroup', 'paypal']
# 18
# ["mcdoland's", 'merceds', 'fluor', 'visa', 'infosys']
# 15
# ['acs', 'nike', 'reliance', 'nestle', 'super dry']
# 94
# ['cisco', 'ford', 'at&t', 'fluor', 'nippon']
# 17
# ['Adobe', 'metlife', 'accenture', 'loreal', 'nike']
# 18
# ['renault', 'facebook', 'sap', 'walmart', 'disney']
# 16
# ['danone', "mcdoland's", 'salesforce', 'sodexo', 'bmw']
# 18
# ['comcast', 'starbucks', 'wipro', 'cosmo', 'super dry']
# 16
# ['renault', 'danaher', 'barclays', 'hp', 'alibaba']
# 17
# ['mahindra', 'siemens', 'crh', 'loreal', 'alibaba']
# 17
# ['amr', 'american express', 'walmart', 'staples', 'tcs']
# 22
# ['microsoft', 'at&t', 'philip', 'acs', 'onex']
# 15
# ['barclays', 'sap', 'citigroup', 'puma', 'onex']
# 16
# ['hp', 'tencent', 'toyota', 'xiaomi', 'airtel']
# 34
# ['danone', 'nokia', 'hp', 'nike', 'volkswagen']
# 89
# ['Adobe', 'ford', 'sony', 'accenture', 'panasonic']
# 17
# ['airtel', 'oracle', 'staples', 'disney', 'super dry']
# 24
# ['mahindra', 'walmart', 'staples', 'paypal', 'ebay']
# 57
# ['target', 'mastercard', 'qualcomm', 'salesforce', 'xiaomi']
# 68
# ['walmart', 'pubg', 'merceds', 'nike', 'puma']
# 34
# ['avnet', 'barclays', 'crh', 'aegon', 'super dry']
# 51
# ['vmware', 'comcast', 'ibm', 'cosmo', 'caterpillar']
# 17
# ['intel', 'mastercard', 'tcs', 'fedEx', 'apple']
# 37
# ['barclays', 'citigroup', 'qualcomn', 'lg', 'toyota']
# 15
# ['danone', 'amazon', 'panasonic', 'qualcomm', 'super dry']
# 16
# ['oracle', 'accenture', 'staples', 'jpmorgan', 'super dry']
# 54
# ['danone', 'netflix', 'tesco', 'loreal', 'apple']
# 15
# ['starbucks', 'tesco', 'facebook', 'pubg', 'samsung']
# 15
# ['amr', 'mahindra', 'cosmo', 'salesforce', 'xiaomi']
# 27
# ['renault', 'metlife', 'hyundai', 'staples', "mcdoland's"]
# 17
# ['wistron', 'barclays', 'american express', 'hp', 'hyundai']
# 97
# ['intel', 'cisco', 'staples', 'coca-cola', 'vadafone']
# 36
# ['microsoft', 'target', 'siemens', 'tesco', 'reliance']
# 75
# ['renault', 'microsoft', 'hitachi', 'mastercard', 'super dry']
# 15
# ['Adobe', 'hp', 'johnson', 'capgemini', 'onex']
# 15
# ['cisco', 'johnson', 'tesla', 'toyota', 'maruhan']
# 83
# ['siemens', 'mastercard', 'canon', 'icbc', 'panasonic']
# 18
# ['crh', 'johnson', 'puma', 'nippon', 'airtel']
# 69
# ['amr', 'intel', 'metlife', 'at&t', 'wipro']
# 58
# ['cisco', 'accenture', "mcdoland's", 'cosmo', 'airtel']
# 17
# ['crh', 'aegon', 'nippon', 'xiaomi', 'vadafone']
# 32
# ['amr', 'wistron', 'staples', 'coca-cola', 'nippon']
# 16
# ['metlife', 'citigroup', 'caterpillar', 'tcs', 'alibaba']
# 18
# ['danone', 'cisco', 'icbc', 'cosmo', 'salesforce']
# 34
# ['abb', 'netflix', 'fedEx', 'rbc', 'sodexo']
# 41
# ['netflix', 'american express', 'loreal', 'tesla', 'maruhan']
# 16
# ['maybank', 'wistron', 'johnson', 'tesla', 'nestle']
# 29
# ['target', 'metlife', 'sony', 'nestle', 'infosys']
# 71
# ['cisco', 'crh', "mcdoland's", 'merceds', 'ebay']
# 17
# ['tesco', 'alphabet', 'coca-cola', 'volkswagen', 'vadafone']
# 16
# ['amazon', 'johnson', 'jpmorgan', 'disney', 'fluor']
# 65
# ['Adobe', 'hyundai', 'qualcomm', 'vadafone', 'bmw']
# 16
# ['renault', 'mastercard', 'hitachi', 'nokia', 'merceds']
# 15
# ['danone', 'sony', 'addidas', 'onex', 'volkswagen']
# 61
# ['intel', 'comcast', 'cisco', 'facebook', 'xiaomi']
# 15
# ['wistron', 'hyundai', 'fluor', 'coca-cola', 'volkswagen']
# 15
# ['renault', 'starbucks', 'cisco', 'danaher', 'salesforce']
# 17
# ['starbucks', 'barclays', 'icbc', 'johnson', 'infosys']
# 15
# ['mahindra', 'woodland', 'disney', 'caterpillar', 'salesforce']
# 19
# ['maybank', 'mastercard', 'wistron', 'canon', 'facebook']
# 73
# ['barclays', 'woodland', 'sap', 'icbc', 'salesforce']
# 16
# ['vmware', 'american express', 'disney', 'onex', 'infosys']
# 15
# ['avnet', 'amazon', 'comcast', 'onex', 'tencent']
# 18
# ['renault', 'amazon', 'woodland', 'netflix', 'hp']
# 74
# ['woodland', 'sony', 'hyundai', 'tesla', 'salesforce']
# 37
# ['crh', 'philip', 'johnson', 'alphabet', 'rbc']
# 61
# ['target', 'danaher', 'philip', 'hp', 'hdfc']
# 16
# ['mastercard', 'oracle', 'loreal', 'puma', 'panasonic']
# 20
# ['amazon', 'abb', 'american express', 'cosmo', 'airtel']
# 78
# ['icici', 'woodland', 'staples', 'icbc', 'maruhan']
# 15
# ['at&t', 'walmart', 'qualcomn', 'volkswagen', 'vadafone']
# 31
# ['starbucks', 'hitachi', 'wipro', 'nvidia', 'airtel']
# 54
# ['maybank', 'intel', 'danone', 'american express', 'tesco']
# 15
# ['starbucks', 'cisco', 'netflix', 'philip', 'salesforce']
# 36
# ['starbucks', 'accenture', 'lg', 'reliance', 'ebay']
# 55
# ['mahindra', 'addidas', "mcdoland's", 'salesforce', 'bmw']
# 17
# ['mastercard', 'hp', 'tencent', 'nestle', 'apple']
# 52
# ['danone', 'intel', 'metlife', 'johnson', 'nike']
# 74
# ['vinci', 'johnson', 'puma', 'fluor', 'ebay']
# 17
# ['sap', 'tesla', 'puma', 'fedEx', 'ebay']
# 39
# ['starbucks', 'caterpillar', 'onex', 'apple', 'bmw']
# 15
# ['philip', 'citigroup', 'tcs', 'rbc', 'bmw']
# 18
# ['mastercard', 'american express', 'philip', 'johnson', 'visa']
# 32
# ['wipro', 'disney', 'alphabet', 'salesforce', 'infosys']
# 70
# ['amazon', 'vinci', 'puma', 'lg', 'alibaba']
# 17
# ['crh', 'nokia', 'wipro', 'alphabet', 'toyota']
# 47
# ['Adobe', 'microsoft', 'tcs', 'nippon', 'nestle']
# 15
# ['hitachi', 'american express', 'hp', 'citigroup', 'merceds']
# 18
# ['johnson', 'reliance', 'paypal', 'onex', 'qualcomm']
# 42
# ['mastercard', 'ford', 'canon', 'nokia', 'tcs']
# 16
# ['starbucks', 'hitachi', 'oracle', 'staples', 'fluor']
# 116
# ['starbucks', 'philip', 'nvidia', 'airtel', 'maruhan']
# 34
# ['amr', 'mahindra', 'icbc', 'alphabet', 'fedEx']
# 63
# ['Adobe', 'facebook', 'lg', 'tencent', 'infosys']
# 86
# ['danone', 'qualcomn', 'alphabet', 'apple', 'infosys']
# 40
# ['starbucks', 'walmart', 'tencent', 'sodexo', 'airtel']
# 73
# ['mahindra', 'abb', "mcdoland's", 'fedEx', 'vadafone']
# 17
# ['intel', 'vinci', 'mastercard', 'aegon', 'nestle']
# 16
# ['woodland', 'pepsi', 'nike', 'tcs', 'xiaomi']
# 82
# ['amazon', 'target', 'sony', 'walmart', 'citigroup']
# 15
# ['starbucks', 'tesla', 'toyota', 'rbc', 'airtel']
# 46
# ['avnet', 'microsoft', 'tesco', 'alphabet', 'samsung']
# 15
# ['target', 'crh', 'citigroup', 'acs', 'hdfc']
# 17
# ['netflix', 'tesco', 'merceds', 'fluor', 'salesforce']
# 17
# ['metlife', 'hp', 'tesla', 'super dry', 'maruhan']
# 53
# ['maybank', 'hp', 'hyundai', 'nvidia', 'coca-cola']
# 17
# ['mastercard', 'aegon', 'capgemini', 'alphabet', 'hdfc']
# 40
# ['sony', 'oracle', 'tcs', 'visa', 'rbc']
# 68
# ['wistron', 'netflix', 'johnson', 'fedEx', 'hdfc']
# 16
# ['cisco', 'johnson', "mcdoland's", 'volkswagen', 'alibaba']
# 44
# ['american express', 'oracle', "mcdoland's", 'hdfc', 'alibaba']
# 58
# ['vmware', 'cisco', 'reliance', 'toyota', 'samsung']
# 18
# ['mastercard', 'aegon', 'loreal', 'lg', 'super dry']
# 42
# ['woodland', 'alphabet', 'nippon', 'tencent', 'toyota']
# 76
# ['renault', 'vinci', 'ibm', 'toyota', 'super dry']
# 15
# ['salesforce', 'staples', 'merceds', 'hdfc', 'rbc']
# 42
# ['vinci', 'ibm', 'wipro', 'nike', 'volkswagen']
# 17
# ['mahindra', 'cisco', 'mastercard', 'nestle', 'super dry']
# 17
# ['metlife', 'citigroup', 'caterpillar', 'onex', 'xiaomi']
# 30
# ['microsoft', 'danone', 'starbucks', 'cisco', 'bmw']
# 58
# ['wistron', 'walmart', 'alphabet', 'bmw', 'samsung']
# 67
# ['hitachi', 'tesco', 'ibm', 'coca-cola', 'bmw']
# 17
# ['target', 'merceds', 'fluor', 'toyota', 'airtel']
# 88
# ['avnet', 'wipro', 'tesla', 'fedEx', 'infosys']
# 18
# ['abb', 'woodland', 'hyundai', 'salesforce', 'alibaba']
# 19
# ['mahindra', 'icici', 'barclays', 'sony', 'hdfc']
# 18
# ['siemens', 'metlife', 'canon', "mcdoland's", 'ebay']
# 15
# ['qualcomn', 'loreal', 'icbc', 'reliance', 'coca-cola']
# 33
# ['mastercard', 'danaher', 'facebook', 'pubg', 'tencent']
# 18
# ['hitachi', 'pepsi', 'wipro', 'merceds', 'tcs']
# 15
# ['renault', 'woodland', 'sap', 'nike', 'panasonic']
# 54
# ['mahindra', 'oracle', 'aegon', 'nvidia', 'caterpillar']
# 65
# ['citigroup', 'accenture', 'hyundai', 'tesla', 'maruhan']
# 15
# ['mastercard', 'johnson', 'infosys', 'bmw', 'samsung']
# 48
# ['cisco', 'netflix', 'ebay', 'nestle', 'super dry']
# 57
# ['aegon', 'nvidia', 'lg', 'tcs', 'apple']
# 116
# ['mahindra', 'crh', 'wipro', 'panasonic', 'salesforce']
# 33
# ['johnson', 'merceds', 'fluor', 'hdfc', 'xiaomi']
# 48
# ['target', 'american express', 'pubg', 'acs', 'fedEx']
# 102
# ['american express', 'cosmo', 'qualcomm', 'xiaomi', 'maruhan']
# 38
# ['canon', 'fluor', 'panasonic', 'qualcomm', 'apple']
# 16
# ['vmware', 'danone', 'amazon', 'tesco', 'merceds']
# 17
# ['comcast', 'addidas', 'merceds', 'nestle', 'salesforce']
# 34
# ['sony', 'disney', 'puma', 'fedEx', 'ebay']
# 96
# ['amazon', 'metlife', 'philip', 'disney', 'rbc']
# 16
# ['Adobe', 'abb', 'barclays', 'nokia', 'panasonic']
# 41
# ['accenture', 'johnson', 'toyota', 'sodexo', 'maruhan']
# 80
# ['microsoft', 'woodland', 'hyundai', 'johnson', 'salesforce']
# 15
# ['merceds', 'jpmorgan', 'apple', 'super dry', 'samsung']
# 16
# ['mastercard', 'crh', 'oracle', 'super dry', 'alibaba']
# 70
# ['woodland', 'pubg', 'nike', 'nestle', 'alibaba']
# 97
# ['target', 'siemens', 'woodland', 'at&t', 'visa']
# 52
# ['maybank', 'siemens', 'johnson', 'puma', 'paypal']
# 15
# ['amr', 'barclays', 'walmart', "mcdoland's", 'fluor']
# 15
# ['vmware', 'danone', 'intel', 'comcast', 'johnson']
# 18
# ['vinci', 'fedEx', 'caterpillar', 'panasonic', 'toyota']
# 16
# ['woodland', 'fedEx', 'onex', 'rbc', 'airtel']
# 15
# ['mahindra', 'netflix', 'ibm', 'merceds', 'nike']
# 43
# ['starbucks', 'facebook', 'capgemini', 'paypal', 'volkswagen']
# 17
# ['starbucks', 'philip', 'pubg', 'staples', 'bmw']
# 17
# ['crh', 'oracle', 'volkswagen', 'xiaomi', 'bmw']
# 39
# ['Adobe', 'danone', 'amazon', 'netflix', 'loreal']
# 69
# ['crh', 'walmart', 'visa', 'toyota', 'bmw']
# 103
# ['Adobe', 'comcast', 'disney', 'nestle', 'sodexo']
# 21
# ['metlife', 'ford', 'oracle', 'hp', 'icbc']
# 16
# ['hitachi', 'facebook', 'oracle', 'fluor', 'ebay']
# 90
# ['microsoft', 'mahindra', 'intel', 'icbc', 'fedEx']
# 55
# ['metlife', 'oracle', 'addidas', 'nvidia', 'sodexo']
# 71
# ['mahindra', 'crh', 'staples', 'nippon', 'airtel']
# 15
# ['comcast', 'johnson', "mcdoland's", 'nvidia', 'visa']
# 58
# ['walmart', "mcdoland's", 'tcs', 'super dry', 'samsung']
# 16
# ['philip', 'merceds', 'volkswagen', 'rbc', 'samsung']
# 17
# ['intel', 'woodland', 'tesla', 'nestle', 'qualcomm']
# 46
# ['maybank', 'mahindra', 'danone', 'toyota', 'vadafone']
# 76
# ['danaher', 'nokia', 'paypal', 'airtel', 'nippon']
# 118
# ['avnet', 'woodland', 'nokia', 'pubg', 'ebay']
# 17
# ['tesco', 'jpmorgan', 'paypal', 'volkswagen', 'ebay']
# 60
# ['danone', 'crh', 'citigroup', 'coca-cola', 'fedEx']
# 16
# ['metlife', 'wistron', 'ibm', 'tcs', 'paypal']
# 36
# ['starbucks', 'ford', 'barclays', 'sap', 'super dry']
# 88
# ['vinci', 'cisco', 'johnson', 'ebay', 'infosys']
# 17
# ['vmware', 'tesco', 'disney', 'capgemini', 'tcs']
# 41
# ['abb', 'woodland', 'hp', 'fedEx', 'toyota']
# 15
# ['mastercard', 'pepsi', 'hp', 'staples', 'vadafone']
# 15
# ['Adobe', 'netflix', 'alphabet', 'bmw', 'infosys']
# 30
# ['comcast', 'ford', 'staples', 'merceds', 'reliance']
# 18
# ['avnet', 'nike', 'nvidia', 'airtel', 'samsung']
# 16
# ['Adobe', 'amr', 'aegon', 'wipro', 'hdfc']
# 36
# ['Adobe', 'vinci', 'at&t', 'hyundai', 'cosmo']
# 72
# ['accenture', 'pubg', 'staples', 'nike', 'volkswagen']
# 18
# ['intel', 'abb', 'woodland', 'oracle', 'tencent']
# 17
# ['qualcomn', 'loreal', 'merceds', 'ebay', 'nestle']
# 15
# ['starbucks', 'abb', 'oracle', 'johnson', 'caterpillar']
# 17
# ['hp', 'ibm', 'johnson', 'nike', 'volkswagen']
# 23
# ['Adobe', 'starbucks', 'danaher', 'puma', 'cosmo']
# 67
# ['vmware', 'accenture', "mcdoland's", 'volkswagen', 'apple']
# 17
# ['amazon', 'oracle', 'pubg', 'tesla', 'puma']
# 15
# ['nokia', 'addidas', 'capgemini', 'tencent', 'alibaba']
# 17
# ['ford', 'crh', 'accenture', 'staples', 'ibm']
# 16
# ['maybank', 'amazon', 'barclays', 'fluor', 'onex']
# 31
# ['hitachi', "mcdoland's", 'nike', 'cosmo', 'maruhan']
# 18
# ['starbucks', 'tesco', 'icbc', 'johnson', 'lg']
# 15
# ['mahindra', 'hitachi', 'hyundai', 'coca-cola', 'bmw']
# 17
# ['danone', 'microsoft', 'citigroup', 'paypal', 'maruhan']
# 15
# ['Adobe', 'netflix', 'alphabet', 'nippon', 'airtel']
# 68
# ['canon', 'netflix', 'walmart', 'onex', 'infosys']
# 44
# ['mahindra', 'barclays', 'cosmo', 'nestle', 'super dry']
# 16
# ['renault', 'hp', 'alphabet', 'tencent', 'vadafone']
# 16
# ['hyundai', 'wipro', 'nippon', 'visa', 'vadafone']
# 30
# ['vmware', 'comcast', 'danaher', 'tesco', 'panasonic']
# 89
# ['mahindra', 'vinci', 'woodland', 'tesla', 'salesforce']
# 16
# ['tesco', 'sap', 'merceds', 'capgemini', 'infosys']
# 40
# ['Adobe', 'alibaba', 'acs', 'wipro', 'vadafone']
# 15
# ['icici', 'oracle', 'merceds', 'johnson', 'rbc']
# 15
# ['intel', 'abb', 'cisco', 'cosmo', 'tcs']
# 16
# ['icici', 'tesco', 'philip', 'onex', 'rbc']
# 18
# ['vmware', 'target', 'facebook', 'fluor', 'maruhan']
# 16
# ['vinci', 'addidas', 'icbc', 'coca-cola', 'nippon']
# 45
# ['amazon', 'crh', 'philip', 'accenture', 'alphabet']
# 84
# ['maybank', 'metlife', 'cisco', 'qualcomm', 'salesforce']
# 15
# ['cisco', 'sap', 'accenture', 'hyundai', 'alphabet']
# 21
# ['target', 'tesco', 'ibm', 'fedEx', 'airtel']
# 18
# ['avnet', 'staples', 'tencent', 'hdfc', 'sodexo']
# 94
# ['barclays', 'crh', 'tesco', 'qualcomn', 'disney']
# 55
# ['danaher', 'crh', 'qualcomn', 'walmart', 'samsung']
# 16
# ['microsoft', 'salesforce', 'loreal', 'fluor', 'apple']
# 15
# ['qualcomn', 'loreal', 'tesla', 'icbc', 'lg']
# 16
# ['mahindra', 'ibm', 'disney', 'coca-cola', 'salesforce']
# 16
# ['renault', 'maybank', 'pepsi', 'jpmorgan', 'airtel']
# 17
# ['hitachi', 'cisco', 'hyundai', 'caterpillar', 'ebay']
# 38
# ['Adobe', 'barclays', 'pubg', 'cosmo', 'reliance']
# 20
# ['metlife', 'netflix', 'wipro', 'johnson', 'fedEx']
# 16
# ['target', 'american express', 'wipro', 'onex', 'visa']
# 17
# ['ford', 'cosmo', 'ebay', 'nestle', 'toyota']
# 16
# ['microsoft', 'nokia', 'johnson', 'tcs', 'visa']
# 16
# ['mahindra', 'cisco', 'citigroup', 'icbc', 'fedEx']
# 58
# ['hitachi', 'woodland', 'staples', 'cosmo', 'nestle']
# 84
# ['abb', 'qualcomn', 'tesla', 'fedEx', 'sodexo']
# 17
# ['woodland', 'pepsi', 'at&t', 'nippon', 'hdfc']
# 15
# ['comcast', 'netflix', 'nike', 'caterpillar', 'nippon']
# 15
# ['danone', 'amazon', 'acs', 'coca-cola', 'visa']
# 18
# ['philip', 'pubg', 'cosmo', 'fedEx', 'hdfc']
# 51
# ['danaher', 'crh', 'sap', 'citigroup', 'puma']
# 89
# ['intel', 'woodland', 'nokia', 'staples', 'tencent']
# 17
# ['woodland', 'qualcomn', 'aegon', 'acs', 'capgemini']
# 26
# ['pubg', 'jpmorgan', 'tesla', 'coca-cola', 'bmw']
# 81
# ['mahindra', 'amazon', 'ford', 'facebook', 'tcs']
# 15
# ['staples', 'addidas', 'infosys', 'ebay', 'samsung']
# 46
# ['danone', 'at&t', 'icbc', 'vadafone', 'airtel']
# 16
# ['danone', 'qualcomn', 'accenture', 'fedEx', 'nippon']
# 15
# ['wistron', 'staples', 'addidas', 'nvidia', 'sodexo']
# 44
# ['mahindra', 'intel', 'hitachi', 'hdfc', 'super dry']
# 17
# ['amr', 'cisco', 'staples', 'onex', 'samsung']
# 17
# ['mahindra', 'cisco', 'woodland', 'accenture', 'rbc']
# 28
# ['cisco', 'hp', 'qualcomn', "mcdoland's", 'puma']
# 74
# ['Adobe', 'merceds', 'johnson', 'capgemini', 'volkswagen']
# 18
# ['icici', 'aegon', 'super dry', 'caterpillar', 'alibaba']
# 16
# ['comcast', 'philip', 'staples', 'wipro', 'merceds']
# 17
# ['danone', 'sap', 'aegon', 'qualcomm', 'rbc']
# 126
# ['sap', 'hp', 'pubg', 'paypal', 'infosys']
# 31
# ['woodland', 'pubg', 'hyundai', 'merceds', 'qualcomm']
# 18
# ['abb', 'netflix', 'johnson', 'alphabet', 'xiaomi']
# 83
# ['Adobe', 'hitachi', 'sony', 'hdfc', 'vadafone']
# 49
# ['siemens', 'facebook', 'sap', 'johnson', 'paypal']
# 18
# ['netflix', 'aegon', 'caterpillar', 'visa', 'maruhan']
# 87
# ['metlife', 'disney', 'panasonic', 'qualcomm', 'airtel']
# 29
# ['siemens', 'abb', 'aegon', 'wipro', 'coca-cola']
# 84
# ['Adobe', 'staples', 'icbc', 'capgemini', 'coca-cola']
# 18
# ['danone', 'crh', "mcdoland's", 'qualcomm', 'xiaomi']
# 15
# ['qualcomn', 'hyundai', 'merceds', 'toyota', 'rbc']
# 17
# ['metlife', 'woodland', 'nike', 'qualcomm', 'sodexo']
# 17
# ['renault', 'danaher', 'canon', 'coca-cola', 'sodexo']
# 45
# ['intel', 'hitachi', 'crh', 'coca-cola', 'airtel']
# 17
# ['ford', 'oracle', 'nippon', 'super dry', 'bmw']
# 15
# ['qualcomn', 'ibm', 'nike', 'hdfc', 'xiaomi']
# 56
# ['amr', 'amazon', 'tesco', 'ebay', 'hdfc']
# 15
# ['cisco', 'pubg', 'tesla', 'onex', 'apple']
# 16
# ['amr', 'nokia', 'fluor', 'panasonic', 'visa']
# 50
# ['siemens', 'accenture', 'cosmo', 'alphabet', 'tencent']
# 17
# ['danone', 'cisco', 'netflix', 'walmart', 'puma']
# 16
# ['sap', 'hp', 'jpmorgan', 'paypal', 'bmw']
# 63
# ['vmware', 'target', 'comcast', 'cisco', 'nestle']
# 15
# ['vmware', 'target', 'alphabet', 'super dry', 'infosys']
# 96
# ['amr', 'merceds', 'reliance', 'alphabet', 'nippon']
# 61
# ['wistron', 'netflix', 'capgemini', 'caterpillar', 'airtel']
# 75
# ['cisco', 'tesco', 'johnson', 'alphabet', 'qualcomm']
# 17
# ['intel', 'cisco', 'nvidia', 'onex', 'sodexo']
# 42
# ['microsoft', 'walmart', 'jpmorgan', 'johnson', 'capgemini']
# 18
# ['crh', 'addidas', "mcdoland's", 'nike', 'sodexo']
# 16
# ['mastercard', 'tesla', 'capgemini', 'reliance', 'nippon']
# 47
# ['sony', 'qualcomn', 'pubg', 'ibm', 'disney']
# 16
# ['vmware', 'woodland', 'loreal', 'disney', 'volkswagen']
# 15
# ['crh', 'philip', 'citigroup', 'tencent', 'infosys']
# 44
# ['sap', 'accenture', 'nike', 'reliance', 'fedEx']
# 15
# ['nokia', 'oracle', 'merceds', 'jpmorgan', 'super dry']
# 16
# ['danaher', 'tesco', 'philip', 'citigroup', 'johnson']
# 55
# ['rbc', 'loreal', 'vadafone', 'salesforce', 'super dry']
# 62
# ['ibm', 'jpmorgan', 'fluor', 'vadafone', 'airtel']
# 16
# ['icici', 'tesco', 'oracle', 'qualcomn', 'hdfc']
# 40
# ['target', 'woodland', 'pubg', 'ibm', 'tcs']
# 52
# ['staples', 'loreal', 'puma', 'nippon', 'panasonic']
# 15
# ['target', 'accenture', 'jpmorgan', 'volkswagen', 'rbc']
# 33
# ['ford', 'philip', 'tesla', 'nike', 'tcs']
# 57
# ['icici', 'nokia', 'citigroup', 'merceds', 'vadafone']
# 17
# ['cisco', 'hyundai', 'disney', 'ebay', 'samsung']
# 43
# ['renault', 'ford', 'danaher', 'facebook', 'sodexo']
# 54
# ['facebook', 'citigroup', 'acs', 'tencent', 'airtel']
# 17
# ['comcast', 'tesco', 'addidas', 'rbc', 'sodexo']
# 16
# ['target', 'american express', 'ibm', 'tencent', 'toyota']
# 58
# ['mahindra', 'metlife', 'lg', 'paypal', 'onex']
# 16
# ['amazon', 'mastercard', 'sony', 'disney', 'nike']
# 15
# ['icici', 'metlife', 'ibm', 'reliance', 'tencent']
# 15
# ['crh', 'hyundai', 'reliance', 'toyota', 'vadafone']
# 72
# ['danone', 'american express', 'aegon', 'acs', 'merceds']
# 29
# ['icici', 'sap', 'disney', 'puma', 'infosys']
# 46
# ['netflix', 'nike', 'tcs', 'nestle', 'apple']
# 17
# ['Adobe', 'at&t', 'nike', 'reliance', 'airtel']
# 28
# ['canon', 'nokia', 'hyundai', 'johnson', 'super dry']
# 17
# ['danone', 'ford', 'merceds', 'tencent', 'hdfc']
# 17
# ['canon', 'pubg', 'loreal', 'johnson', 'maruhan']
# 15
# ['crh', 'wipro', 'caterpillar', 'salesforce', 'infosys']
# 15
# ['Adobe', 'pepsi', 'aegon', 'nippon', 'bmw']
# 17
# ['icici', 'loreal', 'hdfc', 'rbc', 'maruhan']
# 15
# ['hitachi', 'crh', 'tencent', 'hdfc', 'infosys']
# 16
# ['starbucks', 'woodland', 'accenture', 'capgemini', 'onex']
# 15
# ['comcast', 'hp', 'nippon', 'tencent', 'infosys']
# 17
# ['hitachi', 'netflix', 'philip', 'qualcomm', 'salesforce']
# 54
# ['mastercard', 'icbc', 'paypal', 'vadafone', 'nippon']
# 96
# ['amazon', 'qualcomn', 'aegon', 'icbc', 'capgemini']
# 44
# ['amr', 'qualcomn', 'tesla', 'merceds', 'sodexo']
# 82
# ['loreal', 'wipro', 'nvidia', 'onex', 'airtel']
# 109
# ['avnet', 'mastercard', 'sony', 'puma', 'visa']
# 21
# ['Adobe', 'vmware', 'alphabet', 'fedEx', 'tencent']
# 71
# ['Adobe', 'avnet', 'siemens', 'johnson', 'xiaomi']
# 87
# ['amazon', 'tesco', 'disney', 'paypal', 'visa']
# 17
# ['cisco', 'addidas', 'fluor', 'reliance', 'infosys']
# 16
# ['sap', 'addidas', 'merceds', 'nvidia', 'nestle']
# 16
# ['mahindra', 'comcast', 'abb', 'loreal', 'johnson']
# 31
# ['renault', 'cisco', 'woodland', 'american express', "mcdoland's"]
# 74
# ['vmware', 'avnet', 'cosmo', 'tencent', 'vadafone']
# 17
# ['intel', 'crh', 'ibm', 'lg', 'ebay']
# 49
# ['facebook', 'citigroup', 'salesforce', 'bmw', 'samsung']
# 16
# ['Adobe', 'facebook', 'pubg', 'caterpillar', 'vadafone']
# 95
# ['hitachi', 'accenture', 'disney', 'capgemini', 'tencent']
# 47
# ['mahindra', 'qualcomn', 'fluor', 'paypal', 'toyota']
# 61
# ['mahindra', 'amazon', 'netflix', 'acs', 'johnson']
# 17
# ['woodland', 'accenture', 'staples', 'coca-cola', 'onex']
# 56
# ['tcs', 'pubg', 'ibm', 'nippon', 'visa']
# 15
# ['vmware', 'metlife', 'netflix', 'walmart', 'jpmorgan']
# 16
# ['avnet', 'intel', 'tencent', 'tcs', 'hdfc']
# 49
# ['target', 'siemens', 'hitachi', 'pubg', 'staples']
# 15
# ['canon', 'nokia', 'loreal', "mcdoland's", 'tcs']
# 17
# ['renault', 'target', 'metlife', 'oracle', 'acs']
# 38
# ['avnet', 'mastercard', 'wistron', 'sap', 'capgemini']
# 16
# ['renault', 'abb', 'tesla', 'fluor', 'vadafone']
# 104
# ['loreal', 'lg', 'paypal', 'nestle', 'maruhan']
# 26
# ['citigroup', 'staples', 'acs', 'icbc', 'sodexo']
# 29
# ['renault', 'accenture', 'hyundai', 'merceds', 'volkswagen']
# 16
# ['microsoft', 'mahindra', 'walmart', 'citigroup', 'super dry']
# 18
# ['intel', 'comcast', 'jpmorgan', 'reliance', 'rbc']
# 17
# ['woodland', 'cosmo', 'lg', 'nippon', 'sodexo']
# 17
# ['abb', 'woodland', 'tesco', 'wipro', 'tcs']
# 36
# ['tesco', 'wipro', 'merceds', 'jpmorgan', 'bmw']
# 16
# ['woodland', 'netflix', 'acs', 'jpmorgan', 'fedEx']
# 17
# ['danone', 'loreal', 'johnson', 'reliance', 'super dry']
# 17
# ['vmware', 'starbucks', 'visa', 'hdfc', 'apple']
# 77
# ['danone', 'wistron', 'woodland', 'at&t', 'qualcomm']
# 15
# ['siemens', 'vinci', 'wistron', 'reliance', 'tencent']
# 41
# ['pepsi', 'netflix', 'accenture', 'jpmorgan', 'visa']
# 71
# ['amazon', 'ibm', 'fluor', 'reliance', 'xiaomi']
# 15
# ['avnet', 'comcast', 'vadafone', 'airtel', 'bmw']
# 15
# ['danaher', 'tesco', 'capgemini', 'puma', 'visa']
# 32
# ['vmware', 'target', 'cisco', 'icbc', 'tencent']
# 15
# ['maybank', 'mahindra', 'hitachi', 'danaher', 'nike']
# 15
# ['hyundai', 'nike', 'disney', 'puma', 'nestle']
# 17
# ['comcast', 'sap', 'qualcomn', 'tesla', 'panasonic']
# 16
# ['target', 'siemens', 'puma', 'lg', 'qualcomm']
# 52
# ['hitachi', 'acs', 'icbc', 'caterpillar', 'lg']
# 40
# ['Adobe', 'mahindra', 'tesla', 'nvidia', 'tencent']
# 16
# ['maybank', 'mastercard', 'abb', 'netflix', 'toyota']
# 16
# ['mahindra', 'target', 'netflix', 'facebook', 'pubg']
# 54
# ['target', 'starbucks', 'loreal', 'johnson', 'super dry']
# 17
# ['starbucks', 'philip', 'volkswagen', 'rbc', 'sodexo']
# 43
# ['crh', 'facebook', 'accenture', 'staples', 'acs']
# 64
# ['woodland', 'philip', 'walmart', 'merceds', 'bmw']
# 17
# ['siemens', 'qualcomn', 'jpmorgan', "mcdoland's", 'fedEx']
# 37
# ['metlife', 'wistron', 'at&t', 'johnson', 'capgemini']
# 58
# ['Adobe', 'woodland', 'merceds', 'cosmo', 'toyota']
# 94
# ['cisco', 'johnson', 'nvidia', 'panasonic', 'alibaba']
# 26
# ['woodland', 'puma', 'qualcomm', 'maruhan', 'samsung']
# 17
# ['woodland', 'sony', 'nokia', 'crh', 'oracle']
# 15
# ['woodland', 'aegon', 'addidas', 'merceds', 'airtel']
# 59
# ['icici', 'jpmorgan', 'capgemini', 'onex', 'alibaba']
# 93
# ['danaher', 'walmart', 'accenture', 'staples', 'tesla']
# 16
# ['intel', 'amazon', 'starbucks', 'aegon', 'nippon']
# 15
# ['target', 'icici', 'vinci', 'nike', 'coca-cola']
# 15
# ['cisco', 'netflix', 'johnson', 'reliance', 'nestle']
# 15
# ['renault', 'target', 'hitachi', 'aegon', 'ibm']
# 35
# ['pubg', 'loreal', 'icbc', 'nike', 'jpmorgan']
# 16
# ['microsoft', 'cisco', 'facebook', 'hp', 'nvidia']
# 17
# ['comcast', 'tesco', 'jpmorgan', 'paypal', 'vadafone']
# 42
# ['metlife', 'american express', 'pubg', 'jpmorgan', 'airtel']
# 16
# ['metlife', 'jpmorgan', 'puma', 'onex', 'tencent']
# 15
# ['amr', 'mastercard', 'wipro', 'puma', 'tencent']
# 57
# ['Adobe', 'siemens', 'mastercard', 'philip', 'cosmo']
# 54
# ['metlife', 'canon', 'airtel', 'tencent', 'super dry']
# 18
# ['mahindra', 'metlife', 'wipro', 'volkswagen', 'nestle']
# 33
# ['crh', 'netflix', 'hyundai', 'capgemini', 'cosmo']
# 17
# ['Adobe', 'maybank', 'intel', 'target', 'metlife']
# 16
# ['danone', 'target', 'mastercard', "mcdoland's", 'tcs']
# 15
# ['mahindra', 'amazon', 'puma', 'airtel', 'infosys']
# 81
# ['metlife', 'tesco', 'cosmo', 'lg', 'vadafone']
# 86
# ['icici', 'hyundai', "mcdoland's", 'tcs', 'airtel']
# 43
# ['microsoft', 'hp', 'acs', 'coca-cola', 'tencent']
# 50
# ['danone', 'avnet', 'at&t', 'ibm', 'infosys']
# 15
# ['intel', "mcdoland's", 'nvidia', 'panasonic', 'volkswagen']
# 38
# ['danaher', 'disney', 'tcs', 'alibaba', 'maruhan']
# 73
# ['icbc', 'johnson', 'tcs', 'alibaba', 'bmw']
# 15
# ['starbucks', 'ford', 'barclays', 'johnson', 'visa']
# 39
# ['renault', 'amazon', 'icici', 'pepsi', "mcdoland's"]
# 16
# ['maybank', 'cisco', 'nokia', 'icbc', 'sodexo']
# 15
# ['danaher', 'pepsi', 'hyundai', 'nike', 'nvidia']
# 36
# ['mahindra', 'icici', 'starbucks', 'johnson', 'nike']
# 16
# ['woodland', 'nokia', 'tesco', 'staples', 'cosmo']
# 118
# ['danone', 'crh', 'tesco', 'alphabet', 'paypal']
# 25
# ['amazon', 'cisco', 'acs', 'merceds', 'coca-cola']
# 60
# ['amazon', 'abb', 'addidas', 'icbc', 'xiaomi']
# 16
# ['amazon', 'comcast', 'accenture', 'johnson', 'volkswagen']
# 55
# ['renault', 'avnet', 'philip', 'merceds', 'fedEx']
# 52
# ['cisco', 'barclays', 'citigroup', 'johnson', 'fedEx']
# 68
# ['microsoft', 'ford', 'citigroup', 'hyundai', 'ibm']
# 16
# ['nokia', 'nvidia', 'capgemini', 'ebay', 'qualcomm']
# 48
# ['target', 'danaher', 'johnson', 'nike', 'reliance']
# 112
# ['starbucks', 'mastercard', 'hdfc', 'ebay', 'nestle']
# 17
# ['maybank', 'cisco', 'capgemini', 'lg', 'nestle']
# 48
# ['accenture', 'alphabet', 'nippon', 'rbc', 'airtel']
# 15
# ['target', 'hyundai', 'nike', 'nvidia', 'nippon']
# 17
# ['target', 'disney', 'cosmo', 'caterpillar', 'super dry']
# 81
# ['metlife', 'pubg', 'volkswagen', 'ebay', 'infosys']
# 104
# ['Adobe', 'abb', 'philip', 'citigroup', 'reliance']
# 39
# ['abb', 'danaher', 'tesco', 'jpmorgan', 'capgemini']
# 61
# ['amr', 'metlife', 'nokia', 'accenture', 'jpmorgan']
# 17
# ['danaher', 'woodland', 'citigroup', 'cosmo', 'nippon']
# 26
# ['Adobe', 'cosmo', 'salesforce', 'airtel', 'infosys']
# 17
# ['danone', 'intel', 'accenture', 'nestle', 'salesforce']
# 16
# ['avnet', 'intel', 'philip', 'merceds', 'volkswagen']
# 16
# ['danone', 'barclays', 'canon', 'johnson', 'volkswagen']
# 18
# ['mastercard', 'tcs', 'onex', 'nestle', 'salesforce']
# 89
# ['amr', 'siemens', 'mastercard', 'walmart', 'toyota']
# 27
# ['danone', 'mahindra', 'metlife', 'aegon', 'visa']
# 17
# ['wistron', 'staples', 'loreal', 'jpmorgan', 'vadafone']
# 116
# ['avnet', 'maybank', 'metlife', 'onex', 'alibaba']
# 21
# ['amr', 'danone', 'siemens', 'netflix', 'tencent']
# 57
# ['cisco', 'aegon', 'puma', 'visa', 'xiaomi']
# 17
# ['vinci', "mcdoland's", 'reliance', 'coca-cola', 'nestle']
# 24
# ['mastercard', 'sony', 'reliance', 'coca-cola', 'paypal']
# 56
# ['target', 'crh', 'nvidia', 'coca-cola', 'visa']
# 16
# ['starbucks', 'nike', 'cosmo', 'fedEx', 'salesforce']
# 34
# ['avnet', 'wistron', 'oracle', 'pubg', 'icbc']
# 50
# ['mahindra', 'philip', 'tesla', "mcdoland's", 'paypal']
# 109
# ['hp', 'hyundai', 'loreal', 'tesla', 'hdfc']
# 15
# ['starbucks', 'philip', 'staples', 'ibm', 'tencent']
# 61
# ['amazon', 'metlife', 'woodland', 'sony', 'pubg']
# 81
# ['icici', 'american express', 'at&t', 'sap', 'philip']
# 32
# ['comcast', 'abb', 'woodland', 'wipro', 'tencent']
# 74
# ['metlife', 'danaher', 'staples', 'acs', 'hdfc']
# 15
# ['intel', 'ford', 'panasonic', 'apple', 'infosys']
# 18
# ['cisco', 'tesco', 'jpmorgan', 'nike', 'rbc']
# 17
# ['maybank', 'microsoft', 'mastercard', 'johnson', 'paypal']
# 16
# ['sony', 'tesco', 'sap', 'ibm', 'rbc']
# 31
# ['comcast', 'crh', 'pubg', 'tcs', 'salesforce']
# 47
# ['amr', 'avnet', 'metlife', 'sony', 'crh']
# 15
# ['comcast', 'starbucks', 'oracle', 'onex', 'visa']
# 49
# ['siemens', 'pepsi', 'accenture', 'hdfc', 'airtel']
# 82
# ['wistron', 'cisco', 'sony', 'jpmorgan', 'samsung']
# 15
# ['starbucks', 'metlife', 'caterpillar', 'nippon', 'vadafone']
# 47
# ['microsoft', 'hp', 'icbc', 'puma', 'fluor']
# 15
# ['amazon', 'philip', 'oracle', 'staples', 'super dry']
# 17
# ['vmware', 'amazon', 'mastercard', 'sap', 'merceds']
# 49
# ['metlife', 'barclays', 'wipro', 'panasonic', 'nippon']
# 34
# ['target', 'cisco', 'ford', 'philip', 'ebay']
# 16
# ['Adobe', 'barclays', 'at&t', 'staples', 'caterpillar']
# 29
# ['ibm', 'tesla', 'nike', 'xiaomi', 'alibaba']
# 66
# ['renault', 'abb', 'wipro', 'tcs', 'alibaba']
# 16
# ['Adobe', 'comcast', 'lg', 'coca-cola', 'sodexo']
# 32
# ['target', 'citigroup', 'loreal', 'nvidia', 'tencent']
# 17
# ['amr', 'starbucks', 'wipro', 'coca-cola', 'nestle']
# 16
# ['amazon', 'cisco', 'jpmorgan', 'reliance', 'onex']
# 15
# ['mahindra', 'addidas', 'lg', 'nippon', 'bmw']
# 53
# ['avnet', 'mastercard', 'hp', 'tesla', 'qualcomm']
# 17
# ['avnet', 'vinci', 'netflix', 'fluor', 'bmw']
# 30
# ['amr', 'hp', 'pubg', 'puma', 'alphabet']
# 81
# ['abb', 'facebook', 'capgemini', 'cosmo', 'infosys']
# 15
# ['accenture', 'pubg', 'acs', 'fluor', 'visa']
# 54
# ['crh', 'visa', 'caterpillar', 'ebay', 'tencent']
# 57
# ['renault', 'mahindra', 'crh', 'reliance', 'maruhan']
# 18
# ['hp', 'addidas', 'paypal', 'toyota', 'samsung']
# 37
# ['amr', 'mastercard', 'acs', 'disney', 'toyota']
# 15
# ['mastercard', 'citigroup', 'ibm', 'nike', 'rbc']
# 15
# ['hitachi', 'canon', 'crh', 'ibm', 'apple']
# 18
# ['microsoft', 'mahindra', 'comcast', 'facebook', 'wipro']
# 17
# ['cisco', 'danaher', 'paypal', 'apple', 'infosys']
# 16
# ['renault', 'target', 'capgemini', 'caterpillar', 'samsung']
# 36
# ['philip', 'johnson', 'capgemini', 'airtel', 'infosys']
# 60
# ['amr', 'vinci', 'citigroup', 'nike', 'samsung']
# 15
# ['comcast', 'ford', 'crh', 'loreal', 'panasonic']
# 32
# ['danone', 'ford', 'facebook', 'capgemini', 'tencent']
# 61
# ['mahindra', 'target', 'hitachi', 'acs', 'xiaomi']
# 17
# ['amr', 'ford', 'pubg', "mcdoland's", 'vadafone']
# 37
# ['vmware', 'netflix', 'nike', 'nvidia', 'tencent']
# 69
# ['mastercard', 'danaher', 'crh', 'qualcomn', 'airtel']
# 15
# ['comcast', 'citigroup', 'tesla', 'rbc', 'xiaomi']
# 17
# ['amazon', 'netflix', 'tencent', 'lg', 'visa']
# 17
# ['at&t', 'oracle', 'facebook', 'staples', 'bmw']
# 18
# ['nokia', 'pubg', 'addidas', 'johnson', 'lg']
# 22
# ['mahindra', 'johnson', 'cosmo', 'super dry', 'bmw']
# 17
# ['starbucks', 'mastercard', 'cisco', 'american express', "mcdoland's"]
# 16
# ['intel', 'cisco', 'cosmo', 'super dry', 'infosys']
# 30
# ['danone', 'metlife', 'capgemini', 'cosmo', 'paypal']
# 46
# ['amr', 'sony', 'addidas', 'disney', 'xiaomi']
# 16
# ['avnet', 'facebook', 'hp', 'nike', 'caterpillar']
# 16
# ['amr', 'netflix', 'aegon', 'onex', 'airtel']
# 40
# ['renault', 'maybank', 'nokia', 'hyundai', 'sodexo']
# 15
# ['american express', 'staples', 'cosmo', 'visa', 'infosys']
# 38
# ['Adobe', 'crh', 'oracle', 'walmart', 'rbc']
# 75
# ['amr', 'oracle', 'accenture', 'disney', 'volkswagen']
# 100
# ['mahindra', 'target', 'netflix', 'hyundai', 'tcs']
# 15
# ['at&t', 'facebook', 'staples', 'disney', 'super dry']
# 16
# ['vmware', 'microsoft', 'barclays', 'puma', 'volkswagen']
# 15
# ['sap', 'puma', 'fedEx', 'tencent', 'alibaba']
# 16
# ['target', 'crh', 'puma', 'capgemini', 'panasonic']
# 77
# ['abb', 'accenture', 'walmart', 'nippon', 'ebay']
# 16
# ['mahindra', 'amazon', 'siemens', 'comcast', 'ford']
# 15
# ['maybank', 'mastercard', 'hp', 'hyundai', 'puma']
# 18
# ['sap', 'hp', 'ibm', 'merceds', 'acs']
# 15
# ['wistron', 'sony', 'ibm', 'johnson', 'cosmo']
# 49
# ['siemens', 'icici', 'acs', 'fedEx', 'apple']
# 18
# ['starbucks', 'hitachi', 'sony', 'ebay', 'xiaomi']
# 100
# ['starbucks', 'canon', 'lg', 'ebay', 'vadafone']
# 42
# ['mahindra', 'siemens', 'hp', 'wipro', 'tesla']
# 15
# ['mahindra', 'barclays', 'puma', 'coca-cola', 'tcs']
# 15
# ['mahindra', 'wipro', 'johnson', 'paypal', 'super dry']
# 48
# ['abb', 'coca-cola', 'volkswagen', 'salesforce', 'maruhan']
# 71
# ['vmware', 'oracle', 'wipro', 'onex', 'bmw']
# 52
# ['sony', 'canon', 'accenture', 'paypal', 'tencent']
# 17
# ['amazon', 'sap', 'accenture', 'merceds', 'fedEx']
# 60
# ['wistron', 'nokia', 'netflix', 'qualcomn', 'qualcomm']
# 110
# ['philip', 'capgemini', 'nippon', 'onex', 'rbc']
# 26
# ['vinci', 'danaher', 'canon', 'oracle', 'johnson']
# 65
# ['vmware', 'tesco', 'coca-cola', 'tencent', 'sodexo']
# 96
# ['Adobe', 'starbucks', 'qualcomn', 'ibm', 'maruhan']
# 16
# ['Adobe', 'siemens', 'staples', 'nestle', 'airtel']
# 48
# ['nokia', 'at&t', 'acs', 'johnson', 'apple']
# 18
# ['mastercard', 'nvidia', 'puma', 'caterpillar', 'ebay']
# 44
# ['mahindra', 'target', 'abb', 'hp', 'airtel']
# 64
# ['alibaba', 'cisco', 'fedEx', 'tcs', 'vadafone']
# 18
# ['danone', 'sap', 'wipro', 'alibaba', 'samsung']
# 42
# ['amazon', 'intel', 'comcast', 'hitachi', 'nokia']
# 16
# ['woodland', 'sap', 'aegon', 'puma', 'tencent']
# 15
# ['comcast', 'mastercard', 'ford', 'salesforce', 'infosys']
# 47
# ['siemens', 'hitachi', 'merceds', 'nippon', 'visa']
# 36
# ['mahindra', 'hitachi', 'abb', 'sony', 'tesla']
# 70
# ['hitachi', 'cisco', 'crh', 'oracle', 'cosmo']
# 17
# ['icici', 'tesco', 'ibm', 'capgemini', 'fluor']
# 15
# ['woodland', 'citigroup', 'icbc', 'johnson', 'alibaba']
# 15
# ['cisco', 'woodland', 'staples', 'aegon', 'caterpillar']
# 15
# ['starbucks', 'danaher', 'tesco', 'philip', 'aegon']
# 71
# ['target', 'danaher', 'johnson', 'icbc', 'fluor']
# 16
# ['maybank', 'fedEx', 'tesco', 'tesla', 'nippon']
# 28
# ['facebook', 'accenture', 'addidas', 'cosmo', 'infosys']
# 18
# ['woodland', 'accenture', 'icbc', 'fedEx', 'bmw']
# 17
# ['renault', 'amazon', 'cisco', 'icbc', 'tencent']
# 28
# ['avnet', 'intel', 'jpmorgan', 'hdfc', 'qualcomm']
# 101
# ['amr', 'maybank', 'sap', 'citigroup', 'icbc']
# 16
# ['sap', 'capgemini', 'visa', 'xiaomi', 'vadafone']
# 42
# ['metlife', 'accenture', 'reliance', 'salesforce', 'airtel']
# 18
# ['icici', 'oracle', 'citigroup', 'coca-cola', 'visa']
# 15
# ['icici', 'tesco', 'nvidia', 'capgemini', 'lg']
# 15
# ['mastercard', 'nokia', 'sap', 'icbc', 'ebay']
# 86
# ['metlife', 'accenture', 'pubg', 'salesforce', 'airtel']
# 17
# ['amazon', 'danaher', 'sap', 'tesla', 'xiaomi']
# 16
# ['reliance', 'tcs', 'onex', 'apple', 'alibaba']
# 15
# ['Adobe', 'mastercard', 'tesco', 'philip', 'disney']
# 15
# ['avnet', 'cisco', 'hyundai', 'disney', 'visa']
# 25
# ['siemens', 'accenture', 'reliance', 'tencent', 'airtel']
# 66
# ['metlife', 'crh', 'hyundai', 'icbc', 'tencent']
# 15
# ['aegon', 'nvidia', 'lg', 'paypal', 'samsung']
# 20
# ['vmware', 'Adobe', 'johnson', 'tencent', 'infosys']
# 16
# ['intel', 'citigroup', 'johnson', 'ebay', 'tencent']
# 81
# ['woodland', 'netflix', 'accenture', 'ibm', 'apple']
# 26
# ['at&t', 'tesco', 'puma', 'visa', 'maruhan']
# 16
# ['intel', 'tesco', 'oracle', 'toyota', 'apple']
# 17
# ['renault', 'avnet', 'amazon', 'toyota', 'rbc']
# 29
# ['avnet', 'amazon', 'abb', 'tesla', 'maruhan']
# 66
# ['amazon', 'wistron', 'american express', 'lg', 'super dry']
# 15
# ['avnet', 'sony', 'facebook', 'citigroup', 'tesla']
# 30
# ['renault', 'siemens', 'at&t', 'cosmo', 'nestle']
# 50
# ['barclays', 'cosmo', 'coca-cola', 'tcs', 'rbc']
# 88
# ['renault', 'danone', 'mahindra', 'facebook', 'tencent']
# 16
# ['facebook', 'addidas', 'johnson', 'merceds', 'alibaba']
# 64
# ['maybank', 'target', 'hyundai', 'pubg', 'staples']
# 15
# ['target', 'sony', 'nokia', 'citigroup', 'super dry']
# 21
# ['ford', 'facebook', 'sodexo', 'panasonic', 'xiaomi']
# 18
# ['hitachi', 'sony', 'hyundai', 'wipro', 'volkswagen']
# 17
# ['airtel', 'nippon', 'sodexo', 'super dry', 'infosys']
# 56
# ['vmware', 'siemens', 'aegon', 'onex', 'airtel']
# 49
# ['hitachi', 'canon', 'cosmo', 'reliance', 'ebay']
# 17
# ['metlife', 'philip', 'lg', 'nippon', 'sodexo']
# 42
# ['acs', 'jpmorgan', 'johnson', 'loreal', 'super dry']
# 15
# ['amr', 'sony', 'facebook', 'tesco', 'super dry']
# 15
# ['citigroup', 'wipro', "mcdoland's", 'capgemini', 'tcs']
# 62
# ['mahindra', 'metlife', 'danaher', 'staples', 'merceds']
# 15
# ['vmware', 'abb', 'tencent', 'volkswagen', 'nestle']
# 17
# ['danone', 'cisco', 'hp', 'ibm', 'coca-cola']
# 44
# ['Adobe', 'hp', 'nike', 'fedEx', 'onex']
# 70
# ['facebook', 'puma', 'cosmo', 'nippon', 'alibaba']
# 16
# ['avnet', 'sony', 'apple', 'airtel', 'infosys']
# 33
# ['renault', 'metlife', 'sony', 'walmart', 'airtel']
# 105
# ['ford', 'at&t', 'jpmorgan', 'fluor', 'salesforce']
# 16
# ['avnet', 'mahindra', "mcdoland's", 'nestle', 'alibaba']
# 50
# ['amr', 'pepsi', 'jpmorgan', 'coca-cola', 'nestle']
# 16
# ['wistron', 'sony', 'icbc', 'capgemini', 'reliance']
# 117
# ['starbucks', 'philip', 'qualcomn', 'tencent', 'rbc']
# 51
# ['metlife', 'ford', 'netflix', 'american express', 'philip']
# 16
# ['wipro', 'tcs', 'rbc', 'sodexo', 'samsung']
# 16
# ['target', 'staples', 'nvidia', 'cosmo', 'rbc']
# 32
# ['renault', 'mahindra', 'comcast', 'danaher', 'american express']
# 47
# ['rbc', 'panasonic', 'salesforce', 'alibaba', 'nippon']
# 17
# ['mahindra', 'starbucks', 'barclays', 'walmart', 'jpmorgan']
# 47
# ['vinci', 'woodland', 'facebook', 'fluor', 'caterpillar']
# 16
# ['cisco', 'accenture', 'nike', 'coca-cola', 'visa']
# 131
# ['danaher', 'at&t', 'tesco', 'puma', 'toyota']
# 41
# ['Adobe', 'starbucks', 'nippon', 'volkswagen', 'visa']
# 64
# ['amr', 'amazon', 'abb', 'walmart', 'nippon']
# 124
# ['danone', 'siemens', 'netflix', 'lg', 'fedEx']
# 39
# ['abb', 'facebook', 'nvidia', 'fedEx', 'qualcomm']
# 16
# ['vmware', 'icici', 'oracle', 'icbc', 'xiaomi']
# 15
# ['vmware', 'crh', 'hyundai', 'nike', 'nestle']
# 19
# ['avnet', 'at&t', 'philip', 'hyundai', 'rbc']
# 89
# ['maybank', 'mahindra', 'metlife', 'ibm', 'alphabet']
# 65
# ['vmware', 'hp', 'lg', 'volkswagen', 'bmw']
# 57
# ['amazon', 'nvidia', 'lg', 'ebay', 'airtel']
# 17
# ['disney', 'tcs', 'volkswagen', 'hdfc', 'maruhan']
# 90
# ['nokia', 'ibm', 'visa', 'toyota', 'apple']
# 38
# ['sap', 'qualcomn', 'hyundai', 'rbc', 'vadafone']
# 18
# ['wistron', 'woodland', 'nokia', 'facebook', 'tesla']
# 15
# ['woodland', 'staples', 'loreal', 'johnson', 'vadafone']
# 43
# ['renault', 'abb', 'qualcomn', 'jpmorgan', 'onex']
# 54
# ['Adobe', 'microsoft', 'mahindra', 'pubg', 'reliance']
# 112
# ['intel', 'target', 'comcast', 'acs', 'fluor']
# 53
# ['vmware', 'amr', 'cisco', 'abb', 'hdfc']
# 75
# ['nike', 'volkswagen', 'salesforce', 'xiaomi', 'super dry']
# 138
# ['renault', 'maybank', 'alphabet', 'caterpillar', 'tencent']
# 45
# ['philip', 'accenture', 'acs', 'reliance', 'vadafone']
# 57
# ['ford', 'nokia', 'loreal', 'alphabet', 'infosys']
# 15
# ['Adobe', 'intel', 'at&t', "mcdoland's", 'samsung']
# 37
# ['amr', 'netflix', 'cosmo', 'apple', 'airtel']
# 47
# ['starbucks', 'danaher', 'johnson', 'sodexo', 'airtel']
# 17
# ['fedEx', 'hp', 'loreal', 'capgemini', 'tcs']
# 45
# ['renault', 'philip', 'visa', 'salesforce', 'airtel']
# 70
# ['maybank', 'hyundai', 'wipro', 'cosmo', 'vadafone']
# 18
# ['Adobe', 'nike', 'nestle', 'xiaomi', 'alibaba']
# 54
# ['danone', 'amazon', 'loreal', 'tesla', 'qualcomm']
# 67
# ['amazon', 'siemens', 'ford', 'tesla', 'reliance']
# 18
# ['danone', 'metlife', 'sap', 'merceds', 'nippon']
# 38
# ['avnet', 'amazon', 'nokia', 'american express', 'salesforce']
# 65
# ['danone', 'hitachi', 'citigroup', 'hyundai', 'salesforce']
# 18
# ['maybank', 'facebook', 'panasonic', 'nestle', 'paypal']
# 38
# ['Adobe', 'wipro', 'nvidia', 'toyota', 'xiaomi']
# 17
# ['barclays', 'philip', 'aegon', 'loreal', 'coca-cola']
# 104
# ['target', 'ford', 'hp', 'paypal', 'airtel']
# 37
# ['abb', 'hitachi', 'qualcomn', 'puma', 'alibaba']
# 68
# ['vmware', 'mastercard', 'jpmorgan', 'merceds', 'rbc']
# 17
# ['maybank', 'metlife', 'accenture', 'qualcomm', 'infosys']
# 57
# ['amazon', 'sony', 'nike', 'coca-cola', 'apple']
# 16
# ['icici', 'loreal', 'puma', 'volkswagen', 'airtel']
# 17
# ['intel', 'metlife', 'staples', 'hdfc', 'rbc']
# 15
# ['amazon', 'wipro', 'nike', 'rbc', 'bmw']
# 76
# ['canon', 'tesco', 'pubg', 'reliance', 'caterpillar']
# 18
# ['starbucks', 'hitachi', 'woodland', 'crh', 'onex']
# 26
# ['ford', 'cosmo', 'reliance', 'paypal', 'super dry']
# 16
# ['puma', 'reliance', 'tcs', 'volkswagen', 'paypal']
# 15
# ['wipro', 'capgemini', 'paypal', 'bmw', 'samsung']
# 16
# ['pubg', 'johnson', 'cosmo', 'paypal', 'onex']
# 16
# ['target', 'hitachi', 'pepsi', 'tcs', 'visa']
# 15
# ['avnet', 'target', 'american express', 'disney', 'onex']
# 19
# ['tesco', 'icbc', 'nike', 'nestle', 'rbc']
# 65
# ['Adobe', 'vinci', 'hp', 'ibm', 'bmw']
# 16
# ['cisco', 'canon', 'qualcomn', 'icbc', 'tencent']
# 78
# ['amr', 'siemens', 'nike', 'nippon', 'rbc']
# 45
# ['microsoft', 'comcast', 'ford', 'facebook', 'xiaomi']
# 15
# ['amr', 'vinci', 'comcast', 'accenture', 'alphabet']
# 15
# ['ford', 'hyundai', 'alphabet', 'ebay', 'rbc']
# 16
# ['amr', 'amazon', 'metlife', 'disney', 'qualcomm']
# 16
# ['icici', 'nokia', 'hp', 'acs', 'puma']
# 18
# ['renault', 'johnson', 'toyota', 'salesforce', 'bmw']
# 80
# ['mastercard', 'woodland', 'pepsi', 'hyundai', 'onex']
# 15
# ['pepsi', 'cosmo', 'reliance', 'qualcomm', 'airtel']
# 17
# ['danone', 'danaher', 'citigroup', 'onex', 'rbc']
# 67
# ['danaher', 'facebook', 'hp', 'loreal', 'panasonic']
# 16
# ['renault', 'siemens', 'qualcomn', "mcdoland's", 'vadafone']
# 16
# ['starbucks', 'sony', 'tesco', 'alphabet', 'visa']
# 15
# ['woodland', 'american express', 'loreal', 'capgemini', 'apple']
# 100
# ['metlife', 'hdfc', 'nippon', 'nestle', 'qualcomm']
# 47
# ['microsoft', 'merceds', 'cosmo', 'fedEx', 'samsung']
# 44
# ['danone', 'barclays', 'woodland', 'nvidia', 'nippon']
# 63
# ['Adobe', 'intel', 'johnson', 'capgemini', 'vadafone']
# 15
# ['puma', 'lg', 'qualcomm', 'sodexo', 'maruhan']
# 59
# ['target', 'abb', 'crh', 'american express', 'acs']
# 98
# ['hitachi', 'cisco', 'abb', 'woodland', 'vadafone']
# 40
# ['maybank', 'mahindra', 'sony', 'qualcomn', 'johnson']
# 71
# ['amr', 'staples', 'addidas', 'panasonic', 'visa']
# 16
# ['danaher', 'woodland', 'netflix', 'paypal', 'volkswagen']
# 32
# ['maybank', 'intel', 'at&t', 'acs', 'tcs']
# 17
# ['philip', 'hyundai', 'loreal', 'capgemini', 'panasonic']
# 87
# ['abb', 'sap', 'puma', 'salesforce', 'airtel']
# 47
# ['danaher', 'nokia', 'philip', 'coca-cola', 'qualcomm']
# 81
# ['hitachi', 'philip', 'reliance', 'fedEx', 'onex']
# 15
# ['intel', 'merceds', 'cosmo', 'alphabet', 'visa']
# 47
# ['vmware', 'mahindra', 'caterpillar', 'nippon', 'volkswagen']
# 18
# ['avnet', 'jpmorgan', 'johnson', 'coca-cola', 'apple']
# 98
# ['woodland', 'canon', 'nokia', 'hyundai', 'infosys']
# 15
# ['accenture', 'staples', 'capgemini', 'fedEx', 'samsung']
# 70
# ['vmware', 'starbucks', 'mastercard', 'tcs', 'salesforce']
# 61
# ['hp', 'hyundai', 'ibm', 'alphabet', 'nestle']
# 16
# ['facebook', 'hp', 'staples', 'icbc', 'qualcomm']
# 16
# ['Adobe', 'intel', 'johnson', 'nippon', 'samsung']
# 15
# ['amr', 'Adobe', 'amazon', 'addidas', 'volkswagen']
# 50
# ['johnson', 'nike', 'fedEx', 'panasonic', 'toyota']
# 71
# ['vmware', 'danaher', 'hdfc', 'airtel', 'infosys']
# 16
# ['ford', 'woodland', 'loreal', 'super dry', 'infosys']
# 55
# ['acs', 'merceds', 'lg', 'fedEx', 'airtel']
# 16
# ['sony', 'netflix', 'nokia', 'canon', 'ibm']
# 17
# ['amazon', 'philip', 'walmart', 'staples', 'onex']
# 66
# ['facebook', 'sap', 'lg', 'ebay', 'hdfc']
# 67
# ['Adobe', 'hitachi', "mcdoland's", 'capgemini', 'xiaomi']
# 77
# ['siemens', 'hitachi', 'danaher', 'sap', 'rbc']
# 48
# ['nokia', 'staples', 'puma', 'onex', 'nestle']
# 61
# ['mahindra', 'abb', 'walmart', 'panasonic', 'xiaomi']
# 15
# ['intel', 'woodland', 'canon', 'addidas', 'volkswagen']
# 44
# ['renault', 'vmware', 'amr', 'jpmorgan', 'coca-cola']
# 61
# ['Adobe', 'nokia', 'at&t', 'tesco', 'cosmo']
# 90
# ['mastercard', "mcdoland's", 'merceds', 'ebay', 'bmw']
# 37
# ['oracle', 'accenture', 'visa', "mcdoland's", 'tencent']
# 75
# ['vmware', 'danone', 'at&t', 'oracle', 'johnson']
# 16
# ['amr', 'walmart', 'hyundai', 'accenture', 'merceds']
# 18
# ['Adobe', 'alibaba', 'fluor', 'tencent', 'airtel']
# 94
# ['avnet', 'danaher', 'facebook', 'loreal', 'hdfc']
# 16
# ['mahindra', 'caterpillar', 'coca-cola', 'volkswagen', 'bmw']
# 48
# ['ford', 'canon', 'capgemini', 'fedEx', 'ebay']
# 83
# ['Adobe', 'metlife', 'ibm', 'alibaba', 'bmw']
# 16
# ['avnet', 'walmart', 'staples', 'fluor', 'toyota']
# 43
# ['mastercard', 'hp', 'tencent', 'airtel', 'infosys']
# 35
# ['ford', 'at&t', 'paypal', 'hdfc', 'toyota']
# 15
# ['vmware', 'comcast', 'loreal', 'johnson', 'alibaba']
# 45
# ['amr', 'at&t', 'hyundai', 'johnson', 'alphabet']
# 55
# ['hp', 'addidas', 'tesla', 'capgemini', 'apple']

# %%
recommedations
# Out:
# {'user1': ['ford', 'paypal', 'panasonic', 'airtel', 'infosys'],
#  'user2': ['nokia', 'citigroup', 'hyundai', 'disney', 'panasonic'],
#  'user3': ['siemens', 'accenture', 'acs', 'onex', 'super dry'],
#  'user4': ['mahindra', 'icici', 'tcs', 'onex', 'bmw'],
#  'user5': ['amazon', 'hitachi', 'facebook', 'lg', 'panasonic'],
#  'user6': ['wistron', 'pepsi', 'walmart', 'tcs', 'alibaba'],
#  'user7': ['target', 'sap', 'nvidia', 'puma', 'ebay'],
#  'user8': ['tesco', 'ibm', 'tesla', 'vadafone', 'airtel'],
#  'user9': ['accenture', 'acs', 'jpmorgan', 'fluor', 'volkswagen'],
#  'user10': ['avnet', 'mastercard', 'at&t', 'icbc', 'xiaomi'],
#  'user11': ['addidas', 'johnson', 'tcs', 'qualcomm', 'alibaba'],
#  'user12': ['vmware', 'target', 'starbucks', 'hitachi', 'qualcomm'],
#  'user13': ['amazon', 'citigroup', 'acs', 'icbc', 'reliance'],
#  'user14': ['hitachi', 'facebook', 'pubg', 'hyundai', 'panasonic'],
#  'user15': ['danone', 'philip', 'pubg', 'nvidia', 'super dry'],
#  'user16': ['avnet', 'metlife', 'american express', 'aegon', 'cosmo'],
#  'user17': ['avnet', 'mastercard', 'aegon', 'capgemini', 'toyota'],
#  'user18': ['icici', 'citigroup', 'cosmo', 'tcs', 'samsung'],
#  'user19': ['crh', 'sap', 'qualcomn', 'capgemini', 'onex'],
#  'user20': ['woodland', "mcdoland's", 'johnson', 'alphabet', 'bmw'],
#  'user21': ['avnet', 'sodexo', 'hyundai', 'xiaomi', 'maruhan'],
#  'user22': ['comcast', 'danaher', 'hp', 'aegon', 'volkswagen'],
#  'user23': ['renault', 'woodland', 'jpmorgan', 'panasonic', 'xiaomi'],
#  'user24': ['danone', 'mahindra', 'target', 'philip', 'bmw'],
#  'user25': ['woodland', 'sony', 'crh', 'pubg', 'bmw'],
#  'user26': ['mahindra', 'amazon', 'mastercard', 'pubg', 'icbc'],
#  'user27': ['ford', 'danaher', 'nvidia', 'paypal', 'airtel'],
#  'user28': ['microsoft', 'pepsi', 'walmart', 'nippon', 'volkswagen'],
#  'user29': ['starbucks', 'accenture', 'addidas', 'tencent', 'airtel'],
#  'user30': ['Adobe', 'philip', 'walmart', 'nvidia', 'puma'],
#  'user31': ['renault', 'metlife', 'crh', 'philip', 'lg'],
#  'user32': ['mahindra', 'wistron', 'oracle', 'wipro', 'icbc'],
#  'user33': ['tesco', 'at&t', 'ibm', 'icbc', 'vadafone'],
#  'user34': ['icici', 'metlife', 'hitachi', 'citigroup', 'jpmorgan'],
#  'user35': ['mahindra', 'citigroup', 'capgemini', 'coca-cola', 'visa'],
#  'user36': ['target', 'hp', 'loreal', 'nvidia', 'super dry'],
#  'user37': ['intel', 'starbucks', 'icbc', 'reliance', 'paypal'],
#  'user38': ['icici', 'tesco', 'hp', 'toyota', 'salesforce'],
#  'user39': ['renault', 'salesforce', 'accenture', 'nippon', 'apple'],
#  'user40': ['amr', 'maybank', 'ford', 'ibm', 'volkswagen'],
#  'user41': ['accenture', 'hyundai', 'nike', 'alphabet', 'bmw'],
#  'user42': ['comcast', 'starbucks', 'oracle', 'citigroup', 'airtel'],
#  'user43': ['target', 'abb', 'pubg', 'icbc', 'jpmorgan'],
#  'user44': ['capgemini', 'puma', 'infosys', 'salesforce', 'samsung'],
#  'user45': ['metlife', 'abb', 'merceds', 'reliance', 'salesforce'],
#  'user46': ['maybank', 'metlife', 'rbc', 'sap', 'apple'],
#  'user47': ['crh', 'at&t', 'hp', 'johnson', 'alibaba'],
#  'user48': ['maybank', 'hitachi', 'nokia', 'qualcomn', 'onex'],
#  'user49': ['comcast', 'cisco', 'airtel', 'tesla', 'alibaba'],
#  'user50': ['Adobe', 'facebook', 'ibm', 'airtel', 'maruhan'],
#  'user51': ['mastercard', 'walmart', 'staples', 'loreal', 'super dry'],
#  'user52': ['wistron', 'wipro', 'fedEx', 'hdfc', 'nippon'],
#  'user53': ['vinci', 'walmart', 'citigroup', 'nippon', 'hdfc'],
#  'user54': ['amazon', 'loreal', 'hdfc', 'ebay', 'tencent'],
#  'user55': ['facebook', 'disney', 'volkswagen', 'vadafone', 'maruhan'],
#  'user56': ['Adobe', 'hitachi', 'wistron', 'hyundai', 'nvidia'],
#  'user57': ['avnet', 'woodland', 'oracle', 'philip', 'salesforce'],
#  'user58': ['tesco', 'icbc', 'nike', 'fluor', 'onex'],
#  'user59': ['vmware', 'nvidia', 'alphabet', 'onex', 'salesforce'],
#  'user60': ['nvidia', 'fluor', 'caterpillar', 'tcs', 'vadafone'],
#  'user61': ['apple', 'capgemini', 'alphabet', 'rbc', 'samsung'],
#  'user62': ['acs', 'alphabet', 'nippon', 'rbc', 'bmw'],
#  'user63': ['cisco', 'icbc', 'tesla', 'onex', 'volkswagen'],
#  'user64': ['tesco', 'oracle', 'hp', 'alphabet', 'paypal'],
#  'user65': ['vinci', 'mastercard', 'icbc', 'hdfc', 'super dry'],
#  'user66': ['maybank', 'woodland', 'merceds', 'ebay', 'bmw'],
#  'user67': ['Adobe', 'avnet', 'danaher', 'oracle', 'apple'],
#  'user68': ['icici', 'american express', 'jpmorgan', 'fluor', 'tencent'],
#  'user69': ['avnet', 'intel', 'oracle', 'puma', 'paypal'],
#  'user70': ['avnet', 'crh', 'tcs', 'icbc', 'panasonic'],
#  'user71': ['tesco', 'hyundai', 'merceds', 'nestle', 'super dry'],
#  'user72': ['danone', 'amazon', 'tesco', 'aegon', 'nike'],
#  'user73': ['amr', 'microsoft', 'avnet', 'walmart', 'onex'],
#  'user74': ['intel', 'puma', 'alphabet', 'hdfc', 'infosys'],
#  'user75': ['mahindra', 'at&t', 'acs', 'puma', 'samsung'],
#  'user76': ['barclays', 'sap', 'wipro', "mcdoland's", 'nippon'],
#  'user77': ['maybank', 'comcast', 'oracle', 'volkswagen', 'super dry'],
#  'user78': ['pepsi', 'jpmorgan', 'caterpillar', 'ebay', 'airtel'],
#  'user79': ['avnet', 'abb', 'woodland', 'oracle', 'tencent'],
#  'user80': ['maybank', 'target', 'ford', 'citigroup', 'nike'],
#  'user81': ['icici', 'mastercard', 'at&t', 'walmart', 'maruhan'],
#  'user82': ['mahindra', 'qualcomn', 'staples', 'tencent', 'visa'],
#  'user83': ['alibaba', 'walmart', 'ibm', 'fedEx', 'vadafone'],
#  'user84': ['woodland', 'staples', 'loreal', 'ebay', 'salesforce'],
#  'user85': ['starbucks', 'aegon', 'tesla', 'qualcomm', 'infosys'],
#  'user86': ['vmware', 'icici', 'disney', 'alibaba', 'infosys'],
#  'user87': ['abb', 'at&t', 'accenture', 'toyota', 'salesforce'],
#  'user88': ['intel', 'metlife', 'citigroup', 'salesforce', 'vadafone'],
#  'user89': ['sap', 'staples', 'toyota', 'alibaba', 'infosys'],
#  'user90': ['icici', 'fedEx', 'hp', 'paypal', 'volkswagen'],
#  'user91': ['qualcomn', 'accenture', 'jpmorgan', 'capgemini', 'maruhan'],
#  'user92': ['amr', 'maybank', 'mastercard', 'abb', 'ford'],
#  'user93': ['maybank', 'mahindra', 'comcast', 'canon', 'toyota'],
#  'user94': ['crh', 'oracle', 'qualcomm', 'super dry', 'samsung'],
#  'user95': ['hitachi', 'facebook', 'accenture', 'jpmorgan', 'nestle'],
#  'user96': ['jpmorgan', 'caterpillar', 'lg', 'panasonic', 'salesforce'],
#  'user97': ['Adobe', 'amazon', 'target', 'starbucks', 'abb'],
#  'user98': ['renault', 'amr', 'avnet', 'at&t', 'philip'],
#  'user99': ['barclays', 'accenture', 'ibm', 'volkswagen', 'hdfc'],
#  'user100': ['ford', 'facebook', 'qualcomn', 'wipro', 'fedEx'],
#  'user101': ['abb', 'netflix', 'philip', 'fedEx', 'apple'],
#  'user102': ['target', 'starbucks', 'facebook', 'cosmo', 'super dry'],
#  'user103': ['siemens', 'wistron', 'danaher', 'airtel', 'samsung'],
#  'user104': ['amazon', 'siemens', 'ibm', 'fedEx', 'volkswagen'],
#  'user105': ['icici', 'icbc', 'johnson', 'onex', 'vadafone'],
#  'user106': ['walmart', 'staples', 'nippon', 'onex', 'nestle'],
#  'user107': ['mahindra', 'oracle', 'fluor', 'tencent', 'maruhan'],
#  'user108': ['accenture', 'ibm', 'jpmorgan', 'puma', 'salesforce'],
#  'user109': ['Adobe', 'amazon', 'loreal', 'tencent', 'vadafone'],
#  'user110': ['paypal', 'loreal', 'puma', 'panasonic', 'qualcomm'],
#  'user111': ['cisco', 'danaher', 'netflix', 'onex', 'tencent'],
#  'user112': ['facebook', 'citigroup', 'loreal', 'nippon', 'super dry'],
#  'user113': ['amazon', "mcdoland's", 'merceds', 'puma', 'alphabet'],
#  'user114': ['intel', 'woodland', 'ebay', 'tencent', 'super dry'],
#  'user115': ['Adobe', 'microsoft', 'amazon', 'cosmo', 'xiaomi'],
#  'user116': ['intel', 'aegon', 'nvidia', 'volkswagen', 'infosys'],
#  'user117': ['vmware', 'mahindra', 'philip', 'ibm', 'tencent'],
#  'user118': ['vinci', 'disney', 'tencent', 'nestle', 'qualcomm'],
#  'user119': ['hitachi', 'danaher', "mcdoland's", 'jpmorgan', 'qualcomm'],
#  'user120': ['metlife', 'danaher', 'puma', 'apple', 'alibaba'],
#  'user121': ['metlife', 'pubg', 'johnson', 'caterpillar', 'infosys'],
#  'user122': ['renault', 'danone', 'nokia', 'icbc', 'airtel'],
#  'user123': ['hitachi', 'aegon', 'staples', 'merceds', 'samsung'],
#  'user124': ['starbucks', 'woodland', 'loreal', 'tcs', 'onex'],
#  'user125': ['intel', 'vinci', 'icbc', 'puma', 'cosmo'],
#  'user126': ['abb', 'walmart', 'disney', 'onex', 'salesforce'],
#  'user127': ['tesco', 'caterpillar', 'lg', 'bmw', 'infosys'],
#  'user128': ['sap', 'walmart', 'qualcomn', 'puma', 'fedEx'],
#  'user129': ['ford', 'tesco', 'johnson', 'reliance', 'rbc'],
#  'user130': ['abb', 'oracle', 'hyundai', 'staples', 'caterpillar'],
#  'user131': ['siemens', 'johnson', 'puma', 'hdfc', 'super dry'],
#  'user132': ['renault', 'icbc', 'lg', 'panasonic', 'ebay'],
#  'user133': ['danone', 'philip', 'walmart', 'salesforce', 'airtel'],
#  'user134': ['amazon', 'mahindra', 'wipro', 'apple', 'alibaba'],
#  'user135': ['amr', 'sony', 'hyundai', 'salesforce', 'xiaomi'],
#  'user136': ['intel', 'wistron', 'visa', 'fluor', 'tencent'],
#  'user137': ['hitachi', 'netflix', 'tesla', 'johnson', 'tcs'],
#  'user138': ['amr', 'philip', 'accenture', 'tesla', 'airtel'],
#  'user139': ['target', 'alphabet', 'ebay', 'tencent', 'apple'],
#  'user140': ['microsoft', 'mahindra', 'mastercard', 'nike', 'tcs'],
#  'user141': ['Adobe', 'qualcomn', 'pubg', 'alphabet', 'onex'],
#  'user142': ['american express', 'at&t', 'hp', 'tcs', 'nestle'],
#  'user143': ['target', 'icici', 'fluor', 'coca-cola', 'ebay'],
#  'user144': ['mahindra', 'intel', 'tesco', 'puma', 'alibaba'],
#  'user145': ['vmware', 'intel', 'vinci', 'danaher', 'tencent'],
#  'user146': ['philip', 'hyundai', 'jpmorgan', 'icbc', 'cosmo'],
#  'user147': ['sap', 'aegon', 'nike', 'fluor', 'rbc'],
#  'user148': ['Adobe', 'american express', 'oracle', 'tcs', 'visa'],
#  'user149': ['nokia', 'tesco', 'johnson', 'capgemini', 'nestle'],
#  'user150': ['Adobe', 'maybank', 'vinci', 'sony', 'citigroup'],
#  'user151': ['tesco', 'merceds', 'salesforce', 'bmw', 'infosys'],
#  'user152': ['avnet', 'nokia', 'ibm', 'tcs', 'tencent'],
#  'user153': ['amr', 'pepsi', 'disney', 'reliance', 'apple'],
#  'user154': ['hitachi', 'pepsi', 'ibm', 'capgemini', 'reliance'],
#  'user155': ['qualcomn', 'loreal', 'icbc', 'cosmo', 'apple'],
#  'user156': ['vmware', 'microsoft', 'siemens', 'wistron', 'vadafone'],
#  'user157': ['microsoft', 'tesco', 'oracle', 'aegon', 'nippon'],
#  'user158': ['ford', 'oracle', 'alphabet', 'volkswagen', 'bmw'],
#  'user159': ['danone', 'crh', 'panasonic', 'tencent', 'infosys'],
#  'user160': ['target', 'vinci', 'fedEx', 'volkswagen', 'sodexo'],
#  'user161': ['vinci', 'mastercard', 'woodland', 'philip', 'ibm'],
#  'user162': ['Adobe', 'danone', 'vinci', 'oracle', 'ebay'],
#  'user163': ['comcast', 'hp', 'alphabet', 'fedEx', 'visa'],
#  'user164': ['crh', 'puma', 'alphabet', 'coca-cola', 'sodexo'],
#  'user165': ['Adobe', 'starbucks', 'johnson', 'capgemini', 'toyota'],
#  'user166': ['amr', 'vinci', 'tesco', 'hyundai', "mcdoland's"],
#  'user167': ['siemens', 'vinci', 'ford', 'super dry', 'infosys'],
#  'user168': ['amr', 'danaher', 'staples', 'johnson', 'tencent'],
#  'user169': ['addidas', 'icbc', 'loreal', 'fluor', 'super dry'],
#  'user170': ['pubg', 'addidas', 'merceds', 'panasonic', 'salesforce'],
#  'user171': ['nike', 'disney', 'hdfc', 'qualcomm', 'bmw'],
#  'user172': ['comcast', 'coca-cola', 'fedEx', 'maruhan', 'infosys'],
#  'user173': ['mahindra', 'addidas', 'merceds', 'wipro', 'xiaomi'],
#  'user174': ['metlife', 'hp', 'acs', 'cosmo', 'nippon'],
#  'user175': ['tesco', 'oracle', 'philip', 'puma', 'hdfc'],
#  'user176': ['hitachi', 'tesco', 'walmart', 'pubg', 'staples'],
#  'user177': ['starbucks', 'loreal', 'cosmo', 'caterpillar', 'hdfc'],
#  'user178': ['siemens', 'nokia', 'hp', 'hyundai', 'rbc'],
#  'user179': ['mahindra', 'sony', 'loreal', 'nvidia', 'fluor'],
#  'user180': ['mahindra', 'abb', 'danaher', 'cosmo', 'alphabet'],
#  'user181': ['mahindra', 'woodland', 'citigroup', 'xiaomi', 'airtel'],
#  'user182': ['intel', 'woodland', 'canon', 'fedEx', 'super dry'],
#  'user183': ['microsoft', 'netflix', 'philip', "mcdoland's", 'paypal'],
#  'user184': ['acs', 'tesla', 'fluor', 'caterpillar', 'alibaba'],
#  'user185': ['aegon', 'ibm', 'caterpillar', 'volkswagen', 'airtel'],
#  'user186': ['Adobe', 'crh', 'qualcomn', 'loreal', 'johnson'],
#  'user187': ['canon', 'tesco', 'acs', 'capgemini', 'toyota'],
#  'user188': ['starbucks', 'barclays', 'pepsi', 'disney', 'nippon'],
#  'user189': ['avnet', 'netflix', 'hp', 'disney', 'hdfc'],
#  'user190': ['amazon', 'danaher', 'ford', 'volkswagen', 'super dry'],
#  'user191': ['aegon', "mcdoland's", 'panasonic', 'tencent', 'super dry'],
#  'user192': ['mastercard', 'barclays', 'accenture', 'staples', 'ibm'],
#  'user193': ['cisco', 'qualcomn', 'hyundai', 'nvidia', 'toyota'],
#  'user194': ['american express', 'netflix', 'oracle', 'loreal', 'rbc'],
#  'user195': ['comcast', 'hyundai', 'addidas', 'cosmo', 'airtel'],
#  'user196': ['mahindra', 'ibm', 'addidas', 'nike', 'panasonic'],
#  'user197': ['maybank', 'hyundai', 'staples', 'coca-cola', 'tencent'],
#  'user198': ['amr', 'target', 'comcast', 'metlife', 'danaher'],
#  'user199': ['microsoft', 'mastercard', 'johnson', 'nippon', 'visa'],
#  'user200': ['walmart', 'nippon', 'nestle', 'sodexo', 'vadafone'],
#  'user201': ['sony', 'jpmorgan', 'paypal', 'maruhan', 'samsung'],
#  'user202': ['vmware', 'danone', 'woodland', 'citigroup', 'cosmo'],
#  'user203': ['target', 'facebook', 'pubg', 'acs', 'apple'],
#  'user204': ['Adobe', 'mahindra', 'ibm', 'airtel', 'bmw'],
#  'user205': ['Adobe', 'comcast', 'loreal', 'disney', 'capgemini'],
#  'user206': ['cisco', 'netflix', 'philip', 'johnson', 'visa'],
#  'user207': ['salesforce', 'cisco', 'danaher', 'fedEx', 'apple'],
#  'user208': ['microsoft', 'vinci', 'oracle', 'aegon', 'cosmo'],
#  'user209': ['target', 'starbucks', 'merceds', 'puma', 'sodexo'],
#  'user210': ['accenture', 'nike', 'nestle', 'alibaba', 'maruhan'],
#  'user211': ['vinci', 'philip', 'walmart', 'nippon', 'infosys'],
#  'user212': ['intel', 'oracle', 'philip', 'acs', 'onex'],
#  'user213': ['american express', 'at&t', 'philip', 'pubg', 'icbc'],
#  'user214': ['facebook', 'disney', 'coca-cola', 'super dry', 'maruhan'],
#  'user215': ['intel', 'sony', 'qualcomn', 'disney', 'reliance'],
#  'user216': ['avnet', 'hp', 'johnson', 'onex', 'samsung'],
#  'user217': ['american express', 'at&t', 'hp', 'capgemini', 'puma'],
#  'user218': ['avnet', 'starbucks', 'cisco', 'mastercard', 'qualcomn'],
#  'user219': ['canon', 'oracle', 'qualcomn', 'citigroup', 'philip'],
#  'user220': ['microsoft', 'amazon', 'facebook', 'qualcomn', "mcdoland's"],
#  'user221': ['woodland', 'sap', 'qualcomn', 'nike', 'maruhan'],
#  'user222': ['sap', 'acs', 'reliance', 'nippon', 'samsung'],
#  'user223': ['renault', 'woodland', 'qualcomn', 'tencent', 'apple'],
#  'user224': ['hitachi', 'aegon', 'acs', 'capgemini', 'onex'],
#  'user225': ['vinci', 'mastercard', 'acs', 'tcs', 'salesforce'],
#  'user226': ['siemens', 'hitachi', 'sap', 'nike', 'volkswagen'],
#  'user227': ['danone', 'danaher', 'sony', 'qualcomn', 'onex'],
#  'user228': ['starbucks', "mcdoland's", 'puma', 'salesforce', 'sodexo'],
#  'user229': ['icici', 'oracle', 'nippon', 'visa', 'apple'],
#  'user230': ['disney', 'reliance', 'caterpillar', 'onex', 'tencent'],
#  'user231': ['amr', 'icici', 'tesco', 'fluor', 'super dry'],
#  'user232': ['amr', 'starbucks', 'tesco', 'cosmo', 'airtel'],
#  'user233': ['tesco', 'facebook', 'johnson', "mcdoland's", 'infosys'],
#  'user234': ['renault', 'comcast', 'mastercard', 'woodland', 'puma'],
#  'user235': ['metlife', 'hitachi', 'oracle', 'apple', 'vadafone'],
#  'user236': ['maybank', 'hp', 'cosmo', 'alphabet', 'visa'],
#  'user237': ['starbucks', 'abb', 'mastercard', 'citigroup', 'nippon'],
#  'user238': ['salesforce', 'netflix', 'jpmorgan', 'fluor', 'apple'],
#  'user239': ['Adobe', 'qualcomn', 'staples', 'visa', 'sodexo'],
#  'user240': ['danone', 'comcast', "mcdoland's", 'volkswagen', 'alibaba'],
#  'user241': ['microsoft', "mcdoland's", 'hdfc', 'alibaba', 'infosys'],
#  'user242': ['woodland', 'qualcomn', 'ibm', 'tesla', 'disney'],
#  'user243': ['target', 'ford', 'rbc', 'super dry', 'samsung'],
#  'user244': ['hitachi', 'canon', 'at&t', 'citigroup', 'paypal'],
#  'user245': ["mcdoland's", 'merceds', 'fluor', 'visa', 'infosys'],
#  'user246': ['acs', 'nike', 'reliance', 'nestle', 'super dry'],
#  'user247': ['cisco', 'ford', 'at&t', 'fluor', 'nippon'],
#  'user248': ['Adobe', 'metlife', 'accenture', 'loreal', 'nike'],
#  'user249': ['renault', 'facebook', 'sap', 'walmart', 'disney'],
#  'user250': ['danone', "mcdoland's", 'salesforce', 'sodexo', 'bmw'],
#  'user251': ['comcast', 'starbucks', 'wipro', 'cosmo', 'super dry'],
#  'user252': ['renault', 'danaher', 'barclays', 'hp', 'alibaba'],
#  'user253': ['mahindra', 'siemens', 'crh', 'loreal', 'alibaba'],
#  'user254': ['amr', 'american express', 'walmart', 'staples', 'tcs'],
#  'user255': ['microsoft', 'at&t', 'philip', 'acs', 'onex'],
#  'user256': ['barclays', 'sap', 'citigroup', 'puma', 'onex'],
#  'user257': ['hp', 'tencent', 'toyota', 'xiaomi', 'airtel'],
#  'user258': ['danone', 'nokia', 'hp', 'nike', 'volkswagen'],
#  'user259': ['Adobe', 'ford', 'sony', 'accenture', 'panasonic'],
#  'user260': ['airtel', 'oracle', 'staples', 'disney', 'super dry'],
#  'user261': ['mahindra', 'walmart', 'staples', 'paypal', 'ebay'],
#  'user262': ['target', 'mastercard', 'qualcomm', 'salesforce', 'xiaomi'],
#  'user263': ['walmart', 'pubg', 'merceds', 'nike', 'puma'],
#  'user264': ['avnet', 'barclays', 'crh', 'aegon', 'super dry'],
#  'user265': ['vmware', 'comcast', 'ibm', 'cosmo', 'caterpillar'],
#  'user266': ['intel', 'mastercard', 'tcs', 'fedEx', 'apple'],
#  'user267': ['barclays', 'citigroup', 'qualcomn', 'lg', 'toyota'],
#  'user268': ['danone', 'amazon', 'panasonic', 'qualcomm', 'super dry'],
#  'user269': ['oracle', 'accenture', 'staples', 'jpmorgan', 'super dry'],
#  'user270': ['danone', 'netflix', 'tesco', 'loreal', 'apple'],
#  'user271': ['starbucks', 'tesco', 'facebook', 'pubg', 'samsung'],
#  'user272': ['amr', 'mahindra', 'cosmo', 'salesforce', 'xiaomi'],
#  'user273': ['renault', 'metlife', 'hyundai', 'staples', "mcdoland's"],
#  'user274': ['wistron', 'barclays', 'american express', 'hp', 'hyundai'],
#  'user275': ['intel', 'cisco', 'staples', 'coca-cola', 'vadafone'],
#  'user276': ['microsoft', 'target', 'siemens', 'tesco', 'reliance'],
#  'user277': ['renault', 'microsoft', 'hitachi', 'mastercard', 'super dry'],
#  'user278': ['Adobe', 'hp', 'johnson', 'capgemini', 'onex'],
#  'user279': ['cisco', 'johnson', 'tesla', 'toyota', 'maruhan'],
#  'user280': ['siemens', 'mastercard', 'canon', 'icbc', 'panasonic'],
#  'user281': ['crh', 'johnson', 'puma', 'nippon', 'airtel'],
#  'user282': ['amr', 'intel', 'metlife', 'at&t', 'wipro'],
#  'user283': ['cisco', 'accenture', "mcdoland's", 'cosmo', 'airtel'],
#  'user284': ['crh', 'aegon', 'nippon', 'xiaomi', 'vadafone'],
#  'user285': ['amr', 'wistron', 'staples', 'coca-cola', 'nippon'],
#  'user286': ['metlife', 'citigroup', 'caterpillar', 'tcs', 'alibaba'],
#  'user287': ['danone', 'cisco', 'icbc', 'cosmo', 'salesforce'],
#  'user288': ['abb', 'netflix', 'fedEx', 'rbc', 'sodexo'],
#  'user289': ['netflix', 'american express', 'loreal', 'tesla', 'maruhan'],
#  'user290': ['maybank', 'wistron', 'johnson', 'tesla', 'nestle'],
#  'user291': ['target', 'metlife', 'sony', 'nestle', 'infosys'],
#  'user292': ['cisco', 'crh', "mcdoland's", 'merceds', 'ebay'],
#  'user293': ['tesco', 'alphabet', 'coca-cola', 'volkswagen', 'vadafone'],
#  'user294': ['amazon', 'johnson', 'jpmorgan', 'disney', 'fluor'],
#  'user295': ['Adobe', 'hyundai', 'qualcomm', 'vadafone', 'bmw'],
#  'user296': ['renault', 'mastercard', 'hitachi', 'nokia', 'merceds'],
#  'user297': ['danone', 'sony', 'addidas', 'onex', 'volkswagen'],
#  'user298': ['intel', 'comcast', 'cisco', 'facebook', 'xiaomi'],
#  'user299': ['wistron', 'hyundai', 'fluor', 'coca-cola', 'volkswagen'],
#  'user300': ['renault', 'starbucks', 'cisco', 'danaher', 'salesforce'],
#  'user301': ['starbucks', 'barclays', 'icbc', 'johnson', 'infosys'],
#  'user302': ['mahindra', 'woodland', 'disney', 'caterpillar', 'salesforce'],
#  'user303': ['maybank', 'mastercard', 'wistron', 'canon', 'facebook'],
#  'user304': ['barclays', 'woodland', 'sap', 'icbc', 'salesforce'],
#  'user305': ['vmware', 'american express', 'disney', 'onex', 'infosys'],
#  'user306': ['avnet', 'amazon', 'comcast', 'onex', 'tencent'],
#  'user307': ['renault', 'amazon', 'woodland', 'netflix', 'hp'],
#  'user308': ['woodland', 'sony', 'hyundai', 'tesla', 'salesforce'],
#  'user309': ['crh', 'philip', 'johnson', 'alphabet', 'rbc'],
#  'user310': ['target', 'danaher', 'philip', 'hp', 'hdfc'],
#  'user311': ['mastercard', 'oracle', 'loreal', 'puma', 'panasonic'],
#  'user312': ['amazon', 'abb', 'american express', 'cosmo', 'airtel'],
#  'user313': ['icici', 'woodland', 'staples', 'icbc', 'maruhan'],
#  'user314': ['at&t', 'walmart', 'qualcomn', 'volkswagen', 'vadafone'],
#  'user315': ['starbucks', 'hitachi', 'wipro', 'nvidia', 'airtel'],
#  'user316': ['maybank', 'intel', 'danone', 'american express', 'tesco'],
#  'user317': ['starbucks', 'cisco', 'netflix', 'philip', 'salesforce'],
#  'user318': ['starbucks', 'accenture', 'lg', 'reliance', 'ebay'],
#  'user319': ['mahindra', 'addidas', "mcdoland's", 'salesforce', 'bmw'],
#  'user320': ['mastercard', 'hp', 'tencent', 'nestle', 'apple'],
#  'user321': ['danone', 'intel', 'metlife', 'johnson', 'nike'],
#  'user322': ['vinci', 'johnson', 'puma', 'fluor', 'ebay'],
#  'user323': ['sap', 'tesla', 'puma', 'fedEx', 'ebay'],
#  'user324': ['starbucks', 'caterpillar', 'onex', 'apple', 'bmw'],
#  'user325': ['philip', 'citigroup', 'tcs', 'rbc', 'bmw'],
#  'user326': ['mastercard', 'american express', 'philip', 'johnson', 'visa'],
#  'user327': ['wipro', 'disney', 'alphabet', 'salesforce', 'infosys'],
#  'user328': ['amazon', 'vinci', 'puma', 'lg', 'alibaba'],
#  'user329': ['crh', 'nokia', 'wipro', 'alphabet', 'toyota'],
#  'user330': ['Adobe', 'microsoft', 'tcs', 'nippon', 'nestle'],
#  'user331': ['hitachi', 'american express', 'hp', 'citigroup', 'merceds'],
#  'user332': ['johnson', 'reliance', 'paypal', 'onex', 'qualcomm'],
#  'user333': ['mastercard', 'ford', 'canon', 'nokia', 'tcs'],
#  'user334': ['starbucks', 'hitachi', 'oracle', 'staples', 'fluor'],
#  'user335': ['starbucks', 'philip', 'nvidia', 'airtel', 'maruhan'],
#  'user336': ['amr', 'mahindra', 'icbc', 'alphabet', 'fedEx'],
#  'user337': ['Adobe', 'facebook', 'lg', 'tencent', 'infosys'],
#  'user338': ['danone', 'qualcomn', 'alphabet', 'apple', 'infosys'],
#  'user339': ['starbucks', 'walmart', 'tencent', 'sodexo', 'airtel'],
#  'user340': ['mahindra', 'abb', "mcdoland's", 'fedEx', 'vadafone'],
#  'user341': ['intel', 'vinci', 'mastercard', 'aegon', 'nestle'],
#  'user342': ['woodland', 'pepsi', 'nike', 'tcs', 'xiaomi'],
#  'user343': ['amazon', 'target', 'sony', 'walmart', 'citigroup'],
#  'user344': ['starbucks', 'tesla', 'toyota', 'rbc', 'airtel'],
#  'user345': ['avnet', 'microsoft', 'tesco', 'alphabet', 'samsung'],
#  'user346': ['target', 'crh', 'citigroup', 'acs', 'hdfc'],
#  'user347': ['netflix', 'tesco', 'merceds', 'fluor', 'salesforce'],
#  'user348': ['metlife', 'hp', 'tesla', 'super dry', 'maruhan'],
#  'user349': ['maybank', 'hp', 'hyundai', 'nvidia', 'coca-cola'],
#  'user350': ['mastercard', 'aegon', 'capgemini', 'alphabet', 'hdfc'],
#  'user351': ['sony', 'oracle', 'tcs', 'visa', 'rbc'],
#  'user352': ['wistron', 'netflix', 'johnson', 'fedEx', 'hdfc'],
#  'user353': ['cisco', 'johnson', "mcdoland's", 'volkswagen', 'alibaba'],
#  'user354': ['american express', 'oracle', "mcdoland's", 'hdfc', 'alibaba'],
#  'user355': ['vmware', 'cisco', 'reliance', 'toyota', 'samsung'],
#  'user356': ['mastercard', 'aegon', 'loreal', 'lg', 'super dry'],
#  'user357': ['woodland', 'alphabet', 'nippon', 'tencent', 'toyota'],
#  'user358': ['renault', 'vinci', 'ibm', 'toyota', 'super dry'],
#  'user359': ['salesforce', 'staples', 'merceds', 'hdfc', 'rbc'],
#  'user360': ['vinci', 'ibm', 'wipro', 'nike', 'volkswagen'],
#  'user361': ['mahindra', 'cisco', 'mastercard', 'nestle', 'super dry'],
#  'user362': ['metlife', 'citigroup', 'caterpillar', 'onex', 'xiaomi'],
#  'user363': ['microsoft', 'danone', 'starbucks', 'cisco', 'bmw'],
#  'user364': ['wistron', 'walmart', 'alphabet', 'bmw', 'samsung'],
#  'user365': ['hitachi', 'tesco', 'ibm', 'coca-cola', 'bmw'],
#  'user366': ['target', 'merceds', 'fluor', 'toyota', 'airtel'],
#  'user367': ['avnet', 'wipro', 'tesla', 'fedEx', 'infosys'],
#  'user368': ['abb', 'woodland', 'hyundai', 'salesforce', 'alibaba'],
#  'user369': ['mahindra', 'icici', 'barclays', 'sony', 'hdfc'],
#  'user370': ['siemens', 'metlife', 'canon', "mcdoland's", 'ebay'],
#  'user371': ['qualcomn', 'loreal', 'icbc', 'reliance', 'coca-cola'],
#  'user372': ['mastercard', 'danaher', 'facebook', 'pubg', 'tencent'],
#  'user373': ['hitachi', 'pepsi', 'wipro', 'merceds', 'tcs'],
#  'user374': ['renault', 'woodland', 'sap', 'nike', 'panasonic'],
#  'user375': ['mahindra', 'oracle', 'aegon', 'nvidia', 'caterpillar'],
#  'user376': ['citigroup', 'accenture', 'hyundai', 'tesla', 'maruhan'],
#  'user377': ['mastercard', 'johnson', 'infosys', 'bmw', 'samsung'],
#  'user378': ['cisco', 'netflix', 'ebay', 'nestle', 'super dry'],
#  'user379': ['aegon', 'nvidia', 'lg', 'tcs', 'apple'],
#  'user380': ['mahindra', 'crh', 'wipro', 'panasonic', 'salesforce'],
#  'user381': ['johnson', 'merceds', 'fluor', 'hdfc', 'xiaomi'],
#  'user382': ['target', 'american express', 'pubg', 'acs', 'fedEx'],
#  'user383': ['american express', 'cosmo', 'qualcomm', 'xiaomi', 'maruhan'],
#  'user384': ['canon', 'fluor', 'panasonic', 'qualcomm', 'apple'],
#  'user385': ['vmware', 'danone', 'amazon', 'tesco', 'merceds'],
#  'user386': ['comcast', 'addidas', 'merceds', 'nestle', 'salesforce'],
#  'user387': ['sony', 'disney', 'puma', 'fedEx', 'ebay'],
#  'user388': ['amazon', 'metlife', 'philip', 'disney', 'rbc'],
#  'user389': ['Adobe', 'abb', 'barclays', 'nokia', 'panasonic'],
#  'user390': ['accenture', 'johnson', 'toyota', 'sodexo', 'maruhan'],
#  'user391': ['microsoft', 'woodland', 'hyundai', 'johnson', 'salesforce'],
#  'user392': ['merceds', 'jpmorgan', 'apple', 'super dry', 'samsung'],
#  'user393': ['mastercard', 'crh', 'oracle', 'super dry', 'alibaba'],
#  'user394': ['woodland', 'pubg', 'nike', 'nestle', 'alibaba'],
#  'user395': ['target', 'siemens', 'woodland', 'at&t', 'visa'],
#  'user396': ['maybank', 'siemens', 'johnson', 'puma', 'paypal'],
#  'user397': ['amr', 'barclays', 'walmart', "mcdoland's", 'fluor'],
#  'user398': ['vmware', 'danone', 'intel', 'comcast', 'johnson'],
#  'user399': ['vinci', 'fedEx', 'caterpillar', 'panasonic', 'toyota'],
#  'user400': ['woodland', 'fedEx', 'onex', 'rbc', 'airtel'],
#  'user401': ['mahindra', 'netflix', 'ibm', 'merceds', 'nike'],
#  'user402': ['starbucks', 'facebook', 'capgemini', 'paypal', 'volkswagen'],
#  'user403': ['starbucks', 'philip', 'pubg', 'staples', 'bmw'],
#  'user404': ['crh', 'oracle', 'volkswagen', 'xiaomi', 'bmw'],
#  'user405': ['Adobe', 'danone', 'amazon', 'netflix', 'loreal'],
#  'user406': ['crh', 'walmart', 'visa', 'toyota', 'bmw'],
#  'user407': ['Adobe', 'comcast', 'disney', 'nestle', 'sodexo'],
#  'user408': ['metlife', 'ford', 'oracle', 'hp', 'icbc'],
#  'user409': ['hitachi', 'facebook', 'oracle', 'fluor', 'ebay'],
#  'user410': ['microsoft', 'mahindra', 'intel', 'icbc', 'fedEx'],
#  'user411': ['metlife', 'oracle', 'addidas', 'nvidia', 'sodexo'],
#  'user412': ['mahindra', 'crh', 'staples', 'nippon', 'airtel'],
#  'user413': ['comcast', 'johnson', "mcdoland's", 'nvidia', 'visa'],
#  'user414': ['walmart', "mcdoland's", 'tcs', 'super dry', 'samsung'],
#  'user415': ['philip', 'merceds', 'volkswagen', 'rbc', 'samsung'],
#  'user416': ['intel', 'woodland', 'tesla', 'nestle', 'qualcomm'],
#  'user417': ['maybank', 'mahindra', 'danone', 'toyota', 'vadafone'],
#  'user418': ['danaher', 'nokia', 'paypal', 'airtel', 'nippon'],
#  'user419': ['avnet', 'woodland', 'nokia', 'pubg', 'ebay'],
#  'user420': ['tesco', 'jpmorgan', 'paypal', 'volkswagen', 'ebay'],
#  'user421': ['danone', 'crh', 'citigroup', 'coca-cola', 'fedEx'],
#  'user422': ['metlife', 'wistron', 'ibm', 'tcs', 'paypal'],
#  'user423': ['starbucks', 'ford', 'barclays', 'sap', 'super dry'],
#  'user424': ['vinci', 'cisco', 'johnson', 'ebay', 'infosys'],
#  'user425': ['vmware', 'tesco', 'disney', 'capgemini', 'tcs'],
#  'user426': ['abb', 'woodland', 'hp', 'fedEx', 'toyota'],
#  'user427': ['mastercard', 'pepsi', 'hp', 'staples', 'vadafone'],
#  'user428': ['Adobe', 'netflix', 'alphabet', 'bmw', 'infosys'],
#  'user429': ['comcast', 'ford', 'staples', 'merceds', 'reliance'],
#  'user430': ['avnet', 'nike', 'nvidia', 'airtel', 'samsung'],
#  'user431': ['Adobe', 'amr', 'aegon', 'wipro', 'hdfc'],
#  'user432': ['Adobe', 'vinci', 'at&t', 'hyundai', 'cosmo'],
#  'user433': ['accenture', 'pubg', 'staples', 'nike', 'volkswagen'],
#  'user434': ['intel', 'abb', 'woodland', 'oracle', 'tencent'],
#  'user435': ['qualcomn', 'loreal', 'merceds', 'ebay', 'nestle'],
#  'user436': ['starbucks', 'abb', 'oracle', 'johnson', 'caterpillar'],
#  'user437': ['hp', 'ibm', 'johnson', 'nike', 'volkswagen'],
#  'user438': ['Adobe', 'starbucks', 'danaher', 'puma', 'cosmo'],
#  'user439': ['vmware', 'accenture', "mcdoland's", 'volkswagen', 'apple'],
#  'user440': ['amazon', 'oracle', 'pubg', 'tesla', 'puma'],
#  'user441': ['nokia', 'addidas', 'capgemini', 'tencent', 'alibaba'],
#  'user442': ['ford', 'crh', 'accenture', 'staples', 'ibm'],
#  'user443': ['maybank', 'amazon', 'barclays', 'fluor', 'onex'],
#  'user444': ['hitachi', "mcdoland's", 'nike', 'cosmo', 'maruhan'],
#  'user445': ['starbucks', 'tesco', 'icbc', 'johnson', 'lg'],
#  'user446': ['mahindra', 'hitachi', 'hyundai', 'coca-cola', 'bmw'],
#  'user447': ['danone', 'microsoft', 'citigroup', 'paypal', 'maruhan'],
#  'user448': ['Adobe', 'netflix', 'alphabet', 'nippon', 'airtel'],
#  'user449': ['canon', 'netflix', 'walmart', 'onex', 'infosys'],
#  'user450': ['mahindra', 'barclays', 'cosmo', 'nestle', 'super dry'],
#  'user451': ['renault', 'hp', 'alphabet', 'tencent', 'vadafone'],
#  'user452': ['hyundai', 'wipro', 'nippon', 'visa', 'vadafone'],
#  'user453': ['vmware', 'comcast', 'danaher', 'tesco', 'panasonic'],
#  'user454': ['mahindra', 'vinci', 'woodland', 'tesla', 'salesforce'],
#  'user455': ['tesco', 'sap', 'merceds', 'capgemini', 'infosys'],
#  'user456': ['Adobe', 'alibaba', 'acs', 'wipro', 'vadafone'],
#  'user457': ['icici', 'oracle', 'merceds', 'johnson', 'rbc'],
#  'user458': ['intel', 'abb', 'cisco', 'cosmo', 'tcs'],
#  'user459': ['icici', 'tesco', 'philip', 'onex', 'rbc'],
#  'user460': ['vmware', 'target', 'facebook', 'fluor', 'maruhan'],
#  'user461': ['vinci', 'addidas', 'icbc', 'coca-cola', 'nippon'],
#  'user462': ['amazon', 'crh', 'philip', 'accenture', 'alphabet'],
#  'user463': ['maybank', 'metlife', 'cisco', 'qualcomm', 'salesforce'],
#  'user464': ['cisco', 'sap', 'accenture', 'hyundai', 'alphabet'],
#  'user465': ['target', 'tesco', 'ibm', 'fedEx', 'airtel'],
#  'user466': ['avnet', 'staples', 'tencent', 'hdfc', 'sodexo'],
#  'user467': ['barclays', 'crh', 'tesco', 'qualcomn', 'disney'],
#  'user468': ['danaher', 'crh', 'qualcomn', 'walmart', 'samsung'],
#  'user469': ['microsoft', 'salesforce', 'loreal', 'fluor', 'apple'],
#  'user470': ['qualcomn', 'loreal', 'tesla', 'icbc', 'lg'],
#  'user471': ['mahindra', 'ibm', 'disney', 'coca-cola', 'salesforce'],
#  'user472': ['renault', 'maybank', 'pepsi', 'jpmorgan', 'airtel'],
#  'user473': ['hitachi', 'cisco', 'hyundai', 'caterpillar', 'ebay'],
#  'user474': ['Adobe', 'barclays', 'pubg', 'cosmo', 'reliance'],
#  'user475': ['metlife', 'netflix', 'wipro', 'johnson', 'fedEx'],
#  'user476': ['target', 'american express', 'wipro', 'onex', 'visa'],
#  'user477': ['ford', 'cosmo', 'ebay', 'nestle', 'toyota'],
#  'user478': ['microsoft', 'nokia', 'johnson', 'tcs', 'visa'],
#  'user479': ['mahindra', 'cisco', 'citigroup', 'icbc', 'fedEx'],
#  'user480': ['hitachi', 'woodland', 'staples', 'cosmo', 'nestle'],
#  'user481': ['abb', 'qualcomn', 'tesla', 'fedEx', 'sodexo'],
#  'user482': ['woodland', 'pepsi', 'at&t', 'nippon', 'hdfc'],
#  'user483': ['comcast', 'netflix', 'nike', 'caterpillar', 'nippon'],
#  'user484': ['danone', 'amazon', 'acs', 'coca-cola', 'visa'],
#  'user485': ['philip', 'pubg', 'cosmo', 'fedEx', 'hdfc'],
#  'user486': ['danaher', 'crh', 'sap', 'citigroup', 'puma'],
#  'user487': ['intel', 'woodland', 'nokia', 'staples', 'tencent'],
#  'user488': ['woodland', 'qualcomn', 'aegon', 'acs', 'capgemini'],
#  'user489': ['pubg', 'jpmorgan', 'tesla', 'coca-cola', 'bmw'],
#  'user490': ['mahindra', 'amazon', 'ford', 'facebook', 'tcs'],
#  'user491': ['staples', 'addidas', 'infosys', 'ebay', 'samsung'],
#  'user492': ['danone', 'at&t', 'icbc', 'vadafone', 'airtel'],
#  'user493': ['danone', 'qualcomn', 'accenture', 'fedEx', 'nippon'],
#  'user494': ['wistron', 'staples', 'addidas', 'nvidia', 'sodexo'],
#  'user495': ['mahindra', 'intel', 'hitachi', 'hdfc', 'super dry'],
#  'user496': ['amr', 'cisco', 'staples', 'onex', 'samsung'],
#  'user497': ['mahindra', 'cisco', 'woodland', 'accenture', 'rbc'],
#  'user498': ['cisco', 'hp', 'qualcomn', "mcdoland's", 'puma'],
#  'user499': ['Adobe', 'merceds', 'johnson', 'capgemini', 'volkswagen'],
#  'user500': ['icici', 'aegon', 'super dry', 'caterpillar', 'alibaba'],
#  'user501': ['comcast', 'philip', 'staples', 'wipro', 'merceds'],
#  'user502': ['danone', 'sap', 'aegon', 'qualcomm', 'rbc'],
#  'user503': ['sap', 'hp', 'pubg', 'paypal', 'infosys'],
#  'user504': ['woodland', 'pubg', 'hyundai', 'merceds', 'qualcomm'],
#  'user505': ['abb', 'netflix', 'johnson', 'alphabet', 'xiaomi'],
#  'user506': ['Adobe', 'hitachi', 'sony', 'hdfc', 'vadafone'],
#  'user507': ['siemens', 'facebook', 'sap', 'johnson', 'paypal'],
#  'user508': ['netflix', 'aegon', 'caterpillar', 'visa', 'maruhan'],
#  'user509': ['metlife', 'disney', 'panasonic', 'qualcomm', 'airtel'],
#  'user510': ['siemens', 'abb', 'aegon', 'wipro', 'coca-cola'],
#  'user511': ['Adobe', 'staples', 'icbc', 'capgemini', 'coca-cola'],
#  'user512': ['danone', 'crh', "mcdoland's", 'qualcomm', 'xiaomi'],
#  'user513': ['qualcomn', 'hyundai', 'merceds', 'toyota', 'rbc'],
#  'user514': ['metlife', 'woodland', 'nike', 'qualcomm', 'sodexo'],
#  'user515': ['renault', 'danaher', 'canon', 'coca-cola', 'sodexo'],
#  'user516': ['intel', 'hitachi', 'crh', 'coca-cola', 'airtel'],
#  'user517': ['ford', 'oracle', 'nippon', 'super dry', 'bmw'],
#  'user518': ['qualcomn', 'ibm', 'nike', 'hdfc', 'xiaomi'],
#  'user519': ['amr', 'amazon', 'tesco', 'ebay', 'hdfc'],
#  'user520': ['cisco', 'pubg', 'tesla', 'onex', 'apple'],
#  'user521': ['amr', 'nokia', 'fluor', 'panasonic', 'visa'],
#  'user522': ['siemens', 'accenture', 'cosmo', 'alphabet', 'tencent'],
#  'user523': ['danone', 'cisco', 'netflix', 'walmart', 'puma'],
#  'user524': ['sap', 'hp', 'jpmorgan', 'paypal', 'bmw'],
#  'user525': ['vmware', 'target', 'comcast', 'cisco', 'nestle'],
#  'user526': ['vmware', 'target', 'alphabet', 'super dry', 'infosys'],
#  'user527': ['amr', 'merceds', 'reliance', 'alphabet', 'nippon'],
#  'user528': ['wistron', 'netflix', 'capgemini', 'caterpillar', 'airtel'],
#  'user529': ['cisco', 'tesco', 'johnson', 'alphabet', 'qualcomm'],
#  'user530': ['intel', 'cisco', 'nvidia', 'onex', 'sodexo'],
#  'user531': ['microsoft', 'walmart', 'jpmorgan', 'johnson', 'capgemini'],
#  'user532': ['crh', 'addidas', "mcdoland's", 'nike', 'sodexo'],
#  'user533': ['mastercard', 'tesla', 'capgemini', 'reliance', 'nippon'],
#  'user534': ['sony', 'qualcomn', 'pubg', 'ibm', 'disney'],
#  'user535': ['vmware', 'woodland', 'loreal', 'disney', 'volkswagen'],
#  'user536': ['crh', 'philip', 'citigroup', 'tencent', 'infosys'],
#  'user537': ['sap', 'accenture', 'nike', 'reliance', 'fedEx'],
#  'user538': ['nokia', 'oracle', 'merceds', 'jpmorgan', 'super dry'],
#  'user539': ['danaher', 'tesco', 'philip', 'citigroup', 'johnson'],
#  'user540': ['rbc', 'loreal', 'vadafone', 'salesforce', 'super dry'],
#  'user541': ['ibm', 'jpmorgan', 'fluor', 'vadafone', 'airtel'],
#  'user542': ['icici', 'tesco', 'oracle', 'qualcomn', 'hdfc'],
#  'user543': ['target', 'woodland', 'pubg', 'ibm', 'tcs'],
#  'user544': ['staples', 'loreal', 'puma', 'nippon', 'panasonic'],
#  'user545': ['target', 'accenture', 'jpmorgan', 'volkswagen', 'rbc'],
#  'user546': ['ford', 'philip', 'tesla', 'nike', 'tcs'],
#  'user547': ['icici', 'nokia', 'citigroup', 'merceds', 'vadafone'],
#  'user548': ['cisco', 'hyundai', 'disney', 'ebay', 'samsung'],
#  'user549': ['renault', 'ford', 'danaher', 'facebook', 'sodexo'],
#  'user550': ['facebook', 'citigroup', 'acs', 'tencent', 'airtel'],
#  'user551': ['comcast', 'tesco', 'addidas', 'rbc', 'sodexo'],
#  'user552': ['target', 'american express', 'ibm', 'tencent', 'toyota'],
#  'user553': ['mahindra', 'metlife', 'lg', 'paypal', 'onex'],
#  'user554': ['amazon', 'mastercard', 'sony', 'disney', 'nike'],
#  'user555': ['icici', 'metlife', 'ibm', 'reliance', 'tencent'],
#  'user556': ['crh', 'hyundai', 'reliance', 'toyota', 'vadafone'],
#  'user557': ['danone', 'american express', 'aegon', 'acs', 'merceds'],
#  'user558': ['icici', 'sap', 'disney', 'puma', 'infosys'],
#  'user559': ['netflix', 'nike', 'tcs', 'nestle', 'apple'],
#  'user560': ['Adobe', 'at&t', 'nike', 'reliance', 'airtel'],
#  'user561': ['canon', 'nokia', 'hyundai', 'johnson', 'super dry'],
#  'user562': ['danone', 'ford', 'merceds', 'tencent', 'hdfc'],
#  'user563': ['canon', 'pubg', 'loreal', 'johnson', 'maruhan'],
#  'user564': ['crh', 'wipro', 'caterpillar', 'salesforce', 'infosys'],
#  'user565': ['Adobe', 'pepsi', 'aegon', 'nippon', 'bmw'],
#  'user566': ['icici', 'loreal', 'hdfc', 'rbc', 'maruhan'],
#  'user567': ['hitachi', 'crh', 'tencent', 'hdfc', 'infosys'],
#  'user568': ['starbucks', 'woodland', 'accenture', 'capgemini', 'onex'],
#  'user569': ['comcast', 'hp', 'nippon', 'tencent', 'infosys'],
#  'user570': ['hitachi', 'netflix', 'philip', 'qualcomm', 'salesforce'],
#  'user571': ['mastercard', 'icbc', 'paypal', 'vadafone', 'nippon'],
#  'user572': ['amazon', 'qualcomn', 'aegon', 'icbc', 'capgemini'],
#  'user573': ['amr', 'qualcomn', 'tesla', 'merceds', 'sodexo'],
#  'user574': ['loreal', 'wipro', 'nvidia', 'onex', 'airtel'],
#  'user575': ['avnet', 'mastercard', 'sony', 'puma', 'visa'],
#  'user576': ['Adobe', 'vmware', 'alphabet', 'fedEx', 'tencent'],
#  'user577': ['Adobe', 'avnet', 'siemens', 'johnson', 'xiaomi'],
#  'user578': ['amazon', 'tesco', 'disney', 'paypal', 'visa'],
#  'user579': ['cisco', 'addidas', 'fluor', 'reliance', 'infosys'],
#  'user580': ['sap', 'addidas', 'merceds', 'nvidia', 'nestle'],
#  'user581': ['mahindra', 'comcast', 'abb', 'loreal', 'johnson'],
#  'user582': ['renault', 'cisco', 'woodland', 'american express', "mcdoland's"],
#  'user583': ['vmware', 'avnet', 'cosmo', 'tencent', 'vadafone'],
#  'user584': ['intel', 'crh', 'ibm', 'lg', 'ebay'],
#  'user585': ['facebook', 'citigroup', 'salesforce', 'bmw', 'samsung'],
#  'user586': ['Adobe', 'facebook', 'pubg', 'caterpillar', 'vadafone'],
#  'user587': ['hitachi', 'accenture', 'disney', 'capgemini', 'tencent'],
#  'user588': ['mahindra', 'qualcomn', 'fluor', 'paypal', 'toyota'],
#  'user589': ['mahindra', 'amazon', 'netflix', 'acs', 'johnson'],
#  'user590': ['woodland', 'accenture', 'staples', 'coca-cola', 'onex'],
#  'user591': ['tcs', 'pubg', 'ibm', 'nippon', 'visa'],
#  'user592': ['vmware', 'metlife', 'netflix', 'walmart', 'jpmorgan'],
#  'user593': ['avnet', 'intel', 'tencent', 'tcs', 'hdfc'],
#  'user594': ['target', 'siemens', 'hitachi', 'pubg', 'staples'],
#  'user595': ['canon', 'nokia', 'loreal', "mcdoland's", 'tcs'],
#  'user596': ['renault', 'target', 'metlife', 'oracle', 'acs'],
#  'user597': ['avnet', 'mastercard', 'wistron', 'sap', 'capgemini'],
#  'user598': ['renault', 'abb', 'tesla', 'fluor', 'vadafone'],
#  'user599': ['loreal', 'lg', 'paypal', 'nestle', 'maruhan'],
#  'user600': ['citigroup', 'staples', 'acs', 'icbc', 'sodexo'],
#  'user601': ['renault', 'accenture', 'hyundai', 'merceds', 'volkswagen'],
#  'user602': ['microsoft', 'mahindra', 'walmart', 'citigroup', 'super dry'],
#  'user603': ['intel', 'comcast', 'jpmorgan', 'reliance', 'rbc'],
#  'user604': ['woodland', 'cosmo', 'lg', 'nippon', 'sodexo'],
#  'user605': ['abb', 'woodland', 'tesco', 'wipro', 'tcs'],
#  'user606': ['tesco', 'wipro', 'merceds', 'jpmorgan', 'bmw'],
#  'user607': ['woodland', 'netflix', 'acs', 'jpmorgan', 'fedEx'],
#  'user608': ['danone', 'loreal', 'johnson', 'reliance', 'super dry'],
#  'user609': ['vmware', 'starbucks', 'visa', 'hdfc', 'apple'],
#  'user610': ['danone', 'wistron', 'woodland', 'at&t', 'qualcomm'],
#  'user611': ['siemens', 'vinci', 'wistron', 'reliance', 'tencent'],
#  'user612': ['pepsi', 'netflix', 'accenture', 'jpmorgan', 'visa'],
#  'user613': ['amazon', 'ibm', 'fluor', 'reliance', 'xiaomi'],
#  'user614': ['avnet', 'comcast', 'vadafone', 'airtel', 'bmw'],
#  'user615': ['danaher', 'tesco', 'capgemini', 'puma', 'visa'],
#  'user616': ['vmware', 'target', 'cisco', 'icbc', 'tencent'],
#  'user617': ['maybank', 'mahindra', 'hitachi', 'danaher', 'nike'],
#  'user618': ['hyundai', 'nike', 'disney', 'puma', 'nestle'],
#  'user619': ['comcast', 'sap', 'qualcomn', 'tesla', 'panasonic'],
#  'user620': ['target', 'siemens', 'puma', 'lg', 'qualcomm'],
#  'user621': ['hitachi', 'acs', 'icbc', 'caterpillar', 'lg'],
#  'user622': ['Adobe', 'mahindra', 'tesla', 'nvidia', 'tencent'],
#  'user623': ['maybank', 'mastercard', 'abb', 'netflix', 'toyota'],
#  'user624': ['mahindra', 'target', 'netflix', 'facebook', 'pubg'],
#  'user625': ['target', 'starbucks', 'loreal', 'johnson', 'super dry'],
#  'user626': ['starbucks', 'philip', 'volkswagen', 'rbc', 'sodexo'],
#  'user627': ['crh', 'facebook', 'accenture', 'staples', 'acs'],
#  'user628': ['woodland', 'philip', 'walmart', 'merceds', 'bmw'],
#  'user629': ['siemens', 'qualcomn', 'jpmorgan', "mcdoland's", 'fedEx'],
#  'user630': ['metlife', 'wistron', 'at&t', 'johnson', 'capgemini'],
#  'user631': ['Adobe', 'woodland', 'merceds', 'cosmo', 'toyota'],
#  'user632': ['cisco', 'johnson', 'nvidia', 'panasonic', 'alibaba'],
#  'user633': ['woodland', 'puma', 'qualcomm', 'maruhan', 'samsung'],
#  'user634': ['woodland', 'sony', 'nokia', 'crh', 'oracle'],
#  'user635': ['woodland', 'aegon', 'addidas', 'merceds', 'airtel'],
#  'user636': ['icici', 'jpmorgan', 'capgemini', 'onex', 'alibaba'],
#  'user637': ['danaher', 'walmart', 'accenture', 'staples', 'tesla'],
#  'user638': ['intel', 'amazon', 'starbucks', 'aegon', 'nippon'],
#  'user639': ['target', 'icici', 'vinci', 'nike', 'coca-cola'],
#  'user640': ['cisco', 'netflix', 'johnson', 'reliance', 'nestle'],
#  'user641': ['renault', 'target', 'hitachi', 'aegon', 'ibm'],
#  'user642': ['pubg', 'loreal', 'icbc', 'nike', 'jpmorgan'],
#  'user643': ['microsoft', 'cisco', 'facebook', 'hp', 'nvidia'],
#  'user644': ['comcast', 'tesco', 'jpmorgan', 'paypal', 'vadafone'],
#  'user645': ['metlife', 'american express', 'pubg', 'jpmorgan', 'airtel'],
#  'user646': ['metlife', 'jpmorgan', 'puma', 'onex', 'tencent'],
#  'user647': ['amr', 'mastercard', 'wipro', 'puma', 'tencent'],
#  'user648': ['Adobe', 'siemens', 'mastercard', 'philip', 'cosmo'],
#  'user649': ['metlife', 'canon', 'airtel', 'tencent', 'super dry'],
#  'user650': ['mahindra', 'metlife', 'wipro', 'volkswagen', 'nestle'],
#  'user651': ['crh', 'netflix', 'hyundai', 'capgemini', 'cosmo'],
#  'user652': ['Adobe', 'maybank', 'intel', 'target', 'metlife'],
#  'user653': ['danone', 'target', 'mastercard', "mcdoland's", 'tcs'],
#  'user654': ['mahindra', 'amazon', 'puma', 'airtel', 'infosys'],
#  'user655': ['metlife', 'tesco', 'cosmo', 'lg', 'vadafone'],
#  'user656': ['icici', 'hyundai', "mcdoland's", 'tcs', 'airtel'],
#  'user657': ['microsoft', 'hp', 'acs', 'coca-cola', 'tencent'],
#  'user658': ['danone', 'avnet', 'at&t', 'ibm', 'infosys'],
#  'user659': ['intel', "mcdoland's", 'nvidia', 'panasonic', 'volkswagen'],
#  'user660': ['danaher', 'disney', 'tcs', 'alibaba', 'maruhan'],
#  'user661': ['icbc', 'johnson', 'tcs', 'alibaba', 'bmw'],
#  'user662': ['starbucks', 'ford', 'barclays', 'johnson', 'visa'],
#  'user663': ['renault', 'amazon', 'icici', 'pepsi', "mcdoland's"],
#  'user664': ['maybank', 'cisco', 'nokia', 'icbc', 'sodexo'],
#  'user665': ['danaher', 'pepsi', 'hyundai', 'nike', 'nvidia'],
#  'user666': ['mahindra', 'icici', 'starbucks', 'johnson', 'nike'],
#  'user667': ['woodland', 'nokia', 'tesco', 'staples', 'cosmo'],
#  'user668': ['danone', 'crh', 'tesco', 'alphabet', 'paypal'],
#  'user669': ['amazon', 'cisco', 'acs', 'merceds', 'coca-cola'],
#  'user670': ['amazon', 'abb', 'addidas', 'icbc', 'xiaomi'],
#  'user671': ['amazon', 'comcast', 'accenture', 'johnson', 'volkswagen'],
#  'user672': ['renault', 'avnet', 'philip', 'merceds', 'fedEx'],
#  'user673': ['cisco', 'barclays', 'citigroup', 'johnson', 'fedEx'],
#  'user674': ['microsoft', 'ford', 'citigroup', 'hyundai', 'ibm'],
#  'user675': ['nokia', 'nvidia', 'capgemini', 'ebay', 'qualcomm'],
#  'user676': ['target', 'danaher', 'johnson', 'nike', 'reliance'],
#  'user677': ['starbucks', 'mastercard', 'hdfc', 'ebay', 'nestle'],
#  'user678': ['maybank', 'cisco', 'capgemini', 'lg', 'nestle'],
#  'user679': ['accenture', 'alphabet', 'nippon', 'rbc', 'airtel'],
#  'user680': ['target', 'hyundai', 'nike', 'nvidia', 'nippon'],
#  'user681': ['target', 'disney', 'cosmo', 'caterpillar', 'super dry'],
#  'user682': ['metlife', 'pubg', 'volkswagen', 'ebay', 'infosys'],
#  'user683': ['Adobe', 'abb', 'philip', 'citigroup', 'reliance'],
#  'user684': ['abb', 'danaher', 'tesco', 'jpmorgan', 'capgemini'],
#  'user685': ['amr', 'metlife', 'nokia', 'accenture', 'jpmorgan'],
#  'user686': ['danaher', 'woodland', 'citigroup', 'cosmo', 'nippon'],
#  'user687': ['Adobe', 'cosmo', 'salesforce', 'airtel', 'infosys'],
#  'user688': ['danone', 'intel', 'accenture', 'nestle', 'salesforce'],
#  'user689': ['avnet', 'intel', 'philip', 'merceds', 'volkswagen'],
#  'user690': ['danone', 'barclays', 'canon', 'johnson', 'volkswagen'],
#  'user691': ['mastercard', 'tcs', 'onex', 'nestle', 'salesforce'],
#  'user692': ['amr', 'siemens', 'mastercard', 'walmart', 'toyota'],
#  'user693': ['danone', 'mahindra', 'metlife', 'aegon', 'visa'],
#  'user694': ['wistron', 'staples', 'loreal', 'jpmorgan', 'vadafone'],
#  'user695': ['avnet', 'maybank', 'metlife', 'onex', 'alibaba'],
#  'user696': ['amr', 'danone', 'siemens', 'netflix', 'tencent'],
#  'user697': ['cisco', 'aegon', 'puma', 'visa', 'xiaomi'],
#  'user698': ['vinci', "mcdoland's", 'reliance', 'coca-cola', 'nestle'],
#  'user699': ['mastercard', 'sony', 'reliance', 'coca-cola', 'paypal'],
#  'user700': ['target', 'crh', 'nvidia', 'coca-cola', 'visa'],
#  'user701': ['starbucks', 'nike', 'cosmo', 'fedEx', 'salesforce'],
#  'user702': ['avnet', 'wistron', 'oracle', 'pubg', 'icbc'],
#  'user703': ['mahindra', 'philip', 'tesla', "mcdoland's", 'paypal'],
#  'user704': ['hp', 'hyundai', 'loreal', 'tesla', 'hdfc'],
#  'user705': ['starbucks', 'philip', 'staples', 'ibm', 'tencent'],
#  'user706': ['amazon', 'metlife', 'woodland', 'sony', 'pubg'],
#  'user707': ['icici', 'american express', 'at&t', 'sap', 'philip'],
#  'user708': ['comcast', 'abb', 'woodland', 'wipro', 'tencent'],
#  'user709': ['metlife', 'danaher', 'staples', 'acs', 'hdfc'],
#  'user710': ['intel', 'ford', 'panasonic', 'apple', 'infosys'],
#  'user711': ['cisco', 'tesco', 'jpmorgan', 'nike', 'rbc'],
#  'user712': ['maybank', 'microsoft', 'mastercard', 'johnson', 'paypal'],
#  'user713': ['sony', 'tesco', 'sap', 'ibm', 'rbc'],
#  'user714': ['comcast', 'crh', 'pubg', 'tcs', 'salesforce'],
#  'user715': ['amr', 'avnet', 'metlife', 'sony', 'crh'],
#  'user716': ['comcast', 'starbucks', 'oracle', 'onex', 'visa'],
#  'user717': ['siemens', 'pepsi', 'accenture', 'hdfc', 'airtel'],
#  'user718': ['wistron', 'cisco', 'sony', 'jpmorgan', 'samsung'],
#  'user719': ['starbucks', 'metlife', 'caterpillar', 'nippon', 'vadafone'],
#  'user720': ['microsoft', 'hp', 'icbc', 'puma', 'fluor'],
#  'user721': ['amazon', 'philip', 'oracle', 'staples', 'super dry'],
#  'user722': ['vmware', 'amazon', 'mastercard', 'sap', 'merceds'],
#  'user723': ['metlife', 'barclays', 'wipro', 'panasonic', 'nippon'],
#  'user724': ['target', 'cisco', 'ford', 'philip', 'ebay'],
#  'user725': ['Adobe', 'barclays', 'at&t', 'staples', 'caterpillar'],
#  'user726': ['ibm', 'tesla', 'nike', 'xiaomi', 'alibaba'],
#  'user727': ['renault', 'abb', 'wipro', 'tcs', 'alibaba'],
#  'user728': ['Adobe', 'comcast', 'lg', 'coca-cola', 'sodexo'],
#  'user729': ['target', 'citigroup', 'loreal', 'nvidia', 'tencent'],
#  'user730': ['amr', 'starbucks', 'wipro', 'coca-cola', 'nestle'],
#  'user731': ['amazon', 'cisco', 'jpmorgan', 'reliance', 'onex'],
#  'user732': ['mahindra', 'addidas', 'lg', 'nippon', 'bmw'],
#  'user733': ['avnet', 'mastercard', 'hp', 'tesla', 'qualcomm'],
#  'user734': ['avnet', 'vinci', 'netflix', 'fluor', 'bmw'],
#  'user735': ['amr', 'hp', 'pubg', 'puma', 'alphabet'],
#  'user736': ['abb', 'facebook', 'capgemini', 'cosmo', 'infosys'],
# ...
#  'user754': ['mastercard', 'danaher', 'crh', 'qualcomn', 'airtel'],
#  'user755': ['comcast', 'citigroup', 'tesla', 'rbc', 'xiaomi'],
#  'user756': ['amazon', 'netflix', 'tencent', 'lg', 'visa'],
#  'user757': ['at&t', 'oracle', 'facebook', 'staples', 'bmw'],
#  'user758': ['nokia', 'pubg', 'addidas', 'johnson', 'lg'],
#  'user759': ['mahindra', 'johnson', 'cosmo', 'super dry', 'bmw'],
#  'user760': ['starbucks',
#   'mastercard',
#   'cisco',
#   'american express',
#   "mcdoland's"],
#  'user761': ['intel', 'cisco', 'cosmo', 'super dry', 'infosys'],
#  'user762': ['danone', 'metlife', 'capgemini', 'cosmo', 'paypal'],
#  'user763': ['amr', 'sony', 'addidas', 'disney', 'xiaomi'],
#  'user764': ['avnet', 'facebook', 'hp', 'nike', 'caterpillar'],
#  'user765': ['amr', 'netflix', 'aegon', 'onex', 'airtel'],
#  'user766': ['renault', 'maybank', 'nokia', 'hyundai', 'sodexo'],
#  'user767': ['american express', 'staples', 'cosmo', 'visa', 'infosys'],
#  'user768': ['Adobe', 'crh', 'oracle', 'walmart', 'rbc'],
#  'user769': ['amr', 'oracle', 'accenture', 'disney', 'volkswagen'],
#  'user770': ['mahindra', 'target', 'netflix', 'hyundai', 'tcs'],
#  'user771': ['at&t', 'facebook', 'staples', 'disney', 'super dry'],
#  'user772': ['vmware', 'microsoft', 'barclays', 'puma', 'volkswagen'],
#  'user773': ['sap', 'puma', 'fedEx', 'tencent', 'alibaba'],
#  'user774': ['target', 'crh', 'puma', 'capgemini', 'panasonic'],
#  'user775': ['abb', 'accenture', 'walmart', 'nippon', 'ebay'],
#  'user776': ['mahindra', 'amazon', 'siemens', 'comcast', 'ford'],
#  'user777': ['maybank', 'mastercard', 'hp', 'hyundai', 'puma'],
#  'user778': ['sap', 'hp', 'ibm', 'merceds', 'acs'],
#  'user779': ['wistron', 'sony', 'ibm', 'johnson', 'cosmo'],
#  'user780': ['siemens', 'icici', 'acs', 'fedEx', 'apple'],
#  'user781': ['starbucks', 'hitachi', 'sony', 'ebay', 'xiaomi'],
#  'user782': ['starbucks', 'canon', 'lg', 'ebay', 'vadafone'],
#  'user783': ['mahindra', 'siemens', 'hp', 'wipro', 'tesla'],
#  'user784': ['mahindra', 'barclays', 'puma', 'coca-cola', 'tcs'],
#  'user785': ['mahindra', 'wipro', 'johnson', 'paypal', 'super dry'],
#  'user786': ['abb', 'coca-cola', 'volkswagen', 'salesforce', 'maruhan'],
#  'user787': ['vmware', 'oracle', 'wipro', 'onex', 'bmw'],
#  'user788': ['sony', 'canon', 'accenture', 'paypal', 'tencent'],
#  'user789': ['amazon', 'sap', 'accenture', 'merceds', 'fedEx'],
#  'user790': ['wistron', 'nokia', 'netflix', 'qualcomn', 'qualcomm'],
#  'user791': ['philip', 'capgemini', 'nippon', 'onex', 'rbc'],
#  'user792': ['vinci', 'danaher', 'canon', 'oracle', 'johnson'],
#  'user793': ['vmware', 'tesco', 'coca-cola', 'tencent', 'sodexo'],
#  'user794': ['Adobe', 'starbucks', 'qualcomn', 'ibm', 'maruhan'],
#  'user795': ['Adobe', 'siemens', 'staples', 'nestle', 'airtel'],
#  'user796': ['nokia', 'at&t', 'acs', 'johnson', 'apple'],
#  'user797': ['mastercard', 'nvidia', 'puma', 'caterpillar', 'ebay'],
#  'user798': ['mahindra', 'target', 'abb', 'hp', 'airtel'],
#  'user799': ['alibaba', 'cisco', 'fedEx', 'tcs', 'vadafone'],
#  'user800': ['danone', 'sap', 'wipro', 'alibaba', 'samsung'],
#  'user801': ['amazon', 'intel', 'comcast', 'hitachi', 'nokia'],
#  'user802': ['woodland', 'sap', 'aegon', 'puma', 'tencent'],
#  'user803': ['comcast', 'mastercard', 'ford', 'salesforce', 'infosys'],
#  'user804': ['siemens', 'hitachi', 'merceds', 'nippon', 'visa'],
#  'user805': ['mahindra', 'hitachi', 'abb', 'sony', 'tesla'],
#  'user806': ['hitachi', 'cisco', 'crh', 'oracle', 'cosmo'],
#  'user807': ['icici', 'tesco', 'ibm', 'capgemini', 'fluor'],
#  'user808': ['woodland', 'citigroup', 'icbc', 'johnson', 'alibaba'],
#  'user809': ['cisco', 'woodland', 'staples', 'aegon', 'caterpillar'],
#  'user810': ['starbucks', 'danaher', 'tesco', 'philip', 'aegon'],
#  'user811': ['target', 'danaher', 'johnson', 'icbc', 'fluor'],
#  'user812': ['maybank', 'fedEx', 'tesco', 'tesla', 'nippon'],
#  'user813': ['facebook', 'accenture', 'addidas', 'cosmo', 'infosys'],
#  'user814': ['woodland', 'accenture', 'icbc', 'fedEx', 'bmw'],
#  'user815': ['renault', 'amazon', 'cisco', 'icbc', 'tencent'],
#  'user816': ['avnet', 'intel', 'jpmorgan', 'hdfc', 'qualcomm'],
#  'user817': ['amr', 'maybank', 'sap', 'citigroup', 'icbc'],
#  'user818': ['sap', 'capgemini', 'visa', 'xiaomi', 'vadafone'],
#  'user819': ['metlife', 'accenture', 'reliance', 'salesforce', 'airtel'],
#  'user820': ['icici', 'oracle', 'citigroup', 'coca-cola', 'visa'],
#  'user821': ['icici', 'tesco', 'nvidia', 'capgemini', 'lg'],
#  'user822': ['mastercard', 'nokia', 'sap', 'icbc', 'ebay'],
#  'user823': ['metlife', 'accenture', 'pubg', 'salesforce', 'airtel'],
#  'user824': ['amazon', 'danaher', 'sap', 'tesla', 'xiaomi'],
#  'user825': ['reliance', 'tcs', 'onex', 'apple', 'alibaba'],
#  'user826': ['Adobe', 'mastercard', 'tesco', 'philip', 'disney'],
#  'user827': ['avnet', 'cisco', 'hyundai', 'disney', 'visa'],
#  'user828': ['siemens', 'accenture', 'reliance', 'tencent', 'airtel'],
#  'user829': ['metlife', 'crh', 'hyundai', 'icbc', 'tencent'],
#  'user830': ['aegon', 'nvidia', 'lg', 'paypal', 'samsung'],
#  'user831': ['vmware', 'Adobe', 'johnson', 'tencent', 'infosys'],
#  'user832': ['intel', 'citigroup', 'johnson', 'ebay', 'tencent'],
#  'user833': ['woodland', 'netflix', 'accenture', 'ibm', 'apple'],
#  'user834': ['at&t', 'tesco', 'puma', 'visa', 'maruhan'],
#  'user835': ['intel', 'tesco', 'oracle', 'toyota', 'apple'],
#  'user836': ['renault', 'avnet', 'amazon', 'toyota', 'rbc'],
#  'user837': ['avnet', 'amazon', 'abb', 'tesla', 'maruhan'],
#  'user838': ['amazon', 'wistron', 'american express', 'lg', 'super dry'],
#  'user839': ['avnet', 'sony', 'facebook', 'citigroup', 'tesla'],
#  'user840': ['renault', 'siemens', 'at&t', 'cosmo', 'nestle'],
#  'user841': ['barclays', 'cosmo', 'coca-cola', 'tcs', 'rbc'],
#  'user842': ['renault', 'danone', 'mahindra', 'facebook', 'tencent'],
#  'user843': ['facebook', 'addidas', 'johnson', 'merceds', 'alibaba'],
#  'user844': ['maybank', 'target', 'hyundai', 'pubg', 'staples'],
#  'user845': ['target', 'sony', 'nokia', 'citigroup', 'super dry'],
#  'user846': ['ford', 'facebook', 'sodexo', 'panasonic', 'xiaomi'],
#  'user847': ['hitachi', 'sony', 'hyundai', 'wipro', 'volkswagen'],
#  'user848': ['airtel', 'nippon', 'sodexo', 'super dry', 'infosys'],
#  'user849': ['vmware', 'siemens', 'aegon', 'onex', 'airtel'],
#  'user850': ['hitachi', 'canon', 'cosmo', 'reliance', 'ebay'],
#  'user851': ['metlife', 'philip', 'lg', 'nippon', 'sodexo'],
#  'user852': ['acs', 'jpmorgan', 'johnson', 'loreal', 'super dry'],
#  'user853': ['amr', 'sony', 'facebook', 'tesco', 'super dry'],
#  'user854': ['citigroup', 'wipro', "mcdoland's", 'capgemini', 'tcs'],
#  'user855': ['mahindra', 'metlife', 'danaher', 'staples', 'merceds'],
#  'user856': ['vmware', 'abb', 'tencent', 'volkswagen', 'nestle'],
#  'user857': ['danone', 'cisco', 'hp', 'ibm', 'coca-cola'],
#  'user858': ['Adobe', 'hp', 'nike', 'fedEx', 'onex'],
#  'user859': ['facebook', 'puma', 'cosmo', 'nippon', 'alibaba'],
#  'user860': ['avnet', 'sony', 'apple', 'airtel', 'infosys'],
#  'user861': ['renault', 'metlife', 'sony', 'walmart', 'airtel'],
#  'user862': ['ford', 'at&t', 'jpmorgan', 'fluor', 'salesforce'],
#  'user863': ['avnet', 'mahindra', "mcdoland's", 'nestle', 'alibaba'],
#  'user864': ['amr', 'pepsi', 'jpmorgan', 'coca-cola', 'nestle'],
#  'user865': ['wistron', 'sony', 'icbc', 'capgemini', 'reliance'],
#  'user866': ['starbucks', 'philip', 'qualcomn', 'tencent', 'rbc'],
#  'user867': ['metlife', 'ford', 'netflix', 'american express', 'philip'],
#  'user868': ['wipro', 'tcs', 'rbc', 'sodexo', 'samsung'],
#  'user869': ['target', 'staples', 'nvidia', 'cosmo', 'rbc'],
#  'user870': ['renault', 'mahindra', 'comcast', 'danaher', 'american express'],
#  'user871': ['rbc', 'panasonic', 'salesforce', 'alibaba', 'nippon'],
#  'user872': ['mahindra', 'starbucks', 'barclays', 'walmart', 'jpmorgan'],
#  'user873': ['vinci', 'woodland', 'facebook', 'fluor', 'caterpillar'],
#  'user874': ['cisco', 'accenture', 'nike', 'coca-cola', 'visa'],
#  'user875': ['danaher', 'at&t', 'tesco', 'puma', 'toyota'],
#  'user876': ['Adobe', 'starbucks', 'nippon', 'volkswagen', 'visa'],
#  'user877': ['amr', 'amazon', 'abb', 'walmart', 'nippon'],
#  'user878': ['danone', 'siemens', 'netflix', 'lg', 'fedEx'],
#  'user879': ['abb', 'facebook', 'nvidia', 'fedEx', 'qualcomm'],
#  'user880': ['vmware', 'icici', 'oracle', 'icbc', 'xiaomi'],
#  'user881': ['vmware', 'crh', 'hyundai', 'nike', 'nestle'],
#  'user882': ['avnet', 'at&t', 'philip', 'hyundai', 'rbc'],
#  'user883': ['maybank', 'mahindra', 'metlife', 'ibm', 'alphabet'],
#  'user884': ['vmware', 'hp', 'lg', 'volkswagen', 'bmw'],
#  'user885': ['amazon', 'nvidia', 'lg', 'ebay', 'airtel'],
#  'user886': ['disney', 'tcs', 'volkswagen', 'hdfc', 'maruhan'],
#  'user887': ['nokia', 'ibm', 'visa', 'toyota', 'apple'],
#  'user888': ['sap', 'qualcomn', 'hyundai', 'rbc', 'vadafone'],
#  'user889': ['wistron', 'woodland', 'nokia', 'facebook', 'tesla'],
#  'user890': ['woodland', 'staples', 'loreal', 'johnson', 'vadafone'],
#  'user891': ['renault', 'abb', 'qualcomn', 'jpmorgan', 'onex'],
#  'user892': ['Adobe', 'microsoft', 'mahindra', 'pubg', 'reliance'],
#  'user893': ['intel', 'target', 'comcast', 'acs', 'fluor'],
#  'user894': ['vmware', 'amr', 'cisco', 'abb', 'hdfc'],
#  'user895': ['nike', 'volkswagen', 'salesforce', 'xiaomi', 'super dry'],
#  'user896': ['renault', 'maybank', 'alphabet', 'caterpillar', 'tencent'],
#  'user897': ['philip', 'accenture', 'acs', 'reliance', 'vadafone'],
#  'user898': ['ford', 'nokia', 'loreal', 'alphabet', 'infosys'],
#  'user899': ['Adobe', 'intel', 'at&t', "mcdoland's", 'samsung'],
#  'user900': ['amr', 'netflix', 'cosmo', 'apple', 'airtel'],
#  'user901': ['starbucks', 'danaher', 'johnson', 'sodexo', 'airtel'],
#  'user902': ['fedEx', 'hp', 'loreal', 'capgemini', 'tcs'],
#  'user903': ['renault', 'philip', 'visa', 'salesforce', 'airtel'],
#  'user904': ['maybank', 'hyundai', 'wipro', 'cosmo', 'vadafone'],
#  'user905': ['Adobe', 'nike', 'nestle', 'xiaomi', 'alibaba'],
#  'user906': ['danone', 'amazon', 'loreal', 'tesla', 'qualcomm'],
#  'user907': ['amazon', 'siemens', 'ford', 'tesla', 'reliance'],
#  'user908': ['danone', 'metlife', 'sap', 'merceds', 'nippon'],
#  'user909': ['avnet', 'amazon', 'nokia', 'american express', 'salesforce'],
#  'user910': ['danone', 'hitachi', 'citigroup', 'hyundai', 'salesforce'],
#  'user911': ['maybank', 'facebook', 'panasonic', 'nestle', 'paypal'],
#  'user912': ['Adobe', 'wipro', 'nvidia', 'toyota', 'xiaomi'],
#  'user913': ['barclays', 'philip', 'aegon', 'loreal', 'coca-cola'],
#  'user914': ['target', 'ford', 'hp', 'paypal', 'airtel'],
#  'user915': ['abb', 'hitachi', 'qualcomn', 'puma', 'alibaba'],
#  'user916': ['vmware', 'mastercard', 'jpmorgan', 'merceds', 'rbc'],
#  'user917': ['maybank', 'metlife', 'accenture', 'qualcomm', 'infosys'],
#  'user918': ['amazon', 'sony', 'nike', 'coca-cola', 'apple'],
#  'user919': ['icici', 'loreal', 'puma', 'volkswagen', 'airtel'],
#  'user920': ['intel', 'metlife', 'staples', 'hdfc', 'rbc'],
#  'user921': ['amazon', 'wipro', 'nike', 'rbc', 'bmw'],
#  'user922': ['canon', 'tesco', 'pubg', 'reliance', 'caterpillar'],
#  'user923': ['starbucks', 'hitachi', 'woodland', 'crh', 'onex'],
#  'user924': ['ford', 'cosmo', 'reliance', 'paypal', 'super dry'],
#  'user925': ['puma', 'reliance', 'tcs', 'volkswagen', 'paypal'],
#  'user926': ['wipro', 'capgemini', 'paypal', 'bmw', 'samsung'],
#  'user927': ['pubg', 'johnson', 'cosmo', 'paypal', 'onex'],
#  'user928': ['target', 'hitachi', 'pepsi', 'tcs', 'visa'],
#  'user929': ['avnet', 'target', 'american express', 'disney', 'onex'],
#  'user930': ['tesco', 'icbc', 'nike', 'nestle', 'rbc'],
#  'user931': ['Adobe', 'vinci', 'hp', 'ibm', 'bmw'],
#  'user932': ['cisco', 'canon', 'qualcomn', 'icbc', 'tencent'],
#  'user933': ['amr', 'siemens', 'nike', 'nippon', 'rbc'],
#  'user934': ['microsoft', 'comcast', 'ford', 'facebook', 'xiaomi'],
#  'user935': ['amr', 'vinci', 'comcast', 'accenture', 'alphabet'],
#  'user936': ['ford', 'hyundai', 'alphabet', 'ebay', 'rbc'],
#  'user937': ['amr', 'amazon', 'metlife', 'disney', 'qualcomm'],
#  'user938': ['icici', 'nokia', 'hp', 'acs', 'puma'],
#  'user939': ['renault', 'johnson', 'toyota', 'salesforce', 'bmw'],
#  'user940': ['mastercard', 'woodland', 'pepsi', 'hyundai', 'onex'],
#  'user941': ['pepsi', 'cosmo', 'reliance', 'qualcomm', 'airtel'],
#  'user942': ['danone', 'danaher', 'citigroup', 'onex', 'rbc'],
#  'user943': ['danaher', 'facebook', 'hp', 'loreal', 'panasonic'],
#  'user944': ['renault', 'siemens', 'qualcomn', "mcdoland's", 'vadafone'],
#  'user945': ['starbucks', 'sony', 'tesco', 'alphabet', 'visa'],
#  'user946': ['woodland', 'american express', 'loreal', 'capgemini', 'apple'],
#  'user947': ['metlife', 'hdfc', 'nippon', 'nestle', 'qualcomm'],
#  'user948': ['microsoft', 'merceds', 'cosmo', 'fedEx', 'samsung'],
#  'user949': ['danone', 'barclays', 'woodland', 'nvidia', 'nippon'],
#  'user950': ['Adobe', 'intel', 'johnson', 'capgemini', 'vadafone'],
#  'user951': ['puma', 'lg', 'qualcomm', 'sodexo', 'maruhan'],
#  'user952': ['target', 'abb', 'crh', 'american express', 'acs'],
#  'user953': ['hitachi', 'cisco', 'abb', 'woodland', 'vadafone'],
#  'user954': ['maybank', 'mahindra', 'sony', 'qualcomn', 'johnson'],
#  'user955': ['amr', 'staples', 'addidas', 'panasonic', 'visa'],
#  'user956': ['danaher', 'woodland', 'netflix', 'paypal', 'volkswagen'],
#  'user957': ['maybank', 'intel', 'at&t', 'acs', 'tcs'],
#  'user958': ['philip', 'hyundai', 'loreal', 'capgemini', 'panasonic'],
#  'user959': ['abb', 'sap', 'puma', 'salesforce', 'airtel'],
#  'user960': ['danaher', 'nokia', 'philip', 'coca-cola', 'qualcomm'],
#  'user961': ['hitachi', 'philip', 'reliance', 'fedEx', 'onex'],
#  'user962': ['intel', 'merceds', 'cosmo', 'alphabet', 'visa'],
#  'user963': ['vmware', 'mahindra', 'caterpillar', 'nippon', 'volkswagen'],
#  'user964': ['avnet', 'jpmorgan', 'johnson', 'coca-cola', 'apple'],
#  'user965': ['woodland', 'canon', 'nokia', 'hyundai', 'infosys'],
#  'user966': ['accenture', 'staples', 'capgemini', 'fedEx', 'samsung'],
#  'user967': ['vmware', 'starbucks', 'mastercard', 'tcs', 'salesforce'],
#  'user968': ['hp', 'hyundai', 'ibm', 'alphabet', 'nestle'],
#  'user969': ['facebook', 'hp', 'staples', 'icbc', 'qualcomm'],
#  'user970': ['Adobe', 'intel', 'johnson', 'nippon', 'samsung'],
#  'user971': ['amr', 'Adobe', 'amazon', 'addidas', 'volkswagen'],
#  'user972': ['johnson', 'nike', 'fedEx', 'panasonic', 'toyota'],
#  'user973': ['vmware', 'danaher', 'hdfc', 'airtel', 'infosys'],
#  'user974': ['ford', 'woodland', 'loreal', 'super dry', 'infosys'],
#  'user975': ['acs', 'merceds', 'lg', 'fedEx', 'airtel'],
#  'user976': ['sony', 'netflix', 'nokia', 'canon', 'ibm'],
#  'user977': ['amazon', 'philip', 'walmart', 'staples', 'onex'],
#  'user978': ['facebook', 'sap', 'lg', 'ebay', 'hdfc'],
#  'user979': ['Adobe', 'hitachi', "mcdoland's", 'capgemini', 'xiaomi'],
#  'user980': ['siemens', 'hitachi', 'danaher', 'sap', 'rbc'],
#  'user981': ['nokia', 'staples', 'puma', 'onex', 'nestle'],
#  'user982': ['mahindra', 'abb', 'walmart', 'panasonic', 'xiaomi'],
#  'user983': ['intel', 'woodland', 'canon', 'addidas', 'volkswagen'],
#  'user984': ['renault', 'vmware', 'amr', 'jpmorgan', 'coca-cola'],
#  'user985': ['Adobe', 'nokia', 'at&t', 'tesco', 'cosmo'],
#  'user986': ['mastercard', "mcdoland's", 'merceds', 'ebay', 'bmw'],
#  'user987': ['oracle', 'accenture', 'visa', "mcdoland's", 'tencent'],
#  'user988': ['vmware', 'danone', 'at&t', 'oracle', 'johnson'],
#  'user989': ['amr', 'walmart', 'hyundai', 'accenture', 'merceds'],
#  'user990': ['Adobe', 'alibaba', 'fluor', 'tencent', 'airtel'],
#  'user991': ['avnet', 'danaher', 'facebook', 'loreal', 'hdfc'],
#  'user992': ['mahindra', 'caterpillar', 'coca-cola', 'volkswagen', 'bmw'],
#  'user993': ['ford', 'canon', 'capgemini', 'fedEx', 'ebay'],
#  'user994': ['Adobe', 'metlife', 'ibm', 'alibaba', 'bmw'],
#  'user995': ['avnet', 'walmart', 'staples', 'fluor', 'toyota'],
#  'user996': ['mastercard', 'hp', 'tencent', 'airtel', 'infosys'],
#  'user997': ['ford', 'at&t', 'paypal', 'hdfc', 'toyota'],
#  'user998': ['vmware', 'comcast', 'loreal', 'johnson', 'alibaba'],
#  'user999': ['amr', 'at&t', 'hyundai', 'johnson', 'alphabet'],
#  'user1000': ['hp', 'addidas', 'tesla', 'capgemini', 'apple']}

# %%
for key,value in recommedations.items():
    data={
        key:value
    }
    db.Recommendation.insert_one(data)

# %% [markdown]
# # Recommendations of competitors for a given brand

# %%
def getbrand_competitor_mapping():
    brands_competitor_mapping={}
    cursor=profiles.find()  
    for doc in cursor:
        if doc['brand'] not in brands_competitor_mapping:
            if(doc['competitors'] != None):
                brands_competitor_mapping[doc['brand']]=doc['competitors']
            else:
                brands_competitor_mapping[doc['brand']]=[]
        else:
            if doc['competitors']!=None:
                brands_competitor_mapping[doc['brand']]+=doc['competitors']
    return brands_competitor_mapping

# %%
brands_competitor_mapping=getbrand_competitor_mapping()

# %%
def mostfrequentcompetitor(frequency):
    dict1=sorted(frequency.items(),key=lambda x:x[1],reverse=True)
    for key,value in dict1:
        return key

# %%
def recommend_competitor(brand):
    list_of_competitors=brands_competitor_mapping[brand]
    frequency=collections.Counter(list_of_competitors)
    return mostfrequentcompetitor(frequency)

# %%
recommend_competitor('apple')
# Out:
# 'aegon'
