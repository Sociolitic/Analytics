# %%
import numpy as np
import pandas as pd

# %%
import pymongo

# %%
client = pymongo.MongoClient("mongodb+srv://KokilaReddy:KokilaReddy@cluster0.5nrpf.mongodb.net/Social_media_data?retryWrites=true&w=majority")

# %%
db=client["Social_media_data"]

# %%
tumblr=db["tumblr"]

# %%
tumblr
# Out:
# Collection(Database(MongoClient(host=['cluster0-shard-00-01.5nrpf.mongodb.net:27017', 'cluster0-shard-00-00.5nrpf.mongodb.net:27017', 'cluster0-shard-00-02.5nrpf.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-2ieewk-shard-0', ssl=True), 'Social_media_data'), 'tumblr')

# %%
client.list_database_names()
# Out:
# ['Social_media_data', 'admin', 'local']

# %%
for i in tumblr.find():
    print(i)
    print(i)
# Out:
# {'_id': ObjectId('60d07c8930d224b889a1bfdf'), 'title': "Apple TV+ Shares New Teaser for 'Ted Lasso' Season 2 Ahead of July 23 Premiere", 'body': 'https://ift.tt/2Sdh2zM', 'id': '654600449812463616', 'url': 'https://macrumorsnews.tumblr.com/post/654600449812463616/apple-tv-shares-new-teaser-for-ted-lasso-season', 'blog_name': 'macrumorsnews', 'summary': "Apple TV+ Shares New Teaser for 'Ted Lasso' Season 2 Ahead of July 23 Premiere", 'created_time': '2021-06-21 17:10:36', 'tags': ['News', 'apple', 'technology'], 'tag': 'Apple'}
# ...

# %%
myquery={"tag":{"$regex":"Amazon"}}

# %%
df = pd.DataFrame(columns=['_id','title','body','id','url','blog_name','summary','created_time','tags','tag'])

# %%
result=tumblr.find(myquery)

# %%
count=0

# %%
for i in result:
    count+=1
    df=df.append(i,ignore_index=True)

# %%
print(count)
# Out:
# 20

# %%
df
# Out:
#                          _id  \
# 0   611bea46fbbbc0518397cf03
# 1   611bea47fbbbc0518397cf05
# 2   611bea47fbbbc0518397cf06
# 3   611bea48fbbbc0518397cf07
# 4   611bea49fbbbc0518397cf08
# 5   611bea49fbbbc0518397cf09
# 6   611bea4cfbbbc0518397cf0a
# 7   611bea4dfbbbc0518397cf0b
# 8   611bea4efbbbc0518397cf0c
# 9   611bea4efbbbc0518397cf0d
# 10  611bea50fbbbc0518397cf0e
# 11  611bea51fbbbc0518397cf0f
# 12  611bea52fbbbc0518397cf10
# 13  611bea53fbbbc0518397cf11
# 14  611bea53fbbbc0518397cf12
# 15  611bea54fbbbc0518397cf13
# 16  611bea55fbbbc0518397cf14
# 17  611bea56fbbbc0518397cf15
# 18  611bea57fbbbc0518397cf16
# 19  611bea58fbbbc0518397cf17
#
#                                                 title  \
# 0
# 1
# 2                                               image
# 3   💥 Abalorio Ninaqueen de Plata de Ley 925 por s...
# 4   Best practice for removing all inventory and s...
# 5        💥 #Librojuego Crímenes ilustrados por 18,90€
# ...

# %%
for i in df.index:
    print(df.loc[i,'title'])
    print()
    print(df.loc[i,'summary'])
# Out:
# Amazon EC2 推出 m6i 的機器
#
#
# Andrew McDowell
# image
#
# #Be careful what you wish for... DARKENED SOUL: WITCH'S ABYSS is now ON SALE!!!...
# 💥 Abalorio Ninaqueen de Plata de Ley 925 por sólo 12,99€ con el #código: ROIHYGIV
#
# 💥 Abalorio Ninaqueen de Plata de Ley 925 por sólo 12,99€ con el #código: ROIHYGIV
# Best practice for removing all inventory and sending in more? - FBA tips
#
# Best practice for removing all inventory and sending in more? - FBA tips
# 💥 #Librojuego Crímenes ilustrados por 18,90€
#
# 💥 #Librojuego Crímenes ilustrados por 18,90€
# image
#
# Reposted from @linaperozo Ronda Mortal (La trilogía):
# ⭐⭐⭐⭐⭐
# "Me encanto esta trilogía de inicio a fin... Fui de las que compre...
# Product Photography, Part 2: Selecting Tripods
#
# Product Photography, Part 2: Selecting Tripods
# Most Efficient Way to Pay Suppliers? - FBA tips
#
# Most Efficient Way to Pay Suppliers? - FBA tips
# How to enter the Amazon FBA ecosystem? - FBA tips
#
# ...

# %%
df=df.drop("_id",axis=1)

# %%
df.columns
# Out:
# Index(['title', 'body', 'id', 'url', 'blog_name', 'summary', 'created_time',
#        'tags', 'tag', 'createdAt', 'sentiment', 'updatedAt'],
#       dtype='object')

# %%
df.dtypes
# Out:
# title                   object
# body                    object
# id                      object
# url                     object
# blog_name               object
# summary                 object
# created_time            object
# tags                    object
# tag                     object
# createdAt       datetime64[ns]
# sentiment               object
# updatedAt       datetime64[ns]
# dtype: object

# %%
df['title']=df['title'].astype('string')
df['body']=df['body'].astype('string')
df['id']=df['id'].astype('string')
df['url']=df['url'].astype('string')
df['blog_name']=df['blog_name'].astype('string')
df['summary']=df['summary'].astype('string')
df['tag']=df['tag'].astype('string')

# %%
type(df['created_time'])
# Out:
# pandas.core.series.Series

# %%
df['created_time']=df['created_time'].astype('string')

# %%
df.dtypes
# Out:
# title                   string
# body                    string
# id                      string
# url                     string
# blog_name               string
# summary                 string
# created_time            string
# tags                    object
# tag                     string
# createdAt       datetime64[ns]
# sentiment               object
# updatedAt       datetime64[ns]
# dtype: object

# %%
df
# Out:
#                                                 title  \
# 0
# 1
# 2                                               image
# 3   💥 Abalorio Ninaqueen de Plata de Ley 925 por s...
# 4   Best practice for removing all inventory and s...
# 5        💥 #Librojuego Crímenes ilustrados por 18,90€
# 6                                               image
# 7      Product Photography, Part 2: Selecting Tripods
# 8     Most Efficient Way to Pay Suppliers? - FBA tips
# 9   How to enter the Amazon FBA ecosystem? - FBA tips
# 10  💥 #Juegodemesa Dungeons & Dragons: Cartas de o...
# 11
# 12  💥 Teclado mecánico Razer Blackwidow Elite por ...
# 13
# 14  Amazon will monitor customer service workers' ...
# 15  💥 Limpiador facial + accesorios y carga inalám...
# 16  Snake Eyes: G.I. JOE Origins - Movies on Googl...
# 17                                              image
# 18                                              image
# 19                                              image
#
# ...

# %%
import time

# %%
import datetime

# %%
for i in df.index:
    df.loc[i,'created_time']=datetime.datetime.fromtimestamp(df.loc[i,'created_time'].astype(int))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-3cb6398adbb3> in <module>
#       1 for i in df.index:
# ----> 2     df.loc[i,'created_time']=datetime.datetime.fromtimestamp(df.loc[i,'created_time'].astype(int))
#
# AttributeError: 'str' object has no attribute 'astype'

# %%
df
# Out:
#                                                 title  \
# 0   💥 Lámpara de luz diurna Ambother con brillo aj...
# 1   💥 Bandolera Levi's Mini Crossbody Solid por só...
# 2         Don't Buy Supplements From Amazon (Or Ebay)
# 3                                               image
# 4                                               image
# 5                                               image
# 6                                               image
# 7
# 8                                               image
# 9
# 10
# 11                                              image
# 12                                              image
# 13                                              image
# 14                                              image
# 15
# 16                                              image
# 17
# 18
# 19                                              image
# 20                                              image
# 21  💥 1kg de gominolas Fini Mix por sólo 4,80€ ¡¡3...
#
# ...

# %%
df.loc[7,'tags']
# Out:
# ['amazon',
#  'audiobooks',
#  'books',
#  'fantasy',
#  'goodreads',
#  'overdrive',
#  'reading',
#  'romance']

# %%
df.dtypes
# Out:
# title           string
# body            string
# id              string
# url             string
# blog_name       string
# summary         string
# created_time    object
# tags            object
# tag             string
# dtype: object
